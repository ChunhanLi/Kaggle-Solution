# %%
import numpy as np
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt 
from sklearn import preprocessing
from sklearn.preprocessing import LabelEncoder
import catboost as cb
import lightgbm as lgb
from sklearn.ensemble import RandomForestClassifier
from sklearn.model_selection import GridSearchCV, ShuffleSplit,StratifiedKFold,TimeSeriesSplit,KFold,GroupKFold,train_test_split,GroupShuffleSplit,StratifiedShuffleSplit
from sklearn.metrics import roc_auc_score,mean_squared_error,mean_absolute_error,log_loss,confusion_matrix
import sqlite3
import xgboost as xgb
import datetime
from sklearn.linear_model import LogisticRegression
from scipy.stats import pearsonr
import gc
from sklearn.model_selection import TimeSeriesSplit
#from bayes_opt import BayesianOptimization
import re
from string import punctuation
from scipy.spatial import Voronoi
from scipy.spatial import ConvexHull
from scipy.spatial import Delaunay
from tqdm.notebook import tqdm
from numba import jit
from collections import Counter
import json
import joblib
import multiprocessing
import time
from scipy.sparse import csr_matrix
import gc

# %%
def reduce_mem_usage(df, verbose=True):
    numerics = ['int32', 'int64', 'float64']
    start_mem = df.memory_usage().sum() / 1024**2    
    for col in df.columns:
        col_type = df[col].dtypes
        if col_type in numerics:
            c_min = df[col].min()
            c_max = df[col].max()
            if str(col_type)[:3] == 'int':
                if c_min > np.iinfo(np.int16).min and c_max < np.iinfo(np.int16).max:
                    df[col] = df[col].astype(np.int16)
                elif c_min > np.iinfo(np.int32).min and c_max < np.iinfo(np.int32).max:
                    df[col] = df[col].astype(np.int32)
                elif c_min > np.iinfo(np.int64).min and c_max < np.iinfo(np.int64).max:
                    df[col] = df[col].astype(np.int64)  
            else:
                if c_min > np.finfo(np.float32).min and c_max < np.finfo(np.float32).max:
                    df[col] = df[col].astype(np.float32)
                else:
                    df[col] = df[col].astype(np.float64)    
    end_mem = df.memory_usage().sum() / 1024**2
    if verbose: print('Mem. usage decreased to {:5.2f} Mb ({:.1f}% reduction)'.format(end_mem, 100 * (start_mem - end_mem) / start_mem))
    return df

# %%
sample_submission = pd.read_csv('../data/sample_submission.csv')
sell_prices = pd.read_csv('../data/sell_prices.csv')
sales_train = pd.read_csv('../data/sales_train_validation.csv')
calendar = pd.read_csv('../data/calendar.csv')

# %%
sales_train_long_format = pd.melt(sales_train,id_vars=['id','item_id','dept_id','cat_id','store_id','state_id'],var_name = 'day_num',value_name='sale')

# %%
def transform_day_to_num(str1):
    return int(str1[2:])
sales_train_long_format['day_num'] = sales_train_long_format['day_num'].map(transform_day_to_num)
calendar['date'] = pd.to_datetime(calendar['date'])
calendar['day_num'] = calendar['d'].map(transform_day_to_num)
map_day_date = calendar[['date','day_num']].set_index('day_num')['date']
sales_train_long_format['date'] = sales_train_long_format['day_num'].map(map_day_date)
list1 = ['wm_yr_wk','event_name_1', 'event_type_1', 'event_name_2', 'event_type_2','snap_CA', 'snap_TX', 'snap_WI','day_num']
sales_train_long_format = sales_train_long_format.merge(calendar[list1],on='day_num',how='left')

# %%
sales_train_long_format = sales_train_long_format.merge(sell_prices,how='left',on = ['store_id','item_id','wm_yr_wk'])
#sales_train_long_format = reduce_mem_usage(sales_train_long_format)

# %% [markdown]
# ### metric
# #### fast metrirc

# %%
data_for_weight = sales_train_long_format[sales_train_long_format.day_num.between(1886,1913)].copy()
data_for_weight['sale_used'] = data_for_weight['sale'] * data_for_weight['sell_price']
sales = pd.read_csv('../data/sales_train_validation.csv')

# %%
dummies_list = [sales.state_id, sales.store_id, 
                sales.cat_id, sales.dept_id, 
                sales.state_id + sales.cat_id, sales.state_id + sales.dept_id,
                sales.store_id + sales.cat_id, sales.store_id + sales.dept_id, 
                sales.item_id, sales.state_id + sales.item_id, sales.id]


## First element Level_0 aggregation 'all_sales':
dummies_df_list =[pd.DataFrame(np.ones(sales.shape[0]).astype(np.int8), 
                               index=sales.index, columns=['all']).T]

# List of dummy dataframes:
for i, cats in enumerate(dummies_list):
    dummies_df_list +=[pd.get_dummies(cats, drop_first=False).astype(np.int8).T]
    
# Concat dummy dataframes in one go:
## Level is constructed for free.
roll_mat_df = pd.concat(dummies_df_list, keys=list(range(12)), 
                        names=['level','id']).astype(np.int8, copy=False)

# Save values as sparse matrix & save index for future reference:
roll_index = roll_mat_df.index
roll_mat_csr = csr_matrix(roll_mat_df.values)
roll_mat_csr.shape
# Out:
# (42840, 30490)

# %%
# Fucntion to calculate S weights:
def get_s(drop_days=0):
    
    """
    drop_days: int, equals 0 by default, so S is calculated on all data.
               If equals 28, last 28 days want be used in calculating S.
    """
    
    # Rollup sales:
    d_name = ['d_' + str(i+1) for i in range(1913-drop_days)]
    sales_train_val = roll_mat_csr * sales[d_name].values

    # Find sales start index:
    start_no = np.argmax(sales_train_val>0, axis=1)
    
    # Replace days less than min day number with np.nan:
    # Next code line is super slow:
    flag = np.dot(np.diag(1/(start_no+1)) , np.tile(np.arange(1,1914-drop_days),(roll_mat_csr.shape[0],1)))<1
    sales_train_val = np.where(flag, np.nan, sales_train_val)

    # Denominator of RMSSE / RMSSE
    weight1 = np.nansum(np.diff(sales_train_val,axis=1)**2,axis=1)/(1913-start_no - 1)
    
    return weight1

# %%
S = get_s(drop_days=0)
S.shape
# Out:
# (42840,)

# %%
def get_w(sale_usd):
    """
    """
    # Calculate the total sales in USD for each item id:
    total_sales_usd = sale_usd.groupby(['id'],sort=False)['sale_used'].apply(np.sum).values
    
    # Roll up total sales by ids to higher levels:
    weight2 = roll_mat_csr * total_sales_usd
    
    return weight2/np.sum(weight2)

# %%
W = get_w(data_for_weight[['id','sale_used']])
W.shape
# Out:
# (42840,)

# %%
SW = W/np.sqrt(S)

# %%
# Function to do quick rollups:
def rollup(v):
    '''
    v - np.array of size (30490 rows, n day columns)
    v_rolledup - array of size (n, 42840)
    '''
    return (v.T*roll_mat_csr.T).T


# Function to calculate WRMSSE:
def wrmsse(preds, y_true, score_only=False, s = S, w = W, sw=SW):
    '''
    preds - Predictions: pd.DataFrame of size (30490 rows, N day columns)
    y_true - True values: pd.DataFrame of size (30490 rows, N day columns)
    sequence_length - np.array of size (42840,)
    sales_weight - sales weights based on last 28 days: np.array (42840,)
    '''
    
    if score_only:
        return np.sum(
                np.sqrt(
                    np.mean(
                        np.square(rollup(preds.values-y_true.values))
                            ,axis=1)) * sw)
    else: 
        score_matrix = (np.square(rollup(preds.values-y_true.values)) * np.square(w)[:, None]) / s[:, None]
        score = np.sum(np.sqrt(np.mean(score_matrix,axis=1)))
        return score, score_matrix

# %%
class WRMSSE_Evalator_super_version():
    def __init__(self,sw,roll_mat_csr):
        self.sw = sw
        self.roll_mat_csr = roll_mat_csr
    def rollup(self,v):
        '''
        v - np.array of size (30490 rows, n day columns) start with h.... not food
        v_rolledup - array of size (n, 42840)
        '''
        return (v.T*roll_mat_csr.T).T
    def feval(self,y_true,y_pred):
        """
        y_true,y_pred: np.ndarray
        """
        return 'WRMSSE',np.sum(
                np.sqrt(
                    np.mean(
                        np.square(self.rollup(y_pred.reshape(30490,-1,order = 'F')-y_true.reshape(30490,-1,order = 'F')))
                            ,axis=1)) * self.sw),False

# %%
evaluator_super = WRMSSE_Evalator_super_version(sw = SW,roll_mat_csr=roll_mat_csr)

# %% [markdown]
# #### my metric

# %%
class WRMSSE_Evaluator():
    def __init__(self,std_df:pd.DataFrame):
        """
        std_sd:sale_train 格式 
        """
        self.std_df = std_df.copy()
        self.std_df['all_id'] = 0
        self.id_cols = ['id', 'item_id', 'dept_id', 'cat_id', 'store_id', 'state_id','all_id']
        
#         self.train_df = train_df.copy()
#         self.valid_df = valid_df.copy()
#         self.train_df['all_id'] = 0
#         self.valid_df['all_id'] = 0
#         self.train_df = self.train_df[self.id_cols]
#         self.valid_df = self.valid_df[self.id_cols]
        self.group_ids = [
            'all_id',
            'state_id',
            'store_id',
            'cat_id',
            'dept_id',
            ['state_id', 'cat_id'],
            ['state_id', 'dept_id'],
            ['store_id', 'cat_id'],
            ['store_id', 'dept_id'],
            'item_id',
            ['item_id', 'state_id'],
            ['item_id', 'store_id']
        ]

    def rmsse(self, pred: pd.DataFrame, lv: int):
        
        #start = time.time()
        score = (np.square(pred)).mean(axis=1)
        #end = time.time()
        scale_y = getattr(self, f'lv{lv}_scale')
        #print('RMSSE内部',end-start)
        return np.sqrt(score / scale_y)

    def feval(self, y_true,y_pred):

        #start = time.time()
        diff = ((np.array(y_true) - np.array(y_pred))).reshape((-1,30490)).T
        col_eval = [f'c_{_}' for _ in range(diff.shape[1])]
        valid_diff = pd.DataFrame(diff, columns=col_eval)
        valid_diff = pd.concat([self.std_df[self.id_cols], valid_diff], axis=1, sort=False)
        #end = time.time()
        #print(end-start)
        
        all_scores = 0
        self.score_list = []
        for i, group_id in enumerate(self.group_ids):
            #start = time.time()
            lv_scores = self.rmsse(valid_diff.groupby(group_id,sort=False)[col_eval].sum(), i + 1)
            #end = time.time()
            #print(f'gorup_{i}','rmsse',end-start)
            
            #start = time.time()
            weight = getattr(self, f'lv{i + 1}_weight')
            lv_scores = weight*lv_scores
            setattr(self,f'lv{i+1}_loss',lv_scores/12)
            all_scores+=lv_scores.sum()/12
            self.score_list.append(lv_scores.sum())
            #end = time.time()
            #print(f'gorup_{i}',end-start)
            
        return 'WRMSSE', all_scores, False

    def get_weight(self,weight_df1:pd.DataFrame):
        """
        输入df需要筛选过加入weight的天数 long形态
        """
        weight_df = weight_df1.copy()
        weight_df['all_id'] = 0
        weight_df['sale'] = weight_df['sale'].fillna(0)
        weight_df['sell_price'] = weight_df['sell_price'].fillna(0)
        weight_df['total_price'] = weight_df['sale'] * weight_df['sell_price']
        for i, group_id in enumerate(tqdm(self.group_ids)):
            lv_weight = weight_df.groupby(group_id,sort=False)['total_price'].sum()
            setattr(self, f'lv{i + 1}_weight', lv_weight / lv_weight.sum())
    def get_scale(self,scale_df1:pd.DataFrame):
        """
        输入sales_train
        """
        scale_df = scale_df1.copy()
        scale_df['all_id'] = 0
        #scale_df['sale'] = scale_df['sale'].fillna(0)
        col = scale_df.columns[scale_df.columns.str.startswith('d_')].tolist()
        for i, group_id in enumerate(tqdm(self.group_ids)):
            temp_scale = scale_df.groupby(group_id,sort=False)[col].sum()
            scale = []
            scale_index = []
            for _, row in temp_scale.iterrows():
                series = row.values[np.argmax(row.values != 0):]
                scale.append(((series[1:] - series[:-1]) ** 2).mean())
                scale_index.append(_)
                
            temp1 = pd.Series(np.array(scale),index=scale_index)
            setattr(self,f'lv{i + 1}_scale',temp1)

# %%
sales_train = pd.read_csv('../data/sales_train_validation.csv')
evaluator = WRMSSE_Evaluator(sales_train)
evaluator.get_weight(sales_train_long_format[(sales_train_long_format.day_num<=1913)&(sales_train_long_format.day_num>=1886)])
evaluator.get_scale(sales_train[[_ for _ in sales_train.columns if _ not in ['all_id']]
                              ])
# Out:
# HBox(children=(FloatProgress(value=0.0, max=12.0), HTML(value='')))
# HBox(children=(FloatProgress(value=0.0, max=12.0), HTML(value='')))

# %% [markdown]
# ### featuring adding

# %%
train1 = pd.read_pickle('data_part1.pkl')
# Out:
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# <ipython-input-207-151d75a420fb> in <module>
# ----> 1 train1 = pd.read_pickle('data_part1.pkl')
#
# /opt/conda/lib/python3.7/site-packages/pandas/io/pickle.py in read_pickle(path, compression)
#     177                     lambda f: pc.load(f, encoding=encoding, compat=True))
#     178     try:
# --> 179         return try_read(path)
#     180     except Exception:  # noqa: E722
#     181         if PY3:
#
# /opt/conda/lib/python3.7/site-packages/pandas/io/pickle.py in try_read(path, encoding)
#     164                 # We want to silence any warnings about, e.g. moved modules.
#     165                 warnings.simplefilter("ignore", Warning)
# --> 166                 return read_wrapper(lambda f: pkl.load(f))
#     167         except Exception:  # noqa: E722
#     168             # reg/patched pickle
#
# /opt/conda/lib/python3.7/site-packages/pandas/io/pickle.py in read_wrapper(func)
#     146                             is_text=False)
#     147         try:
# --> 148             return func(f)
#     149         finally:
#     150             for _f in fh:
#
# /opt/conda/lib/python3.7/site-packages/pandas/io/pickle.py in <lambda>(f)
#     164                 # We want to silence any warnings about, e.g. moved modules.
#     165                 warnings.simplefilter("ignore", Warning)
# --> 166                 return read_wrapper(lambda f: pkl.load(f))
#     167         except Exception:  # noqa: E722
#     168             # reg/patched pickle
#
# /opt/conda/lib/python3.7/site-packages/pandas/core/indexes/base.py in _new_Index(cls, d)
#     150
#     151
# --> 152 def _new_Index(cls, d):
#     153     """
#     154     This is called upon unpickling, rather than the default which doesn't
#
# KeyboardInterrupt:

# %%
train1.shape

# %%
for _ in ['CA','TX','WI']:
    train1.loc[train1.state_id==_,'snap'] = list(train1.loc[train1.state_id==_,f'snap_{_}'])

# %%
drop_col = ['day_num','date','wm_yr_wk','snap_CA','snap_TX','snap_WI','sale']
cat_col = ['item_id','dept_id','cat_id','store_id','state_id','event_name_1', 'event_type_1', 'event_name_2', 'event_type_2','id']

# %%
for cat in cat_col:
    lbl = preprocessing.LabelEncoder()
    train1[cat] = lbl.fit_transform(train1[cat].astype(str))
    print(cat)
# Out:
# item_id
# dept_id
# cat_id
# store_id
# state_id
# event_name_1
# event_type_1
# event_name_2
# event_type_2

# %%
train1.fillna(-999,inplace=True)

# %%
X_train = train1[(train1.day_num<=1885)&(train1.day_num>=1885-1-364)].drop(drop_col,axis=1).copy()
y_train = train1.loc[(train1.day_num<=1885)&(train1.day_num>=1885-1-364),'sale']
X_valid = train1[(train1.day_num<=1913)&(train1.day_num>=1886)].drop(drop_col,axis=1).copy()
y_valid = train1.loc[(train1.day_num<=1913)&(train1.day_num>=1886),'sale']
y_train[y_train==-999] = 0
y_valid[y_valid==-999] = 0

# %%
X_train.shape
# Out:
# (11159340, 89)

# %%
def func_custom_1_2(scalar):
    if scalar ==0:
        return 0
    elif scalar <= 10**(-8):
        return 10**4
    else:
        return scalar **(-1/2)

# %%
func1 = np.vectorize(func_custom_1_2)

# %%
def custom_obj(y_true, y_pred):
    residual = (y_true - y_pred).astype(np.float128)
    residual = residual.reshape((-1,30490)) 
    d = residual.shape[0]    
    residual_42840 = residual * roll_mat_csr.T
    mean_square_42840 = np.square(residual_42840).sum(axis = 0)
    temp_1 = func1(mean_square_42840)
    part1 = ((1/np.sqrt(S)) * temp_1)/np.sqrt(d)
    part_all = np.multiply(part1,residual_42840) 
    grad = -(part_all * roll_mat_csr).reshape((-1))
    hess_part1 = np.multiply(-(1/np.sqrt(S))/np.sqrt(d)*temp_1**3,np.square(residual_42840))
    hess_part2 = (1/np.sqrt(S))/np.sqrt(d)*temp_1
    hess = ((hess_part1 + hess_part2)*roll_mat_csr).reshape((-1))
    return grad,hess

# %%
def rmse(y_true, y_pred):
    return 'RMSE', np.sqrt(np.mean(np.power((y_pred) - (y_true), 2))), False

# %%
def func_custom_1_2(scalar):
    if scalar <= 10**(-8):
        return 10**4
    else:
        return scalar **(-1/2)

# %%
### add clip 10**-12
lgb_re2.fit(X_train,y_train,eval_set = [(X_valid,y_valid)],verbose=10,
           eval_metric =lambda y_true, y_pred: [evaluator_super.feval(y_true, y_pred), rmse(y_true, y_pred)],
           early_stopping_rounds=50)#,categorical_feature=cat_col)
# Out:
# Training until validation scores don't improve for 50 rounds
# [10]	valid_0's WRMSSE: 2.4077	valid_0's RMSE: 2.46099
# [20]	valid_0's WRMSSE: 1.16522	valid_0's RMSE: 2.03513
# [30]	valid_0's WRMSSE: 0.702458	valid_0's RMSE: 1.9301
# [40]	valid_0's WRMSSE: 0.567804	valid_0's RMSE: 1.90517
# [50]	valid_0's WRMSSE: 0.527994	valid_0's RMSE: 1.89673
# [60]	valid_0's WRMSSE: 0.513228	valid_0's RMSE: 1.8927
# [70]	valid_0's WRMSSE: 0.506294	valid_0's RMSE: 1.89032
# [80]	valid_0's WRMSSE: 0.500432	valid_0's RMSE: 1.88839
# [90]	valid_0's WRMSSE: 0.498318	valid_0's RMSE: 1.88653
# [100]	valid_0's WRMSSE: 0.495208	valid_0's RMSE: 1.88513
# [110]	valid_0's WRMSSE: 0.493699	valid_0's RMSE: 1.8838
# [120]	valid_0's WRMSSE: 0.491817	valid_0's RMSE: 1.88245
# [130]	valid_0's WRMSSE: 0.490924	valid_0's RMSE: 1.88117
# [140]	valid_0's WRMSSE: 0.490298	valid_0's RMSE: 1.88071
# [150]	valid_0's WRMSSE: 0.489538	valid_0's RMSE: 1.87967
# [160]	valid_0's WRMSSE: 0.487933	valid_0's RMSE: 1.87934
# [170]	valid_0's WRMSSE: 0.487691	valid_0's RMSE: 1.87899
# [180]	valid_0's WRMSSE: 0.487069	valid_0's RMSE: 1.87794
# [190]	valid_0's WRMSSE: 0.485519	valid_0's RMSE: 1.87735
# [200]	valid_0's WRMSSE: 0.485912	valid_0's RMSE: 1.87743
# [210]	valid_0's WRMSSE: 0.485367	valid_0's RMSE: 1.87732
# [220]	valid_0's WRMSSE: 0.485319	valid_0's RMSE: 1.87732
# [230]	valid_0's WRMSSE: 0.485477	valid_0's RMSE: 1.87735
# [240]	valid_0's WRMSSE: 0.485567	valid_0's RMSE: 1.87677
# Early stopping, best iteration is:
# [197]	valid_0's WRMSSE: 0.485159	valid_0's RMSE: 1.87735
# Evaluated only: WRMSSE
# LGBMRegressor(bagging_freq=1, boosting_type='gbdt', class_weight=None,
#        colsample_bytree=0.8, first_metric_only=True,
#        importance_type='gain', learning_rate=0.05, max_depth=-1,
#        metric='None', min_child_samples=20, min_child_weight=0.001,
#        min_data_in_leaf=255, min_split_gain=0.0, n_estimators=1000,
#        n_jobs=12, num_leaves=255,
#        objective=<function custom_obj at 0x7fc70852b1e0>, random_state=51,
#        reg_alpha=0.0, reg_lambda=0.0, silent=True, subsample=0.8,
#        subsample_for_bin=200000, subsample_freq=0)

# %%
### add clip 10**-8 cancel 0
lgb_re2.fit(X_train,y_train,eval_set = [(X_valid,y_valid)],verbose=10,
           eval_metric =lambda y_true, y_pred: [evaluator_super.feval(y_true, y_pred), rmse(y_true, y_pred)],
           early_stopping_rounds=50)#,categorical_feature=cat_col)
# Out:
# Training until validation scores don't improve for 50 rounds
# [10]	valid_0's WRMSSE: 2.4077	valid_0's RMSE: 2.46099
# [20]	valid_0's WRMSSE: 1.16522	valid_0's RMSE: 2.03513
# [30]	valid_0's WRMSSE: 0.702458	valid_0's RMSE: 1.9301
# [40]	valid_0's WRMSSE: 0.567804	valid_0's RMSE: 1.90517
# [50]	valid_0's WRMSSE: 0.527994	valid_0's RMSE: 1.89673
# [60]	valid_0's WRMSSE: 0.513228	valid_0's RMSE: 1.8927
# [70]	valid_0's WRMSSE: 0.506294	valid_0's RMSE: 1.89032
# [80]	valid_0's WRMSSE: 0.500432	valid_0's RMSE: 1.88839
# [90]	valid_0's WRMSSE: 0.498318	valid_0's RMSE: 1.88653
# [100]	valid_0's WRMSSE: 0.495208	valid_0's RMSE: 1.88513
# [110]	valid_0's WRMSSE: 0.493837	valid_0's RMSE: 1.88365
# [120]	valid_0's WRMSSE: 0.492381	valid_0's RMSE: 1.88241
# [130]	valid_0's WRMSSE: 0.490501	valid_0's RMSE: 1.88121
# [140]	valid_0's WRMSSE: 0.489744	valid_0's RMSE: 1.88056
# [150]	valid_0's WRMSSE: 0.48937	valid_0's RMSE: 1.87985
# [160]	valid_0's WRMSSE: 0.488638	valid_0's RMSE: 1.87954
# [170]	valid_0's WRMSSE: 0.486779	valid_0's RMSE: 1.87927
# [180]	valid_0's WRMSSE: 0.485905	valid_0's RMSE: 1.8789
# [190]	valid_0's WRMSSE: 0.482912	valid_0's RMSE: 1.87844
# [200]	valid_0's WRMSSE: 0.48256	valid_0's RMSE: 1.87818
# [210]	valid_0's WRMSSE: 0.482341	valid_0's RMSE: 1.87774
# [220]	valid_0's WRMSSE: 0.482217	valid_0's RMSE: 1.8773
# [230]	valid_0's WRMSSE: 0.481766	valid_0's RMSE: 1.87691
# [240]	valid_0's WRMSSE: 0.481801	valid_0's RMSE: 1.87663
# [250]	valid_0's WRMSSE: 0.481132	valid_0's RMSE: 1.87635
# [260]	valid_0's WRMSSE: 0.48112	valid_0's RMSE: 1.87605
# [270]	valid_0's WRMSSE: 0.48141	valid_0's RMSE: 1.87559
# [280]	valid_0's WRMSSE: 0.481373	valid_0's RMSE: 1.87531
# [290]	valid_0's WRMSSE: 0.4812	valid_0's RMSE: 1.87539
# [300]	valid_0's WRMSSE: 0.481166	valid_0's RMSE: 1.87515
# [310]	valid_0's WRMSSE: 0.481045	valid_0's RMSE: 1.87495
# [320]	valid_0's WRMSSE: 0.481	valid_0's RMSE: 1.87481
# [330]	valid_0's WRMSSE: 0.480871	valid_0's RMSE: 1.87477
# [340]	valid_0's WRMSSE: 0.48097	valid_0's RMSE: 1.87461
# [350]	valid_0's WRMSSE: 0.481057	valid_0's RMSE: 1.87453
# [360]	valid_0's WRMSSE: 0.481235	valid_0's RMSE: 1.87431
# [370]	valid_0's WRMSSE: 0.481323	valid_0's RMSE: 1.87392
# [380]	valid_0's WRMSSE: 0.481455	valid_0's RMSE: 1.87382
# Early stopping, best iteration is:
# [330]	valid_0's WRMSSE: 0.480871	valid_0's RMSE: 1.87477
# Evaluated only: WRMSSE
# LGBMRegressor(bagging_freq=1, boosting_type='gbdt', class_weight=None,
#        colsample_bytree=0.8, first_metric_only=True,
#        importance_type='gain', learning_rate=0.05, max_depth=-1,
#        metric='None', min_child_samples=20, min_child_weight=0.001,
#        min_data_in_leaf=255, min_split_gain=0.0, n_estimators=1000,
#        n_jobs=12, num_leaves=255,
#        objective=<function custom_obj at 0x7fc7c69ff620>, random_state=51,
#        reg_alpha=0.0, reg_lambda=0.0, silent=True, subsample=0.8,
#        subsample_for_bin=200000, subsample_freq=0)

# %%
lgb_re2 = lgb.LGBMRegressor(n_estimators=1000, random_state=51,subsample=0.8,
                         colsample_bytree=0.8,learning_rate=0.05 ,importance_type = 'gain',
                 max_depth = -1, num_leaves = 2**8-1,metric='None',bagging_freq=1,n_jobs=12,
                         first_metric_only = True,objective=custom_obj,min_data_in_leaf =  2**8-1)

# %%
### add clip 10**-8
lgb_re2.fit(X_train,y_train,eval_set = [(X_valid,y_valid)],verbose=10,
           eval_metric =lambda y_true, y_pred: [evaluator_super.feval(y_true, y_pred), rmse(y_true, y_pred)],
           early_stopping_rounds=50)#,categorical_feature=cat_col)
# Out:
# Training until validation scores don't improve for 50 rounds
# [10]	valid_0's WRMSSE: 2.4077	valid_0's RMSE: 2.46099
# [20]	valid_0's WRMSSE: 1.16522	valid_0's RMSE: 2.03513
# [30]	valid_0's WRMSSE: 0.702458	valid_0's RMSE: 1.9301
# [40]	valid_0's WRMSSE: 0.567804	valid_0's RMSE: 1.90517
# [50]	valid_0's WRMSSE: 0.527994	valid_0's RMSE: 1.89673
# [60]	valid_0's WRMSSE: 0.513228	valid_0's RMSE: 1.8927
# [70]	valid_0's WRMSSE: 0.506294	valid_0's RMSE: 1.89032
# [80]	valid_0's WRMSSE: 0.500432	valid_0's RMSE: 1.88839
# [90]	valid_0's WRMSSE: 0.498318	valid_0's RMSE: 1.88653
# [100]	valid_0's WRMSSE: 0.495208	valid_0's RMSE: 1.88513
# [110]	valid_0's WRMSSE: 0.493837	valid_0's RMSE: 1.88365
# [120]	valid_0's WRMSSE: 0.492381	valid_0's RMSE: 1.88241
# [130]	valid_0's WRMSSE: 0.490501	valid_0's RMSE: 1.88121
# [140]	valid_0's WRMSSE: 0.489744	valid_0's RMSE: 1.88056
# [150]	valid_0's WRMSSE: 0.48937	valid_0's RMSE: 1.87985
# [160]	valid_0's WRMSSE: 0.488638	valid_0's RMSE: 1.87954
# [170]	valid_0's WRMSSE: 0.486779	valid_0's RMSE: 1.87927
# [180]	valid_0's WRMSSE: 0.485905	valid_0's RMSE: 1.8789
# [190]	valid_0's WRMSSE: 0.482912	valid_0's RMSE: 1.87844
# [200]	valid_0's WRMSSE: 0.48256	valid_0's RMSE: 1.87818
# [210]	valid_0's WRMSSE: 0.482341	valid_0's RMSE: 1.87774
# [220]	valid_0's WRMSSE: 0.482217	valid_0's RMSE: 1.8773
# [230]	valid_0's WRMSSE: 0.481766	valid_0's RMSE: 1.87691
# [240]	valid_0's WRMSSE: 0.481801	valid_0's RMSE: 1.87663
# [250]	valid_0's WRMSSE: 0.481132	valid_0's RMSE: 1.87635
# [260]	valid_0's WRMSSE: 0.48112	valid_0's RMSE: 1.87605
# [270]	valid_0's WRMSSE: 0.48141	valid_0's RMSE: 1.87559
# [280]	valid_0's WRMSSE: 0.481373	valid_0's RMSE: 1.87531
# [290]	valid_0's WRMSSE: 0.4812	valid_0's RMSE: 1.87539
# [300]	valid_0's WRMSSE: 0.481166	valid_0's RMSE: 1.87515
# [310]	valid_0's WRMSSE: 0.481045	valid_0's RMSE: 1.87495
# [320]	valid_0's WRMSSE: 0.481	valid_0's RMSE: 1.87481
# [330]	valid_0's WRMSSE: 0.480871	valid_0's RMSE: 1.87477
# [340]	valid_0's WRMSSE: 0.48097	valid_0's RMSE: 1.87461
# [350]	valid_0's WRMSSE: 0.481057	valid_0's RMSE: 1.87453
# [360]	valid_0's WRMSSE: 0.481235	valid_0's RMSE: 1.87431
# [370]	valid_0's WRMSSE: 0.481323	valid_0's RMSE: 1.87392
# [380]	valid_0's WRMSSE: 0.481455	valid_0's RMSE: 1.87382
# Early stopping, best iteration is:
# [330]	valid_0's WRMSSE: 0.480871	valid_0's RMSE: 1.87477
# Evaluated only: WRMSSE
# LGBMRegressor(bagging_freq=1, boosting_type='gbdt', class_weight=None,
#        colsample_bytree=0.8, first_metric_only=True,
#        importance_type='gain', learning_rate=0.05, max_depth=-1,
#        metric='None', min_child_samples=20, min_child_weight=0.001,
#        min_data_in_leaf=255, min_split_gain=0.0, n_estimators=1000,
#        n_jobs=12, num_leaves=255,
#        objective=<function custom_obj at 0x7fc7c69ff620>, random_state=51,
#        reg_alpha=0.0, reg_lambda=0.0, silent=True, subsample=0.8,
#        subsample_for_bin=200000, subsample_freq=0)

# %%
### add clip
lgb_re2.fit(X_train,y_train,eval_set = [(X_valid,y_valid)],verbose=10,
           eval_metric =lambda y_true, y_pred: [evaluator_super.feval(y_true, y_pred), rmse(y_true, y_pred)],
           early_stopping_rounds=50)#,categorical_feature=cat_col)
# Out:
# Training until validation scores don't improve for 50 rounds
# [10]	valid_0's WRMSSE: 2.4077	valid_0's RMSE: 2.46099
# [20]	valid_0's WRMSSE: 1.16522	valid_0's RMSE: 2.03513
# [30]	valid_0's WRMSSE: 0.702458	valid_0's RMSE: 1.9301
# [40]	valid_0's WRMSSE: 0.567804	valid_0's RMSE: 1.90517
# [50]	valid_0's WRMSSE: 0.527994	valid_0's RMSE: 1.89673
# [60]	valid_0's WRMSSE: 0.513228	valid_0's RMSE: 1.8927
# [70]	valid_0's WRMSSE: 0.506294	valid_0's RMSE: 1.89032
# [80]	valid_0's WRMSSE: 0.500432	valid_0's RMSE: 1.88839
# [90]	valid_0's WRMSSE: 0.498208	valid_0's RMSE: 1.88649
# [100]	valid_0's WRMSSE: 0.494136	valid_0's RMSE: 1.88532
# [110]	valid_0's WRMSSE: 0.492417	valid_0's RMSE: 1.88429
# [120]	valid_0's WRMSSE: 0.490829	valid_0's RMSE: 1.88324
# [130]	valid_0's WRMSSE: 0.489961	valid_0's RMSE: 1.8817
# [140]	valid_0's WRMSSE: 0.489274	valid_0's RMSE: 1.88092
# [150]	valid_0's WRMSSE: 0.488726	valid_0's RMSE: 1.87991
# [160]	valid_0's WRMSSE: 0.48827	valid_0's RMSE: 1.87927
# [170]	valid_0's WRMSSE: 0.48789	valid_0's RMSE: 1.87852
# [180]	valid_0's WRMSSE: 0.487452	valid_0's RMSE: 1.87831
# [190]	valid_0's WRMSSE: 0.486801	valid_0's RMSE: 1.87765
# [200]	valid_0's WRMSSE: 0.485914	valid_0's RMSE: 1.87699
# [210]	valid_0's WRMSSE: 0.485834	valid_0's RMSE: 1.8764
# [220]	valid_0's WRMSSE: 0.485343	valid_0's RMSE: 1.87617
# [230]	valid_0's WRMSSE: 0.485306	valid_0's RMSE: 1.87608
# [240]	valid_0's WRMSSE: 0.484024	valid_0's RMSE: 1.87562
# [250]	valid_0's WRMSSE: 0.483726	valid_0's RMSE: 1.87561
# [260]	valid_0's WRMSSE: 0.483499	valid_0's RMSE: 1.87513
# [270]	valid_0's WRMSSE: 0.483418	valid_0's RMSE: 1.87515
# [280]	valid_0's WRMSSE: 0.48176	valid_0's RMSE: 1.87479
# [290]	valid_0's WRMSSE: 0.481567	valid_0's RMSE: 1.87469
# [300]	valid_0's WRMSSE: 0.481528	valid_0's RMSE: 1.87459
# [310]	valid_0's WRMSSE: 0.481433	valid_0's RMSE: 1.87454
# [320]	valid_0's WRMSSE: 0.481701	valid_0's RMSE: 1.8746
# [330]	valid_0's WRMSSE: 0.481508	valid_0's RMSE: 1.87432
# [340]	valid_0's WRMSSE: 0.481373	valid_0's RMSE: 1.87423
# [350]	valid_0's WRMSSE: 0.48136	valid_0's RMSE: 1.87398
# [360]	valid_0's WRMSSE: 0.481107	valid_0's RMSE: 1.87385
# [370]	valid_0's WRMSSE: 0.480976	valid_0's RMSE: 1.8736
# [380]	valid_0's WRMSSE: 0.481012	valid_0's RMSE: 1.87347
# [390]	valid_0's WRMSSE: 0.4811	valid_0's RMSE: 1.87334
# [400]	valid_0's WRMSSE: 0.481191	valid_0's RMSE: 1.87307
# [410]	valid_0's WRMSSE: 0.481416	valid_0's RMSE: 1.87296
# [420]	valid_0's WRMSSE: 0.481411	valid_0's RMSE: 1.87307
# Early stopping, best iteration is:
# [375]	valid_0's WRMSSE: 0.480904	valid_0's RMSE: 1.8735
# Evaluated only: WRMSSE
# LGBMRegressor(bagging_freq=1, boosting_type='gbdt', class_weight=None,
#        colsample_bytree=0.8, first_metric_only=True,
#        importance_type='gain', learning_rate=0.05, max_depth=-1,
#        metric='None', min_child_samples=20, min_child_weight=0.001,
#        min_data_in_leaf=255, min_split_gain=0.0, n_estimators=1000,
#        n_jobs=12, num_leaves=255,
#        objective=<function custom_obj at 0x7fc7c69ffd90>, random_state=51,
#        reg_alpha=0.0, reg_lambda=0.0, silent=True, subsample=0.8,
#        subsample_for_bin=200000, subsample_freq=0)

# %%
lgb_re2.fit(X_train,y_train,eval_set = [(X_valid,y_valid)],verbose=10,
           eval_metric =lambda y_true, y_pred: [evaluator_super.feval(y_true, y_pred), rmse(y_true, y_pred)],
           early_stopping_rounds=50)#,categorical_feature=cat_col)
# Out:
# Training until validation scores don't improve for 50 rounds
# [10]	valid_0's WRMSSE: 2.4077	valid_0's RMSE: 2.46099
# [20]	valid_0's WRMSSE: 1.16522	valid_0's RMSE: 2.03513
# [30]	valid_0's WRMSSE: 0.702458	valid_0's RMSE: 1.9301
# [40]	valid_0's WRMSSE: 0.567804	valid_0's RMSE: 1.90517
# [50]	valid_0's WRMSSE: 0.527994	valid_0's RMSE: 1.89673
# [60]	valid_0's WRMSSE: 0.513228	valid_0's RMSE: 1.8927
# [70]	valid_0's WRMSSE: 0.506294	valid_0's RMSE: 1.89032
# [80]	valid_0's WRMSSE: 0.500432	valid_0's RMSE: 1.88839
# [90]	valid_0's WRMSSE: 0.498318	valid_0's RMSE: 1.88653
# [100]	valid_0's WRMSSE: 0.495208	valid_0's RMSE: 1.88513
# [110]	valid_0's WRMSSE: 0.493699	valid_0's RMSE: 1.8838
# [120]	valid_0's WRMSSE: 0.491817	valid_0's RMSE: 1.88245
# [130]	valid_0's WRMSSE: 0.490924	valid_0's RMSE: 1.88117
# [140]	valid_0's WRMSSE: 0.490298	valid_0's RMSE: 1.88071
# [150]	valid_0's WRMSSE: 0.489538	valid_0's RMSE: 1.87967
# [160]	valid_0's WRMSSE: 0.487867	valid_0's RMSE: 1.87935
# [170]	valid_0's WRMSSE: 0.487625	valid_0's RMSE: 1.87899
# [180]	valid_0's WRMSSE: 0.487001	valid_0's RMSE: 1.87794
# [190]	valid_0's WRMSSE: 0.485437	valid_0's RMSE: 1.87736
# [200]	valid_0's WRMSSE: 0.485823	valid_0's RMSE: 1.87744
# [210]	valid_0's WRMSSE: 0.485278	valid_0's RMSE: 1.87733
# [220]	valid_0's WRMSSE: 0.485227	valid_0's RMSE: 1.87732
# [230]	valid_0's WRMSSE: 0.485385	valid_0's RMSE: 1.87735
# [240]	valid_0's WRMSSE: 0.485472	valid_0's RMSE: 1.87678
# Early stopping, best iteration is:
# [197]	valid_0's WRMSSE: 0.485075	valid_0's RMSE: 1.87735
# Evaluated only: WRMSSE
# LGBMRegressor(bagging_freq=1, boosting_type='gbdt', class_weight=None,
#        colsample_bytree=0.8, first_metric_only=True,
#        importance_type='gain', learning_rate=0.05, max_depth=-1,
#        metric='None', min_child_samples=20, min_child_weight=0.001,
#        min_data_in_leaf=255, min_split_gain=0.0, n_estimators=1000,
#        n_jobs=12, num_leaves=255,
#        objective=<function custom_obj at 0x7fc7c91e1378>, random_state=51,
#        reg_alpha=0.0, reg_lambda=0.0, silent=True, subsample=0.8,
#        subsample_for_bin=200000, subsample_freq=0)

# %%
lgb_re3 = lgb.LGBMRegressor(n_estimators=1000, random_state=51,subsample=0.8,
                         colsample_bytree=0.8,learning_rate=0.05 ,importance_type = 'gain',
                 max_depth = -1, num_leaves = 2**8-1,metric='None',bagging_freq=1,n_jobs=12,
                         first_metric_only = True,min_data_in_leaf =  2**8-1)

# %%
lgb_re3.fit(X_train,y_train,eval_set = [(X_valid,y_valid)],verbose=10,
           eval_metric =lambda y_true, y_pred: [evaluator_super.feval(y_true, y_pred), rmse(y_true, y_pred)],
           early_stopping_rounds=50)#,categorical_feature=cat_col)
# Out:
# Training until validation scores don't improve for 50 rounds
# [10]	valid_0's WRMSSE: 1.57567	valid_0's RMSE: 2.64149
# [20]	valid_0's WRMSSE: 1.14346	valid_0's RMSE: 2.19562
# [30]	valid_0's WRMSSE: 0.886479	valid_0's RMSE: 2.00782
# [40]	valid_0's WRMSSE: 0.740383	valid_0's RMSE: 1.93324
# [50]	valid_0's WRMSSE: 0.654043	valid_0's RMSE: 1.90254
# [60]	valid_0's WRMSSE: 0.604324	valid_0's RMSE: 1.89012
# [70]	valid_0's WRMSSE: 0.574098	valid_0's RMSE: 1.8841
# [80]	valid_0's WRMSSE: 0.552182	valid_0's RMSE: 1.8814
# [90]	valid_0's WRMSSE: 0.538379	valid_0's RMSE: 1.87962
# [100]	valid_0's WRMSSE: 0.530081	valid_0's RMSE: 1.87841
# [110]	valid_0's WRMSSE: 0.523992	valid_0's RMSE: 1.87758
# [120]	valid_0's WRMSSE: 0.519015	valid_0's RMSE: 1.87692
# [130]	valid_0's WRMSSE: 0.517028	valid_0's RMSE: 1.87637
# [140]	valid_0's WRMSSE: 0.514616	valid_0's RMSE: 1.87572
# [150]	valid_0's WRMSSE: 0.513511	valid_0's RMSE: 1.87565
# [160]	valid_0's WRMSSE: 0.511077	valid_0's RMSE: 1.87527
# [170]	valid_0's WRMSSE: 0.510724	valid_0's RMSE: 1.87523
# [180]	valid_0's WRMSSE: 0.510353	valid_0's RMSE: 1.87492
# [190]	valid_0's WRMSSE: 0.50981	valid_0's RMSE: 1.87482
# [200]	valid_0's WRMSSE: 0.509655	valid_0's RMSE: 1.87474
# [210]	valid_0's WRMSSE: 0.509365	valid_0's RMSE: 1.8749
# [220]	valid_0's WRMSSE: 0.50934	valid_0's RMSE: 1.87494
# [230]	valid_0's WRMSSE: 0.508702	valid_0's RMSE: 1.87464
# [240]	valid_0's WRMSSE: 0.508617	valid_0's RMSE: 1.87477
# [250]	valid_0's WRMSSE: 0.508066	valid_0's RMSE: 1.87447
# [260]	valid_0's WRMSSE: 0.508016	valid_0's RMSE: 1.87433
# [270]	valid_0's WRMSSE: 0.507819	valid_0's RMSE: 1.87427
# [280]	valid_0's WRMSSE: 0.507745	valid_0's RMSE: 1.87432
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# <ipython-input-86-b3c0c6d9c7db> in <module>
#       1 lgb_re3.fit(X_train,y_train,eval_set = [(X_valid,y_valid)],verbose=10,
#       2            eval_metric =lambda y_true, y_pred: [evaluator_super.feval(y_true, y_pred), rmse(y_true, y_pred)],
# ----> 3            early_stopping_rounds=50)#,categorical_feature=cat_col)
#
# /opt/conda/lib/python3.7/site-packages/lightgbm/sklearn.py in fit(self, X, y, sample_weight, init_score, eval_set, eval_names, eval_sample_weight, eval_init_score, eval_metric, early_stopping_rounds, verbose, feature_name, categorical_feature, callbacks)
#     741                                        verbose=verbose, feature_name=feature_name,
#     742                                        categorical_feature=categorical_feature,
# --> 743                                        callbacks=callbacks)
#     744         return self
#     745
#
# /opt/conda/lib/python3.7/site-packages/lightgbm/sklearn.py in fit(self, X, y, sample_weight, init_score, group, eval_set, eval_names, eval_sample_weight, eval_class_weight, eval_init_score, eval_group, eval_metric, early_stopping_rounds, verbose, feature_name, categorical_feature, callbacks)
#     598                               verbose_eval=verbose, feature_name=feature_name,
#     599                               categorical_feature=categorical_feature,
# --> 600                               callbacks=callbacks)
#     601
#     602         if evals_result:
#
# /opt/conda/lib/python3.7/site-packages/lightgbm/engine.py in train(params, train_set, num_boost_round, valid_sets, valid_names, fobj, feval, init_model, feature_name, categorical_feature, early_stopping_rounds, evals_result, verbose_eval, learning_rates, keep_training_booster, callbacks)
#     247                                     evaluation_result_list=None))
#     248
# --> 249         booster.update(fobj=fobj)
#     250
#     251         evaluation_result_list = []
#
# /opt/conda/lib/python3.7/site-packages/lightgbm/basic.py in update(self, train_set, fobj)
#    1974             _safe_call(_LIB.LGBM_BoosterUpdateOneIter(
#    1975                 self.handle,
# -> 1976                 ctypes.byref(is_finished)))
#    1977             self.__is_predicted_cur_iter = [False for _ in range_(self.__num_dataset)]
#    1978             return is_finished.value == 1
#
# KeyboardInterrupt:

# %%
lgb_re4 = lgb.LGBMRegressor(n_estimators=1000, random_state=51,subsample=0.8,
                         colsample_bytree=0.8,learning_rate=0.05 ,importance_type = 'gain',
                 max_depth = -1, num_leaves = 2**8-1,metric='None',bagging_freq=1,n_jobs=12,
                         first_metric_only = True,min_data_in_leaf =  2**8-1,objective='tweedie')

# %%
lgb_re4.fit(X_train,y_train,eval_set = [(X_valid,y_valid)],verbose=10,
           eval_metric =lambda y_true, y_pred: [evaluator_super.feval(y_true, y_pred), rmse(y_true, y_pred)],
           early_stopping_rounds=50)#,categorical_feature=cat_col)
# Out:
# Training until validation scores don't improve for 50 rounds
# [10]	valid_0's WRMSSE: 1.9203	valid_0's RMSE: 3.32246
# [20]	valid_0's WRMSSE: 1.63035	valid_0's RMSE: 3.02362
# [30]	valid_0's WRMSSE: 1.32648	valid_0's RMSE: 2.69143
# [40]	valid_0's WRMSSE: 1.06025	valid_0's RMSE: 2.38488
# [50]	valid_0's WRMSSE: 0.857795	valid_0's RMSE: 2.16012
# [60]	valid_0's WRMSSE: 0.722147	valid_0's RMSE: 2.02327
# [70]	valid_0's WRMSSE: 0.638949	valid_0's RMSE: 1.9542
# [80]	valid_0's WRMSSE: 0.586294	valid_0's RMSE: 1.92093
# [90]	valid_0's WRMSSE: 0.55793	valid_0's RMSE: 1.90588
# [100]	valid_0's WRMSSE: 0.537583	valid_0's RMSE: 1.89684
# [110]	valid_0's WRMSSE: 0.526311	valid_0's RMSE: 1.89228
# [120]	valid_0's WRMSSE: 0.514664	valid_0's RMSE: 1.8893
# [130]	valid_0's WRMSSE: 0.509033	valid_0's RMSE: 1.88668
# [140]	valid_0's WRMSSE: 0.503479	valid_0's RMSE: 1.88426
# [150]	valid_0's WRMSSE: 0.501958	valid_0's RMSE: 1.88298
# [160]	valid_0's WRMSSE: 0.499965	valid_0's RMSE: 1.88175
# [170]	valid_0's WRMSSE: 0.499191	valid_0's RMSE: 1.88088
# [180]	valid_0's WRMSSE: 0.497713	valid_0's RMSE: 1.87988
# [190]	valid_0's WRMSSE: 0.497837	valid_0's RMSE: 1.87964
# [200]	valid_0's WRMSSE: 0.495654	valid_0's RMSE: 1.87911
# [210]	valid_0's WRMSSE: 0.495388	valid_0's RMSE: 1.87924
# [220]	valid_0's WRMSSE: 0.494446	valid_0's RMSE: 1.87868
# [230]	valid_0's WRMSSE: 0.494203	valid_0's RMSE: 1.87803
# [240]	valid_0's WRMSSE: 0.494159	valid_0's RMSE: 1.87808
# [250]	valid_0's WRMSSE: 0.493982	valid_0's RMSE: 1.87803
# [260]	valid_0's WRMSSE: 0.493979	valid_0's RMSE: 1.87776
# [270]	valid_0's WRMSSE: 0.493812	valid_0's RMSE: 1.87773
# [280]	valid_0's WRMSSE: 0.493725	valid_0's RMSE: 1.87726
# [290]	valid_0's WRMSSE: 0.49372	valid_0's RMSE: 1.87687
# [300]	valid_0's WRMSSE: 0.493649	valid_0's RMSE: 1.87685
# [310]	valid_0's WRMSSE: 0.493757	valid_0's RMSE: 1.8767
# [320]	valid_0's WRMSSE: 0.493783	valid_0's RMSE: 1.87672
# [330]	valid_0's WRMSSE: 0.493756	valid_0's RMSE: 1.87668
# [340]	valid_0's WRMSSE: 0.493474	valid_0's RMSE: 1.87649
# [350]	valid_0's WRMSSE: 0.493585	valid_0's RMSE: 1.87636
# [360]	valid_0's WRMSSE: 0.492743	valid_0's RMSE: 1.87603
# [370]	valid_0's WRMSSE: 0.49266	valid_0's RMSE: 1.87588
# [380]	valid_0's WRMSSE: 0.492586	valid_0's RMSE: 1.87586
# [390]	valid_0's WRMSSE: 0.492622	valid_0's RMSE: 1.87573
# [400]	valid_0's WRMSSE: 0.492533	valid_0's RMSE: 1.87519
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# <ipython-input-89-f4c935b715f5> in <module>
#       1 lgb_re4.fit(X_train,y_train,eval_set = [(X_valid,y_valid)],verbose=10,
#       2            eval_metric =lambda y_true, y_pred: [evaluator_super.feval(y_true, y_pred), rmse(y_true, y_pred)],
# ----> 3            early_stopping_rounds=50)#,categorical_feature=cat_col)
#
# /opt/conda/lib/python3.7/site-packages/lightgbm/sklearn.py in fit(self, X, y, sample_weight, init_score, eval_set, eval_names, eval_sample_weight, eval_init_score, eval_metric, early_stopping_rounds, verbose, feature_name, categorical_feature, callbacks)
#     741                                        verbose=verbose, feature_name=feature_name,
#     742                                        categorical_feature=categorical_feature,
# --> 743                                        callbacks=callbacks)
#     744         return self
#     745
#
# /opt/conda/lib/python3.7/site-packages/lightgbm/sklearn.py in fit(self, X, y, sample_weight, init_score, group, eval_set, eval_names, eval_sample_weight, eval_class_weight, eval_init_score, eval_group, eval_metric, early_stopping_rounds, verbose, feature_name, categorical_feature, callbacks)
#     598                               verbose_eval=verbose, feature_name=feature_name,
#     599                               categorical_feature=categorical_feature,
# --> 600                               callbacks=callbacks)
#     601
#     602         if evals_result:
#
# /opt/conda/lib/python3.7/site-packages/lightgbm/engine.py in train(params, train_set, num_boost_round, valid_sets, valid_names, fobj, feval, init_model, feature_name, categorical_feature, early_stopping_rounds, evals_result, verbose_eval, learning_rates, keep_training_booster, callbacks)
#     247                                     evaluation_result_list=None))
#     248
# --> 249         booster.update(fobj=fobj)
#     250
#     251         evaluation_result_list = []
#
# /opt/conda/lib/python3.7/site-packages/lightgbm/basic.py in update(self, train_set, fobj)
#    1974             _safe_call(_LIB.LGBM_BoosterUpdateOneIter(
#    1975                 self.handle,
# -> 1976                 ctypes.byref(is_finished)))
#    1977             self.__is_predicted_cur_iter = [False for _ in range_(self.__num_dataset)]
#    1978             return is_finished.value == 1
#
# KeyboardInterrupt:

# %%
X_train = train1[(train1.day_num<=1885)&(train1.day_num>=1885-1-364)&(train1.date!='2015-12-25')].drop(drop_col,axis=1).copy()
y_train = train1.loc[(train1.day_num<=1885)&(train1.day_num>=1885-1-364)&(train1.date!='2015-12-25'),'sale']
X_valid = train1[(train1.day_num<=1913)&(train1.day_num>=1886)].drop(drop_col,axis=1).copy()
y_valid = train1.loc[(train1.day_num<=1913)&(train1.day_num>=1886),'sale']
y_train[y_train==-999] = 0
y_valid[y_valid==-999] = 0

# %%
X_train.shape
# Out:
# (11128850, 89)

# %%
lgb_re2 = lgb.LGBMRegressor(n_estimators=1000, random_state=51,subsample=0.8,
                         colsample_bytree=0.8,learning_rate=0.05 ,importance_type = 'gain',
                 max_depth = -1, num_leaves = 2**8-1,metric='None',bagging_freq=1,n_jobs=12,
                         first_metric_only = True,objective=custom_obj,min_data_in_leaf =  2**8-1)

# %%
### add clip

lgb_re2.fit(X_train,y_train,eval_set = [(X_valid,y_valid)],verbose=10,
           eval_metric =lambda y_true, y_pred: [evaluator_super.feval(y_true, y_pred), rmse(y_true, y_pred)],
           early_stopping_rounds=50)#,categorical_feature=cat_col)
# Out:
# Training until validation scores don't improve for 50 rounds
# [10]	valid_0's WRMSSE: 2.39835	valid_0's RMSE: 2.45346
# [20]	valid_0's WRMSSE: 1.15425	valid_0's RMSE: 2.03038
# [30]	valid_0's WRMSSE: 0.695587	valid_0's RMSE: 1.92839
# [40]	valid_0's WRMSSE: 0.564787	valid_0's RMSE: 1.90534
# [50]	valid_0's WRMSSE: 0.527349	valid_0's RMSE: 1.89771
# [60]	valid_0's WRMSSE: 0.513985	valid_0's RMSE: 1.89377
# [70]	valid_0's WRMSSE: 0.506717	valid_0's RMSE: 1.89133
# [80]	valid_0's WRMSSE: 0.502145	valid_0's RMSE: 1.88957
# [90]	valid_0's WRMSSE: 0.499353	valid_0's RMSE: 1.88782
# [100]	valid_0's WRMSSE: 0.496294	valid_0's RMSE: 1.88607
# [110]	valid_0's WRMSSE: 0.494545	valid_0's RMSE: 1.88404
# [120]	valid_0's WRMSSE: 0.492418	valid_0's RMSE: 1.8827
# [130]	valid_0's WRMSSE: 0.491035	valid_0's RMSE: 1.88198
# [140]	valid_0's WRMSSE: 0.490311	valid_0's RMSE: 1.88081
# [150]	valid_0's WRMSSE: 0.489509	valid_0's RMSE: 1.87978
# [160]	valid_0's WRMSSE: 0.488654	valid_0's RMSE: 1.87911
# [170]	valid_0's WRMSSE: 0.487559	valid_0's RMSE: 1.87875
# [180]	valid_0's WRMSSE: 0.487024	valid_0's RMSE: 1.87796
# [190]	valid_0's WRMSSE: 0.487029	valid_0's RMSE: 1.87772
# [200]	valid_0's WRMSSE: 0.486333	valid_0's RMSE: 1.87746
# [210]	valid_0's WRMSSE: 0.48598	valid_0's RMSE: 1.87684
# [220]	valid_0's WRMSSE: 0.48568	valid_0's RMSE: 1.87617
# [230]	valid_0's WRMSSE: 0.48542	valid_0's RMSE: 1.87561
# [240]	valid_0's WRMSSE: 0.485252	valid_0's RMSE: 1.87531
# [250]	valid_0's WRMSSE: 0.484544	valid_0's RMSE: 1.87501
# [260]	valid_0's WRMSSE: 0.484587	valid_0's RMSE: 1.87467
# [270]	valid_0's WRMSSE: 0.483929	valid_0's RMSE: 1.87408
# [280]	valid_0's WRMSSE: 0.483713	valid_0's RMSE: 1.87393
# [290]	valid_0's WRMSSE: 0.483809	valid_0's RMSE: 1.874
# [300]	valid_0's WRMSSE: 0.482949	valid_0's RMSE: 1.87396
# [310]	valid_0's WRMSSE: 0.482896	valid_0's RMSE: 1.87383
# [320]	valid_0's WRMSSE: 0.483078	valid_0's RMSE: 1.87373
# [330]	valid_0's WRMSSE: 0.483075	valid_0's RMSE: 1.87356
# [340]	valid_0's WRMSSE: 0.482883	valid_0's RMSE: 1.87328
# [350]	valid_0's WRMSSE: 0.482125	valid_0's RMSE: 1.87327
# [360]	valid_0's WRMSSE: 0.482	valid_0's RMSE: 1.87335
# [370]	valid_0's WRMSSE: 0.481866	valid_0's RMSE: 1.87295
# [380]	valid_0's WRMSSE: 0.480981	valid_0's RMSE: 1.87298
# [390]	valid_0's WRMSSE: 0.481352	valid_0's RMSE: 1.87278
# [400]	valid_0's WRMSSE: 0.481401	valid_0's RMSE: 1.87262
# [410]	valid_0's WRMSSE: 0.481392	valid_0's RMSE: 1.87252
# [420]	valid_0's WRMSSE: 0.481627	valid_0's RMSE: 1.87268
# Early stopping, best iteration is:
# [379]	valid_0's WRMSSE: 0.480976	valid_0's RMSE: 1.87296
# Evaluated only: WRMSSE
# LGBMRegressor(bagging_freq=1, boosting_type='gbdt', class_weight=None,
#        colsample_bytree=0.8, first_metric_only=True,
#        importance_type='gain', learning_rate=0.05, max_depth=-1,
#        metric='None', min_child_samples=20, min_child_weight=0.001,
#        min_data_in_leaf=255, min_split_gain=0.0, n_estimators=1000,
#        n_jobs=12, num_leaves=255,
#        objective=<function custom_obj at 0x7fc7c69ffd90>, random_state=51,
#        reg_alpha=0.0, reg_lambda=0.0, silent=True, subsample=0.8,
#        subsample_for_bin=200000, subsample_freq=0)

# %%
lgb_re2.fit(X_train,y_train,eval_set = [(X_valid,y_valid)],verbose=10,
           eval_metric =lambda y_true, y_pred: [evaluator_super.feval(y_true, y_pred), rmse(y_true, y_pred)],
           early_stopping_rounds=50)#,categorical_feature=cat_col)
# Out:
# Training until validation scores don't improve for 50 rounds
# [10]	valid_0's WRMSSE: 2.39835	valid_0's RMSE: 2.45346
# [20]	valid_0's WRMSSE: 1.15425	valid_0's RMSE: 2.03038
# [30]	valid_0's WRMSSE: 0.695587	valid_0's RMSE: 1.92839
# [40]	valid_0's WRMSSE: 0.564787	valid_0's RMSE: 1.90534
# [50]	valid_0's WRMSSE: 0.527349	valid_0's RMSE: 1.89771
# [60]	valid_0's WRMSSE: 0.513985	valid_0's RMSE: 1.89377
# [70]	valid_0's WRMSSE: 0.506717	valid_0's RMSE: 1.89133
# [80]	valid_0's WRMSSE: 0.502195	valid_0's RMSE: 1.88954
# [90]	valid_0's WRMSSE: 0.499773	valid_0's RMSE: 1.88761
# [100]	valid_0's WRMSSE: 0.496592	valid_0's RMSE: 1.88565
# [110]	valid_0's WRMSSE: 0.495132	valid_0's RMSE: 1.88353
# [120]	valid_0's WRMSSE: 0.493028	valid_0's RMSE: 1.88238
# [130]	valid_0's WRMSSE: 0.490376	valid_0's RMSE: 1.88164
# [140]	valid_0's WRMSSE: 0.489492	valid_0's RMSE: 1.88085
# [150]	valid_0's WRMSSE: 0.488385	valid_0's RMSE: 1.87974
# [160]	valid_0's WRMSSE: 0.487822	valid_0's RMSE: 1.87888
# [170]	valid_0's WRMSSE: 0.487414	valid_0's RMSE: 1.87865
# [180]	valid_0's WRMSSE: 0.486944	valid_0's RMSE: 1.87799
# [190]	valid_0's WRMSSE: 0.485596	valid_0's RMSE: 1.87768
# [200]	valid_0's WRMSSE: 0.48521	valid_0's RMSE: 1.87734
# [210]	valid_0's WRMSSE: 0.485336	valid_0's RMSE: 1.87723
# [220]	valid_0's WRMSSE: 0.485208	valid_0's RMSE: 1.87712
# [230]	valid_0's WRMSSE: 0.484822	valid_0's RMSE: 1.87703
# [240]	valid_0's WRMSSE: 0.484187	valid_0's RMSE: 1.87646
# [250]	valid_0's WRMSSE: 0.483866	valid_0's RMSE: 1.87616
# [260]	valid_0's WRMSSE: 0.48397	valid_0's RMSE: 1.87577
# [270]	valid_0's WRMSSE: 0.483804	valid_0's RMSE: 1.87567
# [280]	valid_0's WRMSSE: 0.483809	valid_0's RMSE: 1.87564
# [290]	valid_0's WRMSSE: 0.48375	valid_0's RMSE: 1.87551
# [300]	valid_0's WRMSSE: 0.483944	valid_0's RMSE: 1.87528
# [310]	valid_0's WRMSSE: 0.486847	valid_0's RMSE: 1.87575
# [320]	valid_0's WRMSSE: 1.00792	valid_0's RMSE: 7.39084
# Early stopping, best iteration is:
# [272]	valid_0's WRMSSE: 0.483717	valid_0's RMSE: 1.8758
# Evaluated only: WRMSSE
# LGBMRegressor(bagging_freq=1, boosting_type='gbdt', class_weight=None,
#        colsample_bytree=0.8, first_metric_only=True,
#        importance_type='gain', learning_rate=0.05, max_depth=-1,
#        metric='None', min_child_samples=20, min_child_weight=0.001,
#        min_data_in_leaf=255, min_split_gain=0.0, n_estimators=1000,
#        n_jobs=12, num_leaves=255,
#        objective=<function custom_obj at 0x7fc7c91e1378>, random_state=51,
#        reg_alpha=0.0, reg_lambda=0.0, silent=True, subsample=0.8,
#        subsample_for_bin=200000, subsample_freq=0)

# %%
pd.DataFrame(lgb_re2.feature_importances_,index=X_train.columns).sort_values(0,ascending=False)
# Out:
#                                                  0
# rolling_sale_28_mean                  86402.379553
# rolling_sale_14_mean                  54087.704597
# rolling_sale_7_mean                   18689.628203
# rolling_sale_91_mean                   7214.236200
# rolling_sale_28_std                    6267.006862
# rolling_sale_dayofweek_52_mean         3390.096602
# dayofweek                              2741.749269
# rolling_sale_dayofweek_52_quantile75   2732.591454
# rolling_sale_14_quantile75             2644.489157
# rolling_sale_364_mean                  2464.654596
# lag_sale_1                             2266.273754
# rolling_sale_3_mean                    1824.575405
# rolling_sale_28_quantile75             1187.993363
# rolling_sale_364_std                   1112.890899
# rolling_sale_dayofweek_24_quantile75    990.596235
# rolling_sale_dayofweek_52_std           974.517269
# rolling_sale_14_std                     863.121638
# rolling_sale_dayofweek_24_mean          810.362701
# rolling_sale_7_median                   803.223655
# snap                                    731.231468
# item_id                                 720.100931
# rolling_sale_7_std                      696.205608
# rolling_sale_7_quantile75               594.236637
# rolling_sale_91_std                     543.025408
# month                                   539.438604
# rolling_sale_dayofweek_8_mean           524.583857
# rolling_sale_dayofweek_12_quantile75    504.339404
# rolling_sale_dayofweek_12_mean          457.040359
# store_id                                452.856617
# sell_price                              431.436198
# ...                                            ...
# rolling_sale_dayofweek_8_median          59.305372
# rolling_sale_dayofweek_4_std             58.194732
# rolling_sale_dayofweek_24_cv             57.926304
# rolling_sale_182_quantile75              56.635255
# lag_sale_7                               55.875792
# rolling_sale_dayofweek_52_median         55.684518
# rolling_sale_28_quantile25               55.397163
# rolling_sale_dayofweek_8_std             52.438460
# rolling_sale_dayofweek_12_cv             50.883836
# year                                     49.791972
# rolling_sale_14_quantile25               49.707084
# rolling_sale_dayofweek_24_std            49.157472
# rolling_sale_dayofweek_8_cv              44.689724
# rolling_sale_dayofweek_12_std            43.865356
# lag_sale_5                               43.187899
# rolling_sale_dayofweek_4_cv              42.874668
# rolling_sale_91_median                   42.290252
# rolling_sale_182_median                  40.825435
# rolling_sale_364_median                  39.282036
# rolling_sale_dayofweek_8_quantile25      39.010406
# rolling_sale_91_quantile25               29.287026
# rolling_sale_dayofweek_52_quantile25     28.846065
# quarter                                  28.603186
# rolling_sale_dayofweek_12_quantile25     28.321198
# cat_id                                   27.073206
# rolling_sale_364_quantile25              24.417662
# rolling_sale_182_quantile25              23.768788
# rolling_sale_dayofweek_24_quantile25     16.055350
# event_type_2                              0.000000
# event_name_2                              0.000000
#
# [89 rows x 1 columns]

# %%
lgb_re2 = lgb.LGBMRegressor(n_estimators=1000, random_state=51,subsample=0.8,
                         colsample_bytree=0.8,learning_rate=0.05 ,importance_type = 'gain',
                 max_depth = -1, num_leaves = 2**8-1,metric='None',bagging_freq=1,n_jobs=12,
                         first_metric_only = True,objective=custom_obj,min_data_in_leaf =  2**8-1,max_bin = 63)

# %%
lgb_re2.fit(X_train,y_train,eval_set = [(X_train,y_train),(X_valid,y_valid)],verbose=1,
           eval_metric =lambda y_true, y_pred: [evaluator_super.feval(y_true, y_pred), rmse(y_true, y_pred)],
           early_stopping_rounds=50,categorical_feature=cat_col)
# Out:
# /opt/conda/lib/python3.7/site-packages/lightgbm/basic.py:1295: UserWarning: categorical_feature in Dataset is overridden.
# New categorical_feature is ['cat_id', 'dept_id', 'event_name_1', 'event_name_2', 'event_type_1', 'event_type_2', 'item_id', 'state_id', 'store_id']
#   'New categorical_feature is {}'.format(sorted(list(categorical_feature))))
# /opt/conda/lib/python3.7/site-packages/lightgbm/basic.py:1295: UserWarning: categorical_feature in Dataset is overridden.
# New categorical_feature is ['cat_id', 'dept_id', 'event_name_1', 'event_name_2', 'event_type_1', 'event_type_2', 'item_id', 'state_id', 'store_id']
#   'New categorical_feature is {}'.format(sorted(list(categorical_feature))))
# [1]	training's WRMSSE: 4.50754	training's RMSE: 3.62865	valid_1's WRMSSE: 4.88574	valid_1's RMSE: 3.63883
# Training until validation scores don't improve for 50 rounds
# [2]	training's WRMSSE: 4.16561	training's RMSE: 3.45067	valid_1's WRMSSE: 4.5155	valid_1's RMSE: 3.44998
# [3]	training's WRMSSE: 3.84857	training's RMSE: 3.28597	valid_1's WRMSSE: 4.17084	valid_1's RMSE: 3.275
# [4]	training's WRMSSE: 3.55624	training's RMSE: 3.13779	valid_1's WRMSSE: 3.85207	valid_1's RMSE: 3.11557
# [5]	training's WRMSSE: 3.28566	training's RMSE: 3.0042	valid_1's WRMSSE: 3.5581	valid_1's RMSE: 2.97403
# [6]	training's WRMSSE: 3.03814	training's RMSE: 2.88619	valid_1's WRMSSE: 3.28833	valid_1's RMSE: 2.8474
# [7]	training's WRMSSE: 2.80873	training's RMSE: 2.7801	valid_1's WRMSSE: 3.03856	valid_1's RMSE: 2.73323
# [8]	training's WRMSSE: 2.59804	training's RMSE: 2.68539	valid_1's WRMSSE: 2.80856	valid_1's RMSE: 2.63228
# [9]	training's WRMSSE: 2.40444	training's RMSE: 2.60038	valid_1's WRMSSE: 2.59652	valid_1's RMSE: 2.54197
# [10]	training's WRMSSE: 2.22665	training's RMSE: 2.52491	valid_1's WRMSSE: 2.40161	valid_1's RMSE: 2.46074
# [11]	training's WRMSSE: 2.06321	training's RMSE: 2.45959	valid_1's WRMSSE: 2.22253	valid_1's RMSE: 2.39046
# [12]	training's WRMSSE: 1.91424	training's RMSE: 2.40177	valid_1's WRMSSE: 2.05819	valid_1's RMSE: 2.3282
# [13]	training's WRMSSE: 1.77796	training's RMSE: 2.34988	valid_1's WRMSSE: 1.90746	valid_1's RMSE: 2.27286
# [14]	training's WRMSSE: 1.65353	training's RMSE: 2.30373	valid_1's WRMSSE: 1.76929	valid_1's RMSE: 2.22383
# [15]	training's WRMSSE: 1.54078	training's RMSE: 2.26412	valid_1's WRMSSE: 1.64298	valid_1's RMSE: 2.18207
# [16]	training's WRMSSE: 1.43733	training's RMSE: 2.22806	valid_1's WRMSSE: 1.52765	valid_1's RMSE: 2.1438
# [17]	training's WRMSSE: 1.3441	training's RMSE: 2.19746	valid_1's WRMSSE: 1.42367	valid_1's RMSE: 2.11166
# [18]	training's WRMSSE: 1.25944	training's RMSE: 2.17054	valid_1's WRMSSE: 1.32785	valid_1's RMSE: 2.08339
# [19]	training's WRMSSE: 1.18316	training's RMSE: 2.14651	valid_1's WRMSSE: 1.24169	valid_1's RMSE: 2.05893
# [20]	training's WRMSSE: 1.11425	training's RMSE: 2.12556	valid_1's WRMSSE: 1.16312	valid_1's RMSE: 2.0374
# [21]	training's WRMSSE: 1.05201	training's RMSE: 2.10833	valid_1's WRMSSE: 1.09299	valid_1's RMSE: 2.0195
# [22]	training's WRMSSE: 0.996105	training's RMSE: 2.09348	valid_1's WRMSSE: 1.02884	valid_1's RMSE: 2.00398
# [23]	training's WRMSSE: 0.946549	training's RMSE: 2.07958	valid_1's WRMSSE: 0.971324	valid_1's RMSE: 1.99062
# [24]	training's WRMSSE: 0.902342	training's RMSE: 2.06751	valid_1's WRMSSE: 0.919897	valid_1's RMSE: 1.97855
# [25]	training's WRMSSE: 0.863813	training's RMSE: 2.05689	valid_1's WRMSSE: 0.874777	valid_1's RMSE: 1.96818
# [26]	training's WRMSSE: 0.829115	training's RMSE: 2.04743	valid_1's WRMSSE: 0.833748	valid_1's RMSE: 1.95918
# [27]	training's WRMSSE: 0.797816	training's RMSE: 2.03953	valid_1's WRMSSE: 0.796904	valid_1's RMSE: 1.95188
# [28]	training's WRMSSE: 0.769876	training's RMSE: 2.03177	valid_1's WRMSSE: 0.764003	valid_1's RMSE: 1.9447
# [29]	training's WRMSSE: 0.745068	training's RMSE: 2.02571	valid_1's WRMSSE: 0.734324	valid_1's RMSE: 1.93889
# [30]	training's WRMSSE: 0.723495	training's RMSE: 2.02027	valid_1's WRMSSE: 0.707629	valid_1's RMSE: 1.93372
# [31]	training's WRMSSE: 0.704163	training's RMSE: 2.01566	valid_1's WRMSSE: 0.685178	valid_1's RMSE: 1.92977
# [32]	training's WRMSSE: 0.688605	training's RMSE: 2.01136	valid_1's WRMSSE: 0.666473	valid_1's RMSE: 1.92599
# [33]	training's WRMSSE: 0.674701	training's RMSE: 2.00759	valid_1's WRMSSE: 0.648817	valid_1's RMSE: 1.92267
# [34]	training's WRMSSE: 0.663526	training's RMSE: 2.00434	valid_1's WRMSSE: 0.635323	valid_1's RMSE: 1.92022
# [35]	training's WRMSSE: 0.653241	training's RMSE: 2.0011	valid_1's WRMSSE: 0.622911	valid_1's RMSE: 1.91793
# [36]	training's WRMSSE: 0.642633	training's RMSE: 1.9986	valid_1's WRMSSE: 0.610771	valid_1's RMSE: 1.91567
# [37]	training's WRMSSE: 0.633968	training's RMSE: 1.99599	valid_1's WRMSSE: 0.600615	valid_1's RMSE: 1.91381
# [38]	training's WRMSSE: 0.626121	training's RMSE: 1.99347	valid_1's WRMSSE: 0.591025	valid_1's RMSE: 1.91166
# [39]	training's WRMSSE: 0.619563	training's RMSE: 1.99166	valid_1's WRMSSE: 0.584097	valid_1's RMSE: 1.91065
# [40]	training's WRMSSE: 0.612831	training's RMSE: 1.98986	valid_1's WRMSSE: 0.57642	valid_1's RMSE: 1.9093
# [41]	training's WRMSSE: 0.607913	training's RMSE: 1.98811	valid_1's WRMSSE: 0.570591	valid_1's RMSE: 1.90828
# [42]	training's WRMSSE: 0.602522	training's RMSE: 1.98654	valid_1's WRMSSE: 0.564471	valid_1's RMSE: 1.90715
# [43]	training's WRMSSE: 0.598603	training's RMSE: 1.98513	valid_1's WRMSSE: 0.560626	valid_1's RMSE: 1.90625
# [44]	training's WRMSSE: 0.593989	training's RMSE: 1.98365	valid_1's WRMSSE: 0.55561	valid_1's RMSE: 1.90491
# [45]	training's WRMSSE: 0.589945	training's RMSE: 1.98245	valid_1's WRMSSE: 0.551369	valid_1's RMSE: 1.90423
# [46]	training's WRMSSE: 0.586429	training's RMSE: 1.98122	valid_1's WRMSSE: 0.547772	valid_1's RMSE: 1.90328
# [47]	training's WRMSSE: 0.582954	training's RMSE: 1.98028	valid_1's WRMSSE: 0.544508	valid_1's RMSE: 1.9025
# [48]	training's WRMSSE: 0.581016	training's RMSE: 1.97965	valid_1's WRMSSE: 0.5423	valid_1's RMSE: 1.90216
# [49]	training's WRMSSE: 0.57878	training's RMSE: 1.97842	valid_1's WRMSSE: 0.539954	valid_1's RMSE: 1.9015
# [50]	training's WRMSSE: 0.575293	training's RMSE: 1.97733	valid_1's WRMSSE: 0.536374	valid_1's RMSE: 1.90087
# [51]	training's WRMSSE: 0.57336	training's RMSE: 1.97607	valid_1's WRMSSE: 0.534911	valid_1's RMSE: 1.90023
# [52]	training's WRMSSE: 0.571202	training's RMSE: 1.97534	valid_1's WRMSSE: 0.533023	valid_1's RMSE: 1.89967
# [53]	training's WRMSSE: 0.569	training's RMSE: 1.97445	valid_1's WRMSSE: 0.530878	valid_1's RMSE: 1.89906
# [54]	training's WRMSSE: 0.567207	training's RMSE: 1.97378	valid_1's WRMSSE: 0.528988	valid_1's RMSE: 1.8987
# [55]	training's WRMSSE: 0.565409	training's RMSE: 1.97293	valid_1's WRMSSE: 0.527384	valid_1's RMSE: 1.89815
# [56]	training's WRMSSE: 0.564174	training's RMSE: 1.97215	valid_1's WRMSSE: 0.52663	valid_1's RMSE: 1.89782
# [57]	training's WRMSSE: 0.56235	training's RMSE: 1.97132	valid_1's WRMSSE: 0.525146	valid_1's RMSE: 1.89757
# [58]	training's WRMSSE: 0.56111	training's RMSE: 1.97082	valid_1's WRMSSE: 0.523894	valid_1's RMSE: 1.89739
# [59]	training's WRMSSE: 0.559764	training's RMSE: 1.97006	valid_1's WRMSSE: 0.523209	valid_1's RMSE: 1.89708
# [60]	training's WRMSSE: 0.558271	training's RMSE: 1.9693	valid_1's WRMSSE: 0.521202	valid_1's RMSE: 1.89633
# [61]	training's WRMSSE: 0.557475	training's RMSE: 1.96861	valid_1's WRMSSE: 0.520716	valid_1's RMSE: 1.8959
# [62]	training's WRMSSE: 0.555981	training's RMSE: 1.96784	valid_1's WRMSSE: 0.51931	valid_1's RMSE: 1.89531
# [63]	training's WRMSSE: 0.553732	training's RMSE: 1.96721	valid_1's WRMSSE: 0.517381	valid_1's RMSE: 1.89501
# [64]	training's WRMSSE: 0.55203	training's RMSE: 1.96657	valid_1's WRMSSE: 0.516708	valid_1's RMSE: 1.89486
# [65]	training's WRMSSE: 0.550357	training's RMSE: 1.96603	valid_1's WRMSSE: 0.515088	valid_1's RMSE: 1.89464
# [66]	training's WRMSSE: 0.549643	training's RMSE: 1.96545	valid_1's WRMSSE: 0.514523	valid_1's RMSE: 1.89445
# [67]	training's WRMSSE: 0.548876	training's RMSE: 1.96504	valid_1's WRMSSE: 0.514001	valid_1's RMSE: 1.89443
# [68]	training's WRMSSE: 0.547847	training's RMSE: 1.96432	valid_1's WRMSSE: 0.512934	valid_1's RMSE: 1.89401
# [69]	training's WRMSSE: 0.547109	training's RMSE: 1.96369	valid_1's WRMSSE: 0.512412	valid_1's RMSE: 1.89366
# [70]	training's WRMSSE: 0.546407	training's RMSE: 1.96318	valid_1's WRMSSE: 0.512127	valid_1's RMSE: 1.8935
# [71]	training's WRMSSE: 0.545697	training's RMSE: 1.9629	valid_1's WRMSSE: 0.511557	valid_1's RMSE: 1.89346
# [72]	training's WRMSSE: 0.544159	training's RMSE: 1.96234	valid_1's WRMSSE: 0.510309	valid_1's RMSE: 1.89316
# [73]	training's WRMSSE: 0.543136	training's RMSE: 1.96191	valid_1's WRMSSE: 0.509979	valid_1's RMSE: 1.89311
# [74]	training's WRMSSE: 0.540946	training's RMSE: 1.96112	valid_1's WRMSSE: 0.508967	valid_1's RMSE: 1.8927
# [75]	training's WRMSSE: 0.540436	training's RMSE: 1.96078	valid_1's WRMSSE: 0.508674	valid_1's RMSE: 1.89257
# [76]	training's WRMSSE: 0.539809	training's RMSE: 1.96043	valid_1's WRMSSE: 0.50854	valid_1's RMSE: 1.89245
# [77]	training's WRMSSE: 0.539349	training's RMSE: 1.96008	valid_1's WRMSSE: 0.50818	valid_1's RMSE: 1.89234
# [78]	training's WRMSSE: 0.538592	training's RMSE: 1.9596	valid_1's WRMSSE: 0.507098	valid_1's RMSE: 1.89189
# [79]	training's WRMSSE: 0.538169	training's RMSE: 1.95909	valid_1's WRMSSE: 0.506524	valid_1's RMSE: 1.89149
# [80]	training's WRMSSE: 0.537757	training's RMSE: 1.95872	valid_1's WRMSSE: 0.506449	valid_1's RMSE: 1.89142
# [81]	training's WRMSSE: 0.537266	training's RMSE: 1.95843	valid_1's WRMSSE: 0.506334	valid_1's RMSE: 1.89133
# [82]	training's WRMSSE: 0.536949	training's RMSE: 1.95803	valid_1's WRMSSE: 0.505909	valid_1's RMSE: 1.89126
# [83]	training's WRMSSE: 0.536417	training's RMSE: 1.95768	valid_1's WRMSSE: 0.505616	valid_1's RMSE: 1.89108
# [84]	training's WRMSSE: 0.535602	training's RMSE: 1.95739	valid_1's WRMSSE: 0.50526	valid_1's RMSE: 1.89095
# [85]	training's WRMSSE: 0.535162	training's RMSE: 1.95713	valid_1's WRMSSE: 0.505285	valid_1's RMSE: 1.89083
# [86]	training's WRMSSE: 0.534784	training's RMSE: 1.95676	valid_1's WRMSSE: 0.505048	valid_1's RMSE: 1.89063
# [87]	training's WRMSSE: 0.534102	training's RMSE: 1.95622	valid_1's WRMSSE: 0.504817	valid_1's RMSE: 1.89032
# [88]	training's WRMSSE: 0.533706	training's RMSE: 1.95584	valid_1's WRMSSE: 0.504484	valid_1's RMSE: 1.89013
# [89]	training's WRMSSE: 0.533446	training's RMSE: 1.9554	valid_1's WRMSSE: 0.504178	valid_1's RMSE: 1.88996
# [90]	training's WRMSSE: 0.533084	training's RMSE: 1.95505	valid_1's WRMSSE: 0.504087	valid_1's RMSE: 1.8898
# [91]	training's WRMSSE: 0.53277	training's RMSE: 1.9547	valid_1's WRMSSE: 0.503953	valid_1's RMSE: 1.88975
# [92]	training's WRMSSE: 0.530044	training's RMSE: 1.95446	valid_1's WRMSSE: 0.502512	valid_1's RMSE: 1.88959
# [93]	training's WRMSSE: 0.529885	training's RMSE: 1.95415	valid_1's WRMSSE: 0.502418	valid_1's RMSE: 1.88953
# [94]	training's WRMSSE: 0.529519	training's RMSE: 1.95362	valid_1's WRMSSE: 0.502393	valid_1's RMSE: 1.88928
# [95]	training's WRMSSE: 0.529198	training's RMSE: 1.95317	valid_1's WRMSSE: 0.502375	valid_1's RMSE: 1.8892
# [96]	training's WRMSSE: 0.528923	training's RMSE: 1.95295	valid_1's WRMSSE: 0.501918	valid_1's RMSE: 1.88904
# [97]	training's WRMSSE: 0.52866	training's RMSE: 1.95265	valid_1's WRMSSE: 0.501802	valid_1's RMSE: 1.88884
# [98]	training's WRMSSE: 0.528589	training's RMSE: 1.95239	valid_1's WRMSSE: 0.501714	valid_1's RMSE: 1.88863
# [99]	training's WRMSSE: 0.52812	training's RMSE: 1.95196	valid_1's WRMSSE: 0.501794	valid_1's RMSE: 1.88853
# [100]	training's WRMSSE: 0.527421	training's RMSE: 1.95178	valid_1's WRMSSE: 0.50124	valid_1's RMSE: 1.88844
# [101]	training's WRMSSE: 0.525466	training's RMSE: 1.95147	valid_1's WRMSSE: 0.500372	valid_1's RMSE: 1.88827
# [102]	training's WRMSSE: 0.525026	training's RMSE: 1.95105	valid_1's WRMSSE: 0.500326	valid_1's RMSE: 1.88815
# [103]	training's WRMSSE: 0.524794	training's RMSE: 1.95075	valid_1's WRMSSE: 0.500184	valid_1's RMSE: 1.88808
# [104]	training's WRMSSE: 0.524266	training's RMSE: 1.9503	valid_1's WRMSSE: 0.499883	valid_1's RMSE: 1.88792
# [105]	training's WRMSSE: 0.523894	training's RMSE: 1.94987	valid_1's WRMSSE: 0.49999	valid_1's RMSE: 1.88772
# [106]	training's WRMSSE: 0.523679	training's RMSE: 1.94944	valid_1's WRMSSE: 0.49981	valid_1's RMSE: 1.8877
# [107]	training's WRMSSE: 0.523279	training's RMSE: 1.94926	valid_1's WRMSSE: 0.499714	valid_1's RMSE: 1.88755
# [108]	training's WRMSSE: 0.523102	training's RMSE: 1.94888	valid_1's WRMSSE: 0.499549	valid_1's RMSE: 1.88721
# [109]	training's WRMSSE: 0.521807	training's RMSE: 1.94857	valid_1's WRMSSE: 0.498965	valid_1's RMSE: 1.88706
# [110]	training's WRMSSE: 0.521533	training's RMSE: 1.94828	valid_1's WRMSSE: 0.498727	valid_1's RMSE: 1.88692
# [111]	training's WRMSSE: 0.521102	training's RMSE: 1.94782	valid_1's WRMSSE: 0.498857	valid_1's RMSE: 1.88666
# [112]	training's WRMSSE: 0.520881	training's RMSE: 1.94758	valid_1's WRMSSE: 0.498651	valid_1's RMSE: 1.88652
# [113]	training's WRMSSE: 0.520599	training's RMSE: 1.94734	valid_1's WRMSSE: 0.498509	valid_1's RMSE: 1.88647
# [114]	training's WRMSSE: 0.520116	training's RMSE: 1.94697	valid_1's WRMSSE: 0.498399	valid_1's RMSE: 1.88627
# [115]	training's WRMSSE: 0.519706	training's RMSE: 1.94647	valid_1's WRMSSE: 0.498256	valid_1's RMSE: 1.88597
# [116]	training's WRMSSE: 0.518594	training's RMSE: 1.94596	valid_1's WRMSSE: 0.49795	valid_1's RMSE: 1.88577
# [117]	training's WRMSSE: 0.517542	training's RMSE: 1.9455	valid_1's WRMSSE: 0.497575	valid_1's RMSE: 1.88559
# [118]	training's WRMSSE: 0.517362	training's RMSE: 1.94521	valid_1's WRMSSE: 0.497493	valid_1's RMSE: 1.88554
# [119]	training's WRMSSE: 0.517193	training's RMSE: 1.94481	valid_1's WRMSSE: 0.497259	valid_1's RMSE: 1.88528
# [120]	training's WRMSSE: 0.515796	training's RMSE: 1.94441	valid_1's WRMSSE: 0.495683	valid_1's RMSE: 1.8849
# [121]	training's WRMSSE: 0.51555	training's RMSE: 1.94413	valid_1's WRMSSE: 0.495622	valid_1's RMSE: 1.88483
# [122]	training's WRMSSE: 0.51526	training's RMSE: 1.9439	valid_1's WRMSSE: 0.495113	valid_1's RMSE: 1.88464
# [123]	training's WRMSSE: 0.514772	training's RMSE: 1.94356	valid_1's WRMSSE: 0.495079	valid_1's RMSE: 1.88457
# [124]	training's WRMSSE: 0.514459	training's RMSE: 1.94322	valid_1's WRMSSE: 0.494886	valid_1's RMSE: 1.88438
# [125]	training's WRMSSE: 0.514299	training's RMSE: 1.9429	valid_1's WRMSSE: 0.494786	valid_1's RMSE: 1.88432
# [126]	training's WRMSSE: 0.513949	training's RMSE: 1.94246	valid_1's WRMSSE: 0.494488	valid_1's RMSE: 1.88405
# [127]	training's WRMSSE: 0.513778	training's RMSE: 1.94208	valid_1's WRMSSE: 0.49434	valid_1's RMSE: 1.88391
# [128]	training's WRMSSE: 0.513637	training's RMSE: 1.94186	valid_1's WRMSSE: 0.494376	valid_1's RMSE: 1.88384
# [129]	training's WRMSSE: 0.513402	training's RMSE: 1.94163	valid_1's WRMSSE: 0.494326	valid_1's RMSE: 1.88363
# [130]	training's WRMSSE: 0.512142	training's RMSE: 1.94117	valid_1's WRMSSE: 0.493741	valid_1's RMSE: 1.88338
# [131]	training's WRMSSE: 0.511928	training's RMSE: 1.94085	valid_1's WRMSSE: 0.493645	valid_1's RMSE: 1.88329
# [132]	training's WRMSSE: 0.511418	training's RMSE: 1.94061	valid_1's WRMSSE: 0.493343	valid_1's RMSE: 1.88303
# [133]	training's WRMSSE: 0.510965	training's RMSE: 1.94023	valid_1's WRMSSE: 0.493021	valid_1's RMSE: 1.88286
# [134]	training's WRMSSE: 0.510638	training's RMSE: 1.93994	valid_1's WRMSSE: 0.492899	valid_1's RMSE: 1.88271
# [135]	training's WRMSSE: 0.510268	training's RMSE: 1.93958	valid_1's WRMSSE: 0.49261	valid_1's RMSE: 1.88256
# [136]	training's WRMSSE: 0.510197	training's RMSE: 1.93932	valid_1's WRMSSE: 0.49266	valid_1's RMSE: 1.88245
# [137]	training's WRMSSE: 0.510101	training's RMSE: 1.93894	valid_1's WRMSSE: 0.492666	valid_1's RMSE: 1.88236
# [138]	training's WRMSSE: 0.509968	training's RMSE: 1.93872	valid_1's WRMSSE: 0.49266	valid_1's RMSE: 1.88231
# [139]	training's WRMSSE: 0.509824	training's RMSE: 1.93853	valid_1's WRMSSE: 0.49259	valid_1's RMSE: 1.88231
# [140]	training's WRMSSE: 0.508896	training's RMSE: 1.93826	valid_1's WRMSSE: 0.492372	valid_1's RMSE: 1.88218
# [141]	training's WRMSSE: 0.508767	training's RMSE: 1.93808	valid_1's WRMSSE: 0.492304	valid_1's RMSE: 1.88214
# [142]	training's WRMSSE: 0.50856	training's RMSE: 1.93765	valid_1's WRMSSE: 0.492135	valid_1's RMSE: 1.88202
# [143]	training's WRMSSE: 0.508319	training's RMSE: 1.93742	valid_1's WRMSSE: 0.491961	valid_1's RMSE: 1.88195
# [144]	training's WRMSSE: 0.50786	training's RMSE: 1.93713	valid_1's WRMSSE: 0.491584	valid_1's RMSE: 1.88172
# [145]	training's WRMSSE: 0.507791	training's RMSE: 1.93691	valid_1's WRMSSE: 0.491543	valid_1's RMSE: 1.8817
# [146]	training's WRMSSE: 0.507601	training's RMSE: 1.93664	valid_1's WRMSSE: 0.491556	valid_1's RMSE: 1.88175
# [147]	training's WRMSSE: 0.507464	training's RMSE: 1.93653	valid_1's WRMSSE: 0.491478	valid_1's RMSE: 1.88172
# [148]	training's WRMSSE: 0.507194	training's RMSE: 1.93616	valid_1's WRMSSE: 0.491245	valid_1's RMSE: 1.88156
# [149]	training's WRMSSE: 0.506886	training's RMSE: 1.93593	valid_1's WRMSSE: 0.49113	valid_1's RMSE: 1.8815
# [150]	training's WRMSSE: 0.506803	training's RMSE: 1.93576	valid_1's WRMSSE: 0.491118	valid_1's RMSE: 1.88144
# [151]	training's WRMSSE: 0.506224	training's RMSE: 1.93562	valid_1's WRMSSE: 0.49068	valid_1's RMSE: 1.88134
# [152]	training's WRMSSE: 0.506095	training's RMSE: 1.93545	valid_1's WRMSSE: 0.490663	valid_1's RMSE: 1.88124
# [153]	training's WRMSSE: 0.505975	training's RMSE: 1.93516	valid_1's WRMSSE: 0.490715	valid_1's RMSE: 1.88117
# [154]	training's WRMSSE: 0.505908	training's RMSE: 1.93499	valid_1's WRMSSE: 0.490749	valid_1's RMSE: 1.8811
# [155]	training's WRMSSE: 0.505786	training's RMSE: 1.93485	valid_1's WRMSSE: 0.490733	valid_1's RMSE: 1.88104
# [156]	training's WRMSSE: 0.504843	training's RMSE: 1.93462	valid_1's WRMSSE: 0.490348	valid_1's RMSE: 1.88093
# [157]	training's WRMSSE: 0.504734	training's RMSE: 1.93435	valid_1's WRMSSE: 0.490296	valid_1's RMSE: 1.88084
# [158]	training's WRMSSE: 0.504618	training's RMSE: 1.93405	valid_1's WRMSSE: 0.49022	valid_1's RMSE: 1.88076
# [159]	training's WRMSSE: 0.504308	training's RMSE: 1.93382	valid_1's WRMSSE: 0.490108	valid_1's RMSE: 1.8807
# [160]	training's WRMSSE: 0.50421	training's RMSE: 1.93363	valid_1's WRMSSE: 0.490131	valid_1's RMSE: 1.88056
# [161]	training's WRMSSE: 0.504075	training's RMSE: 1.93333	valid_1's WRMSSE: 0.490177	valid_1's RMSE: 1.88047
# [162]	training's WRMSSE: 0.503819	training's RMSE: 1.93317	valid_1's WRMSSE: 0.490211	valid_1's RMSE: 1.88047
# [163]	training's WRMSSE: 0.50357	training's RMSE: 1.93302	valid_1's WRMSSE: 0.490132	valid_1's RMSE: 1.88042
# [164]	training's WRMSSE: 0.50343	training's RMSE: 1.93275	valid_1's WRMSSE: 0.490094	valid_1's RMSE: 1.8804
# [165]	training's WRMSSE: 0.503115	training's RMSE: 1.93249	valid_1's WRMSSE: 0.490216	valid_1's RMSE: 1.88042
# [166]	training's WRMSSE: 0.503019	training's RMSE: 1.93228	valid_1's WRMSSE: 0.490182	valid_1's RMSE: 1.88036
# [167]	training's WRMSSE: 0.502563	training's RMSE: 1.9322	valid_1's WRMSSE: 0.490022	valid_1's RMSE: 1.88033
# [168]	training's WRMSSE: 0.502463	training's RMSE: 1.93206	valid_1's WRMSSE: 0.490018	valid_1's RMSE: 1.88036
# [169]	training's WRMSSE: 0.502269	training's RMSE: 1.93178	valid_1's WRMSSE: 0.489982	valid_1's RMSE: 1.88018
# [170]	training's WRMSSE: 0.502179	training's RMSE: 1.93168	valid_1's WRMSSE: 0.489894	valid_1's RMSE: 1.88015
# [171]	training's WRMSSE: 0.502112	training's RMSE: 1.93144	valid_1's WRMSSE: 0.489915	valid_1's RMSE: 1.88002
# [172]	training's WRMSSE: 0.502045	training's RMSE: 1.93132	valid_1's WRMSSE: 0.489919	valid_1's RMSE: 1.88001
# [173]	training's WRMSSE: 0.501948	training's RMSE: 1.93095	valid_1's WRMSSE: 0.489874	valid_1's RMSE: 1.87987
# [174]	training's WRMSSE: 0.50188	training's RMSE: 1.93071	valid_1's WRMSSE: 0.489989	valid_1's RMSE: 1.87974
# [175]	training's WRMSSE: 0.501537	training's RMSE: 1.93039	valid_1's WRMSSE: 0.489975	valid_1's RMSE: 1.8796
# [176]	training's WRMSSE: 0.501444	training's RMSE: 1.9303	valid_1's WRMSSE: 0.489903	valid_1's RMSE: 1.87957
# [177]	training's WRMSSE: 0.501368	training's RMSE: 1.93012	valid_1's WRMSSE: 0.489927	valid_1's RMSE: 1.87944
# [178]	training's WRMSSE: 0.498556	training's RMSE: 1.92981	valid_1's WRMSSE: 0.489418	valid_1's RMSE: 1.87938
# [179]	training's WRMSSE: 0.498383	training's RMSE: 1.92958	valid_1's WRMSSE: 0.48939	valid_1's RMSE: 1.87935
# [180]	training's WRMSSE: 0.498302	training's RMSE: 1.92936	valid_1's WRMSSE: 0.489366	valid_1's RMSE: 1.8793
# [181]	training's WRMSSE: 0.497605	training's RMSE: 1.92902	valid_1's WRMSSE: 0.489195	valid_1's RMSE: 1.87918
# [182]	training's WRMSSE: 0.497498	training's RMSE: 1.92878	valid_1's WRMSSE: 0.489205	valid_1's RMSE: 1.87913
# [183]	training's WRMSSE: 0.49724	training's RMSE: 1.92865	valid_1's WRMSSE: 0.488857	valid_1's RMSE: 1.87901
# [184]	training's WRMSSE: 0.496994	training's RMSE: 1.92844	valid_1's WRMSSE: 0.488768	valid_1's RMSE: 1.87896
# [185]	training's WRMSSE: 0.496828	training's RMSE: 1.92815	valid_1's WRMSSE: 0.488726	valid_1's RMSE: 1.87886
# [186]	training's WRMSSE: 0.496739	training's RMSE: 1.92802	valid_1's WRMSSE: 0.488717	valid_1's RMSE: 1.87884
# [187]	training's WRMSSE: 0.496602	training's RMSE: 1.92771	valid_1's WRMSSE: 0.488591	valid_1's RMSE: 1.87883
# [188]	training's WRMSSE: 0.496486	training's RMSE: 1.92761	valid_1's WRMSSE: 0.48852	valid_1's RMSE: 1.87879
# [189]	training's WRMSSE: 0.496399	training's RMSE: 1.92735	valid_1's WRMSSE: 0.488479	valid_1's RMSE: 1.87866
# [190]	training's WRMSSE: 0.496086	training's RMSE: 1.92725	valid_1's WRMSSE: 0.488216	valid_1's RMSE: 1.87862
# [191]	training's WRMSSE: 0.495916	training's RMSE: 1.92714	valid_1's WRMSSE: 0.488145	valid_1's RMSE: 1.87864
# [192]	training's WRMSSE: 0.495832	training's RMSE: 1.92708	valid_1's WRMSSE: 0.488106	valid_1's RMSE: 1.87863
# [193]	training's WRMSSE: 0.495752	training's RMSE: 1.9268	valid_1's WRMSSE: 0.48801	valid_1's RMSE: 1.87855
# [194]	training's WRMSSE: 0.495683	training's RMSE: 1.92663	valid_1's WRMSSE: 0.487973	valid_1's RMSE: 1.87856
# [195]	training's WRMSSE: 0.495642	training's RMSE: 1.92646	valid_1's WRMSSE: 0.487973	valid_1's RMSE: 1.8785
# [196]	training's WRMSSE: 0.495561	training's RMSE: 1.92629	valid_1's WRMSSE: 0.488004	valid_1's RMSE: 1.87848
# [197]	training's WRMSSE: 0.495455	training's RMSE: 1.92617	valid_1's WRMSSE: 0.488	valid_1's RMSE: 1.87845
# [198]	training's WRMSSE: 0.495405	training's RMSE: 1.92609	valid_1's WRMSSE: 0.487932	valid_1's RMSE: 1.87845
# [199]	training's WRMSSE: 0.49528	training's RMSE: 1.92588	valid_1's WRMSSE: 0.487973	valid_1's RMSE: 1.87843
# [200]	training's WRMSSE: 0.495118	training's RMSE: 1.92575	valid_1's WRMSSE: 0.487932	valid_1's RMSE: 1.87842
# [201]	training's WRMSSE: 0.49503	training's RMSE: 1.9255	valid_1's WRMSSE: 0.487985	valid_1's RMSE: 1.87836
# [202]	training's WRMSSE: 0.494927	training's RMSE: 1.92534	valid_1's WRMSSE: 0.487981	valid_1's RMSE: 1.8783
# [203]	training's WRMSSE: 0.494858	training's RMSE: 1.92519	valid_1's WRMSSE: 0.48798	valid_1's RMSE: 1.87828
# [204]	training's WRMSSE: 0.494701	training's RMSE: 1.92495	valid_1's WRMSSE: 0.488006	valid_1's RMSE: 1.87827
# [205]	training's WRMSSE: 0.494638	training's RMSE: 1.9248	valid_1's WRMSSE: 0.487998	valid_1's RMSE: 1.87823
# [206]	training's WRMSSE: 0.494572	training's RMSE: 1.92453	valid_1's WRMSSE: 0.488014	valid_1's RMSE: 1.87817
# [207]	training's WRMSSE: 0.494505	training's RMSE: 1.92433	valid_1's WRMSSE: 0.488074	valid_1's RMSE: 1.87809
# [208]	training's WRMSSE: 0.494446	training's RMSE: 1.92421	valid_1's WRMSSE: 0.488064	valid_1's RMSE: 1.87812
# [209]	training's WRMSSE: 0.494218	training's RMSE: 1.92464	valid_1's WRMSSE: 0.488138	valid_1's RMSE: 1.87839
# [210]	training's WRMSSE: 0.814485	training's RMSE: 2.05319	valid_1's WRMSSE: 0.487894	valid_1's RMSE: 1.87832
# [211]	training's WRMSSE: 0.779148	training's RMSE: 2.03572	valid_1's WRMSSE: 0.48784	valid_1's RMSE: 1.87829
# [212]	training's WRMSSE: 2.70364	training's RMSE: 5.10657	valid_1's WRMSSE: 2.77585	valid_1's RMSE: 5.40272
# [213]	training's WRMSSE: 2.58105	training's RMSE: 4.93571	valid_1's WRMSSE: 2.65466	valid_1's RMSE: 5.2142
# [214]	training's WRMSSE: 1169.22	training's RMSE: 810.361	valid_1's WRMSSE: 1115.47	valid_1's RMSE: 813.571
# [215]	training's WRMSSE: 359144	training's RMSE: 123116	valid_1's WRMSSE: 370247	valid_1's RMSE: 125018
# /opt/conda/lib/python3.7/site-packages/ipykernel_launcher.py:18: RuntimeWarning: overflow encountered in square
# /opt/conda/lib/python3.7/site-packages/ipykernel_launcher.py:19: RuntimeWarning: invalid value encountered in multiply
# /opt/conda/lib/python3.7/site-packages/ipykernel_launcher.py:2: RuntimeWarning: overflow encountered in power
# [216]	training's WRMSSE: nan	training's RMSE: inf	valid_1's WRMSSE: inf	valid_1's RMSE: inf
# [217]	training's WRMSSE: nan	training's RMSE: inf	valid_1's WRMSSE: nan	valid_1's RMSE: inf
# [218]	training's WRMSSE: nan	training's RMSE: inf	valid_1's WRMSSE: nan	valid_1's RMSE: inf
# [219]	training's WRMSSE: nan	training's RMSE: inf	valid_1's WRMSSE: nan	valid_1's RMSE: inf
# [220]	training's WRMSSE: nan	training's RMSE: inf	valid_1's WRMSSE: nan	valid_1's RMSE: inf
# [221]	training's WRMSSE: nan	training's RMSE: inf	valid_1's WRMSSE: nan	valid_1's RMSE: inf
# [222]	training's WRMSSE: nan	training's RMSE: inf	valid_1's WRMSSE: nan	valid_1's RMSE: inf
# [223]	training's WRMSSE: nan	training's RMSE: inf	valid_1's WRMSSE: nan	valid_1's RMSE: inf
# [224]	training's WRMSSE: nan	training's RMSE: inf	valid_1's WRMSSE: nan	valid_1's RMSE: inf
# [225]	training's WRMSSE: nan	training's RMSE: inf	valid_1's WRMSSE: nan	valid_1's RMSE: inf
# [226]	training's WRMSSE: nan	training's RMSE: inf	valid_1's WRMSSE: nan	valid_1's RMSE: inf
# [227]	training's WRMSSE: nan	training's RMSE: inf	valid_1's WRMSSE: nan	valid_1's RMSE: inf
# [228]	training's WRMSSE: nan	training's RMSE: inf	valid_1's WRMSSE: nan	valid_1's RMSE: inf
# [229]	training's WRMSSE: nan	training's RMSE: inf	valid_1's WRMSSE: nan	valid_1's RMSE: inf
# [230]	training's WRMSSE: nan	training's RMSE: inf	valid_1's WRMSSE: nan	valid_1's RMSE: inf
# [231]	training's WRMSSE: nan	training's RMSE: inf	valid_1's WRMSSE: nan	valid_1's RMSE: inf
# [232]	training's WRMSSE: nan	training's RMSE: inf	valid_1's WRMSSE: nan	valid_1's RMSE: inf
# [233]	training's WRMSSE: nan	training's RMSE: inf	valid_1's WRMSSE: nan	valid_1's RMSE: inf
# [234]	training's WRMSSE: nan	training's RMSE: inf	valid_1's WRMSSE: nan	valid_1's RMSE: inf
# [235]	training's WRMSSE: nan	training's RMSE: inf	valid_1's WRMSSE: nan	valid_1's RMSE: inf
# [236]	training's WRMSSE: nan	training's RMSE: inf	valid_1's WRMSSE: nan	valid_1's RMSE: inf
# [237]	training's WRMSSE: nan	training's RMSE: inf	valid_1's WRMSSE: nan	valid_1's RMSE: inf
# [238]	training's WRMSSE: nan	training's RMSE: inf	valid_1's WRMSSE: nan	valid_1's RMSE: inf
# [239]	training's WRMSSE: nan	training's RMSE: inf	valid_1's WRMSSE: nan	valid_1's RMSE: inf
# [240]	training's WRMSSE: nan	training's RMSE: inf	valid_1's WRMSSE: nan	valid_1's RMSE: inf
# [241]	training's WRMSSE: nan	training's RMSE: inf	valid_1's WRMSSE: nan	valid_1's RMSE: inf
# [242]	training's WRMSSE: nan	training's RMSE: inf	valid_1's WRMSSE: nan	valid_1's RMSE: inf
# [243]	training's WRMSSE: nan	training's RMSE: inf	valid_1's WRMSSE: nan	valid_1's RMSE: inf
# [244]	training's WRMSSE: nan	training's RMSE: inf	valid_1's WRMSSE: nan	valid_1's RMSE: inf
# [245]	training's WRMSSE: nan	training's RMSE: inf	valid_1's WRMSSE: nan	valid_1's RMSE: inf
# [246]	training's WRMSSE: nan	training's RMSE: inf	valid_1's WRMSSE: nan	valid_1's RMSE: inf
# [247]	training's WRMSSE: nan	training's RMSE: inf	valid_1's WRMSSE: nan	valid_1's RMSE: inf
# [248]	training's WRMSSE: nan	training's RMSE: inf	valid_1's WRMSSE: nan	valid_1's RMSE: inf
# [249]	training's WRMSSE: nan	training's RMSE: inf	valid_1's WRMSSE: nan	valid_1's RMSE: inf
# [250]	training's WRMSSE: nan	training's RMSE: inf	valid_1's WRMSSE: nan	valid_1's RMSE: inf
# [251]	training's WRMSSE: nan	training's RMSE: inf	valid_1's WRMSSE: nan	valid_1's RMSE: inf
# [252]	training's WRMSSE: nan	training's RMSE: inf	valid_1's WRMSSE: nan	valid_1's RMSE: inf
# [253]	training's WRMSSE: nan	training's RMSE: inf	valid_1's WRMSSE: nan	valid_1's RMSE: inf
# [254]	training's WRMSSE: nan	training's RMSE: inf	valid_1's WRMSSE: nan	valid_1's RMSE: inf
# [255]	training's WRMSSE: nan	training's RMSE: inf	valid_1's WRMSSE: nan	valid_1's RMSE: inf
# [256]	training's WRMSSE: nan	training's RMSE: inf	valid_1's WRMSSE: nan	valid_1's RMSE: inf
# [257]	training's WRMSSE: nan	training's RMSE: inf	valid_1's WRMSSE: nan	valid_1's RMSE: inf
# [258]	training's WRMSSE: nan	training's RMSE: inf	valid_1's WRMSSE: nan	valid_1's RMSE: inf
# [259]	training's WRMSSE: nan	training's RMSE: inf	valid_1's WRMSSE: nan	valid_1's RMSE: inf
# [260]	training's WRMSSE: nan	training's RMSE: inf	valid_1's WRMSSE: nan	valid_1's RMSE: inf
# [261]	training's WRMSSE: nan	training's RMSE: inf	valid_1's WRMSSE: nan	valid_1's RMSE: inf
# Early stopping, best iteration is:
# [211]	training's WRMSSE: 0.779148	training's RMSE: 2.03572	valid_1's WRMSSE: 0.48784	valid_1's RMSE: 1.87829
# Evaluated only: WRMSSE
# LGBMRegressor(bagging_freq=1, boosting_type='gbdt', class_weight=None,
#        colsample_bytree=0.8, first_metric_only=True,
#        importance_type='gain', learning_rate=0.05, max_bin=63,
#        max_depth=-1, metric='None', min_child_samples=20,
#        min_child_weight=0.001, min_data_in_leaf=255, min_split_gain=0.0,
#        n_estimators=1000, n_jobs=12, num_leaves=255,
#        objective=<function custom_obj at 0x7fc7c69ffe18>, random_state=51,
#        reg_alpha=0.0, reg_lambda=0.0, silent=True, subsample=0.8,
#        subsample_for_bin=200000, subsample_freq=0)

# %%
lgb_re2 = lgb.LGBMRegressor(n_estimators=5000, random_state=51,subsample=0.8,
                         colsample_bytree=0.8,learning_rate=0.01 ,importance_type = 'gain',
                 max_depth = -1, num_leaves = 2**8-1,metric='None',bagging_freq=1,n_jobs=12,
                         first_metric_only = True,objective=custom_obj,min_data_in_leaf =  2**8-1,max_bin = 63)

# %%
lgb_re2.fit(X_train,y_train,eval_set = [(X_train,y_train),(X_valid,y_valid)],verbose=1,
           eval_metric =lambda y_true, y_pred: [evaluator_super.feval(y_true, y_pred), rmse(y_true, y_pred)],
           early_stopping_rounds=50,categorical_feature=cat_col)
# Out:
# /opt/conda/lib/python3.7/site-packages/lightgbm/basic.py:1295: UserWarning: categorical_feature in Dataset is overridden.
# New categorical_feature is ['cat_id', 'dept_id', 'event_name_1', 'event_name_2', 'event_type_1', 'event_type_2', 'item_id', 'state_id', 'store_id']
#   'New categorical_feature is {}'.format(sorted(list(categorical_feature))))
# /opt/conda/lib/python3.7/site-packages/lightgbm/basic.py:1295: UserWarning: categorical_feature in Dataset is overridden.
# New categorical_feature is ['cat_id', 'dept_id', 'event_name_1', 'event_name_2', 'event_type_1', 'event_type_2', 'item_id', 'state_id', 'store_id']
#   'New categorical_feature is {}'.format(sorted(list(categorical_feature))))
# [1]	training's WRMSSE: 4.80529	training's RMSE: 3.7891	valid_1's WRMSSE: 5.20822	valid_1's RMSE: 3.80853
# Training until validation scores don't improve for 50 rounds
# [2]	training's WRMSSE: 4.73251	training's RMSE: 3.74985	valid_1's WRMSSE: 5.12926	valid_1's RMSE: 3.76659
# [3]	training's WRMSSE: 4.66045	training's RMSE: 3.7108	valid_1's WRMSSE: 5.05099	valid_1's RMSE: 3.72499
# [4]	training's WRMSSE: 4.5896	training's RMSE: 3.67249	valid_1's WRMSSE: 4.97407	valid_1's RMSE: 3.68474
# [5]	training's WRMSSE: 4.5196	training's RMSE: 3.63486	valid_1's WRMSSE: 4.89821	valid_1's RMSE: 3.64501
# [6]	training's WRMSSE: 4.45112	training's RMSE: 3.59846	valid_1's WRMSSE: 4.82398	valid_1's RMSE: 3.60659
# [7]	training's WRMSSE: 4.38331	training's RMSE: 3.56233	valid_1's WRMSSE: 4.75048	valid_1's RMSE: 3.56821
# [8]	training's WRMSSE: 4.31668	training's RMSE: 3.52697	valid_1's WRMSSE: 4.67819	valid_1's RMSE: 3.53072
# [9]	training's WRMSSE: 4.25096	training's RMSE: 3.49207	valid_1's WRMSSE: 4.60695	valid_1's RMSE: 3.4937
# [10]	training's WRMSSE: 4.18624	training's RMSE: 3.45811	valid_1's WRMSSE: 4.53677	valid_1's RMSE: 3.45746
# [11]	training's WRMSSE: 4.12246	training's RMSE: 3.42499	valid_1's WRMSSE: 4.46765	valid_1's RMSE: 3.4223
# [12]	training's WRMSSE: 4.05972	training's RMSE: 3.39251	valid_1's WRMSSE: 4.39978	valid_1's RMSE: 3.38791
# [13]	training's WRMSSE: 3.99791	training's RMSE: 3.3604	valid_1's WRMSSE: 4.33284	valid_1's RMSE: 3.35404
# [14]	training's WRMSSE: 3.93714	training's RMSE: 3.32891	valid_1's WRMSSE: 4.26658	valid_1's RMSE: 3.32013
# [15]	training's WRMSSE: 3.87755	training's RMSE: 3.29829	valid_1's WRMSSE: 4.20184	valid_1's RMSE: 3.28804
# [16]	training's WRMSSE: 3.81855	training's RMSE: 3.26785	valid_1's WRMSSE: 4.13774	valid_1's RMSE: 3.25573
# [17]	training's WRMSSE: 3.76051	training's RMSE: 3.23834	valid_1's WRMSSE: 4.07465	valid_1's RMSE: 3.22403
# [18]	training's WRMSSE: 3.70319	training's RMSE: 3.20934	valid_1's WRMSSE: 4.01242	valid_1's RMSE: 3.19289
# [19]	training's WRMSSE: 3.6469	training's RMSE: 3.18083	valid_1's WRMSSE: 3.95105	valid_1's RMSE: 3.16224
# [20]	training's WRMSSE: 3.59144	training's RMSE: 3.15298	valid_1's WRMSSE: 3.89075	valid_1's RMSE: 3.1324
# [21]	training's WRMSSE: 3.53693	training's RMSE: 3.12587	valid_1's WRMSSE: 3.83141	valid_1's RMSE: 3.10323
# [22]	training's WRMSSE: 3.48326	training's RMSE: 3.09925	valid_1's WRMSSE: 3.77292	valid_1's RMSE: 3.07462
# [23]	training's WRMSSE: 3.43054	training's RMSE: 3.0734	valid_1's WRMSSE: 3.7156	valid_1's RMSE: 3.04717
# [24]	training's WRMSSE: 3.37882	training's RMSE: 3.04805	valid_1's WRMSSE: 3.65938	valid_1's RMSE: 3.02025
# [25]	training's WRMSSE: 3.3276	training's RMSE: 3.02282	valid_1's WRMSSE: 3.6035	valid_1's RMSE: 2.99316
# [26]	training's WRMSSE: 3.27727	training's RMSE: 2.9983	valid_1's WRMSSE: 3.54881	valid_1's RMSE: 2.96705
# [27]	training's WRMSSE: 3.22766	training's RMSE: 2.97415	valid_1's WRMSSE: 3.49477	valid_1's RMSE: 2.94137
# [28]	training's WRMSSE: 3.17904	training's RMSE: 2.95065	valid_1's WRMSSE: 3.44171	valid_1's RMSE: 2.91638
# [29]	training's WRMSSE: 3.13083	training's RMSE: 2.92759	valid_1's WRMSSE: 3.38909	valid_1's RMSE: 2.89166
# [30]	training's WRMSSE: 3.08345	training's RMSE: 2.90501	valid_1's WRMSSE: 3.33736	valid_1's RMSE: 2.86756
# [31]	training's WRMSSE: 3.03688	training's RMSE: 2.8831	valid_1's WRMSSE: 3.28664	valid_1's RMSE: 2.84425
# [32]	training's WRMSSE: 2.99122	training's RMSE: 2.8616	valid_1's WRMSSE: 3.23691	valid_1's RMSE: 2.82131
# [33]	training's WRMSSE: 2.94616	training's RMSE: 2.84034	valid_1's WRMSSE: 3.18779	valid_1's RMSE: 2.79867
# [34]	training's WRMSSE: 2.90174	training's RMSE: 2.81964	valid_1's WRMSSE: 3.13941	valid_1's RMSE: 2.7766
# [35]	training's WRMSSE: 2.85815	training's RMSE: 2.7992	valid_1's WRMSSE: 3.09178	valid_1's RMSE: 2.7548
# [36]	training's WRMSSE: 2.81516	training's RMSE: 2.7794	valid_1's WRMSSE: 3.04487	valid_1's RMSE: 2.73369
# [37]	training's WRMSSE: 2.77297	training's RMSE: 2.76001	valid_1's WRMSSE: 2.99876	valid_1's RMSE: 2.71304
# [38]	training's WRMSSE: 2.73136	training's RMSE: 2.74107	valid_1's WRMSSE: 2.95332	valid_1's RMSE: 2.69279
# [39]	training's WRMSSE: 2.69042	training's RMSE: 2.72256	valid_1's WRMSSE: 2.90863	valid_1's RMSE: 2.67304
# [40]	training's WRMSSE: 2.65009	training's RMSE: 2.7043	valid_1's WRMSSE: 2.86455	valid_1's RMSE: 2.65341
# [41]	training's WRMSSE: 2.61046	training's RMSE: 2.68668	valid_1's WRMSSE: 2.82126	valid_1's RMSE: 2.63464
# [42]	training's WRMSSE: 2.5716	training's RMSE: 2.66948	valid_1's WRMSSE: 2.77869	valid_1's RMSE: 2.61632
# [43]	training's WRMSSE: 2.53332	training's RMSE: 2.65254	valid_1's WRMSSE: 2.73676	valid_1's RMSE: 2.59811
# [44]	training's WRMSSE: 2.49557	training's RMSE: 2.6361	valid_1's WRMSSE: 2.69547	valid_1's RMSE: 2.58048
# [45]	training's WRMSSE: 2.45853	training's RMSE: 2.61988	valid_1's WRMSSE: 2.65486	valid_1's RMSE: 2.56307
# [46]	training's WRMSSE: 2.42195	training's RMSE: 2.60411	valid_1's WRMSSE: 2.61476	valid_1's RMSE: 2.54605
# [47]	training's WRMSSE: 2.38607	training's RMSE: 2.58876	valid_1's WRMSSE: 2.57543	valid_1's RMSE: 2.52965
# [48]	training's WRMSSE: 2.35076	training's RMSE: 2.5736	valid_1's WRMSSE: 2.53675	valid_1's RMSE: 2.51342
# [49]	training's WRMSSE: 2.31609	training's RMSE: 2.55894	valid_1's WRMSSE: 2.49867	valid_1's RMSE: 2.49777
# [50]	training's WRMSSE: 2.282	training's RMSE: 2.54454	valid_1's WRMSSE: 2.46121	valid_1's RMSE: 2.48234
# [51]	training's WRMSSE: 2.24838	training's RMSE: 2.53028	valid_1's WRMSSE: 2.42428	valid_1's RMSE: 2.46709
# [52]	training's WRMSSE: 2.21538	training's RMSE: 2.51661	valid_1's WRMSSE: 2.38807	valid_1's RMSE: 2.45242
# [53]	training's WRMSSE: 2.1829	training's RMSE: 2.50321	valid_1's WRMSSE: 2.35236	valid_1's RMSE: 2.43804
# [54]	training's WRMSSE: 2.15095	training's RMSE: 2.48995	valid_1's WRMSSE: 2.31737	valid_1's RMSE: 2.42405
# [55]	training's WRMSSE: 2.11961	training's RMSE: 2.47712	valid_1's WRMSSE: 2.28287	valid_1's RMSE: 2.41027
# [56]	training's WRMSSE: 2.08878	training's RMSE: 2.46455	valid_1's WRMSSE: 2.24883	valid_1's RMSE: 2.39676
# [57]	training's WRMSSE: 2.05843	training's RMSE: 2.45227	valid_1's WRMSSE: 2.21548	valid_1's RMSE: 2.38386
# [58]	training's WRMSSE: 2.02861	training's RMSE: 2.44023	valid_1's WRMSSE: 2.18262	valid_1's RMSE: 2.371
# [59]	training's WRMSSE: 1.99915	training's RMSE: 2.42866	valid_1's WRMSSE: 2.15012	valid_1's RMSE: 2.35844
# [60]	training's WRMSSE: 1.97044	training's RMSE: 2.41733	valid_1's WRMSSE: 2.11849	valid_1's RMSE: 2.34639
# [61]	training's WRMSSE: 1.94215	training's RMSE: 2.40604	valid_1's WRMSSE: 2.08724	valid_1's RMSE: 2.33438
# [62]	training's WRMSSE: 1.91439	training's RMSE: 2.3953	valid_1's WRMSSE: 2.05647	valid_1's RMSE: 2.32292
# [63]	training's WRMSSE: 1.88715	training's RMSE: 2.38474	valid_1's WRMSSE: 2.02637	valid_1's RMSE: 2.31171
# [64]	training's WRMSSE: 1.86026	training's RMSE: 2.37448	valid_1's WRMSSE: 1.99667	valid_1's RMSE: 2.30071
# [65]	training's WRMSSE: 1.83395	training's RMSE: 2.3645	valid_1's WRMSSE: 1.96756	valid_1's RMSE: 2.2901
# [66]	training's WRMSSE: 1.80801	training's RMSE: 2.35463	valid_1's WRMSSE: 1.93885	valid_1's RMSE: 2.27957
# [67]	training's WRMSSE: 1.78253	training's RMSE: 2.34501	valid_1's WRMSSE: 1.9107	valid_1's RMSE: 2.26931
# [68]	training's WRMSSE: 1.75751	training's RMSE: 2.33581	valid_1's WRMSSE: 1.88309	valid_1's RMSE: 2.25955
# [69]	training's WRMSSE: 1.73279	training's RMSE: 2.32671	valid_1's WRMSSE: 1.85563	valid_1's RMSE: 2.2498
# [70]	training's WRMSSE: 1.70861	training's RMSE: 2.31782	valid_1's WRMSSE: 1.82903	valid_1's RMSE: 2.24039
# [71]	training's WRMSSE: 1.68498	training's RMSE: 2.30917	valid_1's WRMSSE: 1.80292	valid_1's RMSE: 2.23119
# [72]	training's WRMSSE: 1.66169	training's RMSE: 2.30067	valid_1's WRMSSE: 1.77693	valid_1's RMSE: 2.22212
# [73]	training's WRMSSE: 1.63865	training's RMSE: 2.29227	valid_1's WRMSSE: 1.75145	valid_1's RMSE: 2.21326
# [74]	training's WRMSSE: 1.6162	training's RMSE: 2.28416	valid_1's WRMSSE: 1.72655	valid_1's RMSE: 2.20469
# [75]	training's WRMSSE: 1.59411	training's RMSE: 2.27627	valid_1's WRMSSE: 1.70209	valid_1's RMSE: 2.19639
# [76]	training's WRMSSE: 1.57248	training's RMSE: 2.26868	valid_1's WRMSSE: 1.67809	valid_1's RMSE: 2.18833
# [77]	training's WRMSSE: 1.55119	training's RMSE: 2.26123	valid_1's WRMSSE: 1.65437	valid_1's RMSE: 2.18042
# [78]	training's WRMSSE: 1.53036	training's RMSE: 2.254	valid_1's WRMSSE: 1.63104	valid_1's RMSE: 2.17275
# [79]	training's WRMSSE: 1.50984	training's RMSE: 2.24683	valid_1's WRMSSE: 1.60819	valid_1's RMSE: 2.16514
# [80]	training's WRMSSE: 1.48972	training's RMSE: 2.23998	valid_1's WRMSSE: 1.58573	valid_1's RMSE: 2.1579
# [81]	training's WRMSSE: 1.46989	training's RMSE: 2.23323	valid_1's WRMSSE: 1.56365	valid_1's RMSE: 2.15078
# [82]	training's WRMSSE: 1.45055	training's RMSE: 2.22671	valid_1's WRMSSE: 1.542	valid_1's RMSE: 2.14387
# [83]	training's WRMSSE: 1.43155	training's RMSE: 2.22037	valid_1's WRMSSE: 1.52088	valid_1's RMSE: 2.1372
# [84]	training's WRMSSE: 1.41293	training's RMSE: 2.21405	valid_1's WRMSSE: 1.50012	valid_1's RMSE: 2.13061
# [85]	training's WRMSSE: 1.39465	training's RMSE: 2.20805	valid_1's WRMSSE: 1.47961	valid_1's RMSE: 2.12418
# [86]	training's WRMSSE: 1.37661	training's RMSE: 2.20223	valid_1's WRMSSE: 1.45946	valid_1's RMSE: 2.11804
# [87]	training's WRMSSE: 1.35905	training's RMSE: 2.19634	valid_1's WRMSSE: 1.43992	valid_1's RMSE: 2.11191
# [88]	training's WRMSSE: 1.34175	training's RMSE: 2.19082	valid_1's WRMSSE: 1.42052	valid_1's RMSE: 2.10607
# [89]	training's WRMSSE: 1.3248	training's RMSE: 2.18544	valid_1's WRMSSE: 1.40146	valid_1's RMSE: 2.10045
# [90]	training's WRMSSE: 1.3082	training's RMSE: 2.18019	valid_1's WRMSSE: 1.38269	valid_1's RMSE: 2.09491
# [91]	training's WRMSSE: 1.29187	training's RMSE: 2.17509	valid_1's WRMSSE: 1.36427	valid_1's RMSE: 2.08956
# [92]	training's WRMSSE: 1.27582	training's RMSE: 2.17009	valid_1's WRMSSE: 1.34625	valid_1's RMSE: 2.08443
# [93]	training's WRMSSE: 1.2602	training's RMSE: 2.16504	valid_1's WRMSSE: 1.32885	valid_1's RMSE: 2.07924
# [94]	training's WRMSSE: 1.24483	training's RMSE: 2.16021	valid_1's WRMSSE: 1.31143	valid_1's RMSE: 2.0742
# [95]	training's WRMSSE: 1.22975	training's RMSE: 2.1556	valid_1's WRMSSE: 1.29427	valid_1's RMSE: 2.06935
# [96]	training's WRMSSE: 1.2149	training's RMSE: 2.15101	valid_1's WRMSSE: 1.27736	valid_1's RMSE: 2.06453
# [97]	training's WRMSSE: 1.20053	training's RMSE: 2.14663	valid_1's WRMSSE: 1.26114	valid_1's RMSE: 2.06
# [98]	training's WRMSSE: 1.18642	training's RMSE: 2.1424	valid_1's WRMSSE: 1.24509	valid_1's RMSE: 2.05562
# [99]	training's WRMSSE: 1.17246	training's RMSE: 2.1382	valid_1's WRMSSE: 1.22931	valid_1's RMSE: 2.05124
# [100]	training's WRMSSE: 1.15872	training's RMSE: 2.13419	valid_1's WRMSSE: 1.21341	valid_1's RMSE: 2.04708
# [101]	training's WRMSSE: 1.14535	training's RMSE: 2.13019	valid_1's WRMSSE: 1.19815	valid_1's RMSE: 2.04305
# [102]	training's WRMSSE: 1.13231	training's RMSE: 2.12628	valid_1's WRMSSE: 1.18336	valid_1's RMSE: 2.03906
# [103]	training's WRMSSE: 1.1195	training's RMSE: 2.12241	valid_1's WRMSSE: 1.16883	valid_1's RMSE: 2.03514
# [104]	training's WRMSSE: 1.10688	training's RMSE: 2.11863	valid_1's WRMSSE: 1.15445	valid_1's RMSE: 2.03131
# [105]	training's WRMSSE: 1.0945	training's RMSE: 2.11521	valid_1's WRMSSE: 1.14021	valid_1's RMSE: 2.02774
# [106]	training's WRMSSE: 1.08243	training's RMSE: 2.11166	valid_1's WRMSSE: 1.12648	valid_1's RMSE: 2.0241
# [107]	training's WRMSSE: 1.07062	training's RMSE: 2.1083	valid_1's WRMSSE: 1.11301	valid_1's RMSE: 2.02062
# [108]	training's WRMSSE: 1.05911	training's RMSE: 2.10499	valid_1's WRMSSE: 1.09986	valid_1's RMSE: 2.01726
# [109]	training's WRMSSE: 1.04775	training's RMSE: 2.10186	valid_1's WRMSSE: 1.08697	valid_1's RMSE: 2.01406
# [110]	training's WRMSSE: 1.03679	training's RMSE: 2.09867	valid_1's WRMSSE: 1.07445	valid_1's RMSE: 2.01082
# [111]	training's WRMSSE: 1.02591	training's RMSE: 2.09572	valid_1's WRMSSE: 1.06219	valid_1's RMSE: 2.00782
# [112]	training's WRMSSE: 1.01536	training's RMSE: 2.09276	valid_1's WRMSSE: 1.05024	valid_1's RMSE: 2.00484
# [113]	training's WRMSSE: 1.00494	training's RMSE: 2.08989	valid_1's WRMSSE: 1.03823	valid_1's RMSE: 2.0019
# [114]	training's WRMSSE: 0.994748	training's RMSE: 2.08721	valid_1's WRMSSE: 1.02654	valid_1's RMSE: 1.99916
# [115]	training's WRMSSE: 0.984698	training's RMSE: 2.08438	valid_1's WRMSSE: 1.01497	valid_1's RMSE: 1.99645
# [116]	training's WRMSSE: 0.974806	training's RMSE: 2.08175	valid_1's WRMSSE: 1.00355	valid_1's RMSE: 1.99377
# [117]	training's WRMSSE: 0.965298	training's RMSE: 2.07908	valid_1's WRMSSE: 0.992537	valid_1's RMSE: 1.99109
# [118]	training's WRMSSE: 0.956002	training's RMSE: 2.07653	valid_1's WRMSSE: 0.981828	valid_1's RMSE: 1.98851
# [119]	training's WRMSSE: 0.946874	training's RMSE: 2.07403	valid_1's WRMSSE: 0.971306	valid_1's RMSE: 1.98604
# [120]	training's WRMSSE: 0.937896	training's RMSE: 2.07166	valid_1's WRMSSE: 0.960828	valid_1's RMSE: 1.98368
# [121]	training's WRMSSE: 0.928996	training's RMSE: 2.06945	valid_1's WRMSSE: 0.950527	valid_1's RMSE: 1.98145
# [122]	training's WRMSSE: 0.920492	training's RMSE: 2.06706	valid_1's WRMSSE: 0.940521	valid_1's RMSE: 1.97916
# [123]	training's WRMSSE: 0.912071	training's RMSE: 2.06487	valid_1's WRMSSE: 0.930681	valid_1's RMSE: 1.97696
# [124]	training's WRMSSE: 0.904022	training's RMSE: 2.06267	valid_1's WRMSSE: 0.921481	valid_1's RMSE: 1.97485
# [125]	training's WRMSSE: 0.896216	training's RMSE: 2.06051	valid_1's WRMSSE: 0.912621	valid_1's RMSE: 1.97283
# [126]	training's WRMSSE: 0.888434	training's RMSE: 2.05847	valid_1's WRMSSE: 0.903451	valid_1's RMSE: 1.97083
# [127]	training's WRMSSE: 0.880833	training's RMSE: 2.05642	valid_1's WRMSSE: 0.894654	valid_1's RMSE: 1.96886
# [128]	training's WRMSSE: 0.873339	training's RMSE: 2.05445	valid_1's WRMSSE: 0.885824	valid_1's RMSE: 1.96698
# [129]	training's WRMSSE: 0.866073	training's RMSE: 2.05257	valid_1's WRMSSE: 0.87741	valid_1's RMSE: 1.96513
# [130]	training's WRMSSE: 0.858848	training's RMSE: 2.05067	valid_1's WRMSSE: 0.868882	valid_1's RMSE: 1.96331
# [131]	training's WRMSSE: 0.851723	training's RMSE: 2.04887	valid_1's WRMSSE: 0.860497	valid_1's RMSE: 1.9616
# [132]	training's WRMSSE: 0.844949	training's RMSE: 2.04721	valid_1's WRMSSE: 0.852596	valid_1's RMSE: 1.95992
# [133]	training's WRMSSE: 0.838375	training's RMSE: 2.04543	valid_1's WRMSSE: 0.844752	valid_1's RMSE: 1.95821
# [134]	training's WRMSSE: 0.831801	training's RMSE: 2.04378	valid_1's WRMSSE: 0.836933	valid_1's RMSE: 1.95661
# [135]	training's WRMSSE: 0.825386	training's RMSE: 2.04218	valid_1's WRMSSE: 0.829376	valid_1's RMSE: 1.95501
# [136]	training's WRMSSE: 0.819156	training's RMSE: 2.04058	valid_1's WRMSSE: 0.821952	valid_1's RMSE: 1.95355
# [137]	training's WRMSSE: 0.813152	training's RMSE: 2.03906	valid_1's WRMSSE: 0.814845	valid_1's RMSE: 1.95211
# [138]	training's WRMSSE: 0.807288	training's RMSE: 2.0376	valid_1's WRMSSE: 0.807821	valid_1's RMSE: 1.95076
# [139]	training's WRMSSE: 0.801525	training's RMSE: 2.03617	valid_1's WRMSSE: 0.801083	valid_1's RMSE: 1.94943
# [140]	training's WRMSSE: 0.795816	training's RMSE: 2.03475	valid_1's WRMSSE: 0.794255	valid_1's RMSE: 1.94811
# [141]	training's WRMSSE: 0.79029	training's RMSE: 2.03339	valid_1's WRMSSE: 0.787576	valid_1's RMSE: 1.94686
# [142]	training's WRMSSE: 0.784888	training's RMSE: 2.03192	valid_1's WRMSSE: 0.781216	valid_1's RMSE: 1.94547
# [143]	training's WRMSSE: 0.779607	training's RMSE: 2.03063	valid_1's WRMSSE: 0.774963	valid_1's RMSE: 1.94425
# [144]	training's WRMSSE: 0.774442	training's RMSE: 2.02941	valid_1's WRMSSE: 0.768682	valid_1's RMSE: 1.94311
# [145]	training's WRMSSE: 0.769593	training's RMSE: 2.02821	valid_1's WRMSSE: 0.762942	valid_1's RMSE: 1.94196
# [146]	training's WRMSSE: 0.764903	training's RMSE: 2.02699	valid_1's WRMSSE: 0.757539	valid_1's RMSE: 1.9409
# [147]	training's WRMSSE: 0.760326	training's RMSE: 2.02579	valid_1's WRMSSE: 0.752298	valid_1's RMSE: 1.93983
# [148]	training's WRMSSE: 0.755664	training's RMSE: 2.02461	valid_1's WRMSSE: 0.746612	valid_1's RMSE: 1.9387
# [149]	training's WRMSSE: 0.750998	training's RMSE: 2.02351	valid_1's WRMSSE: 0.741097	valid_1's RMSE: 1.9377
# [150]	training's WRMSSE: 0.746692	training's RMSE: 2.02247	valid_1's WRMSSE: 0.735978	valid_1's RMSE: 1.93675
# [151]	training's WRMSSE: 0.742432	training's RMSE: 2.02139	valid_1's WRMSSE: 0.730915	valid_1's RMSE: 1.93579
# [152]	training's WRMSSE: 0.738356	training's RMSE: 2.0204	valid_1's WRMSSE: 0.726002	valid_1's RMSE: 1.9349
# [153]	training's WRMSSE: 0.73418	training's RMSE: 2.01938	valid_1's WRMSSE: 0.720912	valid_1's RMSE: 1.93397
# [154]	training's WRMSSE: 0.730202	training's RMSE: 2.01837	valid_1's WRMSSE: 0.716218	valid_1's RMSE: 1.93308
# [155]	training's WRMSSE: 0.726333	training's RMSE: 2.0174	valid_1's WRMSSE: 0.711648	valid_1's RMSE: 1.93225
# [156]	training's WRMSSE: 0.722385	training's RMSE: 2.01649	valid_1's WRMSSE: 0.706992	valid_1's RMSE: 1.93143
# [157]	training's WRMSSE: 0.718652	training's RMSE: 2.01557	valid_1's WRMSSE: 0.702492	valid_1's RMSE: 1.93061
# [158]	training's WRMSSE: 0.714979	training's RMSE: 2.01462	valid_1's WRMSSE: 0.698019	valid_1's RMSE: 1.92978
# [159]	training's WRMSSE: 0.711277	training's RMSE: 2.0138	valid_1's WRMSSE: 0.693655	valid_1's RMSE: 1.92902
# [160]	training's WRMSSE: 0.70796	training's RMSE: 2.01289	valid_1's WRMSSE: 0.689814	valid_1's RMSE: 1.92826
# [161]	training's WRMSSE: 0.704643	training's RMSE: 2.01209	valid_1's WRMSSE: 0.685859	valid_1's RMSE: 1.92758
# [162]	training's WRMSSE: 0.701326	training's RMSE: 2.01128	valid_1's WRMSSE: 0.681893	valid_1's RMSE: 1.9269
# [163]	training's WRMSSE: 0.698121	training's RMSE: 2.0105	valid_1's WRMSSE: 0.67821	valid_1's RMSE: 1.92622
# [164]	training's WRMSSE: 0.694885	training's RMSE: 2.00974	valid_1's WRMSSE: 0.674341	valid_1's RMSE: 1.92558
# [165]	training's WRMSSE: 0.691766	training's RMSE: 2.00897	valid_1's WRMSSE: 0.670616	valid_1's RMSE: 1.9249
# [166]	training's WRMSSE: 0.688665	training's RMSE: 2.00823	valid_1's WRMSSE: 0.66685	valid_1's RMSE: 1.92426
# [167]	training's WRMSSE: 0.685706	training's RMSE: 2.00751	valid_1's WRMSSE: 0.663276	valid_1's RMSE: 1.92365
# [168]	training's WRMSSE: 0.682999	training's RMSE: 2.00684	valid_1's WRMSSE: 0.660169	valid_1's RMSE: 1.92313
# [169]	training's WRMSSE: 0.680141	training's RMSE: 2.00624	valid_1's WRMSSE: 0.656761	valid_1's RMSE: 1.92259
# [170]	training's WRMSSE: 0.677562	training's RMSE: 2.00559	valid_1's WRMSSE: 0.653848	valid_1's RMSE: 1.92209
# [171]	training's WRMSSE: 0.674943	training's RMSE: 2.00493	valid_1's WRMSSE: 0.650593	valid_1's RMSE: 1.92159
# [172]	training's WRMSSE: 0.672361	training's RMSE: 2.00429	valid_1's WRMSSE: 0.647425	valid_1's RMSE: 1.92106
# [173]	training's WRMSSE: 0.669933	training's RMSE: 2.00375	valid_1's WRMSSE: 0.644376	valid_1's RMSE: 1.92063
# [174]	training's WRMSSE: 0.667457	training's RMSE: 2.00314	valid_1's WRMSSE: 0.641357	valid_1's RMSE: 1.9201
# [175]	training's WRMSSE: 0.665045	training's RMSE: 2.00253	valid_1's WRMSSE: 0.638429	valid_1's RMSE: 1.91958
# [176]	training's WRMSSE: 0.662699	training's RMSE: 2.00195	valid_1's WRMSSE: 0.635605	valid_1's RMSE: 1.91908
# [177]	training's WRMSSE: 0.660402	training's RMSE: 2.0013	valid_1's WRMSSE: 0.632795	valid_1's RMSE: 1.91856
# [178]	training's WRMSSE: 0.65789	training's RMSE: 2.00075	valid_1's WRMSSE: 0.629916	valid_1's RMSE: 1.9181
# [179]	training's WRMSSE: 0.655675	training's RMSE: 2.00021	valid_1's WRMSSE: 0.627253	valid_1's RMSE: 1.91768
# [180]	training's WRMSSE: 0.653616	training's RMSE: 1.99965	valid_1's WRMSSE: 0.624782	valid_1's RMSE: 1.91725
# [181]	training's WRMSSE: 0.651455	training's RMSE: 1.999	valid_1's WRMSSE: 0.622157	valid_1's RMSE: 1.91675
# [182]	training's WRMSSE: 0.649275	training's RMSE: 1.99841	valid_1's WRMSSE: 0.619639	valid_1's RMSE: 1.91626
# [183]	training's WRMSSE: 0.647226	training's RMSE: 1.99798	valid_1's WRMSSE: 0.617175	valid_1's RMSE: 1.91588
# [184]	training's WRMSSE: 0.645063	training's RMSE: 1.99753	valid_1's WRMSSE: 0.614712	valid_1's RMSE: 1.91553
# [185]	training's WRMSSE: 0.643149	training's RMSE: 1.99709	valid_1's WRMSSE: 0.61246	valid_1's RMSE: 1.91516
# [186]	training's WRMSSE: 0.641401	training's RMSE: 1.99665	valid_1's WRMSSE: 0.610457	valid_1's RMSE: 1.91483
# [187]	training's WRMSSE: 0.639636	training's RMSE: 1.99611	valid_1's WRMSSE: 0.608327	valid_1's RMSE: 1.91444
# [188]	training's WRMSSE: 0.637739	training's RMSE: 1.99568	valid_1's WRMSSE: 0.606113	valid_1's RMSE: 1.91409
# [189]	training's WRMSSE: 0.635924	training's RMSE: 1.99518	valid_1's WRMSSE: 0.604126	valid_1's RMSE: 1.91371
# [190]	training's WRMSSE: 0.634253	training's RMSE: 1.99472	valid_1's WRMSSE: 0.602274	valid_1's RMSE: 1.91341
# [191]	training's WRMSSE: 0.632664	training's RMSE: 1.99427	valid_1's WRMSSE: 0.600436	valid_1's RMSE: 1.9131
# [192]	training's WRMSSE: 0.631125	training's RMSE: 1.99386	valid_1's WRMSSE: 0.598706	valid_1's RMSE: 1.9128
# [193]	training's WRMSSE: 0.629686	training's RMSE: 1.99343	valid_1's WRMSSE: 0.596966	valid_1's RMSE: 1.91249
# [194]	training's WRMSSE: 0.628181	training's RMSE: 1.99304	valid_1's WRMSSE: 0.59521	valid_1's RMSE: 1.91221
# [195]	training's WRMSSE: 0.626885	training's RMSE: 1.99265	valid_1's WRMSSE: 0.593712	valid_1's RMSE: 1.91199
# [196]	training's WRMSSE: 0.625525	training's RMSE: 1.99235	valid_1's WRMSSE: 0.592055	valid_1's RMSE: 1.91175
# [197]	training's WRMSSE: 0.624243	training's RMSE: 1.99192	valid_1's WRMSSE: 0.590581	valid_1's RMSE: 1.91139
# [198]	training's WRMSSE: 0.622906	training's RMSE: 1.99159	valid_1's WRMSSE: 0.58905	valid_1's RMSE: 1.91115
# [199]	training's WRMSSE: 0.621657	training's RMSE: 1.99125	valid_1's WRMSSE: 0.58759	valid_1's RMSE: 1.91089
# [200]	training's WRMSSE: 0.620329	training's RMSE: 1.99083	valid_1's WRMSSE: 0.586021	valid_1's RMSE: 1.91059
# [201]	training's WRMSSE: 0.619162	training's RMSE: 1.99048	valid_1's WRMSSE: 0.584655	valid_1's RMSE: 1.91035
# [202]	training's WRMSSE: 0.617946	training's RMSE: 1.99013	valid_1's WRMSSE: 0.583279	valid_1's RMSE: 1.91012
# [203]	training's WRMSSE: 0.616751	training's RMSE: 1.98981	valid_1's WRMSSE: 0.581951	valid_1's RMSE: 1.90991
# [204]	training's WRMSSE: 0.615566	training's RMSE: 1.98949	valid_1's WRMSSE: 0.580567	valid_1's RMSE: 1.90966
# [205]	training's WRMSSE: 0.61431	training's RMSE: 1.9892	valid_1's WRMSSE: 0.579098	valid_1's RMSE: 1.90945
# [206]	training's WRMSSE: 0.613256	training's RMSE: 1.98889	valid_1's WRMSSE: 0.57788	valid_1's RMSE: 1.9092
# [207]	training's WRMSSE: 0.61218	training's RMSE: 1.98866	valid_1's WRMSSE: 0.576657	valid_1's RMSE: 1.90904
# [208]	training's WRMSSE: 0.611027	training's RMSE: 1.98843	valid_1's WRMSSE: 0.575462	valid_1's RMSE: 1.90889
# [209]	training's WRMSSE: 0.609963	training's RMSE: 1.98815	valid_1's WRMSSE: 0.574187	valid_1's RMSE: 1.90868
# [210]	training's WRMSSE: 0.608844	training's RMSE: 1.98776	valid_1's WRMSSE: 0.572959	valid_1's RMSE: 1.90838
# [211]	training's WRMSSE: 0.607825	training's RMSE: 1.98749	valid_1's WRMSSE: 0.571848	valid_1's RMSE: 1.90822
# [212]	training's WRMSSE: 0.606903	training's RMSE: 1.98725	valid_1's WRMSSE: 0.570718	valid_1's RMSE: 1.90806
# [213]	training's WRMSSE: 0.605955	training's RMSE: 1.98703	valid_1's WRMSSE: 0.569681	valid_1's RMSE: 1.90792
# [214]	training's WRMSSE: 0.604975	training's RMSE: 1.98668	valid_1's WRMSSE: 0.568612	valid_1's RMSE: 1.90764
# [215]	training's WRMSSE: 0.603893	training's RMSE: 1.98648	valid_1's WRMSSE: 0.567417	valid_1's RMSE: 1.90744
# [216]	training's WRMSSE: 0.602999	training's RMSE: 1.98615	valid_1's WRMSSE: 0.566318	valid_1's RMSE: 1.90717
# [217]	training's WRMSSE: 0.602179	training's RMSE: 1.98589	valid_1's WRMSSE: 0.565431	valid_1's RMSE: 1.90699
# [218]	training's WRMSSE: 0.601216	training's RMSE: 1.98559	valid_1's WRMSSE: 0.564339	valid_1's RMSE: 1.90676
# [219]	training's WRMSSE: 0.600441	training's RMSE: 1.98537	valid_1's WRMSSE: 0.563539	valid_1's RMSE: 1.90661
# [220]	training's WRMSSE: 0.599604	training's RMSE: 1.98509	valid_1's WRMSSE: 0.562599	valid_1's RMSE: 1.90639
# [221]	training's WRMSSE: 0.598741	training's RMSE: 1.98481	valid_1's WRMSSE: 0.561641	valid_1's RMSE: 1.90621
# [222]	training's WRMSSE: 0.597893	training's RMSE: 1.98454	valid_1's WRMSSE: 0.560803	valid_1's RMSE: 1.90599
# [223]	training's WRMSSE: 0.597004	training's RMSE: 1.9843	valid_1's WRMSSE: 0.559759	valid_1's RMSE: 1.90579
# [224]	training's WRMSSE: 0.596152	training's RMSE: 1.98405	valid_1's WRMSSE: 0.55883	valid_1's RMSE: 1.90562
# [225]	training's WRMSSE: 0.595258	training's RMSE: 1.98379	valid_1's WRMSSE: 0.557926	valid_1's RMSE: 1.90544
# [226]	training's WRMSSE: 0.594446	training's RMSE: 1.98356	valid_1's WRMSSE: 0.557069	valid_1's RMSE: 1.90527
# [227]	training's WRMSSE: 0.59363	training's RMSE: 1.98331	valid_1's WRMSSE: 0.556255	valid_1's RMSE: 1.90507
# [228]	training's WRMSSE: 0.593047	training's RMSE: 1.98305	valid_1's WRMSSE: 0.55553	valid_1's RMSE: 1.90489
# [229]	training's WRMSSE: 0.592398	training's RMSE: 1.98278	valid_1's WRMSSE: 0.554761	valid_1's RMSE: 1.90473
# [230]	training's WRMSSE: 0.591653	training's RMSE: 1.98256	valid_1's WRMSSE: 0.55395	valid_1's RMSE: 1.90459
# [231]	training's WRMSSE: 0.591015	training's RMSE: 1.98233	valid_1's WRMSSE: 0.553293	valid_1's RMSE: 1.90445
# [232]	training's WRMSSE: 0.590237	training's RMSE: 1.98205	valid_1's WRMSSE: 0.552602	valid_1's RMSE: 1.90427
# [233]	training's WRMSSE: 0.589429	training's RMSE: 1.98185	valid_1's WRMSSE: 0.551769	valid_1's RMSE: 1.90412
# [234]	training's WRMSSE: 0.588676	training's RMSE: 1.98159	valid_1's WRMSSE: 0.551046	valid_1's RMSE: 1.90392
# [235]	training's WRMSSE: 0.587988	training's RMSE: 1.98132	valid_1's WRMSSE: 0.550313	valid_1's RMSE: 1.90371
# [236]	training's WRMSSE: 0.587212	training's RMSE: 1.98105	valid_1's WRMSSE: 0.549462	valid_1's RMSE: 1.90351
# [237]	training's WRMSSE: 0.586735	training's RMSE: 1.98074	valid_1's WRMSSE: 0.54894	valid_1's RMSE: 1.90331
# [238]	training's WRMSSE: 0.586117	training's RMSE: 1.9805	valid_1's WRMSSE: 0.548301	valid_1's RMSE: 1.90313
# [239]	training's WRMSSE: 0.585077	training's RMSE: 1.98027	valid_1's WRMSSE: 0.547491	valid_1's RMSE: 1.90292
# [240]	training's WRMSSE: 0.584451	training's RMSE: 1.98	valid_1's WRMSSE: 0.546769	valid_1's RMSE: 1.90271
# [241]	training's WRMSSE: 0.583906	training's RMSE: 1.97977	valid_1's WRMSSE: 0.546096	valid_1's RMSE: 1.90258
# [242]	training's WRMSSE: 0.583413	training's RMSE: 1.97952	valid_1's WRMSSE: 0.54553	valid_1's RMSE: 1.90237
# [243]	training's WRMSSE: 0.582757	training's RMSE: 1.97926	valid_1's WRMSSE: 0.544867	valid_1's RMSE: 1.90218
# [244]	training's WRMSSE: 0.582128	training's RMSE: 1.97902	valid_1's WRMSSE: 0.544339	valid_1's RMSE: 1.90204
# [245]	training's WRMSSE: 0.58163	training's RMSE: 1.97885	valid_1's WRMSSE: 0.543887	valid_1's RMSE: 1.90193
# [246]	training's WRMSSE: 0.58112	training's RMSE: 1.97862	valid_1's WRMSSE: 0.543265	valid_1's RMSE: 1.9018
# [247]	training's WRMSSE: 0.580685	training's RMSE: 1.97835	valid_1's WRMSSE: 0.542814	valid_1's RMSE: 1.90163
# [248]	training's WRMSSE: 0.580068	training's RMSE: 1.97815	valid_1's WRMSSE: 0.542104	valid_1's RMSE: 1.90151
# [249]	training's WRMSSE: 0.579528	training's RMSE: 1.97795	valid_1's WRMSSE: 0.541581	valid_1's RMSE: 1.90143
# [250]	training's WRMSSE: 0.578806	training's RMSE: 1.97771	valid_1's WRMSSE: 0.540854	valid_1's RMSE: 1.90129
# [251]	training's WRMSSE: 0.578375	training's RMSE: 1.97753	valid_1's WRMSSE: 0.540395	valid_1's RMSE: 1.90114
# [252]	training's WRMSSE: 0.577967	training's RMSE: 1.97728	valid_1's WRMSSE: 0.53993	valid_1's RMSE: 1.90095
# [253]	training's WRMSSE: 0.577534	training's RMSE: 1.97708	valid_1's WRMSSE: 0.53954	valid_1's RMSE: 1.90087
# [254]	training's WRMSSE: 0.57702	training's RMSE: 1.9769	valid_1's WRMSSE: 0.538992	valid_1's RMSE: 1.90075
# [255]	training's WRMSSE: 0.576433	training's RMSE: 1.97674	valid_1's WRMSSE: 0.538509	valid_1's RMSE: 1.90068
# [256]	training's WRMSSE: 0.575963	training's RMSE: 1.97652	valid_1's WRMSSE: 0.538083	valid_1's RMSE: 1.90054
# [257]	training's WRMSSE: 0.575266	training's RMSE: 1.97624	valid_1's WRMSSE: 0.537445	valid_1's RMSE: 1.90032
# [258]	training's WRMSSE: 0.574718	training's RMSE: 1.9761	valid_1's WRMSSE: 0.536962	valid_1's RMSE: 1.90021
# [259]	training's WRMSSE: 0.574286	training's RMSE: 1.97587	valid_1's WRMSSE: 0.536595	valid_1's RMSE: 1.90011
# [260]	training's WRMSSE: 0.57373	training's RMSE: 1.97565	valid_1's WRMSSE: 0.536064	valid_1's RMSE: 1.89996
# [261]	training's WRMSSE: 0.573369	training's RMSE: 1.97545	valid_1's WRMSSE: 0.535795	valid_1's RMSE: 1.8999
# [262]	training's WRMSSE: 0.572837	training's RMSE: 1.97524	valid_1's WRMSSE: 0.535319	valid_1's RMSE: 1.89979
# [263]	training's WRMSSE: 0.572311	training's RMSE: 1.97501	valid_1's WRMSSE: 0.534868	valid_1's RMSE: 1.89967
# [264]	training's WRMSSE: 0.571838	training's RMSE: 1.9748	valid_1's WRMSSE: 0.53445	valid_1's RMSE: 1.89953
# [265]	training's WRMSSE: 0.571334	training's RMSE: 1.9746	valid_1's WRMSSE: 0.533926	valid_1's RMSE: 1.8994
# [266]	training's WRMSSE: 0.570845	training's RMSE: 1.97446	valid_1's WRMSSE: 0.533518	valid_1's RMSE: 1.89933
# [267]	training's WRMSSE: 0.570499	training's RMSE: 1.97429	valid_1's WRMSSE: 0.53321	valid_1's RMSE: 1.89923
# [268]	training's WRMSSE: 0.56973	training's RMSE: 1.97406	valid_1's WRMSSE: 0.53253	valid_1's RMSE: 1.89907
# [269]	training's WRMSSE: 0.569316	training's RMSE: 1.97386	valid_1's WRMSSE: 0.532095	valid_1's RMSE: 1.89895
# [270]	training's WRMSSE: 0.568953	training's RMSE: 1.97369	valid_1's WRMSSE: 0.531763	valid_1's RMSE: 1.89884
# [271]	training's WRMSSE: 0.56851	training's RMSE: 1.97355	valid_1's WRMSSE: 0.531359	valid_1's RMSE: 1.89875
# [272]	training's WRMSSE: 0.568222	training's RMSE: 1.97337	valid_1's WRMSSE: 0.531142	valid_1's RMSE: 1.89866
# [273]	training's WRMSSE: 0.567696	training's RMSE: 1.9732	valid_1's WRMSSE: 0.530694	valid_1's RMSE: 1.89856
# [274]	training's WRMSSE: 0.567349	training's RMSE: 1.97301	valid_1's WRMSSE: 0.530299	valid_1's RMSE: 1.89845
# [275]	training's WRMSSE: 0.56702	training's RMSE: 1.97284	valid_1's WRMSSE: 0.529983	valid_1's RMSE: 1.89832
# [276]	training's WRMSSE: 0.566694	training's RMSE: 1.97268	valid_1's WRMSSE: 0.529747	valid_1's RMSE: 1.89821
# [277]	training's WRMSSE: 0.566429	training's RMSE: 1.97248	valid_1's WRMSSE: 0.529555	valid_1's RMSE: 1.89809
# [278]	training's WRMSSE: 0.566144	training's RMSE: 1.97231	valid_1's WRMSSE: 0.529355	valid_1's RMSE: 1.89798
# [279]	training's WRMSSE: 0.565895	training's RMSE: 1.9722	valid_1's WRMSSE: 0.529122	valid_1's RMSE: 1.89792
# [280]	training's WRMSSE: 0.56558	training's RMSE: 1.97199	valid_1's WRMSSE: 0.528806	valid_1's RMSE: 1.89779
# [281]	training's WRMSSE: 0.565291	training's RMSE: 1.97182	valid_1's WRMSSE: 0.528595	valid_1's RMSE: 1.89772
# [282]	training's WRMSSE: 0.564863	training's RMSE: 1.97161	valid_1's WRMSSE: 0.528222	valid_1's RMSE: 1.89756
# [283]	training's WRMSSE: 0.564689	training's RMSE: 1.97152	valid_1's WRMSSE: 0.528122	valid_1's RMSE: 1.89752
# [284]	training's WRMSSE: 0.564389	training's RMSE: 1.97139	valid_1's WRMSSE: 0.527954	valid_1's RMSE: 1.89749
# [285]	training's WRMSSE: 0.564128	training's RMSE: 1.97122	valid_1's WRMSSE: 0.527746	valid_1's RMSE: 1.89739
# [286]	training's WRMSSE: 0.563996	training's RMSE: 1.9711	valid_1's WRMSSE: 0.527617	valid_1's RMSE: 1.89734
# [287]	training's WRMSSE: 0.563789	training's RMSE: 1.97097	valid_1's WRMSSE: 0.527505	valid_1's RMSE: 1.89731
# [288]	training's WRMSSE: 0.563588	training's RMSE: 1.97084	valid_1's WRMSSE: 0.527318	valid_1's RMSE: 1.89725
# [289]	training's WRMSSE: 0.563271	training's RMSE: 1.97068	valid_1's WRMSSE: 0.527073	valid_1's RMSE: 1.89716
# [290]	training's WRMSSE: 0.562902	training's RMSE: 1.9705	valid_1's WRMSSE: 0.526759	valid_1's RMSE: 1.89706
# [291]	training's WRMSSE: 0.562636	training's RMSE: 1.97037	valid_1's WRMSSE: 0.526552	valid_1's RMSE: 1.89698
# [292]	training's WRMSSE: 0.562212	training's RMSE: 1.97021	valid_1's WRMSSE: 0.526084	valid_1's RMSE: 1.89688
# [293]	training's WRMSSE: 0.56192	training's RMSE: 1.97007	valid_1's WRMSSE: 0.525925	valid_1's RMSE: 1.89683
# [294]	training's WRMSSE: 0.56168	training's RMSE: 1.96992	valid_1's WRMSSE: 0.525648	valid_1's RMSE: 1.89676
# [295]	training's WRMSSE: 0.5614	training's RMSE: 1.96974	valid_1's WRMSSE: 0.525421	valid_1's RMSE: 1.89663
# [296]	training's WRMSSE: 0.560828	training's RMSE: 1.96953	valid_1's WRMSSE: 0.524923	valid_1's RMSE: 1.89648
# [297]	training's WRMSSE: 0.560161	training's RMSE: 1.96934	valid_1's WRMSSE: 0.524369	valid_1's RMSE: 1.89635
# [298]	training's WRMSSE: 0.559898	training's RMSE: 1.96919	valid_1's WRMSSE: 0.524247	valid_1's RMSE: 1.89631
# [299]	training's WRMSSE: 0.559586	training's RMSE: 1.96905	valid_1's WRMSSE: 0.52398	valid_1's RMSE: 1.89627
# [300]	training's WRMSSE: 0.559371	training's RMSE: 1.96893	valid_1's WRMSSE: 0.523796	valid_1's RMSE: 1.89624
# [301]	training's WRMSSE: 0.558992	training's RMSE: 1.96874	valid_1's WRMSSE: 0.523547	valid_1's RMSE: 1.89614
# [302]	training's WRMSSE: 0.558764	training's RMSE: 1.96864	valid_1's WRMSSE: 0.523397	valid_1's RMSE: 1.89612
# [303]	training's WRMSSE: 0.55842	training's RMSE: 1.96849	valid_1's WRMSSE: 0.523143	valid_1's RMSE: 1.89606
# [304]	training's WRMSSE: 0.557895	training's RMSE: 1.96829	valid_1's WRMSSE: 0.522815	valid_1's RMSE: 1.89595
# [305]	training's WRMSSE: 0.557459	training's RMSE: 1.96815	valid_1's WRMSSE: 0.52259	valid_1's RMSE: 1.89588
# [306]	training's WRMSSE: 0.557234	training's RMSE: 1.968	valid_1's WRMSSE: 0.52243	valid_1's RMSE: 1.89581
# [307]	training's WRMSSE: 0.556934	training's RMSE: 1.96786	valid_1's WRMSSE: 0.52221	valid_1's RMSE: 1.89576
# [308]	training's WRMSSE: 0.55664	training's RMSE: 1.9677	valid_1's WRMSSE: 0.521838	valid_1's RMSE: 1.89563
# [309]	training's WRMSSE: 0.556457	training's RMSE: 1.96762	valid_1's WRMSSE: 0.521717	valid_1's RMSE: 1.8956
# [310]	training's WRMSSE: 0.556216	training's RMSE: 1.9675	valid_1's WRMSSE: 0.521539	valid_1's RMSE: 1.89557
# [311]	training's WRMSSE: 0.556036	training's RMSE: 1.96736	valid_1's WRMSSE: 0.521425	valid_1's RMSE: 1.89549
# [312]	training's WRMSSE: 0.555811	training's RMSE: 1.96726	valid_1's WRMSSE: 0.521293	valid_1's RMSE: 1.89546
# [313]	training's WRMSSE: 0.555579	training's RMSE: 1.96711	valid_1's WRMSSE: 0.52117	valid_1's RMSE: 1.89537
# [314]	training's WRMSSE: 0.555444	training's RMSE: 1.96699	valid_1's WRMSSE: 0.521006	valid_1's RMSE: 1.89528
# [315]	training's WRMSSE: 0.555182	training's RMSE: 1.9668	valid_1's WRMSSE: 0.520748	valid_1's RMSE: 1.89514
# [316]	training's WRMSSE: 0.554864	training's RMSE: 1.96661	valid_1's WRMSSE: 0.520446	valid_1's RMSE: 1.895
# [317]	training's WRMSSE: 0.554621	training's RMSE: 1.96643	valid_1's WRMSSE: 0.520282	valid_1's RMSE: 1.89487
# [318]	training's WRMSSE: 0.554436	training's RMSE: 1.96632	valid_1's WRMSSE: 0.52011	valid_1's RMSE: 1.89481
# [319]	training's WRMSSE: 0.55422	training's RMSE: 1.96618	valid_1's WRMSSE: 0.51993	valid_1's RMSE: 1.89468
# [320]	training's WRMSSE: 0.553906	training's RMSE: 1.966	valid_1's WRMSSE: 0.519573	valid_1's RMSE: 1.89461
# [321]	training's WRMSSE: 0.553737	training's RMSE: 1.96584	valid_1's WRMSSE: 0.519457	valid_1's RMSE: 1.89452
# [322]	training's WRMSSE: 0.55348	training's RMSE: 1.96569	valid_1's WRMSSE: 0.51924	valid_1's RMSE: 1.89444
# [323]	training's WRMSSE: 0.55327	training's RMSE: 1.96559	valid_1's WRMSSE: 0.518969	valid_1's RMSE: 1.89439
# [324]	training's WRMSSE: 0.553076	training's RMSE: 1.96549	valid_1's WRMSSE: 0.518872	valid_1's RMSE: 1.89434
# [325]	training's WRMSSE: 0.552778	training's RMSE: 1.96537	valid_1's WRMSSE: 0.51878	valid_1's RMSE: 1.8943
# [326]	training's WRMSSE: 0.552564	training's RMSE: 1.96519	valid_1's WRMSSE: 0.518584	valid_1's RMSE: 1.89415
# [327]	training's WRMSSE: 0.552236	training's RMSE: 1.96502	valid_1's WRMSSE: 0.518313	valid_1's RMSE: 1.89404
# [328]	training's WRMSSE: 0.551968	training's RMSE: 1.96495	valid_1's WRMSSE: 0.518037	valid_1's RMSE: 1.89402
# [329]	training's WRMSSE: 0.551749	training's RMSE: 1.96478	valid_1's WRMSSE: 0.517817	valid_1's RMSE: 1.89392
# [330]	training's WRMSSE: 0.551391	training's RMSE: 1.96464	valid_1's WRMSSE: 0.51763	valid_1's RMSE: 1.89385
# [331]	training's WRMSSE: 0.551289	training's RMSE: 1.96457	valid_1's WRMSSE: 0.517547	valid_1's RMSE: 1.89382
# [332]	training's WRMSSE: 0.550999	training's RMSE: 1.96449	valid_1's WRMSSE: 0.517274	valid_1's RMSE: 1.89378
# [333]	training's WRMSSE: 0.550832	training's RMSE: 1.96441	valid_1's WRMSSE: 0.517171	valid_1's RMSE: 1.89377
# [334]	training's WRMSSE: 0.550591	training's RMSE: 1.96428	valid_1's WRMSSE: 0.516964	valid_1's RMSE: 1.89371
# [335]	training's WRMSSE: 0.55031	training's RMSE: 1.96414	valid_1's WRMSSE: 0.5168	valid_1's RMSE: 1.89365
# [336]	training's WRMSSE: 0.550074	training's RMSE: 1.964	valid_1's WRMSSE: 0.516694	valid_1's RMSE: 1.89358
# [337]	training's WRMSSE: 0.54976	training's RMSE: 1.96386	valid_1's WRMSSE: 0.516377	valid_1's RMSE: 1.89355
# [338]	training's WRMSSE: 0.549613	training's RMSE: 1.96382	valid_1's WRMSSE: 0.516209	valid_1's RMSE: 1.89355
# [339]	training's WRMSSE: 0.549303	training's RMSE: 1.96372	valid_1's WRMSSE: 0.515975	valid_1's RMSE: 1.89351
# [340]	training's WRMSSE: 0.549187	training's RMSE: 1.96367	valid_1's WRMSSE: 0.515956	valid_1's RMSE: 1.8935
# [341]	training's WRMSSE: 0.54893	training's RMSE: 1.9636	valid_1's WRMSSE: 0.515816	valid_1's RMSE: 1.89347
# [342]	training's WRMSSE: 0.548694	training's RMSE: 1.96353	valid_1's WRMSSE: 0.515572	valid_1's RMSE: 1.89344
# [343]	training's WRMSSE: 0.548408	training's RMSE: 1.96338	valid_1's WRMSSE: 0.515282	valid_1's RMSE: 1.89329
# [344]	training's WRMSSE: 0.548225	training's RMSE: 1.96329	valid_1's WRMSSE: 0.515221	valid_1's RMSE: 1.89326
# [345]	training's WRMSSE: 0.547954	training's RMSE: 1.96317	valid_1's WRMSSE: 0.515024	valid_1's RMSE: 1.89316
# [346]	training's WRMSSE: 0.547701	training's RMSE: 1.9631	valid_1's WRMSSE: 0.514804	valid_1's RMSE: 1.89314
# [347]	training's WRMSSE: 0.547517	training's RMSE: 1.963	valid_1's WRMSSE: 0.514639	valid_1's RMSE: 1.8931
# [348]	training's WRMSSE: 0.54735	training's RMSE: 1.96288	valid_1's WRMSSE: 0.514532	valid_1's RMSE: 1.89305
# [349]	training's WRMSSE: 0.547248	training's RMSE: 1.96281	valid_1's WRMSSE: 0.514453	valid_1's RMSE: 1.89304
# [350]	training's WRMSSE: 0.547051	training's RMSE: 1.96271	valid_1's WRMSSE: 0.514379	valid_1's RMSE: 1.89301
# [351]	training's WRMSSE: 0.546773	training's RMSE: 1.96261	valid_1's WRMSSE: 0.514143	valid_1's RMSE: 1.89295
# [352]	training's WRMSSE: 0.546434	training's RMSE: 1.96248	valid_1's WRMSSE: 0.513938	valid_1's RMSE: 1.89289
# [353]	training's WRMSSE: 0.545969	training's RMSE: 1.96231	valid_1's WRMSSE: 0.513518	valid_1's RMSE: 1.89275
# [354]	training's WRMSSE: 0.545505	training's RMSE: 1.96217	valid_1's WRMSSE: 0.513291	valid_1's RMSE: 1.8927
# [355]	training's WRMSSE: 0.545351	training's RMSE: 1.96204	valid_1's WRMSSE: 0.513202	valid_1's RMSE: 1.89267
# [356]	training's WRMSSE: 0.545066	training's RMSE: 1.96193	valid_1's WRMSSE: 0.513069	valid_1's RMSE: 1.89261
# [357]	training's WRMSSE: 0.544853	training's RMSE: 1.9618	valid_1's WRMSSE: 0.512951	valid_1's RMSE: 1.8925
# [358]	training's WRMSSE: 0.544683	training's RMSE: 1.9617	valid_1's WRMSSE: 0.512855	valid_1's RMSE: 1.89246
# [359]	training's WRMSSE: 0.544567	training's RMSE: 1.96157	valid_1's WRMSSE: 0.512762	valid_1's RMSE: 1.89241
# [360]	training's WRMSSE: 0.544341	training's RMSE: 1.96149	valid_1's WRMSSE: 0.512648	valid_1's RMSE: 1.89236
# [361]	training's WRMSSE: 0.544061	training's RMSE: 1.96133	valid_1's WRMSSE: 0.5123	valid_1's RMSE: 1.89223
# [362]	training's WRMSSE: 0.543999	training's RMSE: 1.96126	valid_1's WRMSSE: 0.512258	valid_1's RMSE: 1.89223
# [363]	training's WRMSSE: 0.543892	training's RMSE: 1.96116	valid_1's WRMSSE: 0.512237	valid_1's RMSE: 1.8922
# [364]	training's WRMSSE: 0.543513	training's RMSE: 1.96096	valid_1's WRMSSE: 0.511887	valid_1's RMSE: 1.89206
# [365]	training's WRMSSE: 0.543428	training's RMSE: 1.9609	valid_1's WRMSSE: 0.511826	valid_1's RMSE: 1.89203
# [366]	training's WRMSSE: 0.543373	training's RMSE: 1.96082	valid_1's WRMSSE: 0.511784	valid_1's RMSE: 1.89199
# [367]	training's WRMSSE: 0.54332	training's RMSE: 1.96076	valid_1's WRMSSE: 0.511739	valid_1's RMSE: 1.89197
# [368]	training's WRMSSE: 0.543053	training's RMSE: 1.96065	valid_1's WRMSSE: 0.511511	valid_1's RMSE: 1.89187
# [369]	training's WRMSSE: 0.542814	training's RMSE: 1.96055	valid_1's WRMSSE: 0.511423	valid_1's RMSE: 1.89186
# [370]	training's WRMSSE: 0.542243	training's RMSE: 1.96038	valid_1's WRMSSE: 0.510925	valid_1's RMSE: 1.89172
# [371]	training's WRMSSE: 0.542008	training's RMSE: 1.96022	valid_1's WRMSSE: 0.51066	valid_1's RMSE: 1.89161
# [372]	training's WRMSSE: 0.541829	training's RMSE: 1.96013	valid_1's WRMSSE: 0.510542	valid_1's RMSE: 1.89158
# [373]	training's WRMSSE: 0.541625	training's RMSE: 1.96008	valid_1's WRMSSE: 0.510377	valid_1's RMSE: 1.89156
# [374]	training's WRMSSE: 0.541221	training's RMSE: 1.95996	valid_1's WRMSSE: 0.510223	valid_1's RMSE: 1.89154
# [375]	training's WRMSSE: 0.541029	training's RMSE: 1.95984	valid_1's WRMSSE: 0.510088	valid_1's RMSE: 1.8915
# [376]	training's WRMSSE: 0.540948	training's RMSE: 1.95976	valid_1's WRMSSE: 0.510026	valid_1's RMSE: 1.89147
# [377]	training's WRMSSE: 0.540885	training's RMSE: 1.95966	valid_1's WRMSSE: 0.510027	valid_1's RMSE: 1.89145
# [378]	training's WRMSSE: 0.540812	training's RMSE: 1.95956	valid_1's WRMSSE: 0.510007	valid_1's RMSE: 1.89144
# [379]	training's WRMSSE: 0.540589	training's RMSE: 1.95948	valid_1's WRMSSE: 0.509943	valid_1's RMSE: 1.8914
# [380]	training's WRMSSE: 0.540039	training's RMSE: 1.95932	valid_1's WRMSSE: 0.509519	valid_1's RMSE: 1.89131
# [381]	training's WRMSSE: 0.53988	training's RMSE: 1.95923	valid_1's WRMSSE: 0.509469	valid_1's RMSE: 1.89126
# [382]	training's WRMSSE: 0.539823	training's RMSE: 1.95916	valid_1's WRMSSE: 0.509426	valid_1's RMSE: 1.89123
# [383]	training's WRMSSE: 0.539693	training's RMSE: 1.95905	valid_1's WRMSSE: 0.50938	valid_1's RMSE: 1.89117
# [384]	training's WRMSSE: 0.539581	training's RMSE: 1.95899	valid_1's WRMSSE: 0.509292	valid_1's RMSE: 1.89115
# [385]	training's WRMSSE: 0.539431	training's RMSE: 1.95887	valid_1's WRMSSE: 0.509155	valid_1's RMSE: 1.89108
# [386]	training's WRMSSE: 0.539339	training's RMSE: 1.95877	valid_1's WRMSSE: 0.509048	valid_1's RMSE: 1.89102
# [387]	training's WRMSSE: 0.539275	training's RMSE: 1.95871	valid_1's WRMSSE: 0.508982	valid_1's RMSE: 1.89099
# [388]	training's WRMSSE: 0.539086	training's RMSE: 1.95861	valid_1's WRMSSE: 0.508764	valid_1's RMSE: 1.89094
# [389]	training's WRMSSE: 0.538974	training's RMSE: 1.95855	valid_1's WRMSSE: 0.508712	valid_1's RMSE: 1.89093
# [390]	training's WRMSSE: 0.538838	training's RMSE: 1.95847	valid_1's WRMSSE: 0.508651	valid_1's RMSE: 1.89092
# [391]	training's WRMSSE: 0.538589	training's RMSE: 1.95837	valid_1's WRMSSE: 0.508566	valid_1's RMSE: 1.89086
# [392]	training's WRMSSE: 0.538458	training's RMSE: 1.95828	valid_1's WRMSSE: 0.508527	valid_1's RMSE: 1.8908
# [393]	training's WRMSSE: 0.538337	training's RMSE: 1.9582	valid_1's WRMSSE: 0.508452	valid_1's RMSE: 1.89077
# [394]	training's WRMSSE: 0.538261	training's RMSE: 1.9581	valid_1's WRMSSE: 0.508374	valid_1's RMSE: 1.89074
# [395]	training's WRMSSE: 0.538188	training's RMSE: 1.95803	valid_1's WRMSSE: 0.508325	valid_1's RMSE: 1.89071
# [396]	training's WRMSSE: 0.538115	training's RMSE: 1.95796	valid_1's WRMSSE: 0.50829	valid_1's RMSE: 1.89071
# [397]	training's WRMSSE: 0.537911	training's RMSE: 1.95787	valid_1's WRMSSE: 0.508196	valid_1's RMSE: 1.89066
# [398]	training's WRMSSE: 0.537831	training's RMSE: 1.95777	valid_1's WRMSSE: 0.508147	valid_1's RMSE: 1.8906
# [399]	training's WRMSSE: 0.53771	training's RMSE: 1.95763	valid_1's WRMSSE: 0.508055	valid_1's RMSE: 1.89048
# [400]	training's WRMSSE: 0.537592	training's RMSE: 1.95755	valid_1's WRMSSE: 0.507957	valid_1's RMSE: 1.89043
# [401]	training's WRMSSE: 0.537424	training's RMSE: 1.95747	valid_1's WRMSSE: 0.507892	valid_1's RMSE: 1.89038
# [402]	training's WRMSSE: 0.537197	training's RMSE: 1.95735	valid_1's WRMSSE: 0.507705	valid_1's RMSE: 1.89035
# [403]	training's WRMSSE: 0.537032	training's RMSE: 1.95724	valid_1's WRMSSE: 0.507637	valid_1's RMSE: 1.8903
# [404]	training's WRMSSE: 0.536981	training's RMSE: 1.95718	valid_1's WRMSSE: 0.507582	valid_1's RMSE: 1.89028
# [405]	training's WRMSSE: 0.53689	training's RMSE: 1.95709	valid_1's WRMSSE: 0.507521	valid_1's RMSE: 1.89026
# [406]	training's WRMSSE: 0.536769	training's RMSE: 1.95704	valid_1's WRMSSE: 0.507485	valid_1's RMSE: 1.89025
# [407]	training's WRMSSE: 0.536435	training's RMSE: 1.9569	valid_1's WRMSSE: 0.507188	valid_1's RMSE: 1.89013
# [408]	training's WRMSSE: 0.536366	training's RMSE: 1.95684	valid_1's WRMSSE: 0.507165	valid_1's RMSE: 1.89011
# [409]	training's WRMSSE: 0.536289	training's RMSE: 1.9568	valid_1's WRMSSE: 0.507152	valid_1's RMSE: 1.8901
# [410]	training's WRMSSE: 0.536226	training's RMSE: 1.95673	valid_1's WRMSSE: 0.507087	valid_1's RMSE: 1.89008
# [411]	training's WRMSSE: 0.536139	training's RMSE: 1.95666	valid_1's WRMSSE: 0.507015	valid_1's RMSE: 1.89004
# [412]	training's WRMSSE: 0.536069	training's RMSE: 1.95652	valid_1's WRMSSE: 0.506966	valid_1's RMSE: 1.88996
# [413]	training's WRMSSE: 0.535983	training's RMSE: 1.95646	valid_1's WRMSSE: 0.506861	valid_1's RMSE: 1.88993
# [414]	training's WRMSSE: 0.535622	training's RMSE: 1.95636	valid_1's WRMSSE: 0.50648	valid_1's RMSE: 1.88985
# [415]	training's WRMSSE: 0.535459	training's RMSE: 1.95631	valid_1's WRMSSE: 0.506316	valid_1's RMSE: 1.88982
# [416]	training's WRMSSE: 0.535382	training's RMSE: 1.95625	valid_1's WRMSSE: 0.506289	valid_1's RMSE: 1.8898
# [417]	training's WRMSSE: 0.535325	training's RMSE: 1.95619	valid_1's WRMSSE: 0.50624	valid_1's RMSE: 1.88978
# [418]	training's WRMSSE: 0.535263	training's RMSE: 1.95613	valid_1's WRMSSE: 0.506168	valid_1's RMSE: 1.88976
# [419]	training's WRMSSE: 0.535125	training's RMSE: 1.95603	valid_1's WRMSSE: 0.506026	valid_1's RMSE: 1.8897
# [420]	training's WRMSSE: 0.535075	training's RMSE: 1.95596	valid_1's WRMSSE: 0.505963	valid_1's RMSE: 1.88969
# [421]	training's WRMSSE: 0.534997	training's RMSE: 1.95592	valid_1's WRMSSE: 0.505893	valid_1's RMSE: 1.88967
# [422]	training's WRMSSE: 0.5348	training's RMSE: 1.95583	valid_1's WRMSSE: 0.505812	valid_1's RMSE: 1.88963
# [423]	training's WRMSSE: 0.534643	training's RMSE: 1.95576	valid_1's WRMSSE: 0.50583	valid_1's RMSE: 1.8896
# [424]	training's WRMSSE: 0.534308	training's RMSE: 1.95568	valid_1's WRMSSE: 0.505577	valid_1's RMSE: 1.88957
# [425]	training's WRMSSE: 0.534172	training's RMSE: 1.95562	valid_1's WRMSSE: 0.505572	valid_1's RMSE: 1.88954
# [426]	training's WRMSSE: 0.534088	training's RMSE: 1.95556	valid_1's WRMSSE: 0.505481	valid_1's RMSE: 1.88952
# [427]	training's WRMSSE: 0.534024	training's RMSE: 1.95545	valid_1's WRMSSE: 0.505466	valid_1's RMSE: 1.88949
# [428]	training's WRMSSE: 0.533761	training's RMSE: 1.95536	valid_1's WRMSSE: 0.505323	valid_1's RMSE: 1.88946
# [429]	training's WRMSSE: 0.533702	training's RMSE: 1.9553	valid_1's WRMSSE: 0.50527	valid_1's RMSE: 1.88942
# [430]	training's WRMSSE: 0.533585	training's RMSE: 1.95522	valid_1's WRMSSE: 0.505237	valid_1's RMSE: 1.8894
# [431]	training's WRMSSE: 0.533545	training's RMSE: 1.95514	valid_1's WRMSSE: 0.505204	valid_1's RMSE: 1.88935
# [432]	training's WRMSSE: 0.533429	training's RMSE: 1.95505	valid_1's WRMSSE: 0.505086	valid_1's RMSE: 1.88928
# [433]	training's WRMSSE: 0.533372	training's RMSE: 1.95498	valid_1's WRMSSE: 0.505057	valid_1's RMSE: 1.88927
# [434]	training's WRMSSE: 0.533308	training's RMSE: 1.95493	valid_1's WRMSSE: 0.505011	valid_1's RMSE: 1.88924
# ...
# [1052]	training's WRMSSE: 0.492472	training's RMSE: 1.92108	valid_1's WRMSSE: 0.48612	valid_1's RMSE: 1.8765
# [1053]	training's WRMSSE: 0.492445	training's RMSE: 1.92104	valid_1's WRMSSE: 0.486126	valid_1's RMSE: 1.87649
# [1054]	training's WRMSSE: 0.492433	training's RMSE: 1.92099	valid_1's WRMSSE: 0.486125	valid_1's RMSE: 1.87648
# [1055]	training's WRMSSE: 0.492425	training's RMSE: 1.92097	valid_1's WRMSSE: 0.486095	valid_1's RMSE: 1.87648
# [1056]	training's WRMSSE: 0.492417	training's RMSE: 1.92093	valid_1's WRMSSE: 0.486104	valid_1's RMSE: 1.87646
# [1057]	training's WRMSSE: 0.492401	training's RMSE: 1.92087	valid_1's WRMSSE: 0.486101	valid_1's RMSE: 1.87646
# [1058]	training's WRMSSE: 0.492374	training's RMSE: 1.92083	valid_1's WRMSSE: 0.486113	valid_1's RMSE: 1.87645
# [1059]	training's WRMSSE: 0.49234	training's RMSE: 1.92081	valid_1's WRMSSE: 0.486111	valid_1's RMSE: 1.87645
# [1060]	training's WRMSSE: 0.492293	training's RMSE: 1.92079	valid_1's WRMSSE: 0.486034	valid_1's RMSE: 1.87644
# [1061]	training's WRMSSE: 0.492282	training's RMSE: 1.92073	valid_1's WRMSSE: 0.486042	valid_1's RMSE: 1.87642
# [1062]	training's WRMSSE: 0.492274	training's RMSE: 1.92071	valid_1's WRMSSE: 0.486042	valid_1's RMSE: 1.8764
# [1063]	training's WRMSSE: 0.492133	training's RMSE: 1.92066	valid_1's WRMSSE: 0.48605	valid_1's RMSE: 1.8764
# [1064]	training's WRMSSE: 0.49212	training's RMSE: 1.92063	valid_1's WRMSSE: 0.486041	valid_1's RMSE: 1.87637
# [1065]	training's WRMSSE: 0.49211	training's RMSE: 1.9206	valid_1's WRMSSE: 0.486048	valid_1's RMSE: 1.87636
# [1066]	training's WRMSSE: 0.492062	training's RMSE: 1.92055	valid_1's WRMSSE: 0.486046	valid_1's RMSE: 1.87634
# [1067]	training's WRMSSE: 0.492021	training's RMSE: 1.92053	valid_1's WRMSSE: 0.485993	valid_1's RMSE: 1.87632
# [1068]	training's WRMSSE: 0.491989	training's RMSE: 1.92052	valid_1's WRMSSE: 0.485995	valid_1's RMSE: 1.87631
# [1069]	training's WRMSSE: 0.491965	training's RMSE: 1.92046	valid_1's WRMSSE: 0.485987	valid_1's RMSE: 1.8763
# [1070]	training's WRMSSE: 0.491942	training's RMSE: 1.92045	valid_1's WRMSSE: 0.485988	valid_1's RMSE: 1.8763
# [1071]	training's WRMSSE: 0.491927	training's RMSE: 1.92043	valid_1's WRMSSE: 0.485978	valid_1's RMSE: 1.87628
# [1072]	training's WRMSSE: 0.491876	training's RMSE: 1.92041	valid_1's WRMSSE: 0.485978	valid_1's RMSE: 1.87628
# [1073]	training's WRMSSE: 0.491866	training's RMSE: 1.92035	valid_1's WRMSSE: 0.485975	valid_1's RMSE: 1.87627
# [1074]	training's WRMSSE: 0.491851	training's RMSE: 1.9203	valid_1's WRMSSE: 0.485968	valid_1's RMSE: 1.87625
# [1075]	training's WRMSSE: 0.491836	training's RMSE: 1.92027	valid_1's WRMSSE: 0.485975	valid_1's RMSE: 1.87624
# [1076]	training's WRMSSE: 0.491825	training's RMSE: 1.92023	valid_1's WRMSSE: 0.485973	valid_1's RMSE: 1.87621
# [1077]	training's WRMSSE: 0.491812	training's RMSE: 1.9202	valid_1's WRMSSE: 0.485972	valid_1's RMSE: 1.87621
# [1078]	training's WRMSSE: 0.491808	training's RMSE: 1.92019	valid_1's WRMSSE: 0.485973	valid_1's RMSE: 1.87621
# [1079]	training's WRMSSE: 0.491795	training's RMSE: 1.92017	valid_1's WRMSSE: 0.485974	valid_1's RMSE: 1.87621
# [1080]	training's WRMSSE: 0.491777	training's RMSE: 1.92016	valid_1's WRMSSE: 0.485961	valid_1's RMSE: 1.87621
# [1081]	training's WRMSSE: 0.491763	training's RMSE: 1.92011	valid_1's WRMSSE: 0.48597	valid_1's RMSE: 1.8762
# [1082]	training's WRMSSE: 0.49175	training's RMSE: 1.92009	valid_1's WRMSSE: 0.485968	valid_1's RMSE: 1.8762
# [1083]	training's WRMSSE: 0.491707	training's RMSE: 1.92004	valid_1's WRMSSE: 0.485965	valid_1's RMSE: 1.87617
# [1084]	training's WRMSSE: 0.491697	training's RMSE: 1.91997	valid_1's WRMSSE: 0.48597	valid_1's RMSE: 1.87614
# [1085]	training's WRMSSE: 0.491685	training's RMSE: 1.91992	valid_1's WRMSSE: 0.48597	valid_1's RMSE: 1.87612
# [1086]	training's WRMSSE: 0.491668	training's RMSE: 1.91988	valid_1's WRMSSE: 0.485968	valid_1's RMSE: 1.87613
# [1087]	training's WRMSSE: 0.491659	training's RMSE: 1.91984	valid_1's WRMSSE: 0.485974	valid_1's RMSE: 1.87611
# [1088]	training's WRMSSE: 0.491634	training's RMSE: 1.91982	valid_1's WRMSSE: 0.485942	valid_1's RMSE: 1.8761
# [1089]	training's WRMSSE: 0.491624	training's RMSE: 1.91977	valid_1's WRMSSE: 0.485947	valid_1's RMSE: 1.87608
# [1090]	training's WRMSSE: 0.491615	training's RMSE: 1.91972	valid_1's WRMSSE: 0.48596	valid_1's RMSE: 1.87607
# [1091]	training's WRMSSE: 0.491591	training's RMSE: 1.91969	valid_1's WRMSSE: 0.485956	valid_1's RMSE: 1.87606
# [1092]	training's WRMSSE: 0.491558	training's RMSE: 1.91963	valid_1's WRMSSE: 0.48597	valid_1's RMSE: 1.87606
# [1093]	training's WRMSSE: 0.491549	training's RMSE: 1.91961	valid_1's WRMSSE: 0.485963	valid_1's RMSE: 1.87605
# [1094]	training's WRMSSE: 0.491536	training's RMSE: 1.91958	valid_1's WRMSSE: 0.485967	valid_1's RMSE: 1.87605
# [1095]	training's WRMSSE: 0.491478	training's RMSE: 1.91955	valid_1's WRMSSE: 0.485971	valid_1's RMSE: 1.87604
# [1096]	training's WRMSSE: 0.491446	training's RMSE: 1.91954	valid_1's WRMSSE: 0.485964	valid_1's RMSE: 1.87604
# [1097]	training's WRMSSE: 0.491432	training's RMSE: 1.9195	valid_1's WRMSSE: 0.485965	valid_1's RMSE: 1.87602
# [1098]	training's WRMSSE: 0.491423	training's RMSE: 1.91948	valid_1's WRMSSE: 0.485967	valid_1's RMSE: 1.87601
# [1099]	training's WRMSSE: 0.491398	training's RMSE: 1.91944	valid_1's WRMSSE: 0.485961	valid_1's RMSE: 1.87601
# [1100]	training's WRMSSE: 0.491389	training's RMSE: 1.91942	valid_1's WRMSSE: 0.485959	valid_1's RMSE: 1.87601
# [1101]	training's WRMSSE: 0.491304	training's RMSE: 1.91938	valid_1's WRMSSE: 0.48597	valid_1's RMSE: 1.876
# [1102]	training's WRMSSE: 0.491294	training's RMSE: 1.91935	valid_1's WRMSSE: 0.485974	valid_1's RMSE: 1.87601
# [1103]	training's WRMSSE: 0.491278	training's RMSE: 1.91933	valid_1's WRMSSE: 0.485978	valid_1's RMSE: 1.876
# [1104]	training's WRMSSE: 0.491223	training's RMSE: 1.9193	valid_1's WRMSSE: 0.48594	valid_1's RMSE: 1.87599
# [1105]	training's WRMSSE: 0.491209	training's RMSE: 1.91925	valid_1's WRMSSE: 0.485943	valid_1's RMSE: 1.87597
# [1106]	training's WRMSSE: 0.491196	training's RMSE: 1.91922	valid_1's WRMSSE: 0.485932	valid_1's RMSE: 1.87595
# [1107]	training's WRMSSE: 0.491181	training's RMSE: 1.91918	valid_1's WRMSSE: 0.485933	valid_1's RMSE: 1.87596
# [1108]	training's WRMSSE: 0.491126	training's RMSE: 1.91912	valid_1's WRMSSE: 0.485905	valid_1's RMSE: 1.87591
# [1109]	training's WRMSSE: 0.491103	training's RMSE: 1.9191	valid_1's WRMSSE: 0.485898	valid_1's RMSE: 1.87591
# [1110]	training's WRMSSE: 0.491072	training's RMSE: 1.91905	valid_1's WRMSSE: 0.485865	valid_1's RMSE: 1.87588
# [1111]	training's WRMSSE: 0.491039	training's RMSE: 1.91902	valid_1's WRMSSE: 0.485839	valid_1's RMSE: 1.87587
# [1112]	training's WRMSSE: 0.490957	training's RMSE: 1.91899	valid_1's WRMSSE: 0.485743	valid_1's RMSE: 1.87587
# [1113]	training's WRMSSE: 0.490946	training's RMSE: 1.91894	valid_1's WRMSSE: 0.485744	valid_1's RMSE: 1.87586
# [1114]	training's WRMSSE: 0.49093	training's RMSE: 1.91889	valid_1's WRMSSE: 0.48573	valid_1's RMSE: 1.87585
# [1115]	training's WRMSSE: 0.4909	training's RMSE: 1.91885	valid_1's WRMSSE: 0.48574	valid_1's RMSE: 1.87584
# [1116]	training's WRMSSE: 0.490879	training's RMSE: 1.91879	valid_1's WRMSSE: 0.485735	valid_1's RMSE: 1.87581
# [1117]	training's WRMSSE: 0.490845	training's RMSE: 1.91875	valid_1's WRMSSE: 0.485739	valid_1's RMSE: 1.8758
# [1118]	training's WRMSSE: 0.490808	training's RMSE: 1.91875	valid_1's WRMSSE: 0.485683	valid_1's RMSE: 1.87586
# [1119]	training's WRMSSE: 0.490797	training's RMSE: 1.91873	valid_1's WRMSSE: 0.485685	valid_1's RMSE: 1.87586
# [1120]	training's WRMSSE: 0.49078	training's RMSE: 1.91871	valid_1's WRMSSE: 0.485683	valid_1's RMSE: 1.87586
# [1121]	training's WRMSSE: 0.490761	training's RMSE: 1.91868	valid_1's WRMSSE: 0.48567	valid_1's RMSE: 1.87585
# [1122]	training's WRMSSE: 0.49074	training's RMSE: 1.91865	valid_1's WRMSSE: 0.485681	valid_1's RMSE: 1.87586
# [1123]	training's WRMSSE: 0.490727	training's RMSE: 1.91858	valid_1's WRMSSE: 0.485698	valid_1's RMSE: 1.87584
# [1124]	training's WRMSSE: 0.490701	training's RMSE: 1.91855	valid_1's WRMSSE: 0.48569	valid_1's RMSE: 1.87583
# [1125]	training's WRMSSE: 0.490677	training's RMSE: 1.91853	valid_1's WRMSSE: 0.485699	valid_1's RMSE: 1.87583
# [1126]	training's WRMSSE: 0.49067	training's RMSE: 1.9185	valid_1's WRMSSE: 0.485689	valid_1's RMSE: 1.87581
# [1127]	training's WRMSSE: 0.490638	training's RMSE: 1.91847	valid_1's WRMSSE: 0.485691	valid_1's RMSE: 1.87583
# [1128]	training's WRMSSE: 0.490617	training's RMSE: 1.91845	valid_1's WRMSSE: 0.48568	valid_1's RMSE: 1.87582
# [1129]	training's WRMSSE: 0.490564	training's RMSE: 1.91842	valid_1's WRMSSE: 0.485666	valid_1's RMSE: 1.87581
# [1130]	training's WRMSSE: 0.490549	training's RMSE: 1.91839	valid_1's WRMSSE: 0.485669	valid_1's RMSE: 1.8758
# [1131]	training's WRMSSE: 0.490534	training's RMSE: 1.91838	valid_1's WRMSSE: 0.485664	valid_1's RMSE: 1.8758
# [1132]	training's WRMSSE: 0.490511	training's RMSE: 1.91834	valid_1's WRMSSE: 0.485664	valid_1's RMSE: 1.87578
# [1133]	training's WRMSSE: 0.490484	training's RMSE: 1.91831	valid_1's WRMSSE: 0.485643	valid_1's RMSE: 1.87579
# [1134]	training's WRMSSE: 0.49044	training's RMSE: 1.91823	valid_1's WRMSSE: 0.485654	valid_1's RMSE: 1.87578
# [1135]	training's WRMSSE: 0.490406	training's RMSE: 1.91817	valid_1's WRMSSE: 0.485629	valid_1's RMSE: 1.87575
# [1136]	training's WRMSSE: 0.490398	training's RMSE: 1.91814	valid_1's WRMSSE: 0.485641	valid_1's RMSE: 1.87573
# [1137]	training's WRMSSE: 0.49038	training's RMSE: 1.91813	valid_1's WRMSSE: 0.485639	valid_1's RMSE: 1.87573
# [1138]	training's WRMSSE: 0.49031	training's RMSE: 1.91812	valid_1's WRMSSE: 0.485615	valid_1's RMSE: 1.87572
# [1139]	training's WRMSSE: 0.490293	training's RMSE: 1.91806	valid_1's WRMSSE: 0.48561	valid_1's RMSE: 1.87571
# [1140]	training's WRMSSE: 0.49028	training's RMSE: 1.91801	valid_1's WRMSSE: 0.485613	valid_1's RMSE: 1.87571
# [1141]	training's WRMSSE: 2.14596	training's RMSE: 2.35035	valid_1's WRMSSE: 0.496617	valid_1's RMSE: 1.88731
# [1142]	training's WRMSSE: 2.11713	training's RMSE: 2.33884	valid_1's WRMSSE: 0.496381	valid_1's RMSE: 1.8872
# [1143]	training's WRMSSE: 2.08844	training's RMSE: 2.32756	valid_1's WRMSSE: 0.496071	valid_1's RMSE: 1.88696
# [1144]	training's WRMSSE: 2.07139	training's RMSE: 2.32177	valid_1's WRMSSE: 0.495918	valid_1's RMSE: 1.88687
# [1145]	training's WRMSSE: 2.04372	training's RMSE: 2.31102	valid_1's WRMSSE: 0.495649	valid_1's RMSE: 1.88665
# [1146]	training's WRMSSE: 2.01628	training's RMSE: 2.3005	valid_1's WRMSSE: 0.495463	valid_1's RMSE: 1.88654
# [1147]	training's WRMSSE: 1.98921	training's RMSE: 2.29017	valid_1's WRMSSE: 0.495174	valid_1's RMSE: 1.88631
# [1148]	training's WRMSSE: 1.9628	training's RMSE: 2.2801	valid_1's WRMSSE: 0.494877	valid_1's RMSE: 1.88608
# [1149]	training's WRMSSE: 1.9535	training's RMSE: 2.27746	valid_1's WRMSSE: 0.494806	valid_1's RMSE: 1.88601
# [1150]	training's WRMSSE: 1.92775	training's RMSE: 2.26795	valid_1's WRMSSE: 0.494581	valid_1's RMSE: 1.88585
# [1151]	training's WRMSSE: 1.90254	training's RMSE: 2.25876	valid_1's WRMSSE: 0.494332	valid_1's RMSE: 1.88565
# [1152]	training's WRMSSE: 1.87754	training's RMSE: 2.24965	valid_1's WRMSSE: 0.494083	valid_1's RMSE: 1.88544
# [1153]	training's WRMSSE: 1.86506	training's RMSE: 2.24572	valid_1's WRMSSE: 0.493986	valid_1's RMSE: 1.88541
# [1154]	training's WRMSSE: 1.84119	training's RMSE: 2.23706	valid_1's WRMSSE: 0.493733	valid_1's RMSE: 1.88522
# [1155]	training's WRMSSE: 1.81714	training's RMSE: 2.22848	valid_1's WRMSSE: 0.493551	valid_1's RMSE: 1.8851
# [1156]	training's WRMSSE: 1.80871	training's RMSE: 2.22542	valid_1's WRMSSE: 0.493463	valid_1's RMSE: 1.88503
# [1157]	training's WRMSSE: 1.78561	training's RMSE: 2.21726	valid_1's WRMSSE: 0.493242	valid_1's RMSE: 1.88486
# [1158]	training's WRMSSE: 1.76315	training's RMSE: 2.20933	valid_1's WRMSSE: 0.493046	valid_1's RMSE: 1.88471
# [1159]	training's WRMSSE: 1.74043	training's RMSE: 2.20144	valid_1's WRMSSE: 0.492813	valid_1's RMSE: 1.88453
# [1160]	training's WRMSSE: 1.7289	training's RMSE: 2.19808	valid_1's WRMSSE: 0.492727	valid_1's RMSE: 1.8845
# [1161]	training's WRMSSE: 1.72127	training's RMSE: 2.19542	valid_1's WRMSSE: 0.492635	valid_1's RMSE: 1.8844
# [1162]	training's WRMSSE: 1.69922	training's RMSE: 2.18794	valid_1's WRMSSE: 0.492457	valid_1's RMSE: 1.88429
# [1163]	training's WRMSSE: 1.6778	training's RMSE: 2.1807	valid_1's WRMSSE: 0.492232	valid_1's RMSE: 1.88411
# [1164]	training's WRMSSE: 1.67168	training's RMSE: 2.17936	valid_1's WRMSSE: 0.492231	valid_1's RMSE: 1.88409
# [1165]	training's WRMSSE: 1.6507	training's RMSE: 2.17238	valid_1's WRMSSE: 0.49203	valid_1's RMSE: 1.88393
# [1166]	training's WRMSSE: 1.64361	training's RMSE: 2.16998	valid_1's WRMSSE: 0.491949	valid_1's RMSE: 1.88384
# [1167]	training's WRMSSE: 1.62302	training's RMSE: 2.16342	valid_1's WRMSSE: 0.492493	valid_1's RMSE: 1.88423
# [1168]	training's WRMSSE: 1.6031	training's RMSE: 2.15691	valid_1's WRMSSE: 0.492287	valid_1's RMSE: 1.88406
# [1169]	training's WRMSSE: 1.58352	training's RMSE: 2.15223	valid_1's WRMSSE: 0.490862	valid_1's RMSE: 1.88721
# [1170]	training's WRMSSE: 13.6134	training's RMSE: 9.91933	valid_1's WRMSSE: 0.492596	valid_1's RMSE: 1.90952
# [1171]	training's WRMSSE: 21167.9	training's RMSE: 8114.47	valid_1's WRMSSE: 0.492553	valid_1's RMSE: 1.9091
# [1172]	training's WRMSSE: 189875	training's RMSE: 65907.4	valid_1's WRMSSE: 0.49257	valid_1's RMSE: 1.9091
# /opt/conda/lib/python3.7/site-packages/ipykernel_launcher.py:18: RuntimeWarning: overflow encountered in square
# /opt/conda/lib/python3.7/site-packages/ipykernel_launcher.py:19: RuntimeWarning: invalid value encountered in multiply
# /opt/conda/lib/python3.7/site-packages/ipykernel_launcher.py:2: RuntimeWarning: overflow encountered in power
# [1173]	training's WRMSSE: nan	training's RMSE: inf	valid_1's WRMSSE: nan	valid_1's RMSE: inf
# [1174]	training's WRMSSE: nan	training's RMSE: inf	valid_1's WRMSSE: nan	valid_1's RMSE: inf
# [1175]	training's WRMSSE: nan	training's RMSE: inf	valid_1's WRMSSE: nan	valid_1's RMSE: inf
# [1176]	training's WRMSSE: nan	training's RMSE: inf	valid_1's WRMSSE: nan	valid_1's RMSE: inf
# [1177]	training's WRMSSE: nan	training's RMSE: inf	valid_1's WRMSSE: nan	valid_1's RMSE: inf
# [1178]	training's WRMSSE: nan	training's RMSE: inf	valid_1's WRMSSE: nan	valid_1's RMSE: inf
# [1179]	training's WRMSSE: nan	training's RMSE: inf	valid_1's WRMSSE: nan	valid_1's RMSE: inf
# [1180]	training's WRMSSE: nan	training's RMSE: inf	valid_1's WRMSSE: nan	valid_1's RMSE: inf
# [1181]	training's WRMSSE: nan	training's RMSE: inf	valid_1's WRMSSE: nan	valid_1's RMSE: inf
# [1182]	training's WRMSSE: nan	training's RMSE: inf	valid_1's WRMSSE: nan	valid_1's RMSE: inf
# [1183]	training's WRMSSE: nan	training's RMSE: inf	valid_1's WRMSSE: nan	valid_1's RMSE: inf
# [1184]	training's WRMSSE: nan	training's RMSE: inf	valid_1's WRMSSE: nan	valid_1's RMSE: inf
# [1185]	training's WRMSSE: nan	training's RMSE: inf	valid_1's WRMSSE: nan	valid_1's RMSE: inf
# [1186]	training's WRMSSE: nan	training's RMSE: inf	valid_1's WRMSSE: nan	valid_1's RMSE: inf
# [1187]	training's WRMSSE: nan	training's RMSE: inf	valid_1's WRMSSE: nan	valid_1's RMSE: inf
# [1188]	training's WRMSSE: nan	training's RMSE: inf	valid_1's WRMSSE: nan	valid_1's RMSE: inf
# [1189]	training's WRMSSE: nan	training's RMSE: inf	valid_1's WRMSSE: nan	valid_1's RMSE: inf
# Early stopping, best iteration is:
# [1139]	training's WRMSSE: 0.490293	training's RMSE: 1.91806	valid_1's WRMSSE: 0.48561	valid_1's RMSE: 1.87571
# Evaluated only: WRMSSE
# LGBMRegressor(bagging_freq=1, boosting_type='gbdt', class_weight=None,
#        colsample_bytree=0.8, first_metric_only=True,
#        importance_type='gain', learning_rate=0.01, max_bin=63,
#        max_depth=-1, metric='None', min_child_samples=20,
#        min_child_weight=0.001, min_data_in_leaf=255, min_split_gain=0.0,
#        n_estimators=5000, n_jobs=12, num_leaves=255,
#        objective=<function custom_obj at 0x7fc7c69ffe18>, random_state=51,
#        reg_alpha=0.0, reg_lambda=0.0, silent=True, subsample=0.8,
#        subsample_for_bin=200000, subsample_freq=0)

# %%
#### 小于0.00001 直接打成100
lgb_re2.fit(X_train,y_train,eval_set = [(X_train,y_train),(X_valid,y_valid)],verbose=1,
           eval_metric =lambda y_true, y_pred: [evaluator_super.feval(y_true, y_pred), rmse(y_true, y_pred)],
           early_stopping_rounds=50,categorical_feature=cat_col)
# Out:
# /opt/conda/lib/python3.7/site-packages/lightgbm/basic.py:1295: UserWarning: categorical_feature in Dataset is overridden.
# New categorical_feature is ['cat_id', 'dept_id', 'event_name_1', 'event_name_2', 'event_type_1', 'event_type_2', 'item_id', 'state_id', 'store_id']
#   'New categorical_feature is {}'.format(sorted(list(categorical_feature))))
# /opt/conda/lib/python3.7/site-packages/lightgbm/basic.py:1295: UserWarning: categorical_feature in Dataset is overridden.
# New categorical_feature is ['cat_id', 'dept_id', 'event_name_1', 'event_name_2', 'event_type_1', 'event_type_2', 'item_id', 'state_id', 'store_id']
#   'New categorical_feature is {}'.format(sorted(list(categorical_feature))))
# [1]	training's WRMSSE: 4.80529	training's RMSE: 3.7891	valid_1's WRMSSE: 5.20822	valid_1's RMSE: 3.80853
# Training until validation scores don't improve for 50 rounds
# [2]	training's WRMSSE: 4.73251	training's RMSE: 3.74985	valid_1's WRMSSE: 5.12926	valid_1's RMSE: 3.76659
# [3]	training's WRMSSE: 4.66045	training's RMSE: 3.7108	valid_1's WRMSSE: 5.05099	valid_1's RMSE: 3.72499
# [4]	training's WRMSSE: 4.5896	training's RMSE: 3.67249	valid_1's WRMSSE: 4.97407	valid_1's RMSE: 3.68474
# [5]	training's WRMSSE: 4.5196	training's RMSE: 3.63486	valid_1's WRMSSE: 4.89821	valid_1's RMSE: 3.64501
# [6]	training's WRMSSE: 4.45112	training's RMSE: 3.59846	valid_1's WRMSSE: 4.82398	valid_1's RMSE: 3.60659
# [7]	training's WRMSSE: 4.38331	training's RMSE: 3.56233	valid_1's WRMSSE: 4.75048	valid_1's RMSE: 3.56821
# [8]	training's WRMSSE: 4.31668	training's RMSE: 3.52697	valid_1's WRMSSE: 4.67819	valid_1's RMSE: 3.53072
# [9]	training's WRMSSE: 4.25096	training's RMSE: 3.49207	valid_1's WRMSSE: 4.60695	valid_1's RMSE: 3.4937
# [10]	training's WRMSSE: 4.18624	training's RMSE: 3.45811	valid_1's WRMSSE: 4.53677	valid_1's RMSE: 3.45746
# [11]	training's WRMSSE: 4.12246	training's RMSE: 3.42499	valid_1's WRMSSE: 4.46765	valid_1's RMSE: 3.4223
# [12]	training's WRMSSE: 4.05972	training's RMSE: 3.39251	valid_1's WRMSSE: 4.39978	valid_1's RMSE: 3.38791
# [13]	training's WRMSSE: 3.99791	training's RMSE: 3.3604	valid_1's WRMSSE: 4.33284	valid_1's RMSE: 3.35404
# [14]	training's WRMSSE: 3.93714	training's RMSE: 3.32891	valid_1's WRMSSE: 4.26658	valid_1's RMSE: 3.32013
# [15]	training's WRMSSE: 3.87755	training's RMSE: 3.29829	valid_1's WRMSSE: 4.20184	valid_1's RMSE: 3.28804
# [16]	training's WRMSSE: 3.81855	training's RMSE: 3.26785	valid_1's WRMSSE: 4.13774	valid_1's RMSE: 3.25573
# [17]	training's WRMSSE: 3.76051	training's RMSE: 3.23834	valid_1's WRMSSE: 4.07465	valid_1's RMSE: 3.22403
# [18]	training's WRMSSE: 3.70319	training's RMSE: 3.20934	valid_1's WRMSSE: 4.01242	valid_1's RMSE: 3.19289
# [19]	training's WRMSSE: 3.6469	training's RMSE: 3.18083	valid_1's WRMSSE: 3.95105	valid_1's RMSE: 3.16224
# [20]	training's WRMSSE: 3.59144	training's RMSE: 3.15298	valid_1's WRMSSE: 3.89075	valid_1's RMSE: 3.1324
# [21]	training's WRMSSE: 3.53693	training's RMSE: 3.12587	valid_1's WRMSSE: 3.83141	valid_1's RMSE: 3.10323
# [22]	training's WRMSSE: 3.48326	training's RMSE: 3.09925	valid_1's WRMSSE: 3.77292	valid_1's RMSE: 3.07462
# [23]	training's WRMSSE: 3.43055	training's RMSE: 3.07339	valid_1's WRMSSE: 3.71564	valid_1's RMSE: 3.04717
# [24]	training's WRMSSE: 3.37882	training's RMSE: 3.04804	valid_1's WRMSSE: 3.65943	valid_1's RMSE: 3.02025
# [25]	training's WRMSSE: 3.32761	training's RMSE: 3.02282	valid_1's WRMSSE: 3.60355	valid_1's RMSE: 2.99316
# [26]	training's WRMSSE: 3.27728	training's RMSE: 2.99829	valid_1's WRMSSE: 3.54886	valid_1's RMSE: 2.96707
# [27]	training's WRMSSE: 3.22766	training's RMSE: 2.97415	valid_1's WRMSSE: 3.49482	valid_1's RMSE: 2.9414
# [28]	training's WRMSSE: 3.17905	training's RMSE: 2.95065	valid_1's WRMSSE: 3.44176	valid_1's RMSE: 2.91641
# [29]	training's WRMSSE: 3.13085	training's RMSE: 2.92759	valid_1's WRMSSE: 3.38914	valid_1's RMSE: 2.89168
# [30]	training's WRMSSE: 3.08347	training's RMSE: 2.90501	valid_1's WRMSSE: 3.33741	valid_1's RMSE: 2.86757
# [31]	training's WRMSSE: 3.03691	training's RMSE: 2.8831	valid_1's WRMSSE: 3.28669	valid_1's RMSE: 2.84426
# [32]	training's WRMSSE: 2.99124	training's RMSE: 2.86161	valid_1's WRMSSE: 3.23696	valid_1's RMSE: 2.82133
# [33]	training's WRMSSE: 2.94622	training's RMSE: 2.8404	valid_1's WRMSSE: 3.18789	valid_1's RMSE: 2.79881
# [34]	training's WRMSSE: 2.90181	training's RMSE: 2.81971	valid_1's WRMSSE: 3.13958	valid_1's RMSE: 2.77681
# [35]	training's WRMSSE: 2.8582	training's RMSE: 2.79925	valid_1's WRMSSE: 3.09192	valid_1's RMSE: 2.755
# [36]	training's WRMSSE: 2.81521	training's RMSE: 2.77948	valid_1's WRMSSE: 3.04503	valid_1's RMSE: 2.7339
# [37]	training's WRMSSE: 2.77306	training's RMSE: 2.76015	valid_1's WRMSSE: 2.9989	valid_1's RMSE: 2.71322
# [38]	training's WRMSSE: 2.73144	training's RMSE: 2.74121	valid_1's WRMSSE: 2.95344	valid_1's RMSE: 2.69291
# [39]	training's WRMSSE: 2.69055	training's RMSE: 2.72273	valid_1's WRMSSE: 2.90879	valid_1's RMSE: 2.67318
# [40]	training's WRMSSE: 2.6502	training's RMSE: 2.7045	valid_1's WRMSSE: 2.86463	valid_1's RMSE: 2.65355
# [41]	training's WRMSSE: 2.61055	training's RMSE: 2.68687	valid_1's WRMSSE: 2.82132	valid_1's RMSE: 2.63477
# [42]	training's WRMSSE: 2.57166	training's RMSE: 2.66959	valid_1's WRMSSE: 2.7787	valid_1's RMSE: 2.61634
# [43]	training's WRMSSE: 2.53337	training's RMSE: 2.65263	valid_1's WRMSSE: 2.73675	valid_1's RMSE: 2.59811
# [44]	training's WRMSSE: 2.49563	training's RMSE: 2.6362	valid_1's WRMSSE: 2.69547	valid_1's RMSE: 2.58049
# [45]	training's WRMSSE: 2.45859	training's RMSE: 2.61999	valid_1's WRMSSE: 2.65486	valid_1's RMSE: 2.56309
# [46]	training's WRMSSE: 2.42201	training's RMSE: 2.60422	valid_1's WRMSSE: 2.61477	valid_1's RMSE: 2.54608
# [47]	training's WRMSSE: 2.38617	training's RMSE: 2.58871	valid_1's WRMSSE: 2.57543	valid_1's RMSE: 2.52944
# [48]	training's WRMSSE: 2.35089	training's RMSE: 2.57354	valid_1's WRMSSE: 2.5368	valid_1's RMSE: 2.51324
# [49]	training's WRMSSE: 2.31622	training's RMSE: 2.55892	valid_1's WRMSSE: 2.49873	valid_1's RMSE: 2.49761
# [50]	training's WRMSSE: 2.28209	training's RMSE: 2.54452	valid_1's WRMSSE: 2.4612	valid_1's RMSE: 2.48215
# [51]	training's WRMSSE: 2.24845	training's RMSE: 2.53029	valid_1's WRMSSE: 2.42427	valid_1's RMSE: 2.46694
# [52]	training's WRMSSE: 2.21539	training's RMSE: 2.51649	valid_1's WRMSSE: 2.38803	valid_1's RMSE: 2.45223
# [53]	training's WRMSSE: 2.1829	training's RMSE: 2.50305	valid_1's WRMSSE: 2.35236	valid_1's RMSE: 2.43797
# [54]	training's WRMSSE: 2.15096	training's RMSE: 2.48988	valid_1's WRMSSE: 2.31729	valid_1's RMSE: 2.42389
# [55]	training's WRMSSE: 2.11961	training's RMSE: 2.47706	valid_1's WRMSSE: 2.2828	valid_1's RMSE: 2.41012
# [56]	training's WRMSSE: 2.08879	training's RMSE: 2.46449	valid_1's WRMSSE: 2.24877	valid_1's RMSE: 2.3966
# [57]	training's WRMSSE: 2.0584	training's RMSE: 2.45218	valid_1's WRMSSE: 2.21543	valid_1's RMSE: 2.38371
# [58]	training's WRMSSE: 2.02868	training's RMSE: 2.44025	valid_1's WRMSSE: 2.18265	valid_1's RMSE: 2.37094
# [59]	training's WRMSSE: 1.99923	training's RMSE: 2.4287	valid_1's WRMSSE: 2.15018	valid_1's RMSE: 2.35837
# [60]	training's WRMSSE: 1.9705	training's RMSE: 2.41736	valid_1's WRMSSE: 2.11847	valid_1's RMSE: 2.34622
# [61]	training's WRMSSE: 1.94226	training's RMSE: 2.40625	valid_1's WRMSSE: 2.08726	valid_1's RMSE: 2.33432
# [62]	training's WRMSSE: 1.91448	training's RMSE: 2.39551	valid_1's WRMSSE: 2.05654	valid_1's RMSE: 2.32285
# [63]	training's WRMSSE: 1.88725	training's RMSE: 2.38497	valid_1's WRMSSE: 2.02641	valid_1's RMSE: 2.31166
# [64]	training's WRMSSE: 1.86028	training's RMSE: 2.37458	valid_1's WRMSSE: 1.99663	valid_1's RMSE: 2.30063
# [65]	training's WRMSSE: 1.83396	training's RMSE: 2.36464	valid_1's WRMSSE: 1.96747	valid_1's RMSE: 2.28996
# [66]	training's WRMSSE: 1.80803	training's RMSE: 2.35476	valid_1's WRMSSE: 1.93878	valid_1's RMSE: 2.27944
# [67]	training's WRMSSE: 1.78253	training's RMSE: 2.34514	valid_1's WRMSSE: 1.91062	valid_1's RMSE: 2.26918
# [68]	training's WRMSSE: 1.75754	training's RMSE: 2.33596	valid_1's WRMSSE: 1.88301	valid_1's RMSE: 2.25943
# [69]	training's WRMSSE: 1.73283	training's RMSE: 2.32686	valid_1's WRMSSE: 1.85559	valid_1's RMSE: 2.24968
# [70]	training's WRMSSE: 1.70866	training's RMSE: 2.31796	valid_1's WRMSSE: 1.82898	valid_1's RMSE: 2.24026
# [71]	training's WRMSSE: 1.68504	training's RMSE: 2.30931	valid_1's WRMSSE: 1.8029	valid_1's RMSE: 2.23107
# [72]	training's WRMSSE: 1.66177	training's RMSE: 2.30084	valid_1's WRMSSE: 1.7769	valid_1's RMSE: 2.22202
# [73]	training's WRMSSE: 1.63874	training's RMSE: 2.29248	valid_1's WRMSSE: 1.75141	valid_1's RMSE: 2.21319
# [74]	training's WRMSSE: 1.61628	training's RMSE: 2.28438	valid_1's WRMSSE: 1.7265	valid_1's RMSE: 2.20464
# [75]	training's WRMSSE: 1.5942	training's RMSE: 2.27648	valid_1's WRMSSE: 1.70202	valid_1's RMSE: 2.19633
# [76]	training's WRMSSE: 1.57255	training's RMSE: 2.26886	valid_1's WRMSSE: 1.678	valid_1's RMSE: 2.18825
# [77]	training's WRMSSE: 1.55125	training's RMSE: 2.26142	valid_1's WRMSSE: 1.6543	valid_1's RMSE: 2.18034
# [78]	training's WRMSSE: 1.53041	training's RMSE: 2.25422	valid_1's WRMSSE: 1.63095	valid_1's RMSE: 2.17267
# [79]	training's WRMSSE: 1.50989	training's RMSE: 2.24705	valid_1's WRMSSE: 1.60809	valid_1's RMSE: 2.16504
# [80]	training's WRMSSE: 1.48976	training's RMSE: 2.24019	valid_1's WRMSSE: 1.58566	valid_1's RMSE: 2.15781
# [81]	training's WRMSSE: 1.46998	training's RMSE: 2.23348	valid_1's WRMSSE: 1.56361	valid_1's RMSE: 2.15072
# [82]	training's WRMSSE: 1.45063	training's RMSE: 2.22696	valid_1's WRMSSE: 1.54194	valid_1's RMSE: 2.14381
# [83]	training's WRMSSE: 1.43161	training's RMSE: 2.22061	valid_1's WRMSSE: 1.52076	valid_1's RMSE: 2.13714
# [84]	training's WRMSSE: 1.413	training's RMSE: 2.21428	valid_1's WRMSSE: 1.5	valid_1's RMSE: 2.13055
# [85]	training's WRMSSE: 1.39469	training's RMSE: 2.20827	valid_1's WRMSSE: 1.47946	valid_1's RMSE: 2.12411
# [86]	training's WRMSSE: 1.3766	training's RMSE: 2.20244	valid_1's WRMSSE: 1.45927	valid_1's RMSE: 2.11797
# [87]	training's WRMSSE: 1.35905	training's RMSE: 2.19655	valid_1's WRMSSE: 1.43974	valid_1's RMSE: 2.11184
# [88]	training's WRMSSE: 1.34174	training's RMSE: 2.19102	valid_1's WRMSSE: 1.42033	valid_1's RMSE: 2.10601
# [89]	training's WRMSSE: 1.32479	training's RMSE: 2.18553	valid_1's WRMSSE: 1.40128	valid_1's RMSE: 2.10027
# [90]	training's WRMSSE: 1.3082	training's RMSE: 2.18028	valid_1's WRMSSE: 1.38257	valid_1's RMSE: 2.09475
# [91]	training's WRMSSE: 1.2919	training's RMSE: 2.17514	valid_1's WRMSSE: 1.36418	valid_1's RMSE: 2.08944
# [92]	training's WRMSSE: 1.27581	training's RMSE: 2.1701	valid_1's WRMSSE: 1.34615	valid_1's RMSE: 2.08426
# [93]	training's WRMSSE: 1.26022	training's RMSE: 2.16504	valid_1's WRMSSE: 1.32876	valid_1's RMSE: 2.07909
# [94]	training's WRMSSE: 1.24485	training's RMSE: 2.16022	valid_1's WRMSSE: 1.31136	valid_1's RMSE: 2.07405
# [95]	training's WRMSSE: 1.22974	training's RMSE: 2.15561	valid_1's WRMSSE: 1.29419	valid_1's RMSE: 2.06929
# [96]	training's WRMSSE: 1.21491	training's RMSE: 2.15103	valid_1's WRMSSE: 1.2773	valid_1's RMSE: 2.06447
# [97]	training's WRMSSE: 1.20056	training's RMSE: 2.14665	valid_1's WRMSSE: 1.26112	valid_1's RMSE: 2.05994
# [98]	training's WRMSSE: 1.18646	training's RMSE: 2.14237	valid_1's WRMSSE: 1.24515	valid_1's RMSE: 2.05552
# [99]	training's WRMSSE: 1.1725	training's RMSE: 2.13816	valid_1's WRMSSE: 1.22937	valid_1's RMSE: 2.05113
# [100]	training's WRMSSE: 1.15876	training's RMSE: 2.13418	valid_1's WRMSSE: 1.21344	valid_1's RMSE: 2.04698
# [101]	training's WRMSSE: 1.14543	training's RMSE: 2.13022	valid_1's WRMSSE: 1.19829	valid_1's RMSE: 2.04294
# [102]	training's WRMSSE: 1.13236	training's RMSE: 2.12632	valid_1's WRMSSE: 1.18349	valid_1's RMSE: 2.03896
# [103]	training's WRMSSE: 1.11954	training's RMSE: 2.12246	valid_1's WRMSSE: 1.16894	valid_1's RMSE: 2.03504
# [104]	training's WRMSSE: 1.10693	training's RMSE: 2.11872	valid_1's WRMSSE: 1.15453	valid_1's RMSE: 2.03118
# [105]	training's WRMSSE: 1.09454	training's RMSE: 2.1153	valid_1's WRMSSE: 1.14026	valid_1's RMSE: 2.0276
# [106]	training's WRMSSE: 1.08247	training's RMSE: 2.11174	valid_1's WRMSSE: 1.12652	valid_1's RMSE: 2.02394
# [107]	training's WRMSSE: 1.07064	training's RMSE: 2.10838	valid_1's WRMSSE: 1.113	valid_1's RMSE: 2.02046
# [108]	training's WRMSSE: 1.05912	training's RMSE: 2.10506	valid_1's WRMSSE: 1.09983	valid_1's RMSE: 2.0171
# [109]	training's WRMSSE: 1.04781	training's RMSE: 2.10184	valid_1's WRMSSE: 1.08698	valid_1's RMSE: 2.01385
# [110]	training's WRMSSE: 1.03684	training's RMSE: 2.09864	valid_1's WRMSSE: 1.07446	valid_1's RMSE: 2.0106
# [111]	training's WRMSSE: 1.02595	training's RMSE: 2.09566	valid_1's WRMSSE: 1.06213	valid_1's RMSE: 2.00758
# [112]	training's WRMSSE: 1.01545	training's RMSE: 2.09271	valid_1's WRMSSE: 1.05015	valid_1's RMSE: 2.00461
# [113]	training's WRMSSE: 1.00504	training's RMSE: 2.08982	valid_1's WRMSSE: 1.0381	valid_1's RMSE: 2.00165
# [114]	training's WRMSSE: 0.994734	training's RMSE: 2.08713	valid_1's WRMSSE: 1.02635	valid_1's RMSE: 1.99888
# [115]	training's WRMSSE: 0.984694	training's RMSE: 2.08431	valid_1's WRMSSE: 1.01478	valid_1's RMSE: 1.99618
# [116]	training's WRMSSE: 0.974794	training's RMSE: 2.08169	valid_1's WRMSSE: 1.00335	valid_1's RMSE: 1.9935
# [117]	training's WRMSSE: 0.965274	training's RMSE: 2.07904	valid_1's WRMSSE: 0.992332	valid_1's RMSE: 1.99087
# [118]	training's WRMSSE: 0.955994	training's RMSE: 2.0765	valid_1's WRMSSE: 0.981678	valid_1's RMSE: 1.98836
# [119]	training's WRMSSE: 0.9469	training's RMSE: 2.07395	valid_1's WRMSSE: 0.971172	valid_1's RMSE: 1.98587
# [120]	training's WRMSSE: 0.937932	training's RMSE: 2.07158	valid_1's WRMSSE: 0.96065	valid_1's RMSE: 1.98352
# [121]	training's WRMSSE: 0.929021	training's RMSE: 2.06937	valid_1's WRMSSE: 0.950331	valid_1's RMSE: 1.98129
# [122]	training's WRMSSE: 0.920474	training's RMSE: 2.06698	valid_1's WRMSSE: 0.94024	valid_1's RMSE: 1.97901
# [123]	training's WRMSSE: 0.912045	training's RMSE: 2.06479	valid_1's WRMSSE: 0.930426	valid_1's RMSE: 1.97681
# [124]	training's WRMSSE: 0.903937	training's RMSE: 2.06259	valid_1's WRMSSE: 0.92115	valid_1's RMSE: 1.9747
# [125]	training's WRMSSE: 0.896143	training's RMSE: 2.06046	valid_1's WRMSSE: 0.912307	valid_1's RMSE: 1.9727
# [126]	training's WRMSSE: 0.888333	training's RMSE: 2.0584	valid_1's WRMSSE: 0.903015	valid_1's RMSE: 1.9707
# [127]	training's WRMSSE: 0.880729	training's RMSE: 2.05636	valid_1's WRMSSE: 0.894164	valid_1's RMSE: 1.96872
# [128]	training's WRMSSE: 0.873217	training's RMSE: 2.05439	valid_1's WRMSSE: 0.885321	valid_1's RMSE: 1.96683
# [129]	training's WRMSSE: 0.865944	training's RMSE: 2.05251	valid_1's WRMSSE: 0.876924	valid_1's RMSE: 1.965
# [130]	training's WRMSSE: 0.85875	training's RMSE: 2.0506	valid_1's WRMSSE: 0.868429	valid_1's RMSE: 1.96318
# [131]	training's WRMSSE: 0.851668	training's RMSE: 2.04881	valid_1's WRMSSE: 0.86013	valid_1's RMSE: 1.96147
# [132]	training's WRMSSE: 0.84487	training's RMSE: 2.04714	valid_1's WRMSSE: 0.85221	valid_1's RMSE: 1.95977
# [133]	training's WRMSSE: 0.838315	training's RMSE: 2.04539	valid_1's WRMSSE: 0.844384	valid_1's RMSE: 1.95807
# [134]	training's WRMSSE: 0.83174	training's RMSE: 2.04374	valid_1's WRMSSE: 0.836568	valid_1's RMSE: 1.95649
# [135]	training's WRMSSE: 0.825351	training's RMSE: 2.04215	valid_1's WRMSSE: 0.829053	valid_1's RMSE: 1.9549
# [136]	training's WRMSSE: 0.819139	training's RMSE: 2.04055	valid_1's WRMSSE: 0.821643	valid_1's RMSE: 1.95343
# [137]	training's WRMSSE: 0.813174	training's RMSE: 2.03903	valid_1's WRMSSE: 0.814527	valid_1's RMSE: 1.95194
# [138]	training's WRMSSE: 0.807361	training's RMSE: 2.03757	valid_1's WRMSSE: 0.807663	valid_1's RMSE: 1.95058
# [139]	training's WRMSSE: 0.801608	training's RMSE: 2.0361	valid_1's WRMSSE: 0.800979	valid_1's RMSE: 1.94925
# [140]	training's WRMSSE: 0.795948	training's RMSE: 2.03469	valid_1's WRMSSE: 0.794124	valid_1's RMSE: 1.94794
# [141]	training's WRMSSE: 0.790425	training's RMSE: 2.03333	valid_1's WRMSSE: 0.787444	valid_1's RMSE: 1.94668
# [142]	training's WRMSSE: 0.785088	training's RMSE: 2.03193	valid_1's WRMSSE: 0.781194	valid_1's RMSE: 1.94535
# [143]	training's WRMSSE: 0.779813	training's RMSE: 2.03063	valid_1's WRMSSE: 0.774961	valid_1's RMSE: 1.94414
# [144]	training's WRMSSE: 0.774691	training's RMSE: 2.02936	valid_1's WRMSSE: 0.768821	valid_1's RMSE: 1.94296
# [145]	training's WRMSSE: 0.769824	training's RMSE: 2.02815	valid_1's WRMSSE: 0.763071	valid_1's RMSE: 1.94184
# [146]	training's WRMSSE: 0.765111	training's RMSE: 2.02689	valid_1's WRMSSE: 0.757644	valid_1's RMSE: 1.94075
# [147]	training's WRMSSE: 0.760535	training's RMSE: 2.02568	valid_1's WRMSSE: 0.752409	valid_1's RMSE: 1.93969
# [148]	training's WRMSSE: 0.755876	training's RMSE: 2.02451	valid_1's WRMSSE: 0.746721	valid_1's RMSE: 1.93858
# [149]	training's WRMSSE: 0.751227	training's RMSE: 2.02341	valid_1's WRMSSE: 0.741068	valid_1's RMSE: 1.93755
# [150]	training's WRMSSE: 0.746881	training's RMSE: 2.02236	valid_1's WRMSSE: 0.735869	valid_1's RMSE: 1.9366
# [151]	training's WRMSSE: 0.742626	training's RMSE: 2.02128	valid_1's WRMSSE: 0.730819	valid_1's RMSE: 1.93564
# [152]	training's WRMSSE: 0.738557	training's RMSE: 2.02028	valid_1's WRMSSE: 0.725935	valid_1's RMSE: 1.93476
# [153]	training's WRMSSE: 0.734465	training's RMSE: 2.01926	valid_1's WRMSSE: 0.720851	valid_1's RMSE: 1.93383
# [154]	training's WRMSSE: 0.730478	training's RMSE: 2.01827	valid_1's WRMSSE: 0.716163	valid_1's RMSE: 1.93296
# [155]	training's WRMSSE: 0.726612	training's RMSE: 2.01731	valid_1's WRMSSE: 0.711566	valid_1's RMSE: 1.93213
# [156]	training's WRMSSE: 0.722678	training's RMSE: 2.0164	valid_1's WRMSSE: 0.706908	valid_1's RMSE: 1.93132
# [157]	training's WRMSSE: 0.718941	training's RMSE: 2.0155	valid_1's WRMSSE: 0.702374	valid_1's RMSE: 1.9305
# [158]	training's WRMSSE: 0.715258	training's RMSE: 2.01461	valid_1's WRMSSE: 0.698009	valid_1's RMSE: 1.92975
# [159]	training's WRMSSE: 0.711502	training's RMSE: 2.01375	valid_1's WRMSSE: 0.693561	valid_1's RMSE: 1.92897
# [160]	training's WRMSSE: 0.70818	training's RMSE: 2.01283	valid_1's WRMSSE: 0.689728	valid_1's RMSE: 1.92821
# [161]	training's WRMSSE: 0.70484	training's RMSE: 2.01205	valid_1's WRMSSE: 0.685665	valid_1's RMSE: 1.92753
# [162]	training's WRMSSE: 0.701536	training's RMSE: 2.01124	valid_1's WRMSSE: 0.681734	valid_1's RMSE: 1.92685
# [163]	training's WRMSSE: 0.698353	training's RMSE: 2.01047	valid_1's WRMSSE: 0.678029	valid_1's RMSE: 1.92623
# [164]	training's WRMSSE: 0.695123	training's RMSE: 2.00972	valid_1's WRMSSE: 0.674169	valid_1's RMSE: 1.92559
# [165]	training's WRMSSE: 0.691989	training's RMSE: 2.00894	valid_1's WRMSSE: 0.670429	valid_1's RMSE: 1.92491
# [166]	training's WRMSSE: 0.688884	training's RMSE: 2.00818	valid_1's WRMSSE: 0.666686	valid_1's RMSE: 1.92427
# [167]	training's WRMSSE: 0.685943	training's RMSE: 2.00746	valid_1's WRMSSE: 0.663127	valid_1's RMSE: 1.92365
# [168]	training's WRMSSE: 0.683271	training's RMSE: 2.0068	valid_1's WRMSSE: 0.660045	valid_1's RMSE: 1.92315
# [169]	training's WRMSSE: 0.680387	training's RMSE: 2.0062	valid_1's WRMSSE: 0.656762	valid_1's RMSE: 1.92262
# [170]	training's WRMSSE: 0.677805	training's RMSE: 2.00556	valid_1's WRMSSE: 0.653834	valid_1's RMSE: 1.9221
# [171]	training's WRMSSE: 0.675193	training's RMSE: 2.00489	valid_1's WRMSSE: 0.650567	valid_1's RMSE: 1.9216
# [172]	training's WRMSSE: 0.672618	training's RMSE: 2.00426	valid_1's WRMSSE: 0.647444	valid_1's RMSE: 1.92109
# [173]	training's WRMSSE: 0.670153	training's RMSE: 2.00374	valid_1's WRMSSE: 0.64427	valid_1's RMSE: 1.92066
# [174]	training's WRMSSE: 0.667621	training's RMSE: 2.00312	valid_1's WRMSSE: 0.641275	valid_1's RMSE: 1.92013
# [175]	training's WRMSSE: 0.665192	training's RMSE: 2.00252	valid_1's WRMSSE: 0.638332	valid_1's RMSE: 1.91961
# [176]	training's WRMSSE: 0.662859	training's RMSE: 2.00194	valid_1's WRMSSE: 0.635534	valid_1's RMSE: 1.9191
# [177]	training's WRMSSE: 0.660545	training's RMSE: 2.00129	valid_1's WRMSSE: 0.63272	valid_1's RMSE: 1.91858
# [178]	training's WRMSSE: 0.658051	training's RMSE: 2.00076	valid_1's WRMSSE: 0.629797	valid_1's RMSE: 1.91809
# [179]	training's WRMSSE: 0.655834	training's RMSE: 2.00022	valid_1's WRMSSE: 0.627167	valid_1's RMSE: 1.91767
# [180]	training's WRMSSE: 0.653793	training's RMSE: 1.99971	valid_1's WRMSSE: 0.624725	valid_1's RMSE: 1.91728
# [181]	training's WRMSSE: 0.651681	training's RMSE: 1.99909	valid_1's WRMSSE: 0.622218	valid_1's RMSE: 1.91682
# [182]	training's WRMSSE: 0.649474	training's RMSE: 1.99849	valid_1's WRMSSE: 0.619598	valid_1's RMSE: 1.91631
# [183]	training's WRMSSE: 0.647468	training's RMSE: 1.99802	valid_1's WRMSSE: 0.617194	valid_1's RMSE: 1.91594
# [184]	training's WRMSSE: 0.645317	training's RMSE: 1.99758	valid_1's WRMSSE: 0.614776	valid_1's RMSE: 1.91558
# [185]	training's WRMSSE: 0.643406	training's RMSE: 1.99715	valid_1's WRMSSE: 0.612608	valid_1's RMSE: 1.91523
# [186]	training's WRMSSE: 0.641656	training's RMSE: 1.9967	valid_1's WRMSSE: 0.610521	valid_1's RMSE: 1.9149
# [187]	training's WRMSSE: 0.639904	training's RMSE: 1.99621	valid_1's WRMSSE: 0.608404	valid_1's RMSE: 1.91448
# [188]	training's WRMSSE: 0.638057	training's RMSE: 1.99579	valid_1's WRMSSE: 0.606312	valid_1's RMSE: 1.91414
# [189]	training's WRMSSE: 0.636238	training's RMSE: 1.9953	valid_1's WRMSSE: 0.604303	valid_1's RMSE: 1.91376
# [190]	training's WRMSSE: 0.634541	training's RMSE: 1.99483	valid_1's WRMSSE: 0.602439	valid_1's RMSE: 1.91346
# [191]	training's WRMSSE: 0.632969	training's RMSE: 1.99438	valid_1's WRMSSE: 0.600626	valid_1's RMSE: 1.91313
# [192]	training's WRMSSE: 0.631448	training's RMSE: 1.99397	valid_1's WRMSSE: 0.598856	valid_1's RMSE: 1.91283
# [193]	training's WRMSSE: 0.629997	training's RMSE: 1.99358	valid_1's WRMSSE: 0.597146	valid_1's RMSE: 1.91256
# [194]	training's WRMSSE: 0.628489	training's RMSE: 1.99317	valid_1's WRMSSE: 0.595395	valid_1's RMSE: 1.91228
# [195]	training's WRMSSE: 0.627165	training's RMSE: 1.99277	valid_1's WRMSSE: 0.593864	valid_1's RMSE: 1.91201
# [196]	training's WRMSSE: 0.625744	training's RMSE: 1.99245	valid_1's WRMSSE: 0.592096	valid_1's RMSE: 1.91176
# [197]	training's WRMSSE: 0.624452	training's RMSE: 1.99207	valid_1's WRMSSE: 0.590611	valid_1's RMSE: 1.91146
# [198]	training's WRMSSE: 0.623083	training's RMSE: 1.99172	valid_1's WRMSSE: 0.589042	valid_1's RMSE: 1.91121
# [199]	training's WRMSSE: 0.621807	training's RMSE: 1.99136	valid_1's WRMSSE: 0.58756	valid_1's RMSE: 1.91094
# [200]	training's WRMSSE: 0.620461	training's RMSE: 1.99094	valid_1's WRMSSE: 0.585983	valid_1's RMSE: 1.91061
# [201]	training's WRMSSE: 0.619303	training's RMSE: 1.99058	valid_1's WRMSSE: 0.584664	valid_1's RMSE: 1.91037
# [202]	training's WRMSSE: 0.618099	training's RMSE: 1.99024	valid_1's WRMSSE: 0.583343	valid_1's RMSE: 1.91015
# [203]	training's WRMSSE: 0.616926	training's RMSE: 1.98993	valid_1's WRMSSE: 0.582046	valid_1's RMSE: 1.90994
# [204]	training's WRMSSE: 0.615742	training's RMSE: 1.98957	valid_1's WRMSSE: 0.580652	valid_1's RMSE: 1.90972
# [205]	training's WRMSSE: 0.614457	training's RMSE: 1.98928	valid_1's WRMSSE: 0.579177	valid_1's RMSE: 1.90951
# [206]	training's WRMSSE: 0.613376	training's RMSE: 1.98895	valid_1's WRMSSE: 0.577911	valid_1's RMSE: 1.90924
# [207]	training's WRMSSE: 0.612264	training's RMSE: 1.98872	valid_1's WRMSSE: 0.576634	valid_1's RMSE: 1.90906
# [208]	training's WRMSSE: 0.611103	training's RMSE: 1.98849	valid_1's WRMSSE: 0.575403	valid_1's RMSE: 1.9089
# [209]	training's WRMSSE: 0.610079	training's RMSE: 1.98815	valid_1's WRMSSE: 0.57418	valid_1's RMSE: 1.90864
# [210]	training's WRMSSE: 0.608991	training's RMSE: 1.98774	valid_1's WRMSSE: 0.572973	valid_1's RMSE: 1.90832
# [211]	training's WRMSSE: 0.607953	training's RMSE: 1.98747	valid_1's WRMSSE: 0.571843	valid_1's RMSE: 1.90816
# [212]	training's WRMSSE: 0.607032	training's RMSE: 1.98723	valid_1's WRMSSE: 0.570713	valid_1's RMSE: 1.90799
# [213]	training's WRMSSE: 0.605957	training's RMSE: 1.98698	valid_1's WRMSSE: 0.569485	valid_1's RMSE: 1.90776
# [214]	training's WRMSSE: 0.604957	training's RMSE: 1.98659	valid_1's WRMSSE: 0.568409	valid_1's RMSE: 1.90747
# [215]	training's WRMSSE: 0.603902	training's RMSE: 1.98638	valid_1's WRMSSE: 0.567304	valid_1's RMSE: 1.90724
# [216]	training's WRMSSE: 0.602982	training's RMSE: 1.98605	valid_1's WRMSSE: 0.566171	valid_1's RMSE: 1.90698
# [217]	training's WRMSSE: 0.602189	training's RMSE: 1.98581	valid_1's WRMSSE: 0.56528	valid_1's RMSE: 1.90682
# [218]	training's WRMSSE: 0.601252	training's RMSE: 1.98557	valid_1's WRMSSE: 0.564267	valid_1's RMSE: 1.90666
# [219]	training's WRMSSE: 0.600471	training's RMSE: 1.98537	valid_1's WRMSSE: 0.563504	valid_1's RMSE: 1.90655
# [220]	training's WRMSSE: 0.599643	training's RMSE: 1.98508	valid_1's WRMSSE: 0.562681	valid_1's RMSE: 1.90635
# [221]	training's WRMSSE: 0.598743	training's RMSE: 1.98479	valid_1's WRMSSE: 0.561788	valid_1's RMSE: 1.90619
# [222]	training's WRMSSE: 0.597876	training's RMSE: 1.98453	valid_1's WRMSSE: 0.560904	valid_1's RMSE: 1.90597
# [223]	training's WRMSSE: 0.596925	training's RMSE: 1.98427	valid_1's WRMSSE: 0.559779	valid_1's RMSE: 1.90577
# [224]	training's WRMSSE: 0.596058	training's RMSE: 1.98394	valid_1's WRMSSE: 0.558814	valid_1's RMSE: 1.90552
# [225]	training's WRMSSE: 0.595218	training's RMSE: 1.98369	valid_1's WRMSSE: 0.557938	valid_1's RMSE: 1.90534
# [226]	training's WRMSSE: 0.594352	training's RMSE: 1.98351	valid_1's WRMSSE: 0.557002	valid_1's RMSE: 1.9052
# [227]	training's WRMSSE: 0.593566	training's RMSE: 1.98326	valid_1's WRMSSE: 0.556161	valid_1's RMSE: 1.90502
# [228]	training's WRMSSE: 0.592993	training's RMSE: 1.983	valid_1's WRMSSE: 0.555442	valid_1's RMSE: 1.90483
# [229]	training's WRMSSE: 0.592356	training's RMSE: 1.98275	valid_1's WRMSSE: 0.554661	valid_1's RMSE: 1.90466
# [230]	training's WRMSSE: 0.591617	training's RMSE: 1.98255	valid_1's WRMSSE: 0.55382	valid_1's RMSE: 1.90453
# [231]	training's WRMSSE: 0.590991	training's RMSE: 1.98232	valid_1's WRMSSE: 0.553185	valid_1's RMSE: 1.9044
# [232]	training's WRMSSE: 0.59021	training's RMSE: 1.98204	valid_1's WRMSSE: 0.552481	valid_1's RMSE: 1.90422
# [233]	training's WRMSSE: 0.589429	training's RMSE: 1.98188	valid_1's WRMSSE: 0.55173	valid_1's RMSE: 1.90409
# [234]	training's WRMSSE: 0.588719	training's RMSE: 1.98162	valid_1's WRMSSE: 0.55104	valid_1's RMSE: 1.90392
# [235]	training's WRMSSE: 0.588052	training's RMSE: 1.98136	valid_1's WRMSSE: 0.550326	valid_1's RMSE: 1.90375
# [236]	training's WRMSSE: 0.587326	training's RMSE: 1.98109	valid_1's WRMSSE: 0.549539	valid_1's RMSE: 1.90356
# [237]	training's WRMSSE: 0.586841	training's RMSE: 1.98085	valid_1's WRMSSE: 0.54899	valid_1's RMSE: 1.90337
# [238]	training's WRMSSE: 0.586219	training's RMSE: 1.98064	valid_1's WRMSSE: 0.548357	valid_1's RMSE: 1.90323
# [239]	training's WRMSSE: 0.5852	training's RMSE: 1.98043	valid_1's WRMSSE: 0.54748	valid_1's RMSE: 1.90302
# [240]	training's WRMSSE: 0.584591	training's RMSE: 1.98015	valid_1's WRMSSE: 0.546798	valid_1's RMSE: 1.9028
# [241]	training's WRMSSE: 0.58408	training's RMSE: 1.97993	valid_1's WRMSSE: 0.546213	valid_1's RMSE: 1.90268
# [242]	training's WRMSSE: 0.583581	training's RMSE: 1.97966	valid_1's WRMSSE: 0.545648	valid_1's RMSE: 1.90248
# [243]	training's WRMSSE: 0.582996	training's RMSE: 1.97942	valid_1's WRMSSE: 0.545028	valid_1's RMSE: 1.90235
# [244]	training's WRMSSE: 0.582378	training's RMSE: 1.97918	valid_1's WRMSSE: 0.544497	valid_1's RMSE: 1.90221
# [245]	training's WRMSSE: 0.581886	training's RMSE: 1.979	valid_1's WRMSSE: 0.544041	valid_1's RMSE: 1.90209
# [246]	training's WRMSSE: 0.581369	training's RMSE: 1.97876	valid_1's WRMSSE: 0.5435	valid_1's RMSE: 1.90196
# [247]	training's WRMSSE: 0.580917	training's RMSE: 1.9785	valid_1's WRMSSE: 0.543063	valid_1's RMSE: 1.90176
# [248]	training's WRMSSE: 0.580299	training's RMSE: 1.97827	valid_1's WRMSSE: 0.54231	valid_1's RMSE: 1.90157
# [249]	training's WRMSSE: 0.579783	training's RMSE: 1.97807	valid_1's WRMSSE: 0.541838	valid_1's RMSE: 1.90149
# [250]	training's WRMSSE: 0.579035	training's RMSE: 1.9778	valid_1's WRMSSE: 0.541105	valid_1's RMSE: 1.90129
# [251]	training's WRMSSE: 0.578585	training's RMSE: 1.97761	valid_1's WRMSSE: 0.540667	valid_1's RMSE: 1.90115
# [252]	training's WRMSSE: 0.578119	training's RMSE: 1.97738	valid_1's WRMSSE: 0.540125	valid_1's RMSE: 1.90097
# [253]	training's WRMSSE: 0.577683	training's RMSE: 1.97718	valid_1's WRMSSE: 0.539695	valid_1's RMSE: 1.90087
# [254]	training's WRMSSE: 0.577159	training's RMSE: 1.97699	valid_1's WRMSSE: 0.539141	valid_1's RMSE: 1.90074
# [255]	training's WRMSSE: 0.576615	training's RMSE: 1.97683	valid_1's WRMSSE: 0.538698	valid_1's RMSE: 1.90067
# [256]	training's WRMSSE: 0.576155	training's RMSE: 1.9766	valid_1's WRMSSE: 0.538263	valid_1's RMSE: 1.90052
# [257]	training's WRMSSE: 0.575461	training's RMSE: 1.97632	valid_1's WRMSSE: 0.537582	valid_1's RMSE: 1.90035
# [258]	training's WRMSSE: 0.575008	training's RMSE: 1.97613	valid_1's WRMSSE: 0.537153	valid_1's RMSE: 1.9002
# [259]	training's WRMSSE: 0.574554	training's RMSE: 1.9759	valid_1's WRMSSE: 0.536718	valid_1's RMSE: 1.90009
# [260]	training's WRMSSE: 0.573959	training's RMSE: 1.97568	valid_1's WRMSSE: 0.536164	valid_1's RMSE: 1.89995
# [261]	training's WRMSSE: 0.573548	training's RMSE: 1.9755	valid_1's WRMSSE: 0.535912	valid_1's RMSE: 1.89988
# [262]	training's WRMSSE: 0.573016	training's RMSE: 1.97524	valid_1's WRMSSE: 0.535454	valid_1's RMSE: 1.8997
# [263]	training's WRMSSE: 0.572466	training's RMSE: 1.975	valid_1's WRMSSE: 0.534933	valid_1's RMSE: 1.89957
# [264]	training's WRMSSE: 0.572087	training's RMSE: 1.9748	valid_1's WRMSSE: 0.534551	valid_1's RMSE: 1.89943
# [265]	training's WRMSSE: 0.571522	training's RMSE: 1.97462	valid_1's WRMSSE: 0.533958	valid_1's RMSE: 1.89932
# [266]	training's WRMSSE: 0.571039	training's RMSE: 1.97447	valid_1's WRMSSE: 0.533501	valid_1's RMSE: 1.89922
# [267]	training's WRMSSE: 0.570632	training's RMSE: 1.97435	valid_1's WRMSSE: 0.533094	valid_1's RMSE: 1.89917
# [268]	training's WRMSSE: 0.569763	training's RMSE: 1.97416	valid_1's WRMSSE: 0.532383	valid_1's RMSE: 1.89906
# [269]	training's WRMSSE: 0.569341	training's RMSE: 1.97394	valid_1's WRMSSE: 0.53193	valid_1's RMSE: 1.89891
# [270]	training's WRMSSE: 0.568946	training's RMSE: 1.97377	valid_1's WRMSSE: 0.531586	valid_1's RMSE: 1.89881
# [271]	training's WRMSSE: 0.56859	training's RMSE: 1.97365	valid_1's WRMSSE: 0.531272	valid_1's RMSE: 1.89876
# [272]	training's WRMSSE: 0.568307	training's RMSE: 1.97347	valid_1's WRMSSE: 0.531056	valid_1's RMSE: 1.89867
# [273]	training's WRMSSE: 0.567815	training's RMSE: 1.9733	valid_1's WRMSSE: 0.530662	valid_1's RMSE: 1.89857
# [274]	training's WRMSSE: 0.567446	training's RMSE: 1.97309	valid_1's WRMSSE: 0.530334	valid_1's RMSE: 1.89844
# [275]	training's WRMSSE: 0.56712	training's RMSE: 1.97288	valid_1's WRMSSE: 0.530009	valid_1's RMSE: 1.8983
# [276]	training's WRMSSE: 0.566822	training's RMSE: 1.97277	valid_1's WRMSSE: 0.529767	valid_1's RMSE: 1.89824
# [277]	training's WRMSSE: 0.566511	training's RMSE: 1.97258	valid_1's WRMSSE: 0.529497	valid_1's RMSE: 1.89815
# [278]	training's WRMSSE: 0.566247	training's RMSE: 1.97243	valid_1's WRMSSE: 0.529303	valid_1's RMSE: 1.89805
# [279]	training's WRMSSE: 0.565721	training's RMSE: 1.9723	valid_1's WRMSSE: 0.528906	valid_1's RMSE: 1.89801
# [280]	training's WRMSSE: 0.565426	training's RMSE: 1.97211	valid_1's WRMSSE: 0.528625	valid_1's RMSE: 1.89788
# [281]	training's WRMSSE: 0.565175	training's RMSE: 1.97196	valid_1's WRMSSE: 0.528415	valid_1's RMSE: 1.89782
# [282]	training's WRMSSE: 0.564726	training's RMSE: 1.97172	valid_1's WRMSSE: 0.528012	valid_1's RMSE: 1.89764
# [283]	training's WRMSSE: 0.564403	training's RMSE: 1.97159	valid_1's WRMSSE: 0.52788	valid_1's RMSE: 1.89758
# [284]	training's WRMSSE: 0.56414	training's RMSE: 1.97145	valid_1's WRMSSE: 0.527725	valid_1's RMSE: 1.89755
# [285]	training's WRMSSE: 0.563851	training's RMSE: 1.97128	valid_1's WRMSSE: 0.527479	valid_1's RMSE: 1.89746
# [286]	training's WRMSSE: 0.563715	training's RMSE: 1.97116	valid_1's WRMSSE: 0.527354	valid_1's RMSE: 1.89741
# [287]	training's WRMSSE: 0.563536	training's RMSE: 1.97108	valid_1's WRMSSE: 0.527253	valid_1's RMSE: 1.89738
# [288]	training's WRMSSE: 0.563332	training's RMSE: 1.97095	valid_1's WRMSSE: 0.527024	valid_1's RMSE: 1.89731
# [289]	training's WRMSSE: 0.563007	training's RMSE: 1.97076	valid_1's WRMSSE: 0.526757	valid_1's RMSE: 1.89722
# [290]	training's WRMSSE: 0.562775	training's RMSE: 1.9706	valid_1's WRMSSE: 0.526619	valid_1's RMSE: 1.89716
# [291]	training's WRMSSE: 0.562531	training's RMSE: 1.97038	valid_1's WRMSSE: 0.526412	valid_1's RMSE: 1.89703
# [292]	training's WRMSSE: 0.562127	training's RMSE: 1.97019	valid_1's WRMSSE: 0.526083	valid_1's RMSE: 1.89694
# [293]	training's WRMSSE: 0.561914	training's RMSE: 1.97006	valid_1's WRMSSE: 0.525977	valid_1's RMSE: 1.89689
# [294]	training's WRMSSE: 0.561658	training's RMSE: 1.96989	valid_1's WRMSSE: 0.52563	valid_1's RMSE: 1.89678
# [295]	training's WRMSSE: 0.56141	training's RMSE: 1.96976	valid_1's WRMSSE: 0.525372	valid_1's RMSE: 1.89671
# [296]	training's WRMSSE: 0.560818	training's RMSE: 1.96956	valid_1's WRMSSE: 0.524873	valid_1's RMSE: 1.89655
# [297]	training's WRMSSE: 0.560152	training's RMSE: 1.96937	valid_1's WRMSSE: 0.524269	valid_1's RMSE: 1.89642
# [298]	training's WRMSSE: 0.559953	training's RMSE: 1.96924	valid_1's WRMSSE: 0.524145	valid_1's RMSE: 1.89637
# [299]	training's WRMSSE: 0.559642	training's RMSE: 1.96911	valid_1's WRMSSE: 0.523854	valid_1's RMSE: 1.8963
# [300]	training's WRMSSE: 0.559354	training's RMSE: 1.96899	valid_1's WRMSSE: 0.523712	valid_1's RMSE: 1.89628
# [301]	training's WRMSSE: 0.559085	training's RMSE: 1.96888	valid_1's WRMSSE: 0.523472	valid_1's RMSE: 1.89623
# [302]	training's WRMSSE: 0.558888	training's RMSE: 1.9688	valid_1's WRMSSE: 0.523331	valid_1's RMSE: 1.89621
# [303]	training's WRMSSE: 0.558564	training's RMSE: 1.96865	valid_1's WRMSSE: 0.52308	valid_1's RMSE: 1.89616
# [304]	training's WRMSSE: 0.558044	training's RMSE: 1.96845	valid_1's WRMSSE: 0.522742	valid_1's RMSE: 1.89605
# [305]	training's WRMSSE: 0.557617	training's RMSE: 1.96834	valid_1's WRMSSE: 0.522469	valid_1's RMSE: 1.896
# [306]	training's WRMSSE: 0.557381	training's RMSE: 1.96823	valid_1's WRMSSE: 0.522326	valid_1's RMSE: 1.89595
# [307]	training's WRMSSE: 0.557103	training's RMSE: 1.96806	valid_1's WRMSSE: 0.522068	valid_1's RMSE: 1.89587
# [308]	training's WRMSSE: 0.556849	training's RMSE: 1.96791	valid_1's WRMSSE: 0.521766	valid_1's RMSE: 1.89577
# [309]	training's WRMSSE: 0.556607	training's RMSE: 1.9678	valid_1's WRMSSE: 0.52164	valid_1's RMSE: 1.89573
# [310]	training's WRMSSE: 0.556345	training's RMSE: 1.96763	valid_1's WRMSSE: 0.521435	valid_1's RMSE: 1.89566
# [311]	training's WRMSSE: 0.556118	training's RMSE: 1.96746	valid_1's WRMSSE: 0.521308	valid_1's RMSE: 1.89554
# [312]	training's WRMSSE: 0.55588	training's RMSE: 1.96735	valid_1's WRMSSE: 0.52117	valid_1's RMSE: 1.8955
# [313]	training's WRMSSE: 0.55569	training's RMSE: 1.96725	valid_1's WRMSSE: 0.521078	valid_1's RMSE: 1.89545
# [314]	training's WRMSSE: 0.555556	training's RMSE: 1.96712	valid_1's WRMSSE: 0.520967	valid_1's RMSE: 1.89535
# [315]	training's WRMSSE: 0.555278	training's RMSE: 1.96696	valid_1's WRMSSE: 0.520714	valid_1's RMSE: 1.89523
# [316]	training's WRMSSE: 0.554912	training's RMSE: 1.96677	valid_1's WRMSSE: 0.520355	valid_1's RMSE: 1.89508
# [317]	training's WRMSSE: 0.554676	training's RMSE: 1.96661	valid_1's WRMSSE: 0.520201	valid_1's RMSE: 1.89498
# [318]	training's WRMSSE: 0.554451	training's RMSE: 1.96649	valid_1's WRMSSE: 0.520105	valid_1's RMSE: 1.89495
# [319]	training's WRMSSE: 0.554187	training's RMSE: 1.96636	valid_1's WRMSSE: 0.51992	valid_1's RMSE: 1.89483
# [320]	training's WRMSSE: 0.553877	training's RMSE: 1.96623	valid_1's WRMSSE: 0.519489	valid_1's RMSE: 1.89476
# [321]	training's WRMSSE: 0.553618	training's RMSE: 1.96609	valid_1's WRMSSE: 0.519248	valid_1's RMSE: 1.89467
# [322]	training's WRMSSE: 0.553368	training's RMSE: 1.96591	valid_1's WRMSSE: 0.518957	valid_1's RMSE: 1.89455
# [323]	training's WRMSSE: 0.55317	training's RMSE: 1.9658	valid_1's WRMSSE: 0.518705	valid_1's RMSE: 1.8945
# [324]	training's WRMSSE: 0.552959	training's RMSE: 1.96567	valid_1's WRMSSE: 0.518528	valid_1's RMSE: 1.89444
# [325]	training's WRMSSE: 0.552663	training's RMSE: 1.96554	valid_1's WRMSSE: 0.518429	valid_1's RMSE: 1.89438
# [326]	training's WRMSSE: 0.552404	training's RMSE: 1.9654	valid_1's WRMSSE: 0.518088	valid_1's RMSE: 1.89424
# [327]	training's WRMSSE: 0.552079	training's RMSE: 1.96524	valid_1's WRMSSE: 0.517759	valid_1's RMSE: 1.89411
# [328]	training's WRMSSE: 0.55196	training's RMSE: 1.96519	valid_1's WRMSSE: 0.517646	valid_1's RMSE: 1.89409
# [329]	training's WRMSSE: 0.551823	training's RMSE: 1.96509	valid_1's WRMSSE: 0.5175	valid_1's RMSE: 1.89402
# [330]	training's WRMSSE: 0.551464	training's RMSE: 1.96494	valid_1's WRMSSE: 0.517262	valid_1's RMSE: 1.89391
# [331]	training's WRMSSE: 0.551273	training's RMSE: 1.96489	valid_1's WRMSSE: 0.517024	valid_1's RMSE: 1.89388
# [332]	training's WRMSSE: 0.551007	training's RMSE: 1.96477	valid_1's WRMSSE: 0.516789	valid_1's RMSE: 1.89383
# [333]	training's WRMSSE: 0.550811	training's RMSE: 1.96466	valid_1's WRMSSE: 0.516688	valid_1's RMSE: 1.89381
# [334]	training's WRMSSE: 0.55064	training's RMSE: 1.96453	valid_1's WRMSSE: 0.516528	valid_1's RMSE: 1.89375
# [335]	training's WRMSSE: 0.550327	training's RMSE: 1.96438	valid_1's WRMSSE: 0.516364	valid_1's RMSE: 1.8937
# [336]	training's WRMSSE: 0.5501	training's RMSE: 1.96426	valid_1's WRMSSE: 0.516264	valid_1's RMSE: 1.89365
# [337]	training's WRMSSE: 0.549788	training's RMSE: 1.96412	valid_1's WRMSSE: 0.515952	valid_1's RMSE: 1.89357
# [338]	training's WRMSSE: 0.54964	training's RMSE: 1.96406	valid_1's WRMSSE: 0.515769	valid_1's RMSE: 1.89355
# [339]	training's WRMSSE: 0.549344	training's RMSE: 1.96394	valid_1's WRMSSE: 0.515556	valid_1's RMSE: 1.89349
# [340]	training's WRMSSE: 0.549231	training's RMSE: 1.9639	valid_1's WRMSSE: 0.515502	valid_1's RMSE: 1.89349
# [341]	training's WRMSSE: 0.548974	training's RMSE: 1.96378	valid_1's WRMSSE: 0.515358	valid_1's RMSE: 1.89341
# [342]	training's WRMSSE: 0.548761	training's RMSE: 1.96371	valid_1's WRMSSE: 0.515137	valid_1's RMSE: 1.89338
# [343]	training's WRMSSE: 0.548498	training's RMSE: 1.96358	valid_1's WRMSSE: 0.514848	valid_1's RMSE: 1.89327
# [344]	training's WRMSSE: 0.548322	training's RMSE: 1.96349	valid_1's WRMSSE: 0.514819	valid_1's RMSE: 1.89323
# [345]	training's WRMSSE: 0.548235	training's RMSE: 1.96345	valid_1's WRMSSE: 0.514717	valid_1's RMSE: 1.89321
# [346]	training's WRMSSE: 0.548005	training's RMSE: 1.96337	valid_1's WRMSSE: 0.514516	valid_1's RMSE: 1.89319
# [347]	training's WRMSSE: 0.547873	training's RMSE: 1.96325	valid_1's WRMSSE: 0.514401	valid_1's RMSE: 1.89315
# [348]	training's WRMSSE: 0.547709	training's RMSE: 1.96317	valid_1's WRMSSE: 0.514302	valid_1's RMSE: 1.89312
# [349]	training's WRMSSE: 0.547634	training's RMSE: 1.96311	valid_1's WRMSSE: 0.514255	valid_1's RMSE: 1.8931
# [350]	training's WRMSSE: 0.547443	training's RMSE: 1.96299	valid_1's WRMSSE: 0.514183	valid_1's RMSE: 1.89305
# [351]	training's WRMSSE: 0.5472	training's RMSE: 1.9629	valid_1's WRMSSE: 0.514014	valid_1's RMSE: 1.89302
# [352]	training's WRMSSE: 0.54687	training's RMSE: 1.96276	valid_1's WRMSSE: 0.513816	valid_1's RMSE: 1.89296
# [353]	training's WRMSSE: 0.546446	training's RMSE: 1.9626	valid_1's WRMSSE: 0.51345	valid_1's RMSE: 1.89284
# [354]	training's WRMSSE: 0.54602	training's RMSE: 1.96245	valid_1's WRMSSE: 0.513102	valid_1's RMSE: 1.89277
# [355]	training's WRMSSE: 0.545872	training's RMSE: 1.96233	valid_1's WRMSSE: 0.513035	valid_1's RMSE: 1.89274
# [356]	training's WRMSSE: 0.545601	training's RMSE: 1.96222	valid_1's WRMSSE: 0.512878	valid_1's RMSE: 1.89269
# [357]	training's WRMSSE: 0.545394	training's RMSE: 1.96211	valid_1's WRMSSE: 0.512753	valid_1's RMSE: 1.89263
# [358]	training's WRMSSE: 0.545196	training's RMSE: 1.96204	valid_1's WRMSSE: 0.512611	valid_1's RMSE: 1.8926
# [359]	training's WRMSSE: 0.545082	training's RMSE: 1.9619	valid_1's WRMSSE: 0.51252	valid_1's RMSE: 1.89253
# [360]	training's WRMSSE: 0.544801	training's RMSE: 1.96179	valid_1's WRMSSE: 0.512469	valid_1's RMSE: 1.89246
# [361]	training's WRMSSE: 0.544527	training's RMSE: 1.96164	valid_1's WRMSSE: 0.512124	valid_1's RMSE: 1.89232
# [362]	training's WRMSSE: 0.54445	training's RMSE: 1.96155	valid_1's WRMSSE: 0.512064	valid_1's RMSE: 1.89231
# [363]	training's WRMSSE: 0.544343	training's RMSE: 1.96147	valid_1's WRMSSE: 0.512024	valid_1's RMSE: 1.89229
# [364]	training's WRMSSE: 0.543871	training's RMSE: 1.96131	valid_1's WRMSSE: 0.51161	valid_1's RMSE: 1.89218
# [365]	training's WRMSSE: 0.543786	training's RMSE: 1.96126	valid_1's WRMSSE: 0.511551	valid_1's RMSE: 1.89215
# [366]	training's WRMSSE: 0.5437	training's RMSE: 1.96118	valid_1's WRMSSE: 0.511491	valid_1's RMSE: 1.89211
# [367]	training's WRMSSE: 0.543642	training's RMSE: 1.96112	valid_1's WRMSSE: 0.51145	valid_1's RMSE: 1.8921
# [368]	training's WRMSSE: 0.543339	training's RMSE: 1.96101	valid_1's WRMSSE: 0.51126	valid_1's RMSE: 1.89206
# [369]	training's WRMSSE: 0.543118	training's RMSE: 1.9609	valid_1's WRMSSE: 0.511129	valid_1's RMSE: 1.89204
# [370]	training's WRMSSE: 0.542552	training's RMSE: 1.96072	valid_1's WRMSSE: 0.510645	valid_1's RMSE: 1.89189
# [371]	training's WRMSSE: 0.542316	training's RMSE: 1.96056	valid_1's WRMSSE: 0.510387	valid_1's RMSE: 1.89178
# [372]	training's WRMSSE: 0.542189	training's RMSE: 1.96049	valid_1's WRMSSE: 0.510345	valid_1's RMSE: 1.89177
# [373]	training's WRMSSE: 0.541943	training's RMSE: 1.96043	valid_1's WRMSSE: 0.510143	valid_1's RMSE: 1.89174
# [374]	training's WRMSSE: 0.541455	training's RMSE: 1.96031	valid_1's WRMSSE: 0.509924	valid_1's RMSE: 1.89171
# [375]	training's WRMSSE: 0.54126	training's RMSE: 1.96021	valid_1's WRMSSE: 0.50979	valid_1's RMSE: 1.89167
# [376]	training's WRMSSE: 0.54117	training's RMSE: 1.96011	valid_1's WRMSSE: 0.509708	valid_1's RMSE: 1.89161
# [377]	training's WRMSSE: 0.541113	training's RMSE: 1.96004	valid_1's WRMSSE: 0.509678	valid_1's RMSE: 1.8916
# [378]	training's WRMSSE: 0.540976	training's RMSE: 1.95995	valid_1's WRMSSE: 0.509616	valid_1's RMSE: 1.89157
# [379]	training's WRMSSE: 0.540771	training's RMSE: 1.95984	valid_1's WRMSSE: 0.509554	valid_1's RMSE: 1.89151
# [380]	training's WRMSSE: 0.540203	training's RMSE: 1.95969	valid_1's WRMSSE: 0.509141	valid_1's RMSE: 1.89141
# [381]	training's WRMSSE: 0.540058	training's RMSE: 1.95955	valid_1's WRMSSE: 0.508999	valid_1's RMSE: 1.89133
# [382]	training's WRMSSE: 0.539966	training's RMSE: 1.95948	valid_1's WRMSSE: 0.508919	valid_1's RMSE: 1.89131
# [383]	training's WRMSSE: 0.539817	training's RMSE: 1.95943	valid_1's WRMSSE: 0.508796	valid_1's RMSE: 1.89129
# [384]	training's WRMSSE: 0.539679	training's RMSE: 1.95938	valid_1's WRMSSE: 0.508682	valid_1's RMSE: 1.89127
# [385]	training's WRMSSE: 0.539542	training's RMSE: 1.95927	valid_1's WRMSSE: 0.508607	valid_1's RMSE: 1.89123
# [386]	training's WRMSSE: 0.539437	training's RMSE: 1.95919	valid_1's WRMSSE: 0.508523	valid_1's RMSE: 1.8912
# [387]	training's WRMSSE: 0.539351	training's RMSE: 1.95912	valid_1's WRMSSE: 0.508458	valid_1's RMSE: 1.89118
# [388]	training's WRMSSE: 0.539217	training's RMSE: 1.95904	valid_1's WRMSSE: 0.508301	valid_1's RMSE: 1.89114
# [389]	training's WRMSSE: 0.539107	training's RMSE: 1.95895	valid_1's WRMSSE: 0.50826	valid_1's RMSE: 1.89111
# [390]	training's WRMSSE: 0.538992	training's RMSE: 1.95889	valid_1's WRMSSE: 0.508194	valid_1's RMSE: 1.89108
# [391]	training's WRMSSE: 0.538763	training's RMSE: 1.95883	valid_1's WRMSSE: 0.508067	valid_1's RMSE: 1.89107
# [392]	training's WRMSSE: 0.538673	training's RMSE: 1.95874	valid_1's WRMSSE: 0.508004	valid_1's RMSE: 1.89101
# [393]	training's WRMSSE: 0.538522	training's RMSE: 1.95862	valid_1's WRMSSE: 0.507963	valid_1's RMSE: 1.89098
# [394]	training's WRMSSE: 0.538411	training's RMSE: 1.95851	valid_1's WRMSSE: 0.507859	valid_1's RMSE: 1.89095
# [395]	training's WRMSSE: 0.538343	training's RMSE: 1.95847	valid_1's WRMSSE: 0.507801	valid_1's RMSE: 1.89094
# [396]	training's WRMSSE: 0.538273	training's RMSE: 1.95839	valid_1's WRMSSE: 0.507764	valid_1's RMSE: 1.89091
# [397]	training's WRMSSE: 0.538075	training's RMSE: 1.95829	valid_1's WRMSSE: 0.507708	valid_1's RMSE: 1.89087
# [398]	training's WRMSSE: 0.538012	training's RMSE: 1.95822	valid_1's WRMSSE: 0.507658	valid_1's RMSE: 1.89086
# [399]	training's WRMSSE: 0.537926	training's RMSE: 1.95817	valid_1's WRMSSE: 0.507573	valid_1's RMSE: 1.89085
# [400]	training's WRMSSE: 0.537739	training's RMSE: 1.9581	valid_1's WRMSSE: 0.507523	valid_1's RMSE: 1.89081
# [401]	training's WRMSSE: 0.537516	training's RMSE: 1.95799	valid_1's WRMSSE: 0.507336	valid_1's RMSE: 1.89077
# [402]	training's WRMSSE: 0.537303	training's RMSE: 1.95789	valid_1's WRMSSE: 0.507233	valid_1's RMSE: 1.89074
# [403]	training's WRMSSE: 0.537147	training's RMSE: 1.95778	valid_1's WRMSSE: 0.507199	valid_1's RMSE: 1.89069
# [404]	training's WRMSSE: 0.537058	training's RMSE: 1.95774	valid_1's WRMSSE: 0.507134	valid_1's RMSE: 1.89068
# [405]	training's WRMSSE: 0.53701	training's RMSE: 1.95767	valid_1's WRMSSE: 0.507103	valid_1's RMSE: 1.89063
# [406]	training's WRMSSE: 0.536865	training's RMSE: 1.95763	valid_1's WRMSSE: 0.507089	valid_1's RMSE: 1.89063
# [407]	training's WRMSSE: 0.536486	training's RMSE: 1.95747	valid_1's WRMSSE: 0.506795	valid_1's RMSE: 1.89049
# [408]	training's WRMSSE: 0.53635	training's RMSE: 1.95736	valid_1's WRMSSE: 0.506742	valid_1's RMSE: 1.8904
# [409]	training's WRMSSE: 0.536212	training's RMSE: 1.95731	valid_1's WRMSSE: 0.506632	valid_1's RMSE: 1.89039
# [410]	training's WRMSSE: 0.536109	training's RMSE: 1.95726	valid_1's WRMSSE: 0.506567	valid_1's RMSE: 1.89037
# [411]	training's WRMSSE: 0.536019	training's RMSE: 1.95719	valid_1's WRMSSE: 0.506501	valid_1's RMSE: 1.89033
# [412]	training's WRMSSE: 0.535914	training's RMSE: 1.95712	valid_1's WRMSSE: 0.506471	valid_1's RMSE: 1.89032
# [413]	training's WRMSSE: 0.535803	training's RMSE: 1.95703	valid_1's WRMSSE: 0.506371	valid_1's RMSE: 1.89029
# [414]	training's WRMSSE: 0.535582	training's RMSE: 1.95694	valid_1's WRMSSE: 0.506245	valid_1's RMSE: 1.89023
# [415]	training's WRMSSE: 0.535283	training's RMSE: 1.9569	valid_1's WRMSSE: 0.506095	valid_1's RMSE: 1.89022
# [416]	training's WRMSSE: 0.5352	training's RMSE: 1.95686	valid_1's WRMSSE: 0.506018	valid_1's RMSE: 1.89022
# [417]	training's WRMSSE: 0.535147	training's RMSE: 1.95677	valid_1's WRMSSE: 0.50596	valid_1's RMSE: 1.89017
# [418]	training's WRMSSE: 0.534998	training's RMSE: 1.95668	valid_1's WRMSSE: 0.505886	valid_1's RMSE: 1.89016
# [419]	training's WRMSSE: 0.534859	training's RMSE: 1.95656	valid_1's WRMSSE: 0.505665	valid_1's RMSE: 1.89011
# [420]	training's WRMSSE: 0.534807	training's RMSE: 1.95649	valid_1's WRMSSE: 0.505601	valid_1's RMSE: 1.89009
# [421]	training's WRMSSE: 0.534734	training's RMSE: 1.9564	valid_1's WRMSSE: 0.505505	valid_1's RMSE: 1.89007
# [422]	training's WRMSSE: 0.534561	training's RMSE: 1.9563	valid_1's WRMSSE: 0.50545	valid_1's RMSE: 1.89001
# [423]	training's WRMSSE: 0.534471	training's RMSE: 1.95619	valid_1's WRMSSE: 0.505439	valid_1's RMSE: 1.88993
# [424]	training's WRMSSE: 0.533956	training's RMSE: 1.9561	valid_1's WRMSSE: 0.505224	valid_1's RMSE: 1.88987
# [425]	training's WRMSSE: 0.53382	training's RMSE: 1.95603	valid_1's WRMSSE: 0.50522	valid_1's RMSE: 1.88984
# [426]	training's WRMSSE: 0.533733	training's RMSE: 1.95597	valid_1's WRMSSE: 0.505203	valid_1's RMSE: 1.88981
# [427]	training's WRMSSE: 0.533656	training's RMSE: 1.95584	valid_1's WRMSSE: 0.505184	valid_1's RMSE: 1.88976
# [428]	training's WRMSSE: 0.533463	training's RMSE: 1.95578	valid_1's WRMSSE: 0.505083	valid_1's RMSE: 1.88974
# [429]	training's WRMSSE: 0.533393	training's RMSE: 1.95571	valid_1's WRMSSE: 0.505039	valid_1's RMSE: 1.8897
# [430]	training's WRMSSE: 0.533277	training's RMSE: 1.95563	valid_1's WRMSSE: 0.505	valid_1's RMSE: 1.88968
# [431]	training's WRMSSE: 0.533229	training's RMSE: 1.95555	valid_1's WRMSSE: 0.504982	valid_1's RMSE: 1.88965
# [432]	training's WRMSSE: 0.533171	training's RMSE: 1.95548	valid_1's WRMSSE: 0.504914	valid_1's RMSE: 1.88961
# [433]	training's WRMSSE: 0.533117	training's RMSE: 1.95539	valid_1's WRMSSE: 0.504867	valid_1's RMSE: 1.88959
# [434]	training's WRMSSE: 0.533001	training's RMSE: 1.95529	valid_1's WRMSSE: 0.504817	valid_1's RMSE: 1.88956
# ...
# [1306]	training's WRMSSE: 0.485185	training's RMSE: 1.91345	valid_1's WRMSSE: 0.483694	valid_1's RMSE: 1.87422
# [1307]	training's WRMSSE: 0.485176	training's RMSE: 1.9134	valid_1's WRMSSE: 0.483705	valid_1's RMSE: 1.8742
# [1308]	training's WRMSSE: 0.485169	training's RMSE: 1.91338	valid_1's WRMSSE: 0.48372	valid_1's RMSE: 1.8742
# [1309]	training's WRMSSE: 0.485161	training's RMSE: 1.91336	valid_1's WRMSSE: 0.483719	valid_1's RMSE: 1.87419
# [1310]	training's WRMSSE: 0.485138	training's RMSE: 1.91334	valid_1's WRMSSE: 0.48371	valid_1's RMSE: 1.87419
# [1311]	training's WRMSSE: 0.485131	training's RMSE: 1.91333	valid_1's WRMSSE: 0.483712	valid_1's RMSE: 1.8742
# [1312]	training's WRMSSE: 0.485117	training's RMSE: 1.91328	valid_1's WRMSSE: 0.483687	valid_1's RMSE: 1.87419
# [1313]	training's WRMSSE: 0.485104	training's RMSE: 1.91325	valid_1's WRMSSE: 0.48368	valid_1's RMSE: 1.87418
# [1314]	training's WRMSSE: 0.485069	training's RMSE: 1.91323	valid_1's WRMSSE: 0.483662	valid_1's RMSE: 1.87417
# [1315]	training's WRMSSE: 0.485057	training's RMSE: 1.91322	valid_1's WRMSSE: 0.483646	valid_1's RMSE: 1.87416
# [1316]	training's WRMSSE: 0.485048	training's RMSE: 1.91321	valid_1's WRMSSE: 0.483645	valid_1's RMSE: 1.87416
# [1317]	training's WRMSSE: 0.485015	training's RMSE: 1.91317	valid_1's WRMSSE: 0.483617	valid_1's RMSE: 1.87415
# [1318]	training's WRMSSE: 0.484999	training's RMSE: 1.91313	valid_1's WRMSSE: 0.483613	valid_1's RMSE: 1.87416
# [1319]	training's WRMSSE: 0.484987	training's RMSE: 1.91312	valid_1's WRMSSE: 0.483608	valid_1's RMSE: 1.87415
# [1320]	training's WRMSSE: 0.484974	training's RMSE: 1.9131	valid_1's WRMSSE: 0.483602	valid_1's RMSE: 1.87414
# [1321]	training's WRMSSE: 0.484962	training's RMSE: 1.91308	valid_1's WRMSSE: 0.483604	valid_1's RMSE: 1.87415
# [1322]	training's WRMSSE: 0.484954	training's RMSE: 1.91306	valid_1's WRMSSE: 0.483608	valid_1's RMSE: 1.87414
# [1323]	training's WRMSSE: 0.484935	training's RMSE: 1.91304	valid_1's WRMSSE: 0.483613	valid_1's RMSE: 1.87414
# [1324]	training's WRMSSE: 0.484926	training's RMSE: 1.91303	valid_1's WRMSSE: 0.483611	valid_1's RMSE: 1.87414
# [1325]	training's WRMSSE: 0.4849	training's RMSE: 1.91298	valid_1's WRMSSE: 0.483639	valid_1's RMSE: 1.87413
# [1326]	training's WRMSSE: 0.484877	training's RMSE: 1.91295	valid_1's WRMSSE: 0.483652	valid_1's RMSE: 1.87412
# [1327]	training's WRMSSE: 0.484836	training's RMSE: 1.91294	valid_1's WRMSSE: 0.483659	valid_1's RMSE: 1.87411
# [1328]	training's WRMSSE: 0.484819	training's RMSE: 1.91291	valid_1's WRMSSE: 0.48366	valid_1's RMSE: 1.87412
# [1329]	training's WRMSSE: 0.484779	training's RMSE: 1.91287	valid_1's WRMSSE: 0.483633	valid_1's RMSE: 1.87409
# [1330]	training's WRMSSE: 0.48477	training's RMSE: 1.91286	valid_1's WRMSSE: 0.483631	valid_1's RMSE: 1.87409
# [1331]	training's WRMSSE: 0.484759	training's RMSE: 1.91284	valid_1's WRMSSE: 0.483632	valid_1's RMSE: 1.87409
# [1332]	training's WRMSSE: 0.48475	training's RMSE: 1.91279	valid_1's WRMSSE: 0.483642	valid_1's RMSE: 1.87409
# [1333]	training's WRMSSE: 0.484729	training's RMSE: 1.91275	valid_1's WRMSSE: 0.483642	valid_1's RMSE: 1.87407
# [1334]	training's WRMSSE: 0.484725	training's RMSE: 1.91272	valid_1's WRMSSE: 0.483651	valid_1's RMSE: 1.87408
# [1335]	training's WRMSSE: 0.484714	training's RMSE: 1.9127	valid_1's WRMSSE: 0.48365	valid_1's RMSE: 1.87408
# [1336]	training's WRMSSE: 0.484686	training's RMSE: 1.91269	valid_1's WRMSSE: 0.483644	valid_1's RMSE: 1.87408
# [1337]	training's WRMSSE: 0.484673	training's RMSE: 1.91267	valid_1's WRMSSE: 0.483645	valid_1's RMSE: 1.87408
# [1338]	training's WRMSSE: 0.484636	training's RMSE: 1.91265	valid_1's WRMSSE: 0.483616	valid_1's RMSE: 1.87407
# [1339]	training's WRMSSE: 0.484555	training's RMSE: 1.9126	valid_1's WRMSSE: 0.483567	valid_1's RMSE: 1.87404
# [1340]	training's WRMSSE: 0.484502	training's RMSE: 1.91254	valid_1's WRMSSE: 0.483528	valid_1's RMSE: 1.87399
# [1341]	training's WRMSSE: 0.484478	training's RMSE: 1.91253	valid_1's WRMSSE: 0.483489	valid_1's RMSE: 1.87399
# [1342]	training's WRMSSE: 0.484463	training's RMSE: 1.91249	valid_1's WRMSSE: 0.483496	valid_1's RMSE: 1.87398
# [1343]	training's WRMSSE: 0.484364	training's RMSE: 1.91246	valid_1's WRMSSE: 0.483489	valid_1's RMSE: 1.87398
# [1344]	training's WRMSSE: 0.484342	training's RMSE: 1.91245	valid_1's WRMSSE: 0.483449	valid_1's RMSE: 1.87398
# [1345]	training's WRMSSE: 0.48433	training's RMSE: 1.91243	valid_1's WRMSSE: 0.483459	valid_1's RMSE: 1.87398
# [1346]	training's WRMSSE: 0.484325	training's RMSE: 1.91242	valid_1's WRMSSE: 0.483456	valid_1's RMSE: 1.87398
# [1347]	training's WRMSSE: 0.484288	training's RMSE: 1.91239	valid_1's WRMSSE: 0.483431	valid_1's RMSE: 1.87397
# [1348]	training's WRMSSE: 0.484279	training's RMSE: 1.91238	valid_1's WRMSSE: 0.483429	valid_1's RMSE: 1.87397
# [1349]	training's WRMSSE: 0.48427	training's RMSE: 1.91237	valid_1's WRMSSE: 0.483426	valid_1's RMSE: 1.87397
# [1350]	training's WRMSSE: 0.484263	training's RMSE: 1.91234	valid_1's WRMSSE: 0.483433	valid_1's RMSE: 1.87396
# [1351]	training's WRMSSE: 0.484207	training's RMSE: 1.91233	valid_1's WRMSSE: 0.483385	valid_1's RMSE: 1.87396
# [1352]	training's WRMSSE: 0.484203	training's RMSE: 1.91231	valid_1's WRMSSE: 0.483375	valid_1's RMSE: 1.87394
# [1353]	training's WRMSSE: 0.484185	training's RMSE: 1.91228	valid_1's WRMSSE: 0.483376	valid_1's RMSE: 1.87394
# [1354]	training's WRMSSE: 0.484161	training's RMSE: 1.91223	valid_1's WRMSSE: 0.483376	valid_1's RMSE: 1.87393
# [1355]	training's WRMSSE: 0.484138	training's RMSE: 1.9122	valid_1's WRMSSE: 0.483368	valid_1's RMSE: 1.87393
# [1356]	training's WRMSSE: 0.484101	training's RMSE: 1.91217	valid_1's WRMSSE: 0.483395	valid_1's RMSE: 1.87392
# [1357]	training's WRMSSE: 0.48409	training's RMSE: 1.91214	valid_1's WRMSSE: 0.483408	valid_1's RMSE: 1.87391
# [1358]	training's WRMSSE: 0.484084	training's RMSE: 1.91214	valid_1's WRMSSE: 0.483412	valid_1's RMSE: 1.87391
# [1359]	training's WRMSSE: 0.484076	training's RMSE: 1.9121	valid_1's WRMSSE: 0.483415	valid_1's RMSE: 1.87392
# [1360]	training's WRMSSE: 0.484066	training's RMSE: 1.91207	valid_1's WRMSSE: 0.483421	valid_1's RMSE: 1.87392
# [1361]	training's WRMSSE: 0.484057	training's RMSE: 1.91204	valid_1's WRMSSE: 0.483417	valid_1's RMSE: 1.87391
# [1362]	training's WRMSSE: 0.484043	training's RMSE: 1.91203	valid_1's WRMSSE: 0.483416	valid_1's RMSE: 1.87391
# [1363]	training's WRMSSE: 0.484034	training's RMSE: 1.91201	valid_1's WRMSSE: 0.483423	valid_1's RMSE: 1.87391
# [1364]	training's WRMSSE: 0.484022	training's RMSE: 1.91196	valid_1's WRMSSE: 0.483428	valid_1's RMSE: 1.87389
# [1365]	training's WRMSSE: 0.48401	training's RMSE: 1.91192	valid_1's WRMSSE: 0.483411	valid_1's RMSE: 1.87387
# [1366]	training's WRMSSE: 0.483928	training's RMSE: 1.91191	valid_1's WRMSSE: 0.483355	valid_1's RMSE: 1.87387
# [1367]	training's WRMSSE: 0.483905	training's RMSE: 1.91187	valid_1's WRMSSE: 0.483329	valid_1's RMSE: 1.87382
# [1368]	training's WRMSSE: 0.483893	training's RMSE: 1.91184	valid_1's WRMSSE: 0.483317	valid_1's RMSE: 1.8738
# [1369]	training's WRMSSE: 0.483886	training's RMSE: 1.91183	valid_1's WRMSSE: 0.483319	valid_1's RMSE: 1.8738
# [1370]	training's WRMSSE: 0.483856	training's RMSE: 1.91179	valid_1's WRMSSE: 0.48331	valid_1's RMSE: 1.87378
# [1371]	training's WRMSSE: 0.483794	training's RMSE: 1.91175	valid_1's WRMSSE: 0.483276	valid_1's RMSE: 1.87376
# [1372]	training's WRMSSE: 0.483783	training's RMSE: 1.91172	valid_1's WRMSSE: 0.483279	valid_1's RMSE: 1.87375
# [1373]	training's WRMSSE: 0.483773	training's RMSE: 1.91169	valid_1's WRMSSE: 0.483277	valid_1's RMSE: 1.87375
# [1374]	training's WRMSSE: 0.483764	training's RMSE: 1.91167	valid_1's WRMSSE: 0.483279	valid_1's RMSE: 1.87375
# [1375]	training's WRMSSE: 0.483761	training's RMSE: 1.91166	valid_1's WRMSSE: 0.483274	valid_1's RMSE: 1.87375
# [1376]	training's WRMSSE: 0.48375	training's RMSE: 1.91163	valid_1's WRMSSE: 0.483278	valid_1's RMSE: 1.87374
# [1377]	training's WRMSSE: 0.483738	training's RMSE: 1.91156	valid_1's WRMSSE: 0.483287	valid_1's RMSE: 1.8737
# [1378]	training's WRMSSE: 0.483728	training's RMSE: 1.91153	valid_1's WRMSSE: 0.483299	valid_1's RMSE: 1.87368
# [1379]	training's WRMSSE: 0.483577	training's RMSE: 1.91148	valid_1's WRMSSE: 0.483302	valid_1's RMSE: 1.87368
# [1380]	training's WRMSSE: 0.483574	training's RMSE: 1.91148	valid_1's WRMSSE: 0.483301	valid_1's RMSE: 1.87368
# [1381]	training's WRMSSE: 0.483556	training's RMSE: 1.91145	valid_1's WRMSSE: 0.483299	valid_1's RMSE: 1.87367
# [1382]	training's WRMSSE: 0.483547	training's RMSE: 1.91144	valid_1's WRMSSE: 0.483299	valid_1's RMSE: 1.87366
# [1383]	training's WRMSSE: 0.483542	training's RMSE: 1.91139	valid_1's WRMSSE: 0.483304	valid_1's RMSE: 1.87366
# [1384]	training's WRMSSE: 0.483508	training's RMSE: 1.91139	valid_1's WRMSSE: 0.483272	valid_1's RMSE: 1.87366
# [1385]	training's WRMSSE: 0.483497	training's RMSE: 1.91136	valid_1's WRMSSE: 0.48328	valid_1's RMSE: 1.87364
# [1386]	training's WRMSSE: 0.48349	training's RMSE: 1.91135	valid_1's WRMSSE: 0.48327	valid_1's RMSE: 1.87364
# [1387]	training's WRMSSE: 0.483482	training's RMSE: 1.91133	valid_1's WRMSSE: 0.483268	valid_1's RMSE: 1.87364
# [1388]	training's WRMSSE: 0.48345	training's RMSE: 1.9113	valid_1's WRMSSE: 0.483247	valid_1's RMSE: 1.87363
# [1389]	training's WRMSSE: 0.483439	training's RMSE: 1.91127	valid_1's WRMSSE: 0.483249	valid_1's RMSE: 1.87362
# [1390]	training's WRMSSE: 0.483424	training's RMSE: 1.91125	valid_1's WRMSSE: 0.483256	valid_1's RMSE: 1.87361
# [1391]	training's WRMSSE: 0.483417	training's RMSE: 1.91124	valid_1's WRMSSE: 0.483257	valid_1's RMSE: 1.87361
# [1392]	training's WRMSSE: 0.483409	training's RMSE: 1.91123	valid_1's WRMSSE: 0.483254	valid_1's RMSE: 1.8736
# [1393]	training's WRMSSE: 0.483405	training's RMSE: 1.91122	valid_1's WRMSSE: 0.483253	valid_1's RMSE: 1.8736
# [1394]	training's WRMSSE: 0.483373	training's RMSE: 1.91118	valid_1's WRMSSE: 0.483242	valid_1's RMSE: 1.8736
# [1395]	training's WRMSSE: 0.483363	training's RMSE: 1.91115	valid_1's WRMSSE: 0.483239	valid_1's RMSE: 1.87357
# [1396]	training's WRMSSE: 0.483347	training's RMSE: 1.91111	valid_1's WRMSSE: 0.48324	valid_1's RMSE: 1.87355
# [1397]	training's WRMSSE: 0.483341	training's RMSE: 1.91107	valid_1's WRMSSE: 0.483238	valid_1's RMSE: 1.87355
# [1398]	training's WRMSSE: 0.483334	training's RMSE: 1.91105	valid_1's WRMSSE: 0.483236	valid_1's RMSE: 1.87355
# [1399]	training's WRMSSE: 0.483265	training's RMSE: 1.91102	valid_1's WRMSSE: 0.483205	valid_1's RMSE: 1.87354
# [1400]	training's WRMSSE: 0.483247	training's RMSE: 1.911	valid_1's WRMSSE: 0.483193	valid_1's RMSE: 1.87353
# [1401]	training's WRMSSE: 0.483238	training's RMSE: 1.91097	valid_1's WRMSSE: 0.483187	valid_1's RMSE: 1.87352
# [1402]	training's WRMSSE: 0.483235	training's RMSE: 1.91097	valid_1's WRMSSE: 0.483185	valid_1's RMSE: 1.87352
# [1403]	training's WRMSSE: 0.483226	training's RMSE: 1.91096	valid_1's WRMSSE: 0.483185	valid_1's RMSE: 1.87352
# [1404]	training's WRMSSE: 0.483212	training's RMSE: 1.91095	valid_1's WRMSSE: 0.483188	valid_1's RMSE: 1.87351
# [1405]	training's WRMSSE: 0.48319	training's RMSE: 1.91089	valid_1's WRMSSE: 0.483183	valid_1's RMSE: 1.87351
# [1406]	training's WRMSSE: 0.483178	training's RMSE: 1.91088	valid_1's WRMSSE: 0.483184	valid_1's RMSE: 1.87351
# [1407]	training's WRMSSE: 0.483174	training's RMSE: 1.91088	valid_1's WRMSSE: 0.483188	valid_1's RMSE: 1.87351
# [1408]	training's WRMSSE: 0.483162	training's RMSE: 1.91085	valid_1's WRMSSE: 0.483183	valid_1's RMSE: 1.87351
# [1409]	training's WRMSSE: 0.482995	training's RMSE: 1.91082	valid_1's WRMSSE: 0.483183	valid_1's RMSE: 1.8735
# [1410]	training's WRMSSE: 0.482989	training's RMSE: 1.91079	valid_1's WRMSSE: 0.483173	valid_1's RMSE: 1.87349
# [1411]	training's WRMSSE: 0.482973	training's RMSE: 1.91074	valid_1's WRMSSE: 0.483176	valid_1's RMSE: 1.87351
# [1412]	training's WRMSSE: 0.482954	training's RMSE: 1.9107	valid_1's WRMSSE: 0.483168	valid_1's RMSE: 1.87351
# [1413]	training's WRMSSE: 0.482951	training's RMSE: 1.91069	valid_1's WRMSSE: 0.483165	valid_1's RMSE: 1.87351
# [1414]	training's WRMSSE: 0.482945	training's RMSE: 1.91067	valid_1's WRMSSE: 0.483164	valid_1's RMSE: 1.87349
# [1415]	training's WRMSSE: 0.482934	training's RMSE: 1.91064	valid_1's WRMSSE: 0.483171	valid_1's RMSE: 1.87351
# [1416]	training's WRMSSE: 0.482923	training's RMSE: 1.9106	valid_1's WRMSSE: 0.483166	valid_1's RMSE: 1.87349
# [1417]	training's WRMSSE: 0.482883	training's RMSE: 1.91057	valid_1's WRMSSE: 0.48317	valid_1's RMSE: 1.87351
# [1418]	training's WRMSSE: 0.48284	training's RMSE: 1.91056	valid_1's WRMSSE: 0.483168	valid_1's RMSE: 1.87351
# [1419]	training's WRMSSE: 0.482828	training's RMSE: 1.91053	valid_1's WRMSSE: 0.483167	valid_1's RMSE: 1.8735
# [1420]	training's WRMSSE: 0.482805	training's RMSE: 1.91051	valid_1's WRMSSE: 0.483156	valid_1's RMSE: 1.87348
# [1421]	training's WRMSSE: 0.482792	training's RMSE: 1.91045	valid_1's WRMSSE: 0.483139	valid_1's RMSE: 1.87344
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# <ipython-input-145-f423d1ca6427> in <module>
#       1 lgb_re2.fit(X_train,y_train,eval_set = [(X_train,y_train),(X_valid,y_valid)],verbose=1,
#       2            eval_metric =lambda y_true, y_pred: [evaluator_super.feval(y_true, y_pred), rmse(y_true, y_pred)],
# ----> 3            early_stopping_rounds=50,categorical_feature=cat_col)
#
# /opt/conda/lib/python3.7/site-packages/lightgbm/sklearn.py in fit(self, X, y, sample_weight, init_score, eval_set, eval_names, eval_sample_weight, eval_init_score, eval_metric, early_stopping_rounds, verbose, feature_name, categorical_feature, callbacks)
#     741                                        verbose=verbose, feature_name=feature_name,
#     742                                        categorical_feature=categorical_feature,
# --> 743                                        callbacks=callbacks)
#     744         return self
#     745
#
# /opt/conda/lib/python3.7/site-packages/lightgbm/sklearn.py in fit(self, X, y, sample_weight, init_score, group, eval_set, eval_names, eval_sample_weight, eval_class_weight, eval_init_score, eval_group, eval_metric, early_stopping_rounds, verbose, feature_name, categorical_feature, callbacks)
#     598                               verbose_eval=verbose, feature_name=feature_name,
#     599                               categorical_feature=categorical_feature,
# --> 600                               callbacks=callbacks)
#     601
#     602         if evals_result:
#
# /opt/conda/lib/python3.7/site-packages/lightgbm/engine.py in train(params, train_set, num_boost_round, valid_sets, valid_names, fobj, feval, init_model, feature_name, categorical_feature, early_stopping_rounds, evals_result, verbose_eval, learning_rates, keep_training_booster, callbacks)
#     247                                     evaluation_result_list=None))
#     248
# --> 249         booster.update(fobj=fobj)
#     250
#     251         evaluation_result_list = []
#
# /opt/conda/lib/python3.7/site-packages/lightgbm/basic.py in update(self, train_set, fobj)
#    1980             if not self.__set_objective_to_none:
#    1981                 self.reset_parameter({"objective": "none"}).__set_objective_to_none = True
# -> 1982             grad, hess = fobj(self.__inner_predict(0), self.train_set)
#    1983             return self.__boost(grad, hess)
#    1984
#
# /opt/conda/lib/python3.7/site-packages/lightgbm/sklearn.py in __call__(self, preds, dataset)
#      68         argc = argc_(self.func)
#      69         if argc == 2:
# ---> 70             grad, hess = self.func(labels, preds)
#      71         elif argc == 3:
#      72             grad, hess = self.func(labels, preds, dataset.get_group())
#
# <ipython-input-143-7db61759c67e> in custom_obj(y_true, y_pred)
#       4     d = residual.shape[0]
#       5     residual_42840 = residual * roll_mat_csr.T
# ----> 6     mean_square_42840 = np.square(residual_42840).sum(axis = 0)
#       7     temp_1 = func1(mean_square_42840)
#       8     part1 = ((1/np.sqrt(S)) * temp_1)/np.sqrt(d)
#
# KeyboardInterrupt:

# %%
X_train = train1[(train1.day_num<=1885- 27)&(train1.day_num>=1885-1-364- 27)&(train1.date!='2015-12-25')&(train1.date!='2014-12-25')].drop(drop_col,axis=1).copy()
y_train = train1.loc[(train1.day_num<=1885- 27)&(train1.day_num>=1885-1-364- 27)&(train1.date!='2015-12-25')&(train1.date!='2014-12-25'),'sale']
X_valid = train1[(train1.day_num<=1913 - 27)&(train1.day_num>=1886- 27)].drop(drop_col,axis=1).copy()
y_valid = train1.loc[(train1.day_num<=1913- 27)&(train1.day_num>=1886- 27),'sale']
y_train[y_train==-999] = 0
y_valid[y_valid==-999] = 0

# %%
lgb_re2 = lgb.LGBMRegressor(n_estimators=1000, random_state=51,subsample=0.8,
                         colsample_bytree=0.8,learning_rate=0.05 ,importance_type = 'gain',
                 max_depth = -1, num_leaves = 2**8-1,metric='None',bagging_freq=1,n_jobs=12,
                         first_metric_only = True,objective=custom_obj,min_data_in_leaf =  2**8-1)

# %%
### add clip

lgb_re2.fit(X_train,y_train,eval_set = [(X_valid,y_valid)],verbose=10,
           eval_metric =lambda y_true, y_pred: [evaluator_super.feval(y_true, y_pred), rmse(y_true, y_pred)],
           early_stopping_rounds=50)#,categorical_feature=cat_col)
# Out:
# Training until validation scores don't improve for 50 rounds
# [10]	valid_0's WRMSSE: 2.37742	valid_0's RMSE: 2.54007
# [20]	valid_0's WRMSSE: 1.17241	valid_0's RMSE: 2.12117
# [30]	valid_0's WRMSSE: 0.745133	valid_0's RMSE: 2.01284
# [40]	valid_0's WRMSSE: 0.629294	valid_0's RMSE: 1.98434
# [50]	valid_0's WRMSSE: 0.598389	valid_0's RMSE: 1.97467
# [60]	valid_0's WRMSSE: 0.588105	valid_0's RMSE: 1.96962
# [70]	valid_0's WRMSSE: 0.58433	valid_0's RMSE: 1.96709
# [80]	valid_0's WRMSSE: 0.582542	valid_0's RMSE: 1.96555
# [90]	valid_0's WRMSSE: 0.581332	valid_0's RMSE: 1.96344
# [100]	valid_0's WRMSSE: 0.580369	valid_0's RMSE: 1.96203
# [110]	valid_0's WRMSSE: 0.580139	valid_0's RMSE: 1.96145
# [120]	valid_0's WRMSSE: 0.580197	valid_0's RMSE: 1.96074
# [130]	valid_0's WRMSSE: 0.579147	valid_0's RMSE: 1.95984
# [140]	valid_0's WRMSSE: 0.578739	valid_0's RMSE: 1.95904
# [150]	valid_0's WRMSSE: 0.578298	valid_0's RMSE: 1.95843
# [160]	valid_0's WRMSSE: 0.577648	valid_0's RMSE: 1.95766
# [170]	valid_0's WRMSSE: 0.577068	valid_0's RMSE: 1.95734
# [180]	valid_0's WRMSSE: 0.576653	valid_0's RMSE: 1.95693
# [190]	valid_0's WRMSSE: 0.576223	valid_0's RMSE: 1.95646
# [200]	valid_0's WRMSSE: 0.575861	valid_0's RMSE: 1.95603
# [210]	valid_0's WRMSSE: 0.575886	valid_0's RMSE: 1.95547
# [220]	valid_0's WRMSSE: 0.575596	valid_0's RMSE: 1.95532
# [230]	valid_0's WRMSSE: 0.574864	valid_0's RMSE: 1.95529
# [240]	valid_0's WRMSSE: 0.574768	valid_0's RMSE: 1.95484
# [250]	valid_0's WRMSSE: 0.574888	valid_0's RMSE: 1.95472
# [260]	valid_0's WRMSSE: 0.574923	valid_0's RMSE: 1.95468
# [270]	valid_0's WRMSSE: 0.574702	valid_0's RMSE: 1.95464
# [280]	valid_0's WRMSSE: 0.575079	valid_0's RMSE: 1.95462
# [290]	valid_0's WRMSSE: 0.574645	valid_0's RMSE: 1.9545
# [300]	valid_0's WRMSSE: 0.574497	valid_0's RMSE: 1.95422
# [310]	valid_0's WRMSSE: 0.574442	valid_0's RMSE: 1.95416
# [320]	valid_0's WRMSSE: 0.574505	valid_0's RMSE: 1.95442
# [330]	valid_0's WRMSSE: 0.574426	valid_0's RMSE: 1.95437
# [340]	valid_0's WRMSSE: 0.573781	valid_0's RMSE: 1.95399
# [350]	valid_0's WRMSSE: 0.5744	valid_0's RMSE: 1.95405
# [360]	valid_0's WRMSSE: 0.574692	valid_0's RMSE: 1.95413
# [370]	valid_0's WRMSSE: 0.574816	valid_0's RMSE: 1.95403
# [380]	valid_0's WRMSSE: 0.574515	valid_0's RMSE: 1.95423
# [390]	valid_0's WRMSSE: 0.574568	valid_0's RMSE: 1.95411
# Early stopping, best iteration is:
# [341]	valid_0's WRMSSE: 0.573761	valid_0's RMSE: 1.95391
# Evaluated only: WRMSSE
# LGBMRegressor(bagging_freq=1, boosting_type='gbdt', class_weight=None,
#        colsample_bytree=0.8, first_metric_only=True,
#        importance_type='gain', learning_rate=0.05, max_depth=-1,
#        metric='None', min_child_samples=20, min_child_weight=0.001,
#        min_data_in_leaf=255, min_split_gain=0.0, n_estimators=1000,
#        n_jobs=12, num_leaves=255,
#        objective=<function custom_obj at 0x7fc7c69ffd90>, random_state=51,
#        reg_alpha=0.0, reg_lambda=0.0, silent=True, subsample=0.8,
#        subsample_for_bin=200000, subsample_freq=0)

# %%
lgb_re2.fit(X_train,y_train,eval_set = [(X_valid,y_valid)],verbose=10,
           eval_metric =lambda y_true, y_pred: [evaluator_super.feval(y_true, y_pred), rmse(y_true, y_pred)],
           early_stopping_rounds=50)#,categorical_feature=cat_col)
# Out:
# Training until validation scores don't improve for 50 rounds
# [10]	valid_0's WRMSSE: 2.37742	valid_0's RMSE: 2.54007
# [20]	valid_0's WRMSSE: 1.17241	valid_0's RMSE: 2.12117
# [30]	valid_0's WRMSSE: 0.745133	valid_0's RMSE: 2.01284
# [40]	valid_0's WRMSSE: 0.629294	valid_0's RMSE: 1.98434
# [50]	valid_0's WRMSSE: 0.598389	valid_0's RMSE: 1.97467
# [60]	valid_0's WRMSSE: 0.588105	valid_0's RMSE: 1.96962
# [70]	valid_0's WRMSSE: 0.58433	valid_0's RMSE: 1.96709
# [80]	valid_0's WRMSSE: 0.582672	valid_0's RMSE: 1.96556
# [90]	valid_0's WRMSSE: 0.582356	valid_0's RMSE: 1.96347
# [100]	valid_0's WRMSSE: 0.581274	valid_0's RMSE: 1.96186
# [110]	valid_0's WRMSSE: 0.580791	valid_0's RMSE: 1.96118
# [120]	valid_0's WRMSSE: 0.581276	valid_0's RMSE: 1.96105
# [130]	valid_0's WRMSSE: 0.580891	valid_0's RMSE: 1.96023
# [140]	valid_0's WRMSSE: 0.580324	valid_0's RMSE: 1.95935
# [150]	valid_0's WRMSSE: 0.57956	valid_0's RMSE: 1.95896
# [160]	valid_0's WRMSSE: 0.579294	valid_0's RMSE: 1.95823
# [170]	valid_0's WRMSSE: 0.579097	valid_0's RMSE: 1.95768
# [180]	valid_0's WRMSSE: 0.578019	valid_0's RMSE: 1.95737
# [190]	valid_0's WRMSSE: 0.577364	valid_0's RMSE: 1.95689
# [200]	valid_0's WRMSSE: 0.577123	valid_0's RMSE: 1.95687
# [210]	valid_0's WRMSSE: 0.577222	valid_0's RMSE: 1.95639
# [220]	valid_0's WRMSSE: 0.576568	valid_0's RMSE: 1.9562
# [230]	valid_0's WRMSSE: 0.57609	valid_0's RMSE: 1.95592
# [240]	valid_0's WRMSSE: 0.575831	valid_0's RMSE: 1.95536
# [250]	valid_0's WRMSSE: 0.577703	valid_0's RMSE: 1.95877
# [260]	valid_0's WRMSSE: 0.589239	valid_0's RMSE: 1.97735
# [270]	valid_0's WRMSSE: 0.595454	valid_0's RMSE: 1.99037
# [280]	valid_0's WRMSSE: 0.597888	valid_0's RMSE: 1.9968
# /opt/conda/lib/python3.7/site-packages/ipykernel_launcher.py:18: RuntimeWarning: overflow encountered in square
# /opt/conda/lib/python3.7/site-packages/ipykernel_launcher.py:2: RuntimeWarning: overflow encountered in power
#
# /opt/conda/lib/python3.7/site-packages/ipykernel_launcher.py:6: RuntimeWarning: overflow encountered in square
#
# /opt/conda/lib/python3.7/site-packages/ipykernel_launcher.py:11: RuntimeWarning: overflow encountered in square
#   # This is added back by InteractiveShellApp.init_path()
# /opt/conda/lib/python3.7/site-packages/ipykernel_launcher.py:11: RuntimeWarning: invalid value encountered in multiply
#   # This is added back by InteractiveShellApp.init_path()
# [290]	valid_0's WRMSSE: inf	valid_0's RMSE: inf
# Early stopping, best iteration is:
# [246]	valid_0's WRMSSE: 0.575458	valid_0's RMSE: 1.95571
# Evaluated only: WRMSSE
# LGBMRegressor(bagging_freq=1, boosting_type='gbdt', class_weight=None,
#        colsample_bytree=0.8, first_metric_only=True,
#        importance_type='gain', learning_rate=0.05, max_depth=-1,
#        metric='None', min_child_samples=20, min_child_weight=0.001,
#        min_data_in_leaf=255, min_split_gain=0.0, n_estimators=1000,
#        n_jobs=12, num_leaves=255,
#        objective=<function custom_obj at 0x7fc7c91e1378>, random_state=51,
#        reg_alpha=0.0, reg_lambda=0.0, silent=True, subsample=0.8,
#        subsample_for_bin=200000, subsample_freq=0)

# %%
###132
lgb_re2.fit(X_train,y_train,eval_set = [(X_train,y_train),(X_valid,y_valid)],verbose=1,
           eval_metric =lambda y_true, y_pred: [evaluator_super.feval(y_true, y_pred), rmse(y_true, y_pred)],
           early_stopping_rounds=50)#,categorical_feature=cat_col)
# Out:
# [1]	training's WRMSSE: 4.45479	training's RMSE: 3.60456	valid_1's WRMSSE: 4.81607	valid_1's RMSE: 3.68804
# Training until validation scores don't improve for 50 rounds
# [2]	training's WRMSSE: 4.1171	training's RMSE: 3.42673	valid_1's WRMSSE: 4.45191	valid_1's RMSE: 3.5035
# [3]	training's WRMSSE: 3.80428	training's RMSE: 3.26389	valid_1's WRMSSE: 4.11494	valid_1's RMSE: 3.33423
# [4]	training's WRMSSE: 3.51563	training's RMSE: 3.11655	valid_1's WRMSSE: 3.80348	valid_1's RMSE: 3.17961
# [5]	training's WRMSSE: 3.24855	training's RMSE: 2.98409	valid_1's WRMSSE: 3.51343	valid_1's RMSE: 3.04112
# [6]	training's WRMSSE: 3.00384	training's RMSE: 2.86735	valid_1's WRMSSE: 3.2491	valid_1's RMSE: 2.91738
# [7]	training's WRMSSE: 2.77691	training's RMSE: 2.76158	valid_1's WRMSSE: 3.00302	valid_1's RMSE: 2.80647
# [8]	training's WRMSSE: 2.56916	training's RMSE: 2.66737	valid_1's WRMSSE: 2.77671	valid_1's RMSE: 2.70736
# [9]	training's WRMSSE: 2.37767	training's RMSE: 2.58307	valid_1's WRMSSE: 2.56848	valid_1's RMSE: 2.61869
# [10]	training's WRMSSE: 2.20215	training's RMSE: 2.5088	valid_1's WRMSSE: 2.37742	valid_1's RMSE: 2.54007
# [11]	training's WRMSSE: 2.04058	training's RMSE: 2.44423	valid_1's WRMSSE: 2.20233	valid_1's RMSE: 2.47168
# [12]	training's WRMSSE: 1.89265	training's RMSE: 2.38725	valid_1's WRMSSE: 2.04121	valid_1's RMSE: 2.41113
# [13]	training's WRMSSE: 1.75812	training's RMSE: 2.33592	valid_1's WRMSSE: 1.89414	valid_1's RMSE: 2.35652
# [14]	training's WRMSSE: 1.63479	training's RMSE: 2.28949	valid_1's WRMSSE: 1.7589	valid_1's RMSE: 2.30704
# [15]	training's WRMSSE: 1.523	training's RMSE: 2.25024	valid_1's WRMSSE: 1.63674	valid_1's RMSE: 2.2649
# [16]	training's WRMSSE: 1.42043	training's RMSE: 2.21515	valid_1's WRMSSE: 1.52396	valid_1's RMSE: 2.22761
# [17]	training's WRMSSE: 1.3278	training's RMSE: 2.1847	valid_1's WRMSSE: 1.42302	valid_1's RMSE: 2.19488
# [18]	training's WRMSSE: 1.24391	training's RMSE: 2.15894	valid_1's WRMSSE: 1.33115	valid_1's RMSE: 2.16752
# [19]	training's WRMSSE: 1.16821	training's RMSE: 2.13555	valid_1's WRMSSE: 1.24731	valid_1's RMSE: 2.1423
# [20]	training's WRMSSE: 1.09979	training's RMSE: 2.11503	valid_1's WRMSSE: 1.17241	valid_1's RMSE: 2.12117
# [21]	training's WRMSSE: 1.03718	training's RMSE: 2.09779	valid_1's WRMSSE: 1.10474	valid_1's RMSE: 2.10305
# [22]	training's WRMSSE: 0.981673	training's RMSE: 2.0822	valid_1's WRMSSE: 1.04328	valid_1's RMSE: 2.08626
# [23]	training's WRMSSE: 0.932227	training's RMSE: 2.06855	valid_1's WRMSSE: 0.988826	valid_1's RMSE: 2.07213
# [24]	training's WRMSSE: 0.888146	training's RMSE: 2.0563	valid_1's WRMSSE: 0.94054	valid_1's RMSE: 2.05957
# [25]	training's WRMSSE: 0.849626	training's RMSE: 2.04598	valid_1's WRMSSE: 0.89791	valid_1's RMSE: 2.04906
# [26]	training's WRMSSE: 0.815283	training's RMSE: 2.03707	valid_1's WRMSSE: 0.860211	valid_1's RMSE: 2.03982
# [27]	training's WRMSSE: 0.78403	training's RMSE: 2.02901	valid_1's WRMSSE: 0.826006	valid_1's RMSE: 2.0317
# [28]	training's WRMSSE: 0.756565	training's RMSE: 2.02176	valid_1's WRMSSE: 0.79599	valid_1's RMSE: 2.02438
# [29]	training's WRMSSE: 0.732047	training's RMSE: 2.01602	valid_1's WRMSSE: 0.768641	valid_1's RMSE: 2.01832
# [30]	training's WRMSSE: 0.710171	training's RMSE: 2.01083	valid_1's WRMSSE: 0.745133	valid_1's RMSE: 2.01284
# [31]	training's WRMSSE: 0.691422	training's RMSE: 2.0064	valid_1's WRMSSE: 0.7245	valid_1's RMSE: 2.00857
# [32]	training's WRMSSE: 0.675198	training's RMSE: 2.0022	valid_1's WRMSSE: 0.707048	valid_1's RMSE: 2.00458
# [33]	training's WRMSSE: 0.661167	training's RMSE: 1.99842	valid_1's WRMSSE: 0.691451	valid_1's RMSE: 2.00099
# [34]	training's WRMSSE: 0.649039	training's RMSE: 1.99505	valid_1's WRMSSE: 0.678325	valid_1's RMSE: 1.99772
# [35]	training's WRMSSE: 0.638516	training's RMSE: 1.99219	valid_1's WRMSSE: 0.667649	valid_1's RMSE: 1.99525
# [36]	training's WRMSSE: 0.628544	training's RMSE: 1.98928	valid_1's WRMSSE: 0.657645	valid_1's RMSE: 1.99249
# [37]	training's WRMSSE: 0.619891	training's RMSE: 1.98687	valid_1's WRMSSE: 0.649186	valid_1's RMSE: 1.99012
# [38]	training's WRMSSE: 0.612177	training's RMSE: 1.98444	valid_1's WRMSSE: 0.641398	valid_1's RMSE: 1.98784
# [39]	training's WRMSSE: 0.605885	training's RMSE: 1.98256	valid_1's WRMSSE: 0.635299	valid_1's RMSE: 1.98598
# [40]	training's WRMSSE: 0.599298	training's RMSE: 1.98057	valid_1's WRMSSE: 0.629294	valid_1's RMSE: 1.98434
# [41]	training's WRMSSE: 0.594063	training's RMSE: 1.97859	valid_1's WRMSSE: 0.624037	valid_1's RMSE: 1.98282
# [42]	training's WRMSSE: 0.589244	training's RMSE: 1.97699	valid_1's WRMSSE: 0.619544	valid_1's RMSE: 1.98164
# [43]	training's WRMSSE: 0.585224	training's RMSE: 1.97546	valid_1's WRMSSE: 0.615578	valid_1's RMSE: 1.98049
# [44]	training's WRMSSE: 0.581093	training's RMSE: 1.97385	valid_1's WRMSSE: 0.611947	valid_1's RMSE: 1.97917
# [45]	training's WRMSSE: 0.576636	training's RMSE: 1.97231	valid_1's WRMSSE: 0.609393	valid_1's RMSE: 1.97815
# [46]	training's WRMSSE: 0.573337	training's RMSE: 1.97109	valid_1's WRMSSE: 0.606467	valid_1's RMSE: 1.9772
# [47]	training's WRMSSE: 0.570905	training's RMSE: 1.97001	valid_1's WRMSSE: 0.604352	valid_1's RMSE: 1.97638
# [48]	training's WRMSSE: 0.568133	training's RMSE: 1.96895	valid_1's WRMSSE: 0.602076	valid_1's RMSE: 1.97579
# [49]	training's WRMSSE: 0.565664	training's RMSE: 1.96802	valid_1's WRMSSE: 0.600414	valid_1's RMSE: 1.97528
# [50]	training's WRMSSE: 0.563275	training's RMSE: 1.96704	valid_1's WRMSSE: 0.598389	valid_1's RMSE: 1.97467
# [51]	training's WRMSSE: 0.561347	training's RMSE: 1.96597	valid_1's WRMSSE: 0.596844	valid_1's RMSE: 1.97415
# [52]	training's WRMSSE: 0.559491	training's RMSE: 1.965	valid_1's WRMSSE: 0.595445	valid_1's RMSE: 1.97347
# [53]	training's WRMSSE: 0.557707	training's RMSE: 1.96384	valid_1's WRMSSE: 0.594185	valid_1's RMSE: 1.97267
# [54]	training's WRMSSE: 0.555855	training's RMSE: 1.9631	valid_1's WRMSSE: 0.593101	valid_1's RMSE: 1.97234
# [55]	training's WRMSSE: 0.553785	training's RMSE: 1.96266	valid_1's WRMSSE: 0.592456	valid_1's RMSE: 1.97202
# [56]	training's WRMSSE: 0.552834	training's RMSE: 1.96201	valid_1's WRMSSE: 0.591572	valid_1's RMSE: 1.97135
# [57]	training's WRMSSE: 0.550642	training's RMSE: 1.96127	valid_1's WRMSSE: 0.590921	valid_1's RMSE: 1.97092
# [58]	training's WRMSSE: 0.549173	training's RMSE: 1.96043	valid_1's WRMSSE: 0.589785	valid_1's RMSE: 1.97032
# [59]	training's WRMSSE: 0.545799	training's RMSE: 1.96003	valid_1's WRMSSE: 0.588692	valid_1's RMSE: 1.97011
# [60]	training's WRMSSE: 0.544617	training's RMSE: 1.95936	valid_1's WRMSSE: 0.588105	valid_1's RMSE: 1.96962
# [61]	training's WRMSSE: 0.542912	training's RMSE: 1.95874	valid_1's WRMSSE: 0.587579	valid_1's RMSE: 1.96931
# [62]	training's WRMSSE: 0.541725	training's RMSE: 1.95812	valid_1's WRMSSE: 0.586869	valid_1's RMSE: 1.96904
# [63]	training's WRMSSE: 0.54091	training's RMSE: 1.95749	valid_1's WRMSSE: 0.586593	valid_1's RMSE: 1.9688
# [64]	training's WRMSSE: 0.536817	training's RMSE: 1.9567	valid_1's WRMSSE: 0.586368	valid_1's RMSE: 1.96863
# [65]	training's WRMSSE: 0.535366	training's RMSE: 1.95605	valid_1's WRMSSE: 0.585833	valid_1's RMSE: 1.96827
# [66]	training's WRMSSE: 0.533388	training's RMSE: 1.9553	valid_1's WRMSSE: 0.585058	valid_1's RMSE: 1.96789
# [67]	training's WRMSSE: 0.532358	training's RMSE: 1.95477	valid_1's WRMSSE: 0.584848	valid_1's RMSE: 1.96775
# [68]	training's WRMSSE: 0.531078	training's RMSE: 1.95435	valid_1's WRMSSE: 0.584401	valid_1's RMSE: 1.96737
# [69]	training's WRMSSE: 0.53048	training's RMSE: 1.9538	valid_1's WRMSSE: 0.584087	valid_1's RMSE: 1.96712
# [70]	training's WRMSSE: 0.528461	training's RMSE: 1.95327	valid_1's WRMSSE: 0.58433	valid_1's RMSE: 1.96709
# [71]	training's WRMSSE: 0.527772	training's RMSE: 1.9529	valid_1's WRMSSE: 0.584335	valid_1's RMSE: 1.9671
# [72]	training's WRMSSE: 0.526759	training's RMSE: 1.95245	valid_1's WRMSSE: 0.584164	valid_1's RMSE: 1.96694
# [73]	training's WRMSSE: 0.526396	training's RMSE: 1.9521	valid_1's WRMSSE: 0.58402	valid_1's RMSE: 1.96664
# [74]	training's WRMSSE: 0.525483	training's RMSE: 1.95172	valid_1's WRMSSE: 0.58367	valid_1's RMSE: 1.96641
# [75]	training's WRMSSE: 0.524051	training's RMSE: 1.95111	valid_1's WRMSSE: 0.582993	valid_1's RMSE: 1.96619
# [76]	training's WRMSSE: 0.523493	training's RMSE: 1.95072	valid_1's WRMSSE: 0.582908	valid_1's RMSE: 1.96607
# [77]	training's WRMSSE: 0.522831	training's RMSE: 1.95037	valid_1's WRMSSE: 0.582778	valid_1's RMSE: 1.96586
# [78]	training's WRMSSE: 0.522296	training's RMSE: 1.9499	valid_1's WRMSSE: 0.582557	valid_1's RMSE: 1.96563
# [79]	training's WRMSSE: 0.521919	training's RMSE: 1.94957	valid_1's WRMSSE: 0.582501	valid_1's RMSE: 1.96561
# [80]	training's WRMSSE: 0.519736	training's RMSE: 1.94912	valid_1's WRMSSE: 0.582672	valid_1's RMSE: 1.96556
# [81]	training's WRMSSE: 0.519227	training's RMSE: 1.94876	valid_1's WRMSSE: 0.582504	valid_1's RMSE: 1.96527
# [82]	training's WRMSSE: 0.51879	training's RMSE: 1.94835	valid_1's WRMSSE: 0.582521	valid_1's RMSE: 1.96521
# [83]	training's WRMSSE: 0.518363	training's RMSE: 1.94813	valid_1's WRMSSE: 0.582475	valid_1's RMSE: 1.96497
# [84]	training's WRMSSE: 0.517593	training's RMSE: 1.94749	valid_1's WRMSSE: 0.582635	valid_1's RMSE: 1.96483
# [85]	training's WRMSSE: 0.517339	training's RMSE: 1.94702	valid_1's WRMSSE: 0.582511	valid_1's RMSE: 1.96436
# [86]	training's WRMSSE: 0.517014	training's RMSE: 1.94664	valid_1's WRMSSE: 0.582527	valid_1's RMSE: 1.9642
# [87]	training's WRMSSE: 0.516824	training's RMSE: 1.94613	valid_1's WRMSSE: 0.582491	valid_1's RMSE: 1.96422
# [88]	training's WRMSSE: 0.516082	training's RMSE: 1.94572	valid_1's WRMSSE: 0.582659	valid_1's RMSE: 1.96404
# [89]	training's WRMSSE: 0.515759	training's RMSE: 1.9453	valid_1's WRMSSE: 0.582459	valid_1's RMSE: 1.96379
# [90]	training's WRMSSE: 0.515152	training's RMSE: 1.94489	valid_1's WRMSSE: 0.582356	valid_1's RMSE: 1.96347
# [91]	training's WRMSSE: 0.514838	training's RMSE: 1.94447	valid_1's WRMSSE: 0.582253	valid_1's RMSE: 1.96327
# [92]	training's WRMSSE: 0.514044	training's RMSE: 1.94411	valid_1's WRMSSE: 0.582267	valid_1's RMSE: 1.96308
# [93]	training's WRMSSE: 0.513866	training's RMSE: 1.94378	valid_1's WRMSSE: 0.582171	valid_1's RMSE: 1.96299
# [94]	training's WRMSSE: 0.512964	training's RMSE: 1.94352	valid_1's WRMSSE: 0.582273	valid_1's RMSE: 1.96289
# [95]	training's WRMSSE: 0.512532	training's RMSE: 1.94325	valid_1's WRMSSE: 0.582049	valid_1's RMSE: 1.96273
# [96]	training's WRMSSE: 0.511504	training's RMSE: 1.94285	valid_1's WRMSSE: 0.582002	valid_1's RMSE: 1.96244
# [97]	training's WRMSSE: 0.511244	training's RMSE: 1.94233	valid_1's WRMSSE: 0.581894	valid_1's RMSE: 1.96249
# [98]	training's WRMSSE: 0.509706	training's RMSE: 1.94191	valid_1's WRMSSE: 0.581524	valid_1's RMSE: 1.96234
# [99]	training's WRMSSE: 0.508027	training's RMSE: 1.94137	valid_1's WRMSSE: 0.581421	valid_1's RMSE: 1.96207
# [100]	training's WRMSSE: 0.507214	training's RMSE: 1.94102	valid_1's WRMSSE: 0.581353	valid_1's RMSE: 1.96187
# [101]	training's WRMSSE: 0.505228	training's RMSE: 1.94061	valid_1's WRMSSE: 0.581351	valid_1's RMSE: 1.9618
# [102]	training's WRMSSE: 0.505017	training's RMSE: 1.94017	valid_1's WRMSSE: 0.581374	valid_1's RMSE: 1.96172
# [103]	training's WRMSSE: 0.504582	training's RMSE: 1.93965	valid_1's WRMSSE: 0.581198	valid_1's RMSE: 1.96153
# [104]	training's WRMSSE: 0.504447	training's RMSE: 1.93941	valid_1's WRMSSE: 0.581252	valid_1's RMSE: 1.96159
# [105]	training's WRMSSE: 0.50405	training's RMSE: 1.93894	valid_1's WRMSSE: 0.581235	valid_1's RMSE: 1.96145
# [106]	training's WRMSSE: 0.503894	training's RMSE: 1.93863	valid_1's WRMSSE: 0.58121	valid_1's RMSE: 1.96135
# [107]	training's WRMSSE: 0.503704	training's RMSE: 1.93831	valid_1's WRMSSE: 0.581062	valid_1's RMSE: 1.96133
# [108]	training's WRMSSE: 0.503336	training's RMSE: 1.93795	valid_1's WRMSSE: 0.580862	valid_1's RMSE: 1.96123
# [109]	training's WRMSSE: 0.501628	training's RMSE: 1.9376	valid_1's WRMSSE: 0.580856	valid_1's RMSE: 1.96115
# [110]	training's WRMSSE: 0.50151	training's RMSE: 1.93726	valid_1's WRMSSE: 0.580873	valid_1's RMSE: 1.96119
# [111]	training's WRMSSE: 0.500954	training's RMSE: 1.93691	valid_1's WRMSSE: 0.581114	valid_1's RMSE: 1.96121
# [112]	training's WRMSSE: 0.500566	training's RMSE: 1.93655	valid_1's WRMSSE: 0.581243	valid_1's RMSE: 1.96123
# [113]	training's WRMSSE: 0.50026	training's RMSE: 1.93606	valid_1's WRMSSE: 0.581099	valid_1's RMSE: 1.96118
# [114]	training's WRMSSE: 0.500069	training's RMSE: 1.93586	valid_1's WRMSSE: 0.581056	valid_1's RMSE: 1.96111
# [115]	training's WRMSSE: 0.49981	training's RMSE: 1.93558	valid_1's WRMSSE: 0.581015	valid_1's RMSE: 1.961
# [116]	training's WRMSSE: 0.498229	training's RMSE: 1.93505	valid_1's WRMSSE: 0.581353	valid_1's RMSE: 1.96104
# [117]	training's WRMSSE: 0.497315	training's RMSE: 1.93476	valid_1's WRMSSE: 0.581215	valid_1's RMSE: 1.96101
# [118]	training's WRMSSE: 0.497191	training's RMSE: 1.93457	valid_1's WRMSSE: 0.581241	valid_1's RMSE: 1.96106
# [119]	training's WRMSSE: 0.496913	training's RMSE: 1.93416	valid_1's WRMSSE: 0.581109	valid_1's RMSE: 1.96094
# [120]	training's WRMSSE: 0.496103	training's RMSE: 1.93373	valid_1's WRMSSE: 0.581369	valid_1's RMSE: 1.96106
# [121]	training's WRMSSE: 0.495662	training's RMSE: 1.9333	valid_1's WRMSSE: 0.58132	valid_1's RMSE: 1.96101
# [122]	training's WRMSSE: 0.495467	training's RMSE: 1.93299	valid_1's WRMSSE: 0.581283	valid_1's RMSE: 1.96088
# [123]	training's WRMSSE: 0.494905	training's RMSE: 1.93241	valid_1's WRMSSE: 0.581268	valid_1's RMSE: 1.96078
# [124]	training's WRMSSE: 0.494776	training's RMSE: 1.93215	valid_1's WRMSSE: 0.581303	valid_1's RMSE: 1.96072
# [125]	training's WRMSSE: 0.494554	training's RMSE: 1.9319	valid_1's WRMSSE: 0.581245	valid_1's RMSE: 1.96067
# [126]	training's WRMSSE: 0.494408	training's RMSE: 1.93149	valid_1's WRMSSE: 0.581195	valid_1's RMSE: 1.96046
# [127]	training's WRMSSE: 0.494301	training's RMSE: 1.93118	valid_1's WRMSSE: 0.581178	valid_1's RMSE: 1.96048
# [128]	training's WRMSSE: 0.492671	training's RMSE: 1.93083	valid_1's WRMSSE: 0.581051	valid_1's RMSE: 1.96039
# [129]	training's WRMSSE: 0.492572	training's RMSE: 1.93053	valid_1's WRMSSE: 0.581029	valid_1's RMSE: 1.96032
# [130]	training's WRMSSE: 0.492362	training's RMSE: 1.93007	valid_1's WRMSSE: 0.580977	valid_1's RMSE: 1.96023
# [131]	training's WRMSSE: 0.492112	training's RMSE: 1.92979	valid_1's WRMSSE: 0.580918	valid_1's RMSE: 1.96013
# [132]	training's WRMSSE: 0.491957	training's RMSE: 1.92941	valid_1's WRMSSE: 0.580932	valid_1's RMSE: 1.96008
# [133]	training's WRMSSE: 0.491762	training's RMSE: 1.92905	valid_1's WRMSSE: 0.580856	valid_1's RMSE: 1.95985
# [134]	training's WRMSSE: 0.491602	training's RMSE: 1.92867	valid_1's WRMSSE: 0.580852	valid_1's RMSE: 1.95979
# [135]	training's WRMSSE: 0.491424	training's RMSE: 1.92838	valid_1's WRMSSE: 0.580738	valid_1's RMSE: 1.95977
# [136]	training's WRMSSE: 0.491294	training's RMSE: 1.92796	valid_1's WRMSSE: 0.580761	valid_1's RMSE: 1.95952
# [137]	training's WRMSSE: 0.491092	training's RMSE: 1.92762	valid_1's WRMSSE: 0.580747	valid_1's RMSE: 1.95944
# [138]	training's WRMSSE: 0.490723	training's RMSE: 1.92734	valid_1's WRMSSE: 0.580582	valid_1's RMSE: 1.95937
# [139]	training's WRMSSE: 0.49064	training's RMSE: 1.92721	valid_1's WRMSSE: 0.580626	valid_1's RMSE: 1.95936
# [140]	training's WRMSSE: 0.490366	training's RMSE: 1.92697	valid_1's WRMSSE: 0.58053	valid_1's RMSE: 1.9593
# [141]	training's WRMSSE: 0.489999	training's RMSE: 1.92684	valid_1's WRMSSE: 0.580342	valid_1's RMSE: 1.95927
# [142]	training's WRMSSE: 0.489852	training's RMSE: 1.92638	valid_1's WRMSSE: 0.580281	valid_1's RMSE: 1.95915
# [143]	training's WRMSSE: 0.489363	training's RMSE: 1.92596	valid_1's WRMSSE: 0.580213	valid_1's RMSE: 1.95907
# [144]	training's WRMSSE: 0.489071	training's RMSE: 1.92559	valid_1's WRMSSE: 0.580088	valid_1's RMSE: 1.95911
# [145]	training's WRMSSE: 0.489008	training's RMSE: 1.92537	valid_1's WRMSSE: 0.580072	valid_1's RMSE: 1.95905
# [146]	training's WRMSSE: 0.48867	training's RMSE: 1.92508	valid_1's WRMSSE: 0.580009	valid_1's RMSE: 1.95909
# [147]	training's WRMSSE: 0.488483	training's RMSE: 1.92482	valid_1's WRMSSE: 0.579971	valid_1's RMSE: 1.95901
# [148]	training's WRMSSE: 0.488219	training's RMSE: 1.92463	valid_1's WRMSSE: 0.57985	valid_1's RMSE: 1.95895
# [149]	training's WRMSSE: 0.48813	training's RMSE: 1.92437	valid_1's WRMSSE: 0.579829	valid_1's RMSE: 1.95899
# [150]	training's WRMSSE: 0.487993	training's RMSE: 1.92409	valid_1's WRMSSE: 0.579755	valid_1's RMSE: 1.95892
# [151]	training's WRMSSE: 0.487894	training's RMSE: 1.92381	valid_1's WRMSSE: 0.579757	valid_1's RMSE: 1.9588
# [152]	training's WRMSSE: 0.487827	training's RMSE: 1.92366	valid_1's WRMSSE: 0.579704	valid_1's RMSE: 1.95871
# [153]	training's WRMSSE: 0.487684	training's RMSE: 1.92328	valid_1's WRMSSE: 0.579633	valid_1's RMSE: 1.95855
# [154]	training's WRMSSE: 0.487439	training's RMSE: 1.92294	valid_1's WRMSSE: 0.579582	valid_1's RMSE: 1.95858
# [155]	training's WRMSSE: 0.486636	training's RMSE: 1.92274	valid_1's WRMSSE: 0.579482	valid_1's RMSE: 1.95855
# [156]	training's WRMSSE: 0.486291	training's RMSE: 1.92237	valid_1's WRMSSE: 0.579401	valid_1's RMSE: 1.95842
# [157]	training's WRMSSE: 0.48607	training's RMSE: 1.92201	valid_1's WRMSSE: 0.579339	valid_1's RMSE: 1.95838
# [158]	training's WRMSSE: 0.486005	training's RMSE: 1.92166	valid_1's WRMSSE: 0.57936	valid_1's RMSE: 1.95827
# [159]	training's WRMSSE: 0.485901	training's RMSE: 1.92139	valid_1's WRMSSE: 0.579335	valid_1's RMSE: 1.95824
# [160]	training's WRMSSE: 0.485743	training's RMSE: 1.92121	valid_1's WRMSSE: 0.579232	valid_1's RMSE: 1.95818
# [161]	training's WRMSSE: 0.485485	training's RMSE: 1.92093	valid_1's WRMSSE: 0.5791	valid_1's RMSE: 1.95808
# [162]	training's WRMSSE: 0.484214	training's RMSE: 1.92067	valid_1's WRMSSE: 0.579273	valid_1's RMSE: 1.95803
# [163]	training's WRMSSE: 0.483813	training's RMSE: 1.92042	valid_1's WRMSSE: 0.579154	valid_1's RMSE: 1.9579
# [164]	training's WRMSSE: 0.483719	training's RMSE: 1.92029	valid_1's WRMSSE: 0.579165	valid_1's RMSE: 1.95785
# [165]	training's WRMSSE: 0.48364	training's RMSE: 1.91991	valid_1's WRMSSE: 0.579183	valid_1's RMSE: 1.95786
# [166]	training's WRMSSE: 0.483395	training's RMSE: 1.91946	valid_1's WRMSSE: 0.579117	valid_1's RMSE: 1.95779
# [167]	training's WRMSSE: 0.483335	training's RMSE: 1.9194	valid_1's WRMSSE: 0.579126	valid_1's RMSE: 1.95776
# [168]	training's WRMSSE: 0.483285	training's RMSE: 1.91932	valid_1's WRMSSE: 0.579172	valid_1's RMSE: 1.95776
# [169]	training's WRMSSE: 0.482416	training's RMSE: 1.91908	valid_1's WRMSSE: 0.579022	valid_1's RMSE: 1.95768
# [170]	training's WRMSSE: 0.482346	training's RMSE: 1.91887	valid_1's WRMSSE: 0.579055	valid_1's RMSE: 1.95765
# [171]	training's WRMSSE: 0.482021	training's RMSE: 1.91867	valid_1's WRMSSE: 0.578703	valid_1's RMSE: 1.95755
# [172]	training's WRMSSE: 0.481903	training's RMSE: 1.91853	valid_1's WRMSSE: 0.578666	valid_1's RMSE: 1.95751
# [173]	training's WRMSSE: 0.481821	training's RMSE: 1.91845	valid_1's WRMSSE: 0.578583	valid_1's RMSE: 1.95746
# [174]	training's WRMSSE: 0.481471	training's RMSE: 1.91825	valid_1's WRMSSE: 0.578453	valid_1's RMSE: 1.95753
# [175]	training's WRMSSE: 0.481371	training's RMSE: 1.91815	valid_1's WRMSSE: 0.578402	valid_1's RMSE: 1.95752
# [176]	training's WRMSSE: 0.481317	training's RMSE: 1.91801	valid_1's WRMSSE: 0.578404	valid_1's RMSE: 1.95749
# [177]	training's WRMSSE: 0.481184	training's RMSE: 1.91745	valid_1's WRMSSE: 0.57838	valid_1's RMSE: 1.95759
# [178]	training's WRMSSE: 0.48103	training's RMSE: 1.91717	valid_1's WRMSSE: 0.578317	valid_1's RMSE: 1.95754
# [179]	training's WRMSSE: 0.479534	training's RMSE: 1.91689	valid_1's WRMSSE: 0.578153	valid_1's RMSE: 1.95741
# [180]	training's WRMSSE: 0.479315	training's RMSE: 1.91666	valid_1's WRMSSE: 0.577986	valid_1's RMSE: 1.95733
# [181]	training's WRMSSE: 0.479093	training's RMSE: 1.91631	valid_1's WRMSSE: 0.577949	valid_1's RMSE: 1.95723
# [182]	training's WRMSSE: 0.478877	training's RMSE: 1.91622	valid_1's WRMSSE: 0.577827	valid_1's RMSE: 1.95719
# [183]	training's WRMSSE: 0.478725	training's RMSE: 1.91597	valid_1's WRMSSE: 0.577761	valid_1's RMSE: 1.95716
# [184]	training's WRMSSE: 0.478611	training's RMSE: 1.91585	valid_1's WRMSSE: 0.577779	valid_1's RMSE: 1.95714
# [185]	training's WRMSSE: 0.478348	training's RMSE: 1.91535	valid_1's WRMSSE: 0.577692	valid_1's RMSE: 1.95713
# [186]	training's WRMSSE: 0.478246	training's RMSE: 1.91508	valid_1's WRMSSE: 0.577641	valid_1's RMSE: 1.9572
# [187]	training's WRMSSE: 0.478167	training's RMSE: 1.91484	valid_1's WRMSSE: 0.57761	valid_1's RMSE: 1.95717
# [188]	training's WRMSSE: 0.477986	training's RMSE: 1.91456	valid_1's WRMSSE: 0.577387	valid_1's RMSE: 1.957
# [189]	training's WRMSSE: 0.477779	training's RMSE: 1.91432	valid_1's WRMSSE: 0.57733	valid_1's RMSE: 1.9569
# [190]	training's WRMSSE: 0.477664	training's RMSE: 1.91403	valid_1's WRMSSE: 0.577326	valid_1's RMSE: 1.95685
# [191]	training's WRMSSE: 0.477603	training's RMSE: 1.91388	valid_1's WRMSSE: 0.577339	valid_1's RMSE: 1.95689
# [192]	training's WRMSSE: 0.477566	training's RMSE: 1.91373	valid_1's WRMSSE: 0.577384	valid_1's RMSE: 1.95695
# [193]	training's WRMSSE: 0.477447	training's RMSE: 1.91323	valid_1's WRMSSE: 0.577365	valid_1's RMSE: 1.95692
# [194]	training's WRMSSE: 0.477384	training's RMSE: 1.91306	valid_1's WRMSSE: 0.577339	valid_1's RMSE: 1.95687
# [195]	training's WRMSSE: 0.477247	training's RMSE: 1.91293	valid_1's WRMSSE: 0.57725	valid_1's RMSE: 1.95689
# [196]	training's WRMSSE: 0.477114	training's RMSE: 1.91276	valid_1's WRMSSE: 0.577131	valid_1's RMSE: 1.95689
# [197]	training's WRMSSE: 0.476999	training's RMSE: 1.91268	valid_1's WRMSSE: 0.577213	valid_1's RMSE: 1.95685
# [198]	training's WRMSSE: 0.476181	training's RMSE: 1.91246	valid_1's WRMSSE: 0.57711	valid_1's RMSE: 1.95682
# [199]	training's WRMSSE: 0.476085	training's RMSE: 1.91212	valid_1's WRMSSE: 0.577083	valid_1's RMSE: 1.95686
# [200]	training's WRMSSE: 0.476003	training's RMSE: 1.91172	valid_1's WRMSSE: 0.577094	valid_1's RMSE: 1.95684
# [201]	training's WRMSSE: 0.475969	training's RMSE: 1.91147	valid_1's WRMSSE: 0.577078	valid_1's RMSE: 1.95675
# [202]	training's WRMSSE: 0.475909	training's RMSE: 1.91124	valid_1's WRMSSE: 0.577082	valid_1's RMSE: 1.95666
# [203]	training's WRMSSE: 0.47585	training's RMSE: 1.91119	valid_1's WRMSSE: 0.577058	valid_1's RMSE: 1.95663
# [204]	training's WRMSSE: 0.475775	training's RMSE: 1.9108	valid_1's WRMSSE: 0.577031	valid_1's RMSE: 1.95655
# [205]	training's WRMSSE: 0.475719	training's RMSE: 1.91068	valid_1's WRMSSE: 0.577054	valid_1's RMSE: 1.95651
# [206]	training's WRMSSE: 0.47567	training's RMSE: 1.91045	valid_1's WRMSSE: 0.577106	valid_1's RMSE: 1.95653
# [207]	training's WRMSSE: 0.475593	training's RMSE: 1.91029	valid_1's WRMSSE: 0.577161	valid_1's RMSE: 1.95649
# [208]	training's WRMSSE: 0.475502	training's RMSE: 1.90986	valid_1's WRMSSE: 0.577165	valid_1's RMSE: 1.95645
# [209]	training's WRMSSE: 0.475436	training's RMSE: 1.90961	valid_1's WRMSSE: 0.577179	valid_1's RMSE: 1.95639
# [210]	training's WRMSSE: 0.475359	training's RMSE: 1.90932	valid_1's WRMSSE: 0.577211	valid_1's RMSE: 1.95636
# [211]	training's WRMSSE: 0.475306	training's RMSE: 1.90918	valid_1's WRMSSE: 0.577195	valid_1's RMSE: 1.95635
# [212]	training's WRMSSE: 0.475195	training's RMSE: 1.90914	valid_1's WRMSSE: 0.577179	valid_1's RMSE: 1.95632
# [213]	training's WRMSSE: 0.47496	training's RMSE: 1.909	valid_1's WRMSSE: 0.577146	valid_1's RMSE: 1.95628
# [214]	training's WRMSSE: 0.474937	training's RMSE: 1.90894	valid_1's WRMSSE: 0.577136	valid_1's RMSE: 1.95627
# [215]	training's WRMSSE: 0.4736	training's RMSE: 1.90876	valid_1's WRMSSE: 0.576743	valid_1's RMSE: 1.95618
# [216]	training's WRMSSE: 0.473485	training's RMSE: 1.9085	valid_1's WRMSSE: 0.57669	valid_1's RMSE: 1.95611
# [217]	training's WRMSSE: 0.473405	training's RMSE: 1.90818	valid_1's WRMSSE: 0.576653	valid_1's RMSE: 1.95616
# [218]	training's WRMSSE: 0.473267	training's RMSE: 1.90783	valid_1's WRMSSE: 0.576693	valid_1's RMSE: 1.9562
# [219]	training's WRMSSE: 0.473184	training's RMSE: 1.9075	valid_1's WRMSSE: 0.576662	valid_1's RMSE: 1.95621
# [220]	training's WRMSSE: 0.47296	training's RMSE: 1.90732	valid_1's WRMSSE: 0.576559	valid_1's RMSE: 1.95617
# [221]	training's WRMSSE: 0.472885	training's RMSE: 1.90708	valid_1's WRMSSE: 0.576573	valid_1's RMSE: 1.95622
# [222]	training's WRMSSE: 0.472808	training's RMSE: 1.9068	valid_1's WRMSSE: 0.5766	valid_1's RMSE: 1.95623
# [223]	training's WRMSSE: 0.472743	training's RMSE: 1.90653	valid_1's WRMSSE: 0.576566	valid_1's RMSE: 1.95625
# [224]	training's WRMSSE: 0.472555	training's RMSE: 1.9064	valid_1's WRMSSE: 0.576545	valid_1's RMSE: 1.95622
# [225]	training's WRMSSE: 0.472462	training's RMSE: 1.90608	valid_1's WRMSSE: 0.576555	valid_1's RMSE: 1.95624
# [226]	training's WRMSSE: 0.472244	training's RMSE: 1.90591	valid_1's WRMSSE: 0.576637	valid_1's RMSE: 1.95621
# [227]	training's WRMSSE: 0.472143	training's RMSE: 1.90558	valid_1's WRMSSE: 0.576622	valid_1's RMSE: 1.95607
# [228]	training's WRMSSE: 0.472013	training's RMSE: 1.90535	valid_1's WRMSSE: 0.576611	valid_1's RMSE: 1.95603
# [229]	training's WRMSSE: 0.471863	training's RMSE: 1.90515	valid_1's WRMSSE: 0.576455	valid_1's RMSE: 1.95591
# [230]	training's WRMSSE: 0.471395	training's RMSE: 1.905	valid_1's WRMSSE: 0.576081	valid_1's RMSE: 1.95589
# [231]	training's WRMSSE: 0.471302	training's RMSE: 1.90475	valid_1's WRMSSE: 0.575992	valid_1's RMSE: 1.95581
# [232]	training's WRMSSE: 0.471231	training's RMSE: 1.90447	valid_1's WRMSSE: 0.575983	valid_1's RMSE: 1.95583
# [233]	training's WRMSSE: 0.471158	training's RMSE: 1.90425	valid_1's WRMSSE: 0.575981	valid_1's RMSE: 1.9558
# [234]	training's WRMSSE: 0.471001	training's RMSE: 1.9039	valid_1's WRMSSE: 0.575953	valid_1's RMSE: 1.95578
# [235]	training's WRMSSE: 0.470866	training's RMSE: 1.90363	valid_1's WRMSSE: 0.57598	valid_1's RMSE: 1.95564
# [236]	training's WRMSSE: 0.470802	training's RMSE: 1.9035	valid_1's WRMSSE: 0.575984	valid_1's RMSE: 1.95556
# [237]	training's WRMSSE: 0.470592	training's RMSE: 1.90345	valid_1's WRMSSE: 0.575827	valid_1's RMSE: 1.95554
# [238]	training's WRMSSE: 0.470533	training's RMSE: 1.90338	valid_1's WRMSSE: 0.575865	valid_1's RMSE: 1.95552
# [239]	training's WRMSSE: 0.470342	training's RMSE: 1.90313	valid_1's WRMSSE: 0.575798	valid_1's RMSE: 1.95544
# [240]	training's WRMSSE: 0.470292	training's RMSE: 1.90284	valid_1's WRMSSE: 0.575822	valid_1's RMSE: 1.95534
# [241]	training's WRMSSE: 0.470223	training's RMSE: 1.90262	valid_1's WRMSSE: 0.575803	valid_1's RMSE: 1.95539
# [242]	training's WRMSSE: 0.470149	training's RMSE: 1.90228	valid_1's WRMSSE: 0.575842	valid_1's RMSE: 1.95551
# [243]	training's WRMSSE: 0.470068	training's RMSE: 1.90203	valid_1's WRMSSE: 0.575849	valid_1's RMSE: 1.95541
# [244]	training's WRMSSE: 0.469992	training's RMSE: 1.90174	valid_1's WRMSSE: 0.575824	valid_1's RMSE: 1.95546
# [245]	training's WRMSSE: 0.483405	training's RMSE: 1.9216	valid_1's WRMSSE: 0.575966	valid_1's RMSE: 1.95551
# [246]	training's WRMSSE: 0.481817	training's RMSE: 1.92017	valid_1's WRMSSE: 0.57547	valid_1's RMSE: 1.95569
# [247]	training's WRMSSE: 0.480088	training's RMSE: 1.918	valid_1's WRMSSE: 0.575572	valid_1's RMSE: 1.95661
# [248]	training's WRMSSE: 0.478552	training's RMSE: 1.91619	valid_1's WRMSSE: 0.576604	valid_1's RMSE: 1.95817
# [249]	training's WRMSSE: 0.476244	training's RMSE: 1.91449	valid_1's WRMSSE: 0.577039	valid_1's RMSE: 1.95821
# [250]	training's WRMSSE: 0.475253	training's RMSE: 1.913	valid_1's WRMSSE: 0.577162	valid_1's RMSE: 1.95829
# [251]	training's WRMSSE: 0.474278	training's RMSE: 1.9116	valid_1's WRMSSE: 0.578385	valid_1's RMSE: 1.96018
# [252]	training's WRMSSE: 0.473595	training's RMSE: 1.91052	valid_1's WRMSSE: 0.579504	valid_1's RMSE: 1.96176
# [253]	training's WRMSSE: 0.472924	training's RMSE: 1.90942	valid_1's WRMSSE: 0.580921	valid_1's RMSE: 1.96399
# [254]	training's WRMSSE: 0.47229	training's RMSE: 1.90819	valid_1's WRMSSE: 0.582535	valid_1's RMSE: 1.96659
# [255]	training's WRMSSE: 0.471789	training's RMSE: 1.90749	valid_1's WRMSSE: 0.583979	valid_1's RMSE: 1.96862
# [256]	training's WRMSSE: 0.471296	training's RMSE: 1.90658	valid_1's WRMSSE: 0.585638	valid_1's RMSE: 1.97137
# [257]	training's WRMSSE: 0.470872	training's RMSE: 1.90586	valid_1's WRMSSE: 0.587168	valid_1's RMSE: 1.97418
# [258]	training's WRMSSE: 0.470458	training's RMSE: 1.90518	valid_1's WRMSSE: 0.587121	valid_1's RMSE: 1.97411
# [259]	training's WRMSSE: 0.47015	training's RMSE: 1.90465	valid_1's WRMSSE: 0.588291	valid_1's RMSE: 1.97608
# [260]	training's WRMSSE: 0.469899	training's RMSE: 1.90417	valid_1's WRMSSE: 0.588283	valid_1's RMSE: 1.97611
# [261]	training's WRMSSE: 0.469614	training's RMSE: 1.90374	valid_1's WRMSSE: 0.588455	valid_1's RMSE: 1.97619
# [262]	training's WRMSSE: 0.469339	training's RMSE: 1.90318	valid_1's WRMSSE: 0.589636	valid_1's RMSE: 1.97844
# [263]	training's WRMSSE: 0.469077	training's RMSE: 1.90266	valid_1's WRMSSE: 0.590637	valid_1's RMSE: 1.98069
# [264]	training's WRMSSE: 0.468887	training's RMSE: 1.90224	valid_1's WRMSSE: 0.590466	valid_1's RMSE: 1.98058
# [265]	training's WRMSSE: 0.468706	training's RMSE: 1.90175	valid_1's WRMSSE: 0.591541	valid_1's RMSE: 1.98289
# [266]	training's WRMSSE: 0.468553	training's RMSE: 1.90139	valid_1's WRMSSE: 0.592467	valid_1's RMSE: 1.98501
# [267]	training's WRMSSE: 0.468367	training's RMSE: 1.90103	valid_1's WRMSSE: 0.592464	valid_1's RMSE: 1.98504
# [268]	training's WRMSSE: 0.4682	training's RMSE: 1.90065	valid_1's WRMSSE: 0.592561	valid_1's RMSE: 1.98525
# [269]	training's WRMSSE: 0.467996	training's RMSE: 1.90019	valid_1's WRMSSE: 0.593314	valid_1's RMSE: 1.98696
# [270]	training's WRMSSE: 0.467876	training's RMSE: 1.89981	valid_1's WRMSSE: 0.594014	valid_1's RMSE: 1.98883
# [271]	training's WRMSSE: 0.467721	training's RMSE: 1.8994	valid_1's WRMSSE: 0.594636	valid_1's RMSE: 1.99014
# [272]	training's WRMSSE: 0.467599	training's RMSE: 1.89912	valid_1's WRMSSE: 0.59457	valid_1's RMSE: 1.99009
# [273]	training's WRMSSE: 0.46753	training's RMSE: 1.89891	valid_1's WRMSSE: 0.595034	valid_1's RMSE: 1.99153
# [274]	training's WRMSSE: 0.46744	training's RMSE: 1.89856	valid_1's WRMSSE: 0.595006	valid_1's RMSE: 1.99152
# [275]	training's WRMSSE: 0.467318	training's RMSE: 1.8982	valid_1's WRMSSE: 0.59492	valid_1's RMSE: 1.99144
# [276]	training's WRMSSE: 0.467239	training's RMSE: 1.89785	valid_1's WRMSSE: 0.594878	valid_1's RMSE: 1.99136
# [277]	training's WRMSSE: 0.467118	training's RMSE: 1.89756	valid_1's WRMSSE: 0.59524	valid_1's RMSE: 1.99218
# [278]	training's WRMSSE: 0.467033	training's RMSE: 1.89725	valid_1's WRMSSE: 0.595736	valid_1's RMSE: 1.99335
# [279]	training's WRMSSE: 0.466924	training's RMSE: 1.89705	valid_1's WRMSSE: 0.596225	valid_1's RMSE: 1.99452
# [280]	training's WRMSSE: 0.466839	training's RMSE: 1.89681	valid_1's WRMSSE: 0.59686	valid_1's RMSE: 1.9958
# [281]	training's WRMSSE: 0.466665	training's RMSE: 1.8965	valid_1's WRMSSE: 0.596882	valid_1's RMSE: 1.99575
# [282]	training's WRMSSE: 0.46661	training's RMSE: 1.89629	valid_1's WRMSSE: 0.596798	valid_1's RMSE: 1.99576
# /opt/conda/lib/python3.7/site-packages/ipykernel_launcher.py:18: RuntimeWarning: overflow encountered in square
# /opt/conda/lib/python3.7/site-packages/ipykernel_launcher.py:2: RuntimeWarning: overflow encountered in power
# [283]	training's WRMSSE: inf	training's RMSE: inf	valid_1's WRMSSE: inf	valid_1's RMSE: inf
# [284]	training's WRMSSE: inf	training's RMSE: inf	valid_1's WRMSSE: inf	valid_1's RMSE: inf
# [285]	training's WRMSSE: inf	training's RMSE: inf	valid_1's WRMSSE: inf	valid_1's RMSE: inf
# [286]	training's WRMSSE: inf	training's RMSE: inf	valid_1's WRMSSE: inf	valid_1's RMSE: inf
# [287]	training's WRMSSE: inf	training's RMSE: inf	valid_1's WRMSSE: inf	valid_1's RMSE: inf
# [288]	training's WRMSSE: inf	training's RMSE: inf	valid_1's WRMSSE: inf	valid_1's RMSE: inf
# [289]	training's WRMSSE: inf	training's RMSE: inf	valid_1's WRMSSE: inf	valid_1's RMSE: inf
# [290]	training's WRMSSE: inf	training's RMSE: inf	valid_1's WRMSSE: inf	valid_1's RMSE: inf
# /opt/conda/lib/python3.7/site-packages/ipykernel_launcher.py:19: RuntimeWarning: invalid value encountered in multiply
# [291]	training's WRMSSE: nan	training's RMSE: inf	valid_1's WRMSSE: inf	valid_1's RMSE: inf
# [292]	training's WRMSSE: nan	training's RMSE: inf	valid_1's WRMSSE: inf	valid_1's RMSE: inf
# [293]	training's WRMSSE: nan	training's RMSE: inf	valid_1's WRMSSE: inf	valid_1's RMSE: inf
# [294]	training's WRMSSE: nan	training's RMSE: inf	valid_1's WRMSSE: inf	valid_1's RMSE: inf
# [295]	training's WRMSSE: nan	training's RMSE: inf	valid_1's WRMSSE: inf	valid_1's RMSE: inf
# [296]	training's WRMSSE: nan	training's RMSE: inf	valid_1's WRMSSE: inf	valid_1's RMSE: inf
# Early stopping, best iteration is:
# [246]	training's WRMSSE: 0.481817	training's RMSE: 1.92017	valid_1's WRMSSE: 0.57547	valid_1's RMSE: 1.95569
# Evaluated only: WRMSSE
# LGBMRegressor(bagging_freq=1, boosting_type='gbdt', class_weight=None,
#        colsample_bytree=0.8, first_metric_only=True,
#        importance_type='gain', learning_rate=0.05, max_depth=-1,
#        metric='None', min_child_samples=20, min_child_weight=0.001,
#        min_data_in_leaf=255, min_split_gain=0.0, n_estimators=1000,
#        n_jobs=12, num_leaves=255,
#        objective=<function custom_obj at 0x7fc7c69ffe18>, random_state=51,
#        reg_alpha=0.0, reg_lambda=0.0, silent=True, subsample=0.8,
#        subsample_for_bin=200000, subsample_freq=0)

# %%
pd.DataFrame(lgb_re2.feature_importances_,index=X_train.columns).sort_values(0,ascending=False)
# Out:
#                                                  0
# rolling_sale_28_mean                  87141.288933
# rolling_sale_14_mean                  56283.416315
# rolling_sale_7_mean                   17893.890398
# rolling_sale_28_std                    7466.099073
# rolling_sale_91_mean                   6777.943901
# rolling_sale_dayofweek_52_mean         3857.052207
# rolling_sale_dayofweek_52_quantile75   2828.453954
# dayofweek                              2768.577187
# rolling_sale_14_quantile75             2712.326157
# rolling_sale_364_mean                  2533.893001
# lag_sale_1                             2234.660781
# rolling_sale_3_mean                    1915.871024
# rolling_sale_dayofweek_24_mean          922.773309
# rolling_sale_dayofweek_52_std           920.617444
# rolling_sale_364_std                    915.689105
# rolling_sale_dayofweek_24_quantile75    890.894291
# rolling_sale_7_median                   784.569170
# snap                                    710.121527
# rolling_sale_7_std                      684.613882
# item_id                                 681.208012
# rolling_sale_7_quantile75               660.295159
# rolling_sale_dayofweek_12_mean          593.988256
# rolling_sale_14_std                     589.686120
# rolling_sale_91_std                     523.320686
# month                                   508.906647
# rolling_sale_182_mean                   507.612741
# store_id                                449.693687
# rolling_sale_dayofweek_12_quantile75    440.512551
# rolling_sale_dayofweek_8_quantile75     439.403173
# rolling_sale_7_quantile25               420.932424
# ...                                            ...
# state_id                                 57.560994
# rolling_sale_364_quantile75              54.930238
# lag_sale_7                               54.206980
# rolling_sale_182_quantile75              52.268074
# rolling_sale_dayofweek_4_std             50.991416
# rolling_sale_91_median                   50.882004
# rolling_sale_dayofweek_24_std            50.663820
# rolling_sale_dayofweek_52_quantile25     48.552859
# rolling_sale_28_quantile25               47.325681
# rolling_sale_14_quantile25               45.641119
# rolling_sale_dayofweek_12_median         44.723185
# rolling_sale_dayofweek_12_std            44.648234
# rolling_sale_dayofweek_12_cv             44.445600
# rolling_sale_dayofweek_8_std             43.560661
# rolling_sale_dayofweek_8_cv              42.613178
# rolling_sale_dayofweek_4_cv              39.446488
# lag_sale_5                               38.955668
# rolling_sale_182_median                  38.307427
# rolling_sale_364_median                  34.551915
# cat_id                                   29.549152
# quarter                                  27.940583
# rolling_sale_dayofweek_8_quantile25      26.734854
# rolling_sale_dayofweek_24_median         24.983410
# rolling_sale_182_quantile25              23.847222
# rolling_sale_91_quantile25               23.722294
# rolling_sale_364_quantile25              22.892079
# rolling_sale_dayofweek_12_quantile25     20.590858
# rolling_sale_dayofweek_24_quantile25     16.276433
# event_type_2                              0.000000
# event_name_2                              0.000000
#
# [89 rows x 1 columns]

# %%
X_train = train1[(train1.day_num<=1913 - 365)&(train1.day_num>=1913 - 365 - 364)&(train1.date!='2015-12-25')&(train1.date!='2014-12-25')].drop(drop_col,axis=1).copy()
y_train = train1.loc[(train1.day_num<=1913 - 365)&(train1.day_num>=1913 - 365 - 364)&(train1.date!='2015-12-25')&(train1.date!='2014-12-25'),'sale']
X_valid = train1[(train1.day_num<=1969 - 365)&(train1.day_num>=1914 - 365)].drop(drop_col,axis=1).copy()
y_valid = train1.loc[(train1.day_num<=1969 - 365)&(train1.day_num>=1914 - 365),'sale']
y_train[y_train==-999] = 0
y_valid[y_valid==-999] = 0

# %%
lgb_re2 = lgb.LGBMRegressor(n_estimators=1000, random_state=51,subsample=0.8,
                         colsample_bytree=0.8,learning_rate=0.05 ,importance_type = 'gain',
                 max_depth = -1, num_leaves = 2**8-1,metric='None',bagging_freq=1,n_jobs=12,
                         first_metric_only = True,objective=custom_obj,min_data_in_leaf =  2**8-1)

# %%
lgb_re2.fit(X_train,y_train,eval_set = [(X_valid,y_valid)],verbose=10,
           eval_metric =lambda y_true, y_pred: [evaluator_super.feval(y_true, y_pred), rmse(y_true, y_pred)],
           early_stopping_rounds=50)#,categorical_feature=cat_col)
# Out:
# Training until validation scores don't improve for 50 rounds
# [10]	valid_0's WRMSSE: 2.19161	valid_0's RMSE: 2.55361
# [20]	valid_0's WRMSSE: 1.13524	valid_0's RMSE: 2.17808
# [30]	valid_0's WRMSSE: 0.739586	valid_0's RMSE: 2.07345
# [40]	valid_0's WRMSSE: 0.616608	valid_0's RMSE: 2.04285
# [50]	valid_0's WRMSSE: 0.574425	valid_0's RMSE: 2.03068
# [60]	valid_0's WRMSSE: 0.55651	valid_0's RMSE: 2.02307
# [70]	valid_0's WRMSSE: 0.546072	valid_0's RMSE: 2.01855
# [80]	valid_0's WRMSSE: 0.537512	valid_0's RMSE: 2.01509
# [90]	valid_0's WRMSSE: 0.534495	valid_0's RMSE: 2.0131
# [100]	valid_0's WRMSSE: 0.531604	valid_0's RMSE: 2.01062
# /opt/conda/lib/python3.7/site-packages/ipykernel_launcher.py:18: RuntimeWarning: overflow encountered in square
# /opt/conda/lib/python3.7/site-packages/ipykernel_launcher.py:19: RuntimeWarning: invalid value encountered in multiply
# /opt/conda/lib/python3.7/site-packages/ipykernel_launcher.py:2: RuntimeWarning: overflow encountered in power
#
# /opt/conda/lib/python3.7/site-packages/ipykernel_launcher.py:6: RuntimeWarning: overflow encountered in square
#
# /opt/conda/lib/python3.7/site-packages/ipykernel_launcher.py:11: RuntimeWarning: overflow encountered in square
#   # This is added back by InteractiveShellApp.init_path()
# /opt/conda/lib/python3.7/site-packages/ipykernel_launcher.py:11: RuntimeWarning: invalid value encountered in multiply
#   # This is added back by InteractiveShellApp.init_path()
# [110]	valid_0's WRMSSE: nan	valid_0's RMSE: inf
# [120]	valid_0's WRMSSE: nan	valid_0's RMSE: inf
# [130]	valid_0's WRMSSE: nan	valid_0's RMSE: inf
# [140]	valid_0's WRMSSE: nan	valid_0's RMSE: inf
# [150]	valid_0's WRMSSE: nan	valid_0's RMSE: inf
# Early stopping, best iteration is:
# [106]	valid_0's WRMSSE: 0.530099	valid_0's RMSE: 2.00976
# Evaluated only: WRMSSE
# LGBMRegressor(bagging_freq=1, boosting_type='gbdt', class_weight=None,
#        colsample_bytree=0.8, first_metric_only=True,
#        importance_type='gain', learning_rate=0.05, max_depth=-1,
#        metric='None', min_child_samples=20, min_child_weight=0.001,
#        min_data_in_leaf=255, min_split_gain=0.0, n_estimators=1000,
#        n_jobs=12, num_leaves=255,
#        objective=<function custom_obj at 0x7fc7c91e1378>, random_state=51,
#        reg_alpha=0.0, reg_lambda=0.0, silent=True, subsample=0.8,
#        subsample_for_bin=200000, subsample_freq=0)

# %%
lgb_re2.fit(X_train,y_train,eval_set = [(X_train,y_train),(X_valid,y_valid)],verbose=1,
           eval_metric =lambda y_true, y_pred: [evaluator_super.feval(y_true, y_pred), rmse(y_true, y_pred)],
           early_stopping_rounds=50)#,categorical_feature=cat_col)
# Out:
# [1]	training's WRMSSE: 4.10622	training's RMSE: 3.59316	valid_1's WRMSSE: 4.31389	valid_1's RMSE: 3.57134
# Training until validation scores don't improve for 50 rounds
# [2]	training's WRMSSE: 3.7983	training's RMSE: 3.41612	valid_1's WRMSSE: 3.9968	valid_1's RMSE: 3.40478
# [3]	training's WRMSSE: 3.51389	training's RMSE: 3.25618	valid_1's WRMSSE: 3.70323	valid_1's RMSE: 3.25426
# [4]	training's WRMSSE: 3.25126	training's RMSE: 3.11117	valid_1's WRMSSE: 3.43153	valid_1's RMSE: 3.11791
# [5]	training's WRMSSE: 3.00885	training's RMSE: 2.98211	valid_1's WRMSSE: 3.18128	valid_1's RMSE: 2.99708
# [6]	training's WRMSSE: 2.78557	training's RMSE: 2.8652	valid_1's WRMSSE: 2.95032	valid_1's RMSE: 2.88768
# [7]	training's WRMSSE: 2.57887	training's RMSE: 2.75921	valid_1's WRMSSE: 2.73636	valid_1's RMSE: 2.78813
# [8]	training's WRMSSE: 2.3889	training's RMSE: 2.6664	valid_1's WRMSSE: 2.53941	valid_1's RMSE: 2.70148
# [9]	training's WRMSSE: 2.21374	training's RMSE: 2.58367	valid_1's WRMSSE: 2.35806	valid_1's RMSE: 2.62343
# [10]	training's WRMSSE: 2.05309	training's RMSE: 2.50874	valid_1's WRMSSE: 2.19161	valid_1's RMSE: 2.55361
# [11]	training's WRMSSE: 1.90584	training's RMSE: 2.44205	valid_1's WRMSSE: 2.03858	valid_1's RMSE: 2.4916
# [12]	training's WRMSSE: 1.77138	training's RMSE: 2.38431	valid_1's WRMSSE: 1.89862	valid_1's RMSE: 2.43706
# [13]	training's WRMSSE: 1.64756	training's RMSE: 2.33255	valid_1's WRMSSE: 1.7703	valid_1's RMSE: 2.38887
# [14]	training's WRMSSE: 1.53422	training's RMSE: 2.28659	valid_1's WRMSSE: 1.65195	valid_1's RMSE: 2.34639
# [15]	training's WRMSSE: 1.431	training's RMSE: 2.24607	valid_1's WRMSSE: 1.54388	valid_1's RMSE: 2.3084
# [16]	training's WRMSSE: 1.33679	training's RMSE: 2.20979	valid_1's WRMSSE: 1.44536	valid_1's RMSE: 2.27479
# [17]	training's WRMSSE: 1.25122	training's RMSE: 2.17871	valid_1's WRMSSE: 1.35608	valid_1's RMSE: 2.24553
# [18]	training's WRMSSE: 1.17376	training's RMSE: 2.15137	valid_1's WRMSSE: 1.2752	valid_1's RMSE: 2.21992
# [19]	training's WRMSSE: 1.10324	training's RMSE: 2.12781	valid_1's WRMSSE: 1.20088	valid_1's RMSE: 2.19786
# [20]	training's WRMSSE: 1.03976	training's RMSE: 2.10655	valid_1's WRMSSE: 1.13524	valid_1's RMSE: 2.17808
# [21]	training's WRMSSE: 0.98244	training's RMSE: 2.08758	valid_1's WRMSSE: 1.07469	valid_1's RMSE: 2.16019
# [22]	training's WRMSSE: 0.930442	training's RMSE: 2.0719	valid_1's WRMSSE: 1.01932	valid_1's RMSE: 2.14516
# [23]	training's WRMSSE: 0.884415	training's RMSE: 2.05732	valid_1's WRMSSE: 0.970026	valid_1's RMSE: 2.13121
# [24]	training's WRMSSE: 0.843099	training's RMSE: 2.04495	valid_1's WRMSSE: 0.925712	valid_1's RMSE: 2.1191
# [25]	training's WRMSSE: 0.805844	training's RMSE: 2.03406	valid_1's WRMSSE: 0.885357	valid_1's RMSE: 2.10868
# [26]	training's WRMSSE: 0.773208	training's RMSE: 2.02456	valid_1's WRMSSE: 0.850182	valid_1's RMSE: 2.0995
# [27]	training's WRMSSE: 0.742866	training's RMSE: 2.01591	valid_1's WRMSSE: 0.81668	valid_1's RMSE: 2.0913
# [28]	training's WRMSSE: 0.715532	training's RMSE: 2.00915	valid_1's WRMSSE: 0.786863	valid_1's RMSE: 2.08484
# [29]	training's WRMSSE: 0.692401	training's RMSE: 2.00304	valid_1's WRMSSE: 0.762139	valid_1's RMSE: 2.07896
# [30]	training's WRMSSE: 0.671654	training's RMSE: 1.9973	valid_1's WRMSSE: 0.739586	valid_1's RMSE: 2.07345
# [31]	training's WRMSSE: 0.653378	training's RMSE: 1.99223	valid_1's WRMSSE: 0.71894	valid_1's RMSE: 2.06859
# [32]	training's WRMSSE: 0.637578	training's RMSE: 1.98799	valid_1's WRMSSE: 0.702303	valid_1's RMSE: 2.06464
# [33]	training's WRMSSE: 0.623289	training's RMSE: 1.98379	valid_1's WRMSSE: 0.686846	valid_1's RMSE: 2.06068
# [34]	training's WRMSSE: 0.611036	training's RMSE: 1.97992	valid_1's WRMSSE: 0.672625	valid_1's RMSE: 2.05667
# [35]	training's WRMSSE: 0.600168	training's RMSE: 1.97677	valid_1's WRMSSE: 0.660213	valid_1's RMSE: 2.05365
# [36]	training's WRMSSE: 0.590105	training's RMSE: 1.97389	valid_1's WRMSSE: 0.649254	valid_1's RMSE: 2.05123
# [37]	training's WRMSSE: 0.580782	training's RMSE: 1.97149	valid_1's WRMSSE: 0.639542	valid_1's RMSE: 2.04896
# [38]	training's WRMSSE: 0.573513	training's RMSE: 1.96933	valid_1's WRMSSE: 0.631457	valid_1's RMSE: 2.04683
# [39]	training's WRMSSE: 0.567222	training's RMSE: 1.96719	valid_1's WRMSSE: 0.623729	valid_1's RMSE: 2.04475
# [40]	training's WRMSSE: 0.561525	training's RMSE: 1.96536	valid_1's WRMSSE: 0.616608	valid_1's RMSE: 2.04285
# [41]	training's WRMSSE: 0.555979	training's RMSE: 1.96375	valid_1's WRMSSE: 0.610767	valid_1's RMSE: 2.04132
# [42]	training's WRMSSE: 0.551172	training's RMSE: 1.96214	valid_1's WRMSSE: 0.605036	valid_1's RMSE: 2.03977
# [43]	training's WRMSSE: 0.546719	training's RMSE: 1.96065	valid_1's WRMSSE: 0.599815	valid_1's RMSE: 2.03821
# [44]	training's WRMSSE: 0.543179	training's RMSE: 1.95917	valid_1's WRMSSE: 0.595376	valid_1's RMSE: 2.03676
# [45]	training's WRMSSE: 0.539157	training's RMSE: 1.95801	valid_1's WRMSSE: 0.590864	valid_1's RMSE: 2.0358
# [46]	training's WRMSSE: 0.535844	training's RMSE: 1.95664	valid_1's WRMSSE: 0.586698	valid_1's RMSE: 2.0344
# [47]	training's WRMSSE: 0.533229	training's RMSE: 1.95559	valid_1's WRMSSE: 0.582927	valid_1's RMSE: 2.03323
# [48]	training's WRMSSE: 0.529734	training's RMSE: 1.95465	valid_1's WRMSSE: 0.579397	valid_1's RMSE: 2.03243
# [49]	training's WRMSSE: 0.527684	training's RMSE: 1.95375	valid_1's WRMSSE: 0.576696	valid_1's RMSE: 2.03152
# [50]	training's WRMSSE: 0.525781	training's RMSE: 1.95288	valid_1's WRMSSE: 0.574425	valid_1's RMSE: 2.03068
# [51]	training's WRMSSE: 0.523923	training's RMSE: 1.95196	valid_1's WRMSSE: 0.572722	valid_1's RMSE: 2.02987
# [52]	training's WRMSSE: 0.522296	training's RMSE: 1.95107	valid_1's WRMSSE: 0.570524	valid_1's RMSE: 2.02886
# [53]	training's WRMSSE: 0.520142	training's RMSE: 1.95048	valid_1's WRMSSE: 0.568696	valid_1's RMSE: 2.02823
# [54]	training's WRMSSE: 0.517879	training's RMSE: 1.94949	valid_1's WRMSSE: 0.56615	valid_1's RMSE: 2.02717
# [55]	training's WRMSSE: 0.515953	training's RMSE: 1.94833	valid_1's WRMSSE: 0.563993	valid_1's RMSE: 2.02606
# [56]	training's WRMSSE: 0.514758	training's RMSE: 1.94755	valid_1's WRMSSE: 0.56236	valid_1's RMSE: 2.02534
# [57]	training's WRMSSE: 0.512514	training's RMSE: 1.94662	valid_1's WRMSSE: 0.560567	valid_1's RMSE: 2.02445
# [58]	training's WRMSSE: 0.510534	training's RMSE: 1.94618	valid_1's WRMSSE: 0.559531	valid_1's RMSE: 2.02419
# [59]	training's WRMSSE: 0.509507	training's RMSE: 1.94548	valid_1's WRMSSE: 0.558337	valid_1's RMSE: 2.02359
# [60]	training's WRMSSE: 0.508112	training's RMSE: 1.94489	valid_1's WRMSSE: 0.55651	valid_1's RMSE: 2.02307
# [61]	training's WRMSSE: 0.507014	training's RMSE: 1.94448	valid_1's WRMSSE: 0.555338	valid_1's RMSE: 2.02273
# [62]	training's WRMSSE: 0.505912	training's RMSE: 1.94377	valid_1's WRMSSE: 0.55403	valid_1's RMSE: 2.02205
# [63]	training's WRMSSE: 0.505079	training's RMSE: 1.94308	valid_1's WRMSSE: 0.553277	valid_1's RMSE: 2.02167
# [64]	training's WRMSSE: 0.503783	training's RMSE: 1.94256	valid_1's WRMSSE: 0.552152	valid_1's RMSE: 2.02135
# [65]	training's WRMSSE: 0.502994	training's RMSE: 1.94212	valid_1's WRMSSE: 0.551126	valid_1's RMSE: 2.02095
# [66]	training's WRMSSE: 0.501942	training's RMSE: 1.94154	valid_1's WRMSSE: 0.550497	valid_1's RMSE: 2.02057
# [67]	training's WRMSSE: 0.500343	training's RMSE: 1.94076	valid_1's WRMSSE: 0.54922	valid_1's RMSE: 2.01981
# [68]	training's WRMSSE: 0.498932	training's RMSE: 1.94017	valid_1's WRMSSE: 0.548191	valid_1's RMSE: 2.01932
# [69]	training's WRMSSE: 0.497472	training's RMSE: 1.93957	valid_1's WRMSSE: 0.546775	valid_1's RMSE: 2.01891
# [70]	training's WRMSSE: 0.496909	training's RMSE: 1.93914	valid_1's WRMSSE: 0.546072	valid_1's RMSE: 2.01855
# [71]	training's WRMSSE: 0.495214	training's RMSE: 1.93858	valid_1's WRMSSE: 0.543987	valid_1's RMSE: 2.01813
# [72]	training's WRMSSE: 0.493223	training's RMSE: 1.93797	valid_1's WRMSSE: 0.54257	valid_1's RMSE: 2.0177
# [73]	training's WRMSSE: 0.492133	training's RMSE: 1.93734	valid_1's WRMSSE: 0.54188	valid_1's RMSE: 2.01722
# [74]	training's WRMSSE: 0.491789	training's RMSE: 1.93691	valid_1's WRMSSE: 0.54165	valid_1's RMSE: 2.01701
# [75]	training's WRMSSE: 0.491293	training's RMSE: 1.93653	valid_1's WRMSSE: 0.541435	valid_1's RMSE: 2.01691
# [76]	training's WRMSSE: 0.490491	training's RMSE: 1.93597	valid_1's WRMSSE: 0.540314	valid_1's RMSE: 2.01648
# [77]	training's WRMSSE: 0.490016	training's RMSE: 1.93558	valid_1's WRMSSE: 0.539963	valid_1's RMSE: 2.01625
# [78]	training's WRMSSE: 0.489261	training's RMSE: 1.93505	valid_1's WRMSSE: 0.539623	valid_1's RMSE: 2.01596
# [79]	training's WRMSSE: 0.486999	training's RMSE: 1.93452	valid_1's WRMSSE: 0.538116	valid_1's RMSE: 2.01551
# [80]	training's WRMSSE: 0.486055	training's RMSE: 1.93401	valid_1's WRMSSE: 0.537512	valid_1's RMSE: 2.01509
# [81]	training's WRMSSE: 0.485766	training's RMSE: 1.9336	valid_1's WRMSSE: 0.537405	valid_1's RMSE: 2.01483
# [82]	training's WRMSSE: 0.485462	training's RMSE: 1.93314	valid_1's WRMSSE: 0.537316	valid_1's RMSE: 2.01477
# [83]	training's WRMSSE: 0.484921	training's RMSE: 1.93281	valid_1's WRMSSE: 0.537094	valid_1's RMSE: 2.01453
# [84]	training's WRMSSE: 0.482695	training's RMSE: 1.93238	valid_1's WRMSSE: 0.535666	valid_1's RMSE: 2.01421
# [85]	training's WRMSSE: 0.482457	training's RMSE: 1.93205	valid_1's WRMSSE: 0.535512	valid_1's RMSE: 2.01398
# [86]	training's WRMSSE: 0.481844	training's RMSE: 1.93177	valid_1's WRMSSE: 0.535384	valid_1's RMSE: 2.01385
# [87]	training's WRMSSE: 0.481582	training's RMSE: 1.93142	valid_1's WRMSSE: 0.535329	valid_1's RMSE: 2.01367
# [88]	training's WRMSSE: 0.480951	training's RMSE: 1.9312	valid_1's WRMSSE: 0.53503	valid_1's RMSE: 2.01354
# [89]	training's WRMSSE: 0.480686	training's RMSE: 1.93089	valid_1's WRMSSE: 0.534861	valid_1's RMSE: 2.01333
# [90]	training's WRMSSE: 0.480374	training's RMSE: 1.93046	valid_1's WRMSSE: 0.534495	valid_1's RMSE: 2.0131
# [91]	training's WRMSSE: 0.480146	training's RMSE: 1.93016	valid_1's WRMSSE: 0.534463	valid_1's RMSE: 2.01289
# [92]	training's WRMSSE: 0.479907	training's RMSE: 1.92983	valid_1's WRMSSE: 0.534049	valid_1's RMSE: 2.01265
# [93]	training's WRMSSE: 0.479472	training's RMSE: 1.92928	valid_1's WRMSSE: 0.533791	valid_1's RMSE: 2.01238
# [94]	training's WRMSSE: 0.478888	training's RMSE: 1.92891	valid_1's WRMSSE: 0.533299	valid_1's RMSE: 2.01213
# [95]	training's WRMSSE: 0.478682	training's RMSE: 1.92854	valid_1's WRMSSE: 0.533216	valid_1's RMSE: 2.01192
# [96]	training's WRMSSE: 0.478032	training's RMSE: 1.92817	valid_1's WRMSSE: 0.532636	valid_1's RMSE: 2.01173
# [97]	training's WRMSSE: 0.477862	training's RMSE: 1.92783	valid_1's WRMSSE: 0.532413	valid_1's RMSE: 2.01145
# [98]	training's WRMSSE: 0.477448	training's RMSE: 1.92734	valid_1's WRMSSE: 0.531982	valid_1's RMSE: 2.01119
# [99]	training's WRMSSE: 0.47722	training's RMSE: 1.92682	valid_1's WRMSSE: 0.531782	valid_1's RMSE: 2.0109
# [100]	training's WRMSSE: 0.476828	training's RMSE: 1.92621	valid_1's WRMSSE: 0.531604	valid_1's RMSE: 2.01062
# [101]	training's WRMSSE: 0.476665	training's RMSE: 1.92591	valid_1's WRMSSE: 0.531599	valid_1's RMSE: 2.01053
# [102]	training's WRMSSE: 0.476384	training's RMSE: 1.92558	valid_1's WRMSSE: 0.531282	valid_1's RMSE: 2.01034
# [103]	training's WRMSSE: 0.475874	training's RMSE: 1.92514	valid_1's WRMSSE: 0.530809	valid_1's RMSE: 2.01007
# [104]	training's WRMSSE: 0.475364	training's RMSE: 1.92484	valid_1's WRMSSE: 0.530384	valid_1's RMSE: 2.01002
# [105]	training's WRMSSE: 0.474879	training's RMSE: 1.92453	valid_1's WRMSSE: 0.530209	valid_1's RMSE: 2.00988
# [106]	training's WRMSSE: 0.474681	training's RMSE: 1.92419	valid_1's WRMSSE: 0.530099	valid_1's RMSE: 2.00976
# /opt/conda/lib/python3.7/site-packages/ipykernel_launcher.py:18: RuntimeWarning: overflow encountered in square
# /opt/conda/lib/python3.7/site-packages/ipykernel_launcher.py:19: RuntimeWarning: invalid value encountered in multiply
# /opt/conda/lib/python3.7/site-packages/ipykernel_launcher.py:2: RuntimeWarning: overflow encountered in power
# [107]	training's WRMSSE: nan	training's RMSE: inf	valid_1's WRMSSE: nan	valid_1's RMSE: inf
# /opt/conda/lib/python3.7/site-packages/ipykernel_launcher.py:6: RuntimeWarning: overflow encountered in square
#
# /opt/conda/lib/python3.7/site-packages/ipykernel_launcher.py:11: RuntimeWarning: overflow encountered in square
#   # This is added back by InteractiveShellApp.init_path()
# /opt/conda/lib/python3.7/site-packages/ipykernel_launcher.py:11: RuntimeWarning: invalid value encountered in multiply
#   # This is added back by InteractiveShellApp.init_path()
# [108]	training's WRMSSE: nan	training's RMSE: inf	valid_1's WRMSSE: nan	valid_1's RMSE: inf
# [109]	training's WRMSSE: nan	training's RMSE: inf	valid_1's WRMSSE: nan	valid_1's RMSE: inf
# [110]	training's WRMSSE: nan	training's RMSE: inf	valid_1's WRMSSE: nan	valid_1's RMSE: inf
# [111]	training's WRMSSE: nan	training's RMSE: inf	valid_1's WRMSSE: nan	valid_1's RMSE: inf
# [112]	training's WRMSSE: nan	training's RMSE: inf	valid_1's WRMSSE: nan	valid_1's RMSE: inf
# [113]	training's WRMSSE: nan	training's RMSE: inf	valid_1's WRMSSE: nan	valid_1's RMSE: inf
# [114]	training's WRMSSE: nan	training's RMSE: inf	valid_1's WRMSSE: nan	valid_1's RMSE: inf
# [115]	training's WRMSSE: nan	training's RMSE: inf	valid_1's WRMSSE: nan	valid_1's RMSE: inf
# [116]	training's WRMSSE: nan	training's RMSE: inf	valid_1's WRMSSE: nan	valid_1's RMSE: inf
# [117]	training's WRMSSE: nan	training's RMSE: inf	valid_1's WRMSSE: nan	valid_1's RMSE: inf
# [118]	training's WRMSSE: nan	training's RMSE: inf	valid_1's WRMSSE: nan	valid_1's RMSE: inf
# [119]	training's WRMSSE: nan	training's RMSE: inf	valid_1's WRMSSE: nan	valid_1's RMSE: inf
# [120]	training's WRMSSE: nan	training's RMSE: inf	valid_1's WRMSSE: nan	valid_1's RMSE: inf
# [121]	training's WRMSSE: nan	training's RMSE: inf	valid_1's WRMSSE: nan	valid_1's RMSE: inf
# [122]	training's WRMSSE: nan	training's RMSE: inf	valid_1's WRMSSE: nan	valid_1's RMSE: inf
# [123]	training's WRMSSE: nan	training's RMSE: inf	valid_1's WRMSSE: nan	valid_1's RMSE: inf
# [124]	training's WRMSSE: nan	training's RMSE: inf	valid_1's WRMSSE: nan	valid_1's RMSE: inf
# [125]	training's WRMSSE: nan	training's RMSE: inf	valid_1's WRMSSE: nan	valid_1's RMSE: inf
# [126]	training's WRMSSE: nan	training's RMSE: inf	valid_1's WRMSSE: nan	valid_1's RMSE: inf
# [127]	training's WRMSSE: nan	training's RMSE: inf	valid_1's WRMSSE: nan	valid_1's RMSE: inf
# [128]	training's WRMSSE: nan	training's RMSE: inf	valid_1's WRMSSE: nan	valid_1's RMSE: inf
# [129]	training's WRMSSE: nan	training's RMSE: inf	valid_1's WRMSSE: nan	valid_1's RMSE: inf
# [130]	training's WRMSSE: nan	training's RMSE: inf	valid_1's WRMSSE: nan	valid_1's RMSE: inf
# [131]	training's WRMSSE: nan	training's RMSE: inf	valid_1's WRMSSE: nan	valid_1's RMSE: inf
# [132]	training's WRMSSE: nan	training's RMSE: inf	valid_1's WRMSSE: nan	valid_1's RMSE: inf
# [133]	training's WRMSSE: nan	training's RMSE: inf	valid_1's WRMSSE: nan	valid_1's RMSE: inf
# [134]	training's WRMSSE: nan	training's RMSE: inf	valid_1's WRMSSE: nan	valid_1's RMSE: inf
# [135]	training's WRMSSE: nan	training's RMSE: inf	valid_1's WRMSSE: nan	valid_1's RMSE: inf
# [136]	training's WRMSSE: nan	training's RMSE: inf	valid_1's WRMSSE: nan	valid_1's RMSE: inf
# [137]	training's WRMSSE: nan	training's RMSE: inf	valid_1's WRMSSE: nan	valid_1's RMSE: inf
# [138]	training's WRMSSE: nan	training's RMSE: inf	valid_1's WRMSSE: nan	valid_1's RMSE: inf
# [139]	training's WRMSSE: nan	training's RMSE: inf	valid_1's WRMSSE: nan	valid_1's RMSE: inf
# [140]	training's WRMSSE: nan	training's RMSE: inf	valid_1's WRMSSE: nan	valid_1's RMSE: inf
# [141]	training's WRMSSE: nan	training's RMSE: inf	valid_1's WRMSSE: nan	valid_1's RMSE: inf
# [142]	training's WRMSSE: nan	training's RMSE: inf	valid_1's WRMSSE: nan	valid_1's RMSE: inf
# [143]	training's WRMSSE: nan	training's RMSE: inf	valid_1's WRMSSE: nan	valid_1's RMSE: inf
# [144]	training's WRMSSE: nan	training's RMSE: inf	valid_1's WRMSSE: nan	valid_1's RMSE: inf
# [145]	training's WRMSSE: nan	training's RMSE: inf	valid_1's WRMSSE: nan	valid_1's RMSE: inf
# [146]	training's WRMSSE: nan	training's RMSE: inf	valid_1's WRMSSE: nan	valid_1's RMSE: inf
# [147]	training's WRMSSE: nan	training's RMSE: inf	valid_1's WRMSSE: nan	valid_1's RMSE: inf
# [148]	training's WRMSSE: nan	training's RMSE: inf	valid_1's WRMSSE: nan	valid_1's RMSE: inf
# [149]	training's WRMSSE: nan	training's RMSE: inf	valid_1's WRMSSE: nan	valid_1's RMSE: inf
# [150]	training's WRMSSE: nan	training's RMSE: inf	valid_1's WRMSSE: nan	valid_1's RMSE: inf
# [151]	training's WRMSSE: nan	training's RMSE: inf	valid_1's WRMSSE: nan	valid_1's RMSE: inf
# [152]	training's WRMSSE: nan	training's RMSE: inf	valid_1's WRMSSE: nan	valid_1's RMSE: inf
# [153]	training's WRMSSE: nan	training's RMSE: inf	valid_1's WRMSSE: nan	valid_1's RMSE: inf
# [154]	training's WRMSSE: nan	training's RMSE: inf	valid_1's WRMSSE: nan	valid_1's RMSE: inf
# [155]	training's WRMSSE: nan	training's RMSE: inf	valid_1's WRMSSE: nan	valid_1's RMSE: inf
# [156]	training's WRMSSE: nan	training's RMSE: inf	valid_1's WRMSSE: nan	valid_1's RMSE: inf
# Early stopping, best iteration is:
# [106]	training's WRMSSE: 0.474681	training's RMSE: 1.92419	valid_1's WRMSSE: 0.530099	valid_1's RMSE: 2.00976
# Evaluated only: WRMSSE
# LGBMRegressor(bagging_freq=1, boosting_type='gbdt', class_weight=None,
#        colsample_bytree=0.8, first_metric_only=True,
#        importance_type='gain', learning_rate=0.05, max_depth=-1,
#        metric='None', min_child_samples=20, min_child_weight=0.001,
#        min_data_in_leaf=255, min_split_gain=0.0, n_estimators=1000,
#        n_jobs=12, num_leaves=255,
#        objective=<function custom_obj at 0x7fc7c91e1378>, random_state=51,
#        reg_alpha=0.0, reg_lambda=0.0, silent=True, subsample=0.8,
#        subsample_for_bin=200000, subsample_freq=0)

# %%
###改成float128
lgb_re2.fit(X_train,y_train,eval_set = [(X_train,y_train),(X_valid,y_valid)],verbose=1,
           eval_metric =lambda y_true, y_pred: [evaluator_super.feval(y_true, y_pred), rmse(y_true, y_pred)],
           early_stopping_rounds=50)#,categorical_feature=cat_col)
# Out:
# [1]	training's WRMSSE: 4.10622	training's RMSE: 3.59316	valid_1's WRMSSE: 4.31389	valid_1's RMSE: 3.57134
# Training until validation scores don't improve for 50 rounds
# [2]	training's WRMSSE: 3.7983	training's RMSE: 3.41612	valid_1's WRMSSE: 3.9968	valid_1's RMSE: 3.40478
# [3]	training's WRMSSE: 3.51389	training's RMSE: 3.25618	valid_1's WRMSSE: 3.70323	valid_1's RMSE: 3.25426
# [4]	training's WRMSSE: 3.25126	training's RMSE: 3.11117	valid_1's WRMSSE: 3.43153	valid_1's RMSE: 3.11791
# [5]	training's WRMSSE: 3.00885	training's RMSE: 2.98211	valid_1's WRMSSE: 3.18128	valid_1's RMSE: 2.99708
# [6]	training's WRMSSE: 2.78557	training's RMSE: 2.8652	valid_1's WRMSSE: 2.95032	valid_1's RMSE: 2.88768
# [7]	training's WRMSSE: 2.57887	training's RMSE: 2.75921	valid_1's WRMSSE: 2.73636	valid_1's RMSE: 2.78813
# [8]	training's WRMSSE: 2.3889	training's RMSE: 2.6664	valid_1's WRMSSE: 2.53941	valid_1's RMSE: 2.70148
# [9]	training's WRMSSE: 2.21374	training's RMSE: 2.58367	valid_1's WRMSSE: 2.35806	valid_1's RMSE: 2.62343
# [10]	training's WRMSSE: 2.05309	training's RMSE: 2.50874	valid_1's WRMSSE: 2.19161	valid_1's RMSE: 2.55361
# [11]	training's WRMSSE: 1.90584	training's RMSE: 2.44205	valid_1's WRMSSE: 2.03858	valid_1's RMSE: 2.4916
# [12]	training's WRMSSE: 1.77138	training's RMSE: 2.38431	valid_1's WRMSSE: 1.89862	valid_1's RMSE: 2.43706
# [13]	training's WRMSSE: 1.64756	training's RMSE: 2.33255	valid_1's WRMSSE: 1.7703	valid_1's RMSE: 2.38887
# [14]	training's WRMSSE: 1.53422	training's RMSE: 2.28659	valid_1's WRMSSE: 1.65195	valid_1's RMSE: 2.34639
# [15]	training's WRMSSE: 1.431	training's RMSE: 2.24607	valid_1's WRMSSE: 1.54388	valid_1's RMSE: 2.3084
# [16]	training's WRMSSE: 1.33679	training's RMSE: 2.20979	valid_1's WRMSSE: 1.44536	valid_1's RMSE: 2.27479
# [17]	training's WRMSSE: 1.25122	training's RMSE: 2.17871	valid_1's WRMSSE: 1.35608	valid_1's RMSE: 2.24553
# [18]	training's WRMSSE: 1.17376	training's RMSE: 2.15137	valid_1's WRMSSE: 1.2752	valid_1's RMSE: 2.21992
# [19]	training's WRMSSE: 1.10324	training's RMSE: 2.12781	valid_1's WRMSSE: 1.20088	valid_1's RMSE: 2.19786
# [20]	training's WRMSSE: 1.03976	training's RMSE: 2.10655	valid_1's WRMSSE: 1.13524	valid_1's RMSE: 2.17808
# [21]	training's WRMSSE: 0.98244	training's RMSE: 2.08758	valid_1's WRMSSE: 1.07469	valid_1's RMSE: 2.16019
# [22]	training's WRMSSE: 0.930442	training's RMSE: 2.0719	valid_1's WRMSSE: 1.01932	valid_1's RMSE: 2.14516
# [23]	training's WRMSSE: 0.884415	training's RMSE: 2.05732	valid_1's WRMSSE: 0.970026	valid_1's RMSE: 2.13121
# [24]	training's WRMSSE: 0.843099	training's RMSE: 2.04495	valid_1's WRMSSE: 0.925712	valid_1's RMSE: 2.1191
# [25]	training's WRMSSE: 0.805844	training's RMSE: 2.03406	valid_1's WRMSSE: 0.885357	valid_1's RMSE: 2.10868
# [26]	training's WRMSSE: 0.773208	training's RMSE: 2.02456	valid_1's WRMSSE: 0.850182	valid_1's RMSE: 2.0995
# [27]	training's WRMSSE: 0.742866	training's RMSE: 2.01591	valid_1's WRMSSE: 0.81668	valid_1's RMSE: 2.0913
# [28]	training's WRMSSE: 0.715532	training's RMSE: 2.00915	valid_1's WRMSSE: 0.786863	valid_1's RMSE: 2.08484
# [29]	training's WRMSSE: 0.692401	training's RMSE: 2.00304	valid_1's WRMSSE: 0.762139	valid_1's RMSE: 2.07896
# [30]	training's WRMSSE: 0.671654	training's RMSE: 1.9973	valid_1's WRMSSE: 0.739586	valid_1's RMSE: 2.07345
# [31]	training's WRMSSE: 0.653378	training's RMSE: 1.99223	valid_1's WRMSSE: 0.71894	valid_1's RMSE: 2.06859
# [32]	training's WRMSSE: 0.637578	training's RMSE: 1.98799	valid_1's WRMSSE: 0.702303	valid_1's RMSE: 2.06464
# [33]	training's WRMSSE: 0.623289	training's RMSE: 1.98379	valid_1's WRMSSE: 0.686846	valid_1's RMSE: 2.06068
# [34]	training's WRMSSE: 0.611036	training's RMSE: 1.97992	valid_1's WRMSSE: 0.672625	valid_1's RMSE: 2.05667
# [35]	training's WRMSSE: 0.600168	training's RMSE: 1.97677	valid_1's WRMSSE: 0.660213	valid_1's RMSE: 2.05365
# [36]	training's WRMSSE: 0.590105	training's RMSE: 1.97389	valid_1's WRMSSE: 0.649254	valid_1's RMSE: 2.05123
# [37]	training's WRMSSE: 0.580782	training's RMSE: 1.97149	valid_1's WRMSSE: 0.639542	valid_1's RMSE: 2.04896
# [38]	training's WRMSSE: 0.573513	training's RMSE: 1.96933	valid_1's WRMSSE: 0.631457	valid_1's RMSE: 2.04683
# [39]	training's WRMSSE: 0.567222	training's RMSE: 1.96719	valid_1's WRMSSE: 0.623729	valid_1's RMSE: 2.04475
# [40]	training's WRMSSE: 0.561525	training's RMSE: 1.96536	valid_1's WRMSSE: 0.616608	valid_1's RMSE: 2.04285
# [41]	training's WRMSSE: 0.555979	training's RMSE: 1.96375	valid_1's WRMSSE: 0.610767	valid_1's RMSE: 2.04132
# [42]	training's WRMSSE: 0.551172	training's RMSE: 1.96214	valid_1's WRMSSE: 0.605036	valid_1's RMSE: 2.03977
# [43]	training's WRMSSE: 0.546719	training's RMSE: 1.96065	valid_1's WRMSSE: 0.599815	valid_1's RMSE: 2.03821
# [44]	training's WRMSSE: 0.543179	training's RMSE: 1.95917	valid_1's WRMSSE: 0.595376	valid_1's RMSE: 2.03676
# [45]	training's WRMSSE: 0.539157	training's RMSE: 1.95801	valid_1's WRMSSE: 0.590864	valid_1's RMSE: 2.0358
# [46]	training's WRMSSE: 0.535844	training's RMSE: 1.95664	valid_1's WRMSSE: 0.586698	valid_1's RMSE: 2.0344
# [47]	training's WRMSSE: 0.533229	training's RMSE: 1.95559	valid_1's WRMSSE: 0.582927	valid_1's RMSE: 2.03323
# [48]	training's WRMSSE: 0.529734	training's RMSE: 1.95465	valid_1's WRMSSE: 0.579397	valid_1's RMSE: 2.03243
# [49]	training's WRMSSE: 0.527684	training's RMSE: 1.95375	valid_1's WRMSSE: 0.576696	valid_1's RMSE: 2.03152
# [50]	training's WRMSSE: 0.525781	training's RMSE: 1.95288	valid_1's WRMSSE: 0.574425	valid_1's RMSE: 2.03068
# [51]	training's WRMSSE: 0.523923	training's RMSE: 1.95196	valid_1's WRMSSE: 0.572722	valid_1's RMSE: 2.02987
# [52]	training's WRMSSE: 0.522296	training's RMSE: 1.95107	valid_1's WRMSSE: 0.570524	valid_1's RMSE: 2.02886
# [53]	training's WRMSSE: 0.520142	training's RMSE: 1.95048	valid_1's WRMSSE: 0.568696	valid_1's RMSE: 2.02823
# [54]	training's WRMSSE: 0.517879	training's RMSE: 1.94949	valid_1's WRMSSE: 0.56615	valid_1's RMSE: 2.02717
# [55]	training's WRMSSE: 0.515953	training's RMSE: 1.94833	valid_1's WRMSSE: 0.563993	valid_1's RMSE: 2.02606
# [56]	training's WRMSSE: 0.514758	training's RMSE: 1.94755	valid_1's WRMSSE: 0.56236	valid_1's RMSE: 2.02534
# [57]	training's WRMSSE: 0.512514	training's RMSE: 1.94662	valid_1's WRMSSE: 0.560567	valid_1's RMSE: 2.02445
# [58]	training's WRMSSE: 0.510534	training's RMSE: 1.94618	valid_1's WRMSSE: 0.559531	valid_1's RMSE: 2.02419
# [59]	training's WRMSSE: 0.509507	training's RMSE: 1.94548	valid_1's WRMSSE: 0.558337	valid_1's RMSE: 2.02359
# [60]	training's WRMSSE: 0.508112	training's RMSE: 1.94489	valid_1's WRMSSE: 0.55651	valid_1's RMSE: 2.02307
# [61]	training's WRMSSE: 0.507014	training's RMSE: 1.94448	valid_1's WRMSSE: 0.555338	valid_1's RMSE: 2.02273
# [62]	training's WRMSSE: 0.505912	training's RMSE: 1.94377	valid_1's WRMSSE: 0.55403	valid_1's RMSE: 2.02205
# [63]	training's WRMSSE: 0.505079	training's RMSE: 1.94308	valid_1's WRMSSE: 0.553277	valid_1's RMSE: 2.02167
# [64]	training's WRMSSE: 0.503783	training's RMSE: 1.94256	valid_1's WRMSSE: 0.552152	valid_1's RMSE: 2.02135
# [65]	training's WRMSSE: 0.502994	training's RMSE: 1.94212	valid_1's WRMSSE: 0.551126	valid_1's RMSE: 2.02095
# [66]	training's WRMSSE: 0.501942	training's RMSE: 1.94154	valid_1's WRMSSE: 0.550497	valid_1's RMSE: 2.02057
# [67]	training's WRMSSE: 0.500343	training's RMSE: 1.94076	valid_1's WRMSSE: 0.54922	valid_1's RMSE: 2.01981
# [68]	training's WRMSSE: 0.498932	training's RMSE: 1.94017	valid_1's WRMSSE: 0.548191	valid_1's RMSE: 2.01932
# [69]	training's WRMSSE: 0.497472	training's RMSE: 1.93957	valid_1's WRMSSE: 0.546775	valid_1's RMSE: 2.01891
# [70]	training's WRMSSE: 0.496909	training's RMSE: 1.93914	valid_1's WRMSSE: 0.546072	valid_1's RMSE: 2.01855
# [71]	training's WRMSSE: 0.495214	training's RMSE: 1.93858	valid_1's WRMSSE: 0.543987	valid_1's RMSE: 2.01813
# [72]	training's WRMSSE: 0.493223	training's RMSE: 1.93797	valid_1's WRMSSE: 0.54257	valid_1's RMSE: 2.0177
# [73]	training's WRMSSE: 0.492133	training's RMSE: 1.93734	valid_1's WRMSSE: 0.54188	valid_1's RMSE: 2.01722
# [74]	training's WRMSSE: 0.491789	training's RMSE: 1.93691	valid_1's WRMSSE: 0.54165	valid_1's RMSE: 2.01701
# [75]	training's WRMSSE: 0.491293	training's RMSE: 1.93653	valid_1's WRMSSE: 0.541435	valid_1's RMSE: 2.01691
# [76]	training's WRMSSE: 0.490491	training's RMSE: 1.93597	valid_1's WRMSSE: 0.540314	valid_1's RMSE: 2.01648
# [77]	training's WRMSSE: 0.490016	training's RMSE: 1.93558	valid_1's WRMSSE: 0.539963	valid_1's RMSE: 2.01625
# [78]	training's WRMSSE: 0.489261	training's RMSE: 1.93505	valid_1's WRMSSE: 0.539623	valid_1's RMSE: 2.01596
# [79]	training's WRMSSE: 0.486999	training's RMSE: 1.93452	valid_1's WRMSSE: 0.538116	valid_1's RMSE: 2.01551
# [80]	training's WRMSSE: 0.486055	training's RMSE: 1.93401	valid_1's WRMSSE: 0.537512	valid_1's RMSE: 2.01509
# [81]	training's WRMSSE: 0.485766	training's RMSE: 1.9336	valid_1's WRMSSE: 0.537405	valid_1's RMSE: 2.01483
# [82]	training's WRMSSE: 0.485462	training's RMSE: 1.93314	valid_1's WRMSSE: 0.537316	valid_1's RMSE: 2.01477
# [83]	training's WRMSSE: 0.484921	training's RMSE: 1.93281	valid_1's WRMSSE: 0.537094	valid_1's RMSE: 2.01453
# [84]	training's WRMSSE: 0.482695	training's RMSE: 1.93238	valid_1's WRMSSE: 0.535666	valid_1's RMSE: 2.01421
# [85]	training's WRMSSE: 0.482457	training's RMSE: 1.93205	valid_1's WRMSSE: 0.535512	valid_1's RMSE: 2.01398
# [86]	training's WRMSSE: 0.481844	training's RMSE: 1.93177	valid_1's WRMSSE: 0.535384	valid_1's RMSE: 2.01385
# [87]	training's WRMSSE: 0.481582	training's RMSE: 1.93142	valid_1's WRMSSE: 0.535329	valid_1's RMSE: 2.01367
# [88]	training's WRMSSE: 0.480951	training's RMSE: 1.9312	valid_1's WRMSSE: 0.53503	valid_1's RMSE: 2.01354
# [89]	training's WRMSSE: 0.480686	training's RMSE: 1.93089	valid_1's WRMSSE: 0.534861	valid_1's RMSE: 2.01333
# [90]	training's WRMSSE: 0.480374	training's RMSE: 1.93046	valid_1's WRMSSE: 0.534495	valid_1's RMSE: 2.0131
# [91]	training's WRMSSE: 0.480146	training's RMSE: 1.93016	valid_1's WRMSSE: 0.534463	valid_1's RMSE: 2.01289
# [92]	training's WRMSSE: 0.479907	training's RMSE: 1.92983	valid_1's WRMSSE: 0.534049	valid_1's RMSE: 2.01265
# [93]	training's WRMSSE: 0.479472	training's RMSE: 1.92928	valid_1's WRMSSE: 0.533791	valid_1's RMSE: 2.01238
# [94]	training's WRMSSE: 0.478888	training's RMSE: 1.92891	valid_1's WRMSSE: 0.533299	valid_1's RMSE: 2.01213
# [95]	training's WRMSSE: 0.478682	training's RMSE: 1.92854	valid_1's WRMSSE: 0.533216	valid_1's RMSE: 2.01192
# [96]	training's WRMSSE: 0.478032	training's RMSE: 1.92817	valid_1's WRMSSE: 0.532636	valid_1's RMSE: 2.01173
# [97]	training's WRMSSE: 0.477862	training's RMSE: 1.92783	valid_1's WRMSSE: 0.532413	valid_1's RMSE: 2.01145
# [98]	training's WRMSSE: 0.477448	training's RMSE: 1.92734	valid_1's WRMSSE: 0.531982	valid_1's RMSE: 2.01119
# [99]	training's WRMSSE: 0.47722	training's RMSE: 1.92682	valid_1's WRMSSE: 0.531782	valid_1's RMSE: 2.0109
# [100]	training's WRMSSE: 0.476828	training's RMSE: 1.92621	valid_1's WRMSSE: 0.531604	valid_1's RMSE: 2.01062
# [101]	training's WRMSSE: 0.476665	training's RMSE: 1.92591	valid_1's WRMSSE: 0.531599	valid_1's RMSE: 2.01053
# [102]	training's WRMSSE: 0.476384	training's RMSE: 1.92558	valid_1's WRMSSE: 0.531282	valid_1's RMSE: 2.01034
# [103]	training's WRMSSE: 0.475874	training's RMSE: 1.92514	valid_1's WRMSSE: 0.530809	valid_1's RMSE: 2.01007
# [104]	training's WRMSSE: 0.475364	training's RMSE: 1.92484	valid_1's WRMSSE: 0.530384	valid_1's RMSE: 2.01002
# [105]	training's WRMSSE: 0.474879	training's RMSE: 1.92453	valid_1's WRMSSE: 0.530209	valid_1's RMSE: 2.00988
# [106]	training's WRMSSE: 0.474681	training's RMSE: 1.92419	valid_1's WRMSSE: 0.530099	valid_1's RMSE: 2.00976
# /opt/conda/lib/python3.7/site-packages/ipykernel_launcher.py:18: RuntimeWarning: overflow encountered in square
# /opt/conda/lib/python3.7/site-packages/ipykernel_launcher.py:19: RuntimeWarning: invalid value encountered in multiply
# /opt/conda/lib/python3.7/site-packages/ipykernel_launcher.py:2: RuntimeWarning: overflow encountered in power
# [107]	training's WRMSSE: nan	training's RMSE: inf	valid_1's WRMSSE: nan	valid_1's RMSE: inf
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# <ipython-input-127-be53a4028959> in <module>
#       2 lgb_re2.fit(X_train,y_train,eval_set = [(X_train,y_train),(X_valid,y_valid)],verbose=1,
#       3            eval_metric =lambda y_true, y_pred: [evaluator_super.feval(y_true, y_pred), rmse(y_true, y_pred)],
# ----> 4            early_stopping_rounds=50)#,categorical_feature=cat_col)
#
# /opt/conda/lib/python3.7/site-packages/lightgbm/sklearn.py in fit(self, X, y, sample_weight, init_score, eval_set, eval_names, eval_sample_weight, eval_init_score, eval_metric, early_stopping_rounds, verbose, feature_name, categorical_feature, callbacks)
#     741                                        verbose=verbose, feature_name=feature_name,
#     742                                        categorical_feature=categorical_feature,
# --> 743                                        callbacks=callbacks)
#     744         return self
#     745
#
# /opt/conda/lib/python3.7/site-packages/lightgbm/sklearn.py in fit(self, X, y, sample_weight, init_score, group, eval_set, eval_names, eval_sample_weight, eval_class_weight, eval_init_score, eval_group, eval_metric, early_stopping_rounds, verbose, feature_name, categorical_feature, callbacks)
#     598                               verbose_eval=verbose, feature_name=feature_name,
#     599                               categorical_feature=categorical_feature,
# --> 600                               callbacks=callbacks)
#     601
#     602         if evals_result:
#
# /opt/conda/lib/python3.7/site-packages/lightgbm/engine.py in train(params, train_set, num_boost_round, valid_sets, valid_names, fobj, feval, init_model, feature_name, categorical_feature, early_stopping_rounds, evals_result, verbose_eval, learning_rates, keep_training_booster, callbacks)
#     247                                     evaluation_result_list=None))
#     248
# --> 249         booster.update(fobj=fobj)
#     250
#     251         evaluation_result_list = []
#
# /opt/conda/lib/python3.7/site-packages/lightgbm/basic.py in update(self, train_set, fobj)
#    1981                 self.reset_parameter({"objective": "none"}).__set_objective_to_none = True
#    1982             grad, hess = fobj(self.__inner_predict(0), self.train_set)
# -> 1983             return self.__boost(grad, hess)
#    1984
#    1985     def __boost(self, grad, hess):
#
# /opt/conda/lib/python3.7/site-packages/lightgbm/basic.py in __boost(self, grad, hess)
#    2016             grad.ctypes.data_as(ctypes.POINTER(ctypes.c_float)),
#    2017             hess.ctypes.data_as(ctypes.POINTER(ctypes.c_float)),
# -> 2018             ctypes.byref(is_finished)))
#    2019         self.__is_predicted_cur_iter = [False for _ in range_(self.__num_dataset)]
#    2020         return is_finished.value == 1
#
# KeyboardInterrupt:

# %%
a = pd.Series([1,2,3]).astype('float')

# %%
np.float128
# Out:
# numpy.float128

# %%
np.fl

# %%
import numpy
# warning is not logged here. Perfect for clean unit test output
with numpy.errstate(divide='ignore'):
    c = numpy.float64(1.0) / 0.0

# %% [markdown]
# ### score
# - 0.4851 480
# - 0.575458 57376
# - 0.530099

# %% [markdown]
# ###  add test1

# %%
X_train.columns
# Out:
# Index(['item_id', 'dept_id', 'cat_id', 'store_id', 'state_id', 'event_name_1',
#        'event_type_1', 'event_name_2', 'event_type_2', 'sell_price', 'year',
#        'month', 'dayofweek', 'quarter', 'lag_sale_1', 'lag_sale_2',
#        'lag_sale_3', 'lag_sale_4', 'lag_sale_5', 'lag_sale_6', 'lag_sale_7',
#        'rolling_sale_3_mean', 'rolling_sale_7_mean', 'rolling_sale_7_std',
#        'rolling_sale_7_median', 'rolling_sale_14_mean', 'rolling_sale_14_std',
#        'rolling_sale_14_median', 'rolling_sale_28_mean', 'rolling_sale_28_std',
#        'rolling_sale_28_median', 'rolling_sale_91_mean', 'rolling_sale_91_std',
#        'rolling_sale_91_median', 'rolling_sale_182_mean',
#        'rolling_sale_182_std', 'rolling_sale_182_median',
#        'rolling_sale_364_mean', 'rolling_sale_364_std',
#        'rolling_sale_364_median', 'rolling_sale_7_cv', 'rolling_sale_14_cv',
#        'rolling_sale_28_cv', 'rolling_sale_91_cv', 'rolling_sale_182_cv',
#        'rolling_sale_364_cv', 'rolling_sale_7_quantile25',
#        'rolling_sale_14_quantile25', 'rolling_sale_28_quantile25',
#        'rolling_sale_91_quantile25', 'rolling_sale_182_quantile25',
#        'rolling_sale_364_quantile25', 'rolling_sale_7_quantile75',
#        'rolling_sale_14_quantile75', 'rolling_sale_28_quantile75',
#        'rolling_sale_91_quantile75', 'rolling_sale_182_quantile75',
#        'rolling_sale_364_quantile75', 'rolling_sale_dayofweek_2_mean',
#        'rolling_sale_dayofweek_4_mean', 'rolling_sale_dayofweek_4_std',
#        'rolling_sale_dayofweek_8_mean', 'rolling_sale_dayofweek_8_std',
#        'rolling_sale_dayofweek_8_median', 'rolling_sale_dayofweek_12_mean',
#        'rolling_sale_dayofweek_12_std', 'rolling_sale_dayofweek_12_median',
#        'rolling_sale_dayofweek_24_mean', 'rolling_sale_dayofweek_24_std',
#        'rolling_sale_dayofweek_24_median', 'rolling_sale_dayofweek_52_mean',
#        'rolling_sale_dayofweek_52_std', 'rolling_sale_dayofweek_52_median',
#        'rolling_sale_dayofweek_4_cv', 'rolling_sale_dayofweek_8_cv',
#        'rolling_sale_dayofweek_12_cv', 'rolling_sale_dayofweek_24_cv',
#        'rolling_sale_dayofweek_52_cv', 'lag_price1', 'ratio_now_lag1price',
#        'rolling_sale_dayofweek_8_quantile25',
#        'rolling_sale_dayofweek_12_quantile25',
#        'rolling_sale_dayofweek_24_quantile25',
#        'rolling_sale_dayofweek_52_quantile25',
#        'rolling_sale_dayofweek_8_quantile75',
#        'rolling_sale_dayofweek_12_quantile75',
#        'rolling_sale_dayofweek_24_quantile75',
#        'rolling_sale_dayofweek_52_quantile75', 'snap'],
#       dtype='object')

# %%
def func_custom_1_2(scalar):
    if scalar ==0:
        return 0
    elif scalar <= 10**(-8):
        return 10**4
    else:
        return scalar **(-1/2)

# %%
func1 = np.vectorize(func_custom_1_2)

# %%
def custom_obj(y_true, y_pred):
    residual = (y_true - y_pred).astype(np.float128)
    residual = residual.reshape((-1,30490)) 
    d = residual.shape[0]    
    residual_42840 = residual * roll_mat_csr.T
    mean_square_42840 = np.square(residual_42840).sum(axis = 0)
    temp_1 = func1(mean_square_42840)
    part1 = ((1/np.sqrt(S)) * temp_1)/np.sqrt(d)
    part_all = np.multiply(part1,residual_42840) 
    grad = -(part_all * roll_mat_csr).reshape((-1))
    hess_part1 = np.multiply(-(1/np.sqrt(S))/np.sqrt(d)*temp_1**3,np.square(residual_42840))
    hess_part2 = (1/np.sqrt(S))/np.sqrt(d)*temp_1
    hess = ((hess_part1 + hess_part2)*roll_mat_csr).reshape((-1))
    return grad,hess

# %%
X_train = train1[(train1.day_num<=1885)&(train1.day_num>=1885-1-364)&(train1.date!='2015-12-25')].drop(drop_col,axis=1).copy()
y_train = train1.loc[(train1.day_num<=1885)&(train1.day_num>=1885-1-364)&(train1.date!='2015-12-25'),'sale']
X_valid = train1[(train1.day_num<=1913)&(train1.day_num>=1886)].drop(drop_col,axis=1).copy()
y_valid = train1.loc[(train1.day_num<=1913)&(train1.day_num>=1886),'sale']
y_train[y_train==-999] = 0
y_valid[y_valid==-999] = 0

# %%
X_train['lag_7_14_ratio_mean'] = np.clip(X_train['rolling_sale_7_mean'] * 7 / (X_train['rolling_sale_14_mean']*14 - X_train['rolling_sale_7_mean'] * 7),-999,999)
X_train['lag_14_28_ratio_mean'] = np.clip(X_train['rolling_sale_14_mean'] * 14 / (X_train['rolling_sale_28_mean']*28 - X_train['rolling_sale_14_mean'] * 14),-999,999)
X_train['lag_7_14_ratio_median'] = np.clip(X_train['rolling_sale_7_median'] / X_train['rolling_sale_14_median'],-999,999)
X_train['lag_14_28_ratio_median'] = np.clip(X_train['rolling_sale_14_median']  / X_train['rolling_sale_28_median'],-999,999)

X_train['lag_7_14_diff_mean'] = X_train['rolling_sale_7_mean'] * 7 - (X_train['rolling_sale_14_mean']*14 - X_train['rolling_sale_7_mean'] * 7)
X_train['lag_14_28_diff_mean'] = X_train['rolling_sale_14_mean'] * 14 - (X_train['rolling_sale_28_mean']*28 - X_train['rolling_sale_14_mean'] * 14)
X_train['lag_7_14_diff_median'] = X_train['rolling_sale_7_median'] - X_train['rolling_sale_14_median']
X_train['lag_14_28_diff_median'] = X_train['rolling_sale_14_median']  - X_train['rolling_sale_28_median']
X_train.fillna(-999,inplace=True)

# %%
X_valid['lag_7_14_ratio_mean'] = np.clip(X_valid['rolling_sale_7_mean'] * 7 / (X_valid['rolling_sale_14_mean']*14 - X_valid['rolling_sale_7_mean'] * 7),-999,999)
X_valid['lag_14_28_ratio_mean'] = np.clip(X_valid['rolling_sale_14_mean'] * 14 / (X_valid['rolling_sale_28_mean']*28 - X_valid['rolling_sale_14_mean'] * 14),-999,999)
X_valid['lag_7_14_ratio_median'] = np.clip(X_valid['rolling_sale_7_median'] / X_valid['rolling_sale_14_median'],-999,999)
X_valid['lag_14_28_ratio_median'] = np.clip(X_valid['rolling_sale_14_median']  / X_valid['rolling_sale_28_median'],-999,999)

X_valid['lag_7_14_diff_mean'] = X_valid['rolling_sale_7_mean'] * 7 - (X_valid['rolling_sale_14_mean']*14 - X_valid['rolling_sale_7_mean'] * 7)
X_valid['lag_14_28_diff_mean'] = X_valid['rolling_sale_14_mean'] * 14 - (X_valid['rolling_sale_28_mean']*28 - X_valid['rolling_sale_14_mean'] * 14)
X_valid['lag_7_14_diff_median'] = X_valid['rolling_sale_7_median'] - X_valid['rolling_sale_14_median']
X_valid['lag_14_28_diff_median'] = X_valid['rolling_sale_14_median']  - X_valid['rolling_sale_28_median']
X_valid.fillna(-999,inplace=True)

# %%
add_list = ['lag_7_14_ratio_mean','lag_14_28_ratio_mean','lag_7_14_ratio_median','lag_14_28_ratio_median',
           'lag_7_14_diff_mean','lag_14_28_diff_mean','lag_7_14_diff_median','lag_14_28_diff_median']

# %%
lgb_re2.fit(X_train,y_train,eval_set = [(X_valid,y_valid)],verbose=10,
           eval_metric =lambda y_true, y_pred: [evaluator_super.feval(y_true, y_pred), rmse(y_true, y_pred)],
           early_stopping_rounds=50)#,categorical_feature=cat_col)
# Out:
# Training until validation scores don't improve for 50 rounds
# [10]	valid_0's WRMSSE: 2.40059	valid_0's RMSE: 2.45251
# [20]	valid_0's WRMSSE: 1.15888	valid_0's RMSE: 2.03083
# [30]	valid_0's WRMSSE: 0.699217	valid_0's RMSE: 1.92816
# [40]	valid_0's WRMSSE: 0.56777	valid_0's RMSE: 1.90386
# [50]	valid_0's WRMSSE: 0.530414	valid_0's RMSE: 1.89582
# [60]	valid_0's WRMSSE: 0.516311	valid_0's RMSE: 1.8911
# [70]	valid_0's WRMSSE: 0.5072	valid_0's RMSE: 1.88823
# [80]	valid_0's WRMSSE: 0.502527	valid_0's RMSE: 1.88642
# [90]	valid_0's WRMSSE: 0.499122	valid_0's RMSE: 1.88489
# [100]	valid_0's WRMSSE: 0.495211	valid_0's RMSE: 1.8834
# [110]	valid_0's WRMSSE: 0.492223	valid_0's RMSE: 1.88233
# [120]	valid_0's WRMSSE: 0.490358	valid_0's RMSE: 1.88103
# [130]	valid_0's WRMSSE: 0.489176	valid_0's RMSE: 1.88022
# [140]	valid_0's WRMSSE: 0.488839	valid_0's RMSE: 1.87962
# [150]	valid_0's WRMSSE: 0.488125	valid_0's RMSE: 1.87911
# [160]	valid_0's WRMSSE: 0.486724	valid_0's RMSE: 1.878
# [170]	valid_0's WRMSSE: 0.486559	valid_0's RMSE: 1.87727
# [180]	valid_0's WRMSSE: 0.485763	valid_0's RMSE: 1.87691
# [190]	valid_0's WRMSSE: 0.4851	valid_0's RMSE: 1.87626
# [200]	valid_0's WRMSSE: 0.48477	valid_0's RMSE: 1.87583
# [210]	valid_0's WRMSSE: 0.484734	valid_0's RMSE: 1.87539
# [220]	valid_0's WRMSSE: 0.484091	valid_0's RMSE: 1.8752
# [230]	valid_0's WRMSSE: 0.48384	valid_0's RMSE: 1.87481
# [240]	valid_0's WRMSSE: 0.483374	valid_0's RMSE: 1.87424
# [250]	valid_0's WRMSSE: 0.483277	valid_0's RMSE: 1.87377
# [260]	valid_0's WRMSSE: 0.483277	valid_0's RMSE: 1.87376
# [270]	valid_0's WRMSSE: 0.483076	valid_0's RMSE: 1.87358
# [280]	valid_0's WRMSSE: 0.483158	valid_0's RMSE: 1.87352
# [290]	valid_0's WRMSSE: 0.482515	valid_0's RMSE: 1.87307
# [300]	valid_0's WRMSSE: 0.482414	valid_0's RMSE: 1.87279
# [310]	valid_0's WRMSSE: 0.482357	valid_0's RMSE: 1.87259
# [320]	valid_0's WRMSSE: 0.482323	valid_0's RMSE: 1.87246
# [330]	valid_0's WRMSSE: 0.482525	valid_0's RMSE: 1.87231
# [340]	valid_0's WRMSSE: 0.482398	valid_0's RMSE: 1.8722
# [350]	valid_0's WRMSSE: 0.482168	valid_0's RMSE: 1.87197
# [360]	valid_0's WRMSSE: 0.481409	valid_0's RMSE: 1.87192
# [370]	valid_0's WRMSSE: 0.481499	valid_0's RMSE: 1.87184
# [380]	valid_0's WRMSSE: 0.481498	valid_0's RMSE: 1.87184
# [390]	valid_0's WRMSSE: 0.481539	valid_0's RMSE: 1.87174
# [400]	valid_0's WRMSSE: 0.481561	valid_0's RMSE: 1.87163
# Early stopping, best iteration is:
# [359]	valid_0's WRMSSE: 0.481388	valid_0's RMSE: 1.87188
# Evaluated only: WRMSSE
# LGBMRegressor(bagging_freq=1, boosting_type='gbdt', class_weight=None,
#        colsample_bytree=0.8, first_metric_only=True,
#        importance_type='gain', learning_rate=0.05, max_depth=-1,
#        metric='None', min_child_samples=20, min_child_weight=0.001,
#        min_data_in_leaf=255, min_split_gain=0.0, n_estimators=1000,
#        n_jobs=12, num_leaves=255,
#        objective=<function custom_obj at 0x7fc70852b1e0>, random_state=51,
#        reg_alpha=0.0, reg_lambda=0.0, silent=True, subsample=0.8,
#        subsample_for_bin=200000, subsample_freq=0)

# %%
pd.DataFrame(lgb_re2.feature_importances_,index=X_train.columns).sort_values(0,ascending=False)
# Out:
#                                                  0
# rolling_sale_28_mean                  98780.277753
# rolling_sale_14_mean                  49073.054152
# rolling_sale_7_mean                   16023.867886
# rolling_sale_dayofweek_52_mean         4714.203745
# rolling_sale_364_mean                  3242.140471
# rolling_sale_dayofweek_52_quantile75   2973.342364
# lag_14_28_ratio_mean                   2816.472452
# rolling_sale_28_std                    2801.249147
# rolling_sale_91_std                    2721.982046
# dayofweek                              2697.461168
# rolling_sale_91_mean                   2273.182352
# lag_sale_1                             2193.002664
# rolling_sale_3_mean                    1696.450967
# rolling_sale_dayofweek_24_quantile75   1074.671915
# rolling_sale_7_median                   799.762415
# item_id                                 749.586826
# snap                                    738.932155
# rolling_sale_7_std                      737.249289
# rolling_sale_dayofweek_52_std           705.208128
# rolling_sale_364_std                    684.445228
# rolling_sale_dayofweek_24_mean          659.506607
# rolling_sale_14_std                     658.339031
# rolling_sale_28_quantile75              654.816323
# rolling_sale_dayofweek_8_mean           606.613019
# month                                   572.164413
# rolling_sale_7_quantile25               564.369351
# rolling_sale_7_quantile75               545.422993
# lag_7_14_ratio_mean                     535.119780
# store_id                                478.927504
# sell_price                              419.552469
# ...                                            ...
# rolling_sale_182_quantile75              62.598014
# rolling_sale_dayofweek_8_median          62.548497
# rolling_sale_dayofweek_12_std            61.570407
# rolling_sale_dayofweek_8_cv              58.403430
# lag_sale_5                               57.705838
# rolling_sale_28_quantile25               56.939829
# rolling_sale_dayofweek_52_median         52.699694
# rolling_sale_91_median                   52.426606
# rolling_sale_14_quantile25               52.349423
# rolling_sale_dayofweek_4_cv              52.231215
# state_id                                 51.864007
# rolling_sale_364_median                  51.315300
# year                                     50.041609
# lag_7_14_diff_median                     48.924406
# rolling_sale_14_median                   46.386012
# rolling_sale_182_median                  41.164565
# rolling_sale_dayofweek_24_median         39.904534
# rolling_sale_dayofweek_8_quantile25      39.315323
# lag_14_28_diff_median                    38.619840
# rolling_sale_dayofweek_12_median         36.260972
# quarter                                  32.085801
# cat_id                                   31.614767
# rolling_sale_dayofweek_12_quantile25     30.969224
# rolling_sale_91_quantile25               27.736591
# rolling_sale_dayofweek_52_quantile25     27.137235
# rolling_sale_182_quantile25              25.334457
# rolling_sale_dayofweek_24_quantile25     23.833581
# rolling_sale_364_quantile25              22.370394
# event_type_2                              0.000000
# event_name_2                              0.000000
#
# [97 rows x 1 columns]

# %%
pd.DataFrame(lgb_re2.feature_importances_,index=X_train.columns).sort_values(0,ascending=False).loc[add_list]
# Out:
#                                   0
# lag_7_14_ratio_mean      535.119780
# lag_14_28_ratio_mean    2816.472452
# lag_7_14_ratio_median     82.951708
# lag_14_28_ratio_median    95.485843
# lag_7_14_diff_mean       398.046599
# lag_14_28_diff_mean      344.766909
# lag_7_14_diff_median      48.924406
# lag_14_28_diff_median     38.619840

# %% [markdown]
# ### add id

# %%
def func_custom_1_2(scalar):
    if scalar ==0:
        return 0
    elif scalar <= 10**(-8):
        return 10**4
    else:
        return scalar **(-1/2)

# %%
func1 = np.vectorize(func_custom_1_2)

# %%
def custom_obj(y_true, y_pred):
    residual = (y_true - y_pred).astype(np.float128)
    residual = residual.reshape((-1,30490)) 
    d = residual.shape[0]    
    residual_42840 = residual * roll_mat_csr.T
    mean_square_42840 = np.square(residual_42840).sum(axis = 0)
    temp_1 = func1(mean_square_42840)
    part1 = ((1/np.sqrt(S)) * temp_1)/np.sqrt(d)
    part_all = np.multiply(part1,residual_42840) 
    grad = -(part_all * roll_mat_csr).reshape((-1))
    hess_part1 = np.multiply(-(1/np.sqrt(S))/np.sqrt(d)*temp_1**3,np.square(residual_42840))
    hess_part2 = (1/np.sqrt(S))/np.sqrt(d)*temp_1
    hess = ((hess_part1 + hess_part2)*roll_mat_csr).reshape((-1))
    return grad,hess

# %%
train1 = pd.read_pickle('data_part1.pkl')

# %%
train1.shape
# Out:
# (60034810, 96)

# %%
for _ in ['CA','TX','WI']:
    train1.loc[train1.state_id==_,'snap'] = list(train1.loc[train1.state_id==_,f'snap_{_}'])

# %%
drop_col = ['day_num','date','wm_yr_wk','snap_CA','snap_TX','snap_WI','sale']
cat_col = ['item_id','dept_id','cat_id','store_id','state_id','event_name_1', 'event_type_1', 'event_name_2', 'event_type_2','id']

# %%
for cat in cat_col:
    lbl = preprocessing.LabelEncoder()
    train1[cat] = lbl.fit_transform(train1[cat].astype(str))
    print(cat)
# Out:
# item_id
# dept_id
# cat_id
# store_id
# state_id
# event_name_1
# event_type_1
# event_name_2
# event_type_2
# id

# %%
train1.fillna(-999,inplace=True)

# %%
X_train = train1[(train1.day_num<=1885)&(train1.day_num>=1885-1-364)&(train1.date!='2015-12-25')].drop(drop_col,axis=1).copy()
y_train = train1.loc[(train1.day_num<=1885)&(train1.day_num>=1885-1-364)&(train1.date!='2015-12-25'),'sale']
X_valid = train1[(train1.day_num<=1913)&(train1.day_num>=1886)].drop(drop_col,axis=1).copy()
y_valid = train1.loc[(train1.day_num<=1913)&(train1.day_num>=1886),'sale']
y_train[y_train==-999] = 0
y_valid[y_valid==-999] = 0

# %%
X_train['lag_7_14_ratio_mean'] = np.clip(X_train['rolling_sale_7_mean'] * 7 / (X_train['rolling_sale_14_mean']*14 - X_train['rolling_sale_7_mean'] * 7),-999,999)
X_train['lag_14_28_ratio_mean'] = np.clip(X_train['rolling_sale_14_mean'] * 14 / (X_train['rolling_sale_28_mean']*28 - X_train['rolling_sale_14_mean'] * 14),-999,999)
X_train['lag_7_14_ratio_median'] = np.clip(X_train['rolling_sale_7_median'] / X_train['rolling_sale_14_median'],-999,999)
X_train['lag_14_28_ratio_median'] = np.clip(X_train['rolling_sale_14_median']  / X_train['rolling_sale_28_median'],-999,999)

X_train['lag_7_14_diff_mean'] = X_train['rolling_sale_7_mean'] * 7 - (X_train['rolling_sale_14_mean']*14 - X_train['rolling_sale_7_mean'] * 7)
X_train['lag_14_28_diff_mean'] = X_train['rolling_sale_14_mean'] * 14 - (X_train['rolling_sale_28_mean']*28 - X_train['rolling_sale_14_mean'] * 14)
X_train['lag_7_14_diff_median'] = X_train['rolling_sale_7_median'] - X_train['rolling_sale_14_median']
X_train['lag_14_28_diff_median'] = X_train['rolling_sale_14_median']  - X_train['rolling_sale_28_median']
X_train.fillna(-999,inplace=True)

# %%
X_valid['lag_7_14_ratio_mean'] = np.clip(X_valid['rolling_sale_7_mean'] * 7 / (X_valid['rolling_sale_14_mean']*14 - X_valid['rolling_sale_7_mean'] * 7),-999,999)
X_valid['lag_14_28_ratio_mean'] = np.clip(X_valid['rolling_sale_14_mean'] * 14 / (X_valid['rolling_sale_28_mean']*28 - X_valid['rolling_sale_14_mean'] * 14),-999,999)
X_valid['lag_7_14_ratio_median'] = np.clip(X_valid['rolling_sale_7_median'] / X_valid['rolling_sale_14_median'],-999,999)
X_valid['lag_14_28_ratio_median'] = np.clip(X_valid['rolling_sale_14_median']  / X_valid['rolling_sale_28_median'],-999,999)

X_valid['lag_7_14_diff_mean'] = X_valid['rolling_sale_7_mean'] * 7 - (X_valid['rolling_sale_14_mean']*14 - X_valid['rolling_sale_7_mean'] * 7)
X_valid['lag_14_28_diff_mean'] = X_valid['rolling_sale_14_mean'] * 14 - (X_valid['rolling_sale_28_mean']*28 - X_valid['rolling_sale_14_mean'] * 14)
X_valid['lag_7_14_diff_median'] = X_valid['rolling_sale_7_median'] - X_valid['rolling_sale_14_median']
X_valid['lag_14_28_diff_median'] = X_valid['rolling_sale_14_median']  - X_valid['rolling_sale_28_median']
X_valid.fillna(-999,inplace=True)

# %%
lgb_re2 = lgb.LGBMRegressor(n_estimators=1000, random_state=51,subsample=0.8,
                         colsample_bytree=0.8,learning_rate=0.05 ,importance_type = 'gain',
                 max_depth = -1, num_leaves = 2**8-1,metric='None',bagging_freq=1,n_jobs=12,
                         first_metric_only = True,objective=custom_obj,min_data_in_leaf =  2**8-1)

# %%
lgb_re2.fit(X_train,y_train,eval_set = [(X_valid,y_valid)],verbose=10,
           eval_metric =lambda y_true, y_pred: [evaluator_super.feval(y_true, y_pred), rmse(y_true, y_pred)],
           early_stopping_rounds=50)#,categorical_feature=cat_col)
# Out:
# Training until validation scores don't improve for 50 rounds
# [10]	valid_0's WRMSSE: 2.39846	valid_0's RMSE: 2.45216
# [20]	valid_0's WRMSSE: 1.15766	valid_0's RMSE: 2.02959
# [30]	valid_0's WRMSSE: 0.702352	valid_0's RMSE: 1.92727
# [40]	valid_0's WRMSSE: 0.566343	valid_0's RMSE: 1.90474
# [50]	valid_0's WRMSSE: 0.529916	valid_0's RMSE: 1.89744
# [60]	valid_0's WRMSSE: 0.515683	valid_0's RMSE: 1.89312
# [70]	valid_0's WRMSSE: 0.50703	valid_0's RMSE: 1.89065
# [80]	valid_0's WRMSSE: 0.500732	valid_0's RMSE: 1.88802
# [90]	valid_0's WRMSSE: 0.496982	valid_0's RMSE: 1.88559
# [100]	valid_0's WRMSSE: 0.494658	valid_0's RMSE: 1.88393
# [110]	valid_0's WRMSSE: 0.493061	valid_0's RMSE: 1.88243
# [120]	valid_0's WRMSSE: 0.491859	valid_0's RMSE: 1.88116
# [130]	valid_0's WRMSSE: 0.490448	valid_0's RMSE: 1.88026
# [140]	valid_0's WRMSSE: 0.487957	valid_0's RMSE: 1.87967
# [150]	valid_0's WRMSSE: 0.487325	valid_0's RMSE: 1.87869
# [160]	valid_0's WRMSSE: 0.486916	valid_0's RMSE: 1.87846
# [170]	valid_0's WRMSSE: 0.485976	valid_0's RMSE: 1.87787
# [180]	valid_0's WRMSSE: 0.485763	valid_0's RMSE: 1.87737
# [190]	valid_0's WRMSSE: 0.485294	valid_0's RMSE: 1.87675
# [200]	valid_0's WRMSSE: 0.484933	valid_0's RMSE: 1.87623
# [210]	valid_0's WRMSSE: 0.484148	valid_0's RMSE: 1.87593
# [220]	valid_0's WRMSSE: 0.484175	valid_0's RMSE: 1.87557
# [230]	valid_0's WRMSSE: 0.484071	valid_0's RMSE: 1.87536
# [240]	valid_0's WRMSSE: 0.483998	valid_0's RMSE: 1.87498
# [250]	valid_0's WRMSSE: 0.483842	valid_0's RMSE: 1.87465
# [260]	valid_0's WRMSSE: 0.483481	valid_0's RMSE: 1.87437
# [270]	valid_0's WRMSSE: 0.482027	valid_0's RMSE: 1.87398
# [280]	valid_0's WRMSSE: 0.481653	valid_0's RMSE: 1.87352
# [290]	valid_0's WRMSSE: 0.481152	valid_0's RMSE: 1.87348
# [300]	valid_0's WRMSSE: 0.480821	valid_0's RMSE: 1.87321
# [310]	valid_0's WRMSSE: 0.479411	valid_0's RMSE: 1.87311
# [320]	valid_0's WRMSSE: 0.479494	valid_0's RMSE: 1.87311
# [330]	valid_0's WRMSSE: 0.479532	valid_0's RMSE: 1.87304
# [340]	valid_0's WRMSSE: 0.479608	valid_0's RMSE: 1.87315
# [350]	valid_0's WRMSSE: 0.479459	valid_0's RMSE: 1.87323
# [360]	valid_0's WRMSSE: 0.478997	valid_0's RMSE: 1.87286
# [370]	valid_0's WRMSSE: 0.478982	valid_0's RMSE: 1.87274
# [380]	valid_0's WRMSSE: 0.478919	valid_0's RMSE: 1.87268
# [390]	valid_0's WRMSSE: 0.4785	valid_0's RMSE: 1.87244
# [400]	valid_0's WRMSSE: 0.47851	valid_0's RMSE: 1.87227
# [410]	valid_0's WRMSSE: 0.478834	valid_0's RMSE: 1.87239
# [420]	valid_0's WRMSSE: 0.478332	valid_0's RMSE: 1.8723
# [430]	valid_0's WRMSSE: 0.478693	valid_0's RMSE: 1.87217
# [440]	valid_0's WRMSSE: 0.478517	valid_0's RMSE: 1.87257
# [450]	valid_0's WRMSSE: 0.478595	valid_0's RMSE: 1.87261
# [460]	valid_0's WRMSSE: 0.478638	valid_0's RMSE: 1.87283
# [470]	valid_0's WRMSSE: 0.478877	valid_0's RMSE: 1.87284
# Early stopping, best iteration is:
# [424]	valid_0's WRMSSE: 0.478301	valid_0's RMSE: 1.87228
# Evaluated only: WRMSSE
# LGBMRegressor(bagging_freq=1, boosting_type='gbdt', class_weight=None,
#        colsample_bytree=0.8, first_metric_only=True,
#        importance_type='gain', learning_rate=0.05, max_depth=-1,
#        metric='None', min_child_samples=20, min_child_weight=0.001,
#        min_data_in_leaf=255, min_split_gain=0.0, n_estimators=1000,
#        n_jobs=12, num_leaves=255,
#        objective=<function custom_obj at 0x7fc7086cb840>, random_state=51,
#        reg_alpha=0.0, reg_lambda=0.0, silent=True, subsample=0.8,
#        subsample_for_bin=200000, subsample_freq=0)

# %%
pd.DataFrame(lgb_re2.feature_importances_,index=X_train.columns).sort_values(0,ascending=False)
# Out:
#                                                  0
# rolling_sale_28_mean                  95073.988015
# rolling_sale_14_mean                  39882.594788
# rolling_sale_7_mean                   18660.063379
# rolling_sale_28_quantile75            14838.065727
# rolling_sale_dayofweek_52_mean         4662.955348
# rolling_sale_28_std                    3752.157256
# rolling_sale_364_mean                  3379.377961
# rolling_sale_91_mean                   3009.157637
# lag_14_28_ratio_mean                   2973.019135
# rolling_sale_dayofweek_52_quantile75   2897.027534
# dayofweek                              2660.571036
# lag_sale_1                             2272.280271
# rolling_sale_3_mean                    1598.408243
# rolling_sale_dayofweek_24_quantile75   1043.296178
# rolling_sale_364_std                   1017.647679
# rolling_sale_7_std                      765.627907
# snap                                    758.867971
# lag_7_14_ratio_mean                     650.233244
# rolling_sale_dayofweek_24_mean          613.002018
# rolling_sale_14_std                     593.250956
# month                                   578.987010
# rolling_sale_dayofweek_8_mean           556.945390
# id                                      513.644464
# store_id                                506.147323
# rolling_sale_dayofweek_12_mean          504.827019
# rolling_sale_7_median                   499.711362
# sell_price                              486.190891
# rolling_sale_dayofweek_52_std           467.737493
# item_id                                 435.589202
# rolling_sale_7_quantile25               431.659383
# ...                                            ...
# rolling_sale_28_median                   70.164819
# rolling_sale_dayofweek_8_cv              69.720059
# lag_sale_5                               66.137523
# lag_7_14_diff_median                     62.763796
# rolling_sale_dayofweek_8_median          62.464671
# rolling_sale_dayofweek_4_cv              62.077340
# rolling_sale_14_median                   61.530470
# rolling_sale_182_quantile75              60.829463
# rolling_sale_dayofweek_52_median         59.165005
# rolling_sale_28_quantile25               56.526049
# rolling_sale_dayofweek_12_median         55.677330
# year                                     52.967986
# rolling_sale_91_median                   51.782921
# rolling_sale_14_quantile25               49.328052
# rolling_sale_182_median                  46.701616
# state_id                                 45.382354
# rolling_sale_dayofweek_8_quantile25      44.556972
# rolling_sale_364_median                  43.911240
# lag_14_28_diff_median                    42.911603
# rolling_sale_91_quantile25               36.129498
# rolling_sale_dayofweek_12_quantile25     32.869037
# rolling_sale_dayofweek_52_quantile25     32.628177
# rolling_sale_dayofweek_24_median         31.051498
# quarter                                  29.011235
# rolling_sale_dayofweek_24_quantile25     25.202153
# rolling_sale_182_quantile25              23.982810
# rolling_sale_364_quantile25              23.868883
# cat_id                                   15.162349
# event_type_2                              0.000000
# event_name_2                              0.000000
#
# [98 rows x 1 columns]

# %%
####drop id
lgb_re2 = lgb.LGBMRegressor(n_estimators=1000, random_state=51,subsample=0.8,
                         colsample_bytree=0.8,learning_rate=0.05 ,importance_type = 'gain',
                 max_depth = -1, num_leaves = 2**8-1,metric='None',bagging_freq=1,n_jobs=12,
                         first_metric_only = True,objective=custom_obj,min_data_in_leaf =  2**8-1)

# %%
lgb_re2.fit(X_train.drop(['id'],axis=1),y_train,eval_set = [(X_valid.drop(['id'],axis=1),y_valid)],verbose=10,
           eval_metric =lambda y_true, y_pred: [evaluator_super.feval(y_true, y_pred), rmse(y_true, y_pred)],
           early_stopping_rounds=50)#,categorical_feature=cat_col)
# Out:
# Training until validation scores don't improve for 50 rounds
# [10]	valid_0's WRMSSE: 2.40059	valid_0's RMSE: 2.45251
# [20]	valid_0's WRMSSE: 1.15888	valid_0's RMSE: 2.03083
# [30]	valid_0's WRMSSE: 0.699217	valid_0's RMSE: 1.92816
# [40]	valid_0's WRMSSE: 0.56777	valid_0's RMSE: 1.90386
# [50]	valid_0's WRMSSE: 0.530414	valid_0's RMSE: 1.89582
# [60]	valid_0's WRMSSE: 0.516311	valid_0's RMSE: 1.8911
# [70]	valid_0's WRMSSE: 0.5072	valid_0's RMSE: 1.88823
# [80]	valid_0's WRMSSE: 0.502527	valid_0's RMSE: 1.88642
# [90]	valid_0's WRMSSE: 0.499122	valid_0's RMSE: 1.88489
# [100]	valid_0's WRMSSE: 0.495211	valid_0's RMSE: 1.8834
# [110]	valid_0's WRMSSE: 0.492223	valid_0's RMSE: 1.88233
# [120]	valid_0's WRMSSE: 0.490358	valid_0's RMSE: 1.88103
# [130]	valid_0's WRMSSE: 0.489176	valid_0's RMSE: 1.88022
# [140]	valid_0's WRMSSE: 0.488839	valid_0's RMSE: 1.87962
# [150]	valid_0's WRMSSE: 0.488125	valid_0's RMSE: 1.87911
# [160]	valid_0's WRMSSE: 0.486724	valid_0's RMSE: 1.878
# [170]	valid_0's WRMSSE: 0.486559	valid_0's RMSE: 1.87727
# [180]	valid_0's WRMSSE: 0.485763	valid_0's RMSE: 1.87691
# [190]	valid_0's WRMSSE: 0.4851	valid_0's RMSE: 1.87626
# [200]	valid_0's WRMSSE: 0.48477	valid_0's RMSE: 1.87583
# [210]	valid_0's WRMSSE: 0.484734	valid_0's RMSE: 1.87539
# [220]	valid_0's WRMSSE: 0.484091	valid_0's RMSE: 1.8752
# [230]	valid_0's WRMSSE: 0.48384	valid_0's RMSE: 1.87481
# [240]	valid_0's WRMSSE: 0.483374	valid_0's RMSE: 1.87424
# [250]	valid_0's WRMSSE: 0.483277	valid_0's RMSE: 1.87377
# [260]	valid_0's WRMSSE: 0.483277	valid_0's RMSE: 1.87376
# [270]	valid_0's WRMSSE: 0.483076	valid_0's RMSE: 1.87358
# [280]	valid_0's WRMSSE: 0.483158	valid_0's RMSE: 1.87352
# [290]	valid_0's WRMSSE: 0.482515	valid_0's RMSE: 1.87307
# [300]	valid_0's WRMSSE: 0.482414	valid_0's RMSE: 1.87279
# [310]	valid_0's WRMSSE: 0.482357	valid_0's RMSE: 1.87259
# [320]	valid_0's WRMSSE: 0.482323	valid_0's RMSE: 1.87246
# [330]	valid_0's WRMSSE: 0.482525	valid_0's RMSE: 1.87231
# [340]	valid_0's WRMSSE: 0.482398	valid_0's RMSE: 1.8722
# [350]	valid_0's WRMSSE: 0.482168	valid_0's RMSE: 1.87197
# [360]	valid_0's WRMSSE: 0.481409	valid_0's RMSE: 1.87192
# [370]	valid_0's WRMSSE: 0.481499	valid_0's RMSE: 1.87184
# [380]	valid_0's WRMSSE: 0.481498	valid_0's RMSE: 1.87184
# [390]	valid_0's WRMSSE: 0.481539	valid_0's RMSE: 1.87174
# [400]	valid_0's WRMSSE: 0.481561	valid_0's RMSE: 1.87163
# Early stopping, best iteration is:
# [359]	valid_0's WRMSSE: 0.481388	valid_0's RMSE: 1.87188
# Evaluated only: WRMSSE
# LGBMRegressor(bagging_freq=1, boosting_type='gbdt', class_weight=None,
#        colsample_bytree=0.8, first_metric_only=True,
#        importance_type='gain', learning_rate=0.05, max_depth=-1,
#        metric='None', min_child_samples=20, min_child_weight=0.001,
#        min_data_in_leaf=255, min_split_gain=0.0, n_estimators=1000,
#        n_jobs=12, num_leaves=255,
#        objective=<function custom_obj at 0x7fc7086cb840>, random_state=51,
#        reg_alpha=0.0, reg_lambda=0.0, silent=True, subsample=0.8,
#        subsample_for_bin=200000, subsample_freq=0)

# %%
c = train1.iloc[-30490*100:].copy()

# %%
TARGET = 'sale'
def find_last_sale(df,n_day):
    
    # Limit initial df
    ls_df = df[['id','day_num',TARGET]]
    
    # Convert target to binary
    ls_df['non_zero'] = (ls_df[TARGET]>0).astype(np.int8)
    
    # Make lags to prevent any leakage
    ls_df['non_zero_lag'] = ls_df.groupby(['id'])['non_zero'].transform(lambda x: x.shift(n_day).rolling(2000,1).sum()).fillna(-1)

    temp_df = ls_df[['id','day_num','non_zero_lag']].drop_duplicates(subset=['id','non_zero_lag'])
    temp_df.columns = ['id','day_num_min','non_zero_lag']

    ls_df = ls_df.merge(temp_df, on=['id','non_zero_lag'], how='left')
    ls_df['last_sale'] = ls_df['day_num'] - ls_df['day_num_min']

    return ls_df[['last_sale']]

# %%
ls_df = c[['id','day_num',TARGET]]
ls_df['non_zero'] = (ls_df[TARGET]>0).astype(np.int8)
ls_df['non_zero_lag'] = ls_df.groupby(['id'])['non_zero'].transform(lambda x: x.shift(1).rolling(2000,1).sum()).fillna(-1)
# Out:
# /opt/conda/lib/python3.7/site-packages/ipykernel_launcher.py:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
#
# /opt/conda/lib/python3.7/site-packages/ipykernel_launcher.py:3: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
#   This is separate from the ipykernel package so we can avoid doing imports until

# %%
temp_df = ls_df[['id','day_num','non_zero_lag']].drop_duplicates(subset=['id','non_zero_lag'])

# %%
temp_df
# Out:
#              id  day_num  non_zero_lag
# 56985810  14370     1870          -1.0
# 56985811  14380     1870          -1.0
# 56985812  14390     1870          -1.0
# 56985813  14400     1870          -1.0
# 56985814  14410     1870          -1.0
# 56985815  14420     1870          -1.0
# 56985816  14430     1870          -1.0
# 56985817  14440     1870          -1.0
# 56985818  14450     1870          -1.0
# 56985819  14460     1870          -1.0
# 56985820  14470     1870          -1.0
# 56985821  14480     1870          -1.0
# 56985822  14490     1870          -1.0
# 56985823  14500     1870          -1.0
# 56985824  14510     1870          -1.0
# 56985825  14520     1870          -1.0
# 56985826  14530     1870          -1.0
# 56985827  14540     1870          -1.0
# 56985828  14550     1870          -1.0
# 56985829  14560     1870          -1.0
# 56985830  14570     1870          -1.0
# 56985831  14580     1870          -1.0
# 56985832  14590     1870          -1.0
# 56985833  14600     1870          -1.0
# 56985834  14610     1870          -1.0
# 56985835  14620     1870          -1.0
# 56985836  14630     1870          -1.0
# 56985837  14640     1870          -1.0
# 56985838  14650     1870          -1.0
# 56985839  14660     1870          -1.0
# ...         ...      ...           ...
# 58357809  13869     1914          17.0
# 58357810  13879     1914          10.0
# 58357812  13899     1914          33.0
# 58357814  13919     1914          40.0
# 58357817  13949     1914           5.0
# 58357818  13959     1914          30.0
# 58357820  13979     1914          26.0
# 58357821  13989     1914          44.0
# 58357824  14019     1914          35.0
# 58357825  14029     1914          32.0
# 58357826  14039     1914          11.0
# 58357827  14049     1914          36.0
# 58357829  14069     1914          35.0
# 58357830  14079     1914          14.0
# 58357832  14099     1914          44.0
# 58357833  14109     1914          39.0
# 58357836  14139     1914          40.0
# 58357837  14149     1914          35.0
# 58357838  14159     1914          19.0
# 58357842  14199     1914          20.0
# 58357843  14209     1914          44.0
# 58357844  14219     1914          29.0
# 58357846  14239     1914          37.0
# 58357849  14269     1914           9.0
# 58357850  14279     1914          34.0
# 58357851  14289     1914          41.0
# 58357852  14299     1914          38.0
# 58357854  14319     1914          38.0
# 58357855  14329     1914           4.0
# 58357858  14359     1914          30.0
#
# [628981 rows x 3 columns]

# %%
b = find_last_sale(c,1)
# Out:
# /opt/conda/lib/python3.7/site-packages/ipykernel_launcher.py:8: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
#
# /opt/conda/lib/python3.7/site-packages/ipykernel_launcher.py:11: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
#   # This is added back by InteractiveShellApp.init_path()

# %%
c['last_sale'] = b

# %%
c.last_sale.value_counts()
# Out:
# Series([], Name: last_sale, dtype: int64)

# %% [markdown]
# ### add last non-zero??

# %%
TARGET = 'sale'
def find_last_sale(df,n_day):
    
    # Limit initial df
    ls_df = df[['id','day_num',TARGET]]
    
    # Convert target to binary
    ls_df['non_zero'] = (ls_df[TARGET]>0).astype(np.int8)
    
    # Make lags to prevent any leakage
    ls_df['non_zero_lag'] = ls_df.groupby(['id'])['non_zero'].transform(lambda x: x.shift(n_day).rolling(2000,1).sum()).fillna(-1)

    temp_df = ls_df[['id','day_num','non_zero_lag']].drop_duplicates(subset=['id','non_zero_lag'])
    temp_df.columns = ['id','day_num_min','non_zero_lag']

    ls_df = ls_df.merge(temp_df, on=['id','non_zero_lag'], how='left')
    ls_df['last_sale'] = ls_df['day_num'] - ls_df['day_num_min']

    return ls_df[['last_sale']]

# %%
temp = find_last_sale(train1,1)
# Out:
# /opt/conda/lib/python3.7/site-packages/ipykernel_launcher.py:8: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
#
# /opt/conda/lib/python3.7/site-packages/ipykernel_launcher.py:11: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
#   # This is added back by InteractiveShellApp.init_path()

# %%
train1['last_sale_diff'] = temp.values

# %% [markdown]
# #### fold1

# %%
lgb_re2 = lgb.LGBMRegressor(n_estimators=1000, random_state=51,subsample=0.8,
                         colsample_bytree=0.8,learning_rate=0.05 ,importance_type = 'gain',
                 max_depth = -1, num_leaves = 2**8-1,metric='None',bagging_freq=1,n_jobs=12,
                         first_metric_only = True,objective=custom_obj,min_data_in_leaf =  2**8-1)

# %%
lgb_re2.fit(X_train,y_train,eval_set = [(X_valid,y_valid)],verbose=10,
           eval_metric =lambda y_true, y_pred: [evaluator_super.feval(y_true, y_pred), rmse(y_true, y_pred)],
           early_stopping_rounds=50)#,categorical_feature=cat_col)
# Out:
# Training until validation scores don't improve for 50 rounds
# [10]	valid_0's WRMSSE: 2.40055	valid_0's RMSE: 2.45303
# [20]	valid_0's WRMSSE: 1.1563	valid_0's RMSE: 2.02957
# [30]	valid_0's WRMSSE: 0.700509	valid_0's RMSE: 1.92957
# [40]	valid_0's WRMSSE: 0.565931	valid_0's RMSE: 1.90564
# [50]	valid_0's WRMSSE: 0.527569	valid_0's RMSE: 1.89817
# [60]	valid_0's WRMSSE: 0.514544	valid_0's RMSE: 1.8941
# [70]	valid_0's WRMSSE: 0.505963	valid_0's RMSE: 1.89132
# [80]	valid_0's WRMSSE: 0.501377	valid_0's RMSE: 1.89001
# [90]	valid_0's WRMSSE: 0.497029	valid_0's RMSE: 1.88775
# [100]	valid_0's WRMSSE: 0.493531	valid_0's RMSE: 1.88562
# [110]	valid_0's WRMSSE: 0.490625	valid_0's RMSE: 1.88436
# [120]	valid_0's WRMSSE: 0.488768	valid_0's RMSE: 1.88323
# [130]	valid_0's WRMSSE: 0.4873	valid_0's RMSE: 1.88233
# [140]	valid_0's WRMSSE: 0.485419	valid_0's RMSE: 1.88154
# [150]	valid_0's WRMSSE: 0.484824	valid_0's RMSE: 1.88048
# [160]	valid_0's WRMSSE: 0.483993	valid_0's RMSE: 1.88006
# [170]	valid_0's WRMSSE: 0.484026	valid_0's RMSE: 1.87965
# [180]	valid_0's WRMSSE: 0.483618	valid_0's RMSE: 1.87945
# [190]	valid_0's WRMSSE: 0.482644	valid_0's RMSE: 1.87899
# [200]	valid_0's WRMSSE: 0.482492	valid_0's RMSE: 1.87875
# [210]	valid_0's WRMSSE: 0.48256	valid_0's RMSE: 1.87863
# [220]	valid_0's WRMSSE: 0.482101	valid_0's RMSE: 1.87813
# [230]	valid_0's WRMSSE: 0.481699	valid_0's RMSE: 1.87786
# [240]	valid_0's WRMSSE: 0.481508	valid_0's RMSE: 1.87764
# [250]	valid_0's WRMSSE: 0.480922	valid_0's RMSE: 1.87752
# [260]	valid_0's WRMSSE: 0.480844	valid_0's RMSE: 1.87728
# [270]	valid_0's WRMSSE: 0.481047	valid_0's RMSE: 1.87616
# [280]	valid_0's WRMSSE: 0.480972	valid_0's RMSE: 1.87597
# [290]	valid_0's WRMSSE: 0.480945	valid_0's RMSE: 1.87557
# [300]	valid_0's WRMSSE: 0.480925	valid_0's RMSE: 1.87541
# Early stopping, best iteration is:
# [259]	valid_0's WRMSSE: 0.480842	valid_0's RMSE: 1.87728
# Evaluated only: WRMSSE
# LGBMRegressor(bagging_freq=1, boosting_type='gbdt', class_weight=None,
#        colsample_bytree=0.8, first_metric_only=True,
#        importance_type='gain', learning_rate=0.05, max_depth=-1,
#        metric='None', min_child_samples=20, min_child_weight=0.001,
#        min_data_in_leaf=255, min_split_gain=0.0, n_estimators=1000,
#        n_jobs=12, num_leaves=255,
#        objective=<function custom_obj at 0x7fc71813d488>, random_state=51,
#        reg_alpha=0.0, reg_lambda=0.0, silent=True, subsample=0.8,
#        subsample_for_bin=200000, subsample_freq=0)

# %%
pd.DataFrame(lgb_re2.feature_importances_,index=X_train.columns).sort_values(0,ascending=False)
# Out:
#                                                   0
# rolling_sale_28_mean                  117225.747885
# rolling_sale_14_mean                   34671.211633
# rolling_sale_7_mean                    18504.770387
# rolling_sale_dayofweek_52_mean          5057.493673
# last_sale_diff                          4697.483032
# dayofweek                               2590.372615
# rolling_sale_dayofweek_52_quantile75    2432.115734
# rolling_sale_364_mean                   2302.643092
# lag_sale_1                              1809.991379
# rolling_sale_28_quantile75              1454.189932
# rolling_sale_dayofweek_24_quantile75    1275.022423
# rolling_sale_91_mean                    1263.315402
# rolling_sale_3_mean                     1160.683949
# lag_14_28_ratio_mean                    1094.663081
# rolling_sale_364_std                    1020.341218
# snap                                     727.895651
# rolling_sale_7_median                    590.095377
# rolling_sale_dayofweek_24_mean           549.641500
# rolling_sale_182_mean                    548.564433
# rolling_sale_dayofweek_8_mean            505.235330
# rolling_sale_dayofweek_12_mean           497.623203
# rolling_sale_dayofweek_52_std            487.557095
# month                                    485.357708
# id                                       454.899141
# store_id                                 427.556845
# rolling_sale_dayofweek_8_quantile75      419.458332
# rolling_sale_7_quantile75                390.646197
# rolling_sale_7_std                       377.618258
# rolling_sale_7_quantile25                376.049897
# item_id                                  373.451692
# ...                                             ...
# rolling_sale_dayofweek_52_median          48.390869
# rolling_sale_28_quantile25                46.954604
# rolling_sale_182_median                   46.933816
# rolling_sale_28_median                    45.808724
# rolling_sale_dayofweek_12_cv              45.500021
# rolling_sale_91_median                    44.763362
# year                                      44.354826
# lag_7_14_diff_median                      44.272219
# rolling_sale_dayofweek_4_std              43.877924
# rolling_sale_dayofweek_12_std             42.095165
# rolling_sale_dayofweek_8_cv               37.729925
# rolling_sale_364_median                   37.293136
# rolling_sale_14_quantile25                36.837506
# lag_sale_5                                34.613481
# rolling_sale_dayofweek_4_cv               34.442842
# rolling_sale_14_median                    34.270728
# lag_sale_4                                32.272224
# rolling_sale_dayofweek_24_median          32.126375
# lag_14_28_diff_median                     29.851163
# quarter                                   29.151494
# rolling_sale_dayofweek_8_quantile25       28.865322
# rolling_sale_91_quantile25                24.719691
# rolling_sale_364_quantile25               22.849440
# rolling_sale_dayofweek_52_quantile25      22.575611
# rolling_sale_dayofweek_12_quantile25      21.194262
# rolling_sale_182_quantile25               17.493112
# rolling_sale_dayofweek_24_quantile25      16.456060
# cat_id                                    15.234666
# event_type_2                               0.000000
# event_name_2                               0.000000
#
# [99 rows x 1 columns]

# %% [markdown]
# #### fold2

# %%
X_train = train1[(train1.day_num<=1885- 27)&(train1.day_num>=1885-1-364- 27)&(train1.date!='2015-12-25')&(train1.date!='2014-12-25')].drop(drop_col,axis=1).copy()
y_train = train1.loc[(train1.day_num<=1885- 27)&(train1.day_num>=1885-1-364- 27)&(train1.date!='2015-12-25')&(train1.date!='2014-12-25'),'sale']
X_valid = train1[(train1.day_num<=1913 - 27)&(train1.day_num>=1886- 27)].drop(drop_col,axis=1).copy()
y_valid = train1.loc[(train1.day_num<=1913- 27)&(train1.day_num>=1886- 27),'sale']
y_train[y_train==-999] = 0
y_valid[y_valid==-999] = 0

# %%
1942 - 364
# Out:
# 1578

# %%
lgb_re2 = lgb.LGBMRegressor(n_estimators=1000, random_state=51,subsample=0.8,
                         colsample_bytree=0.8,learning_rate=0.05 ,importance_type = 'gain',
                 max_depth = -1, num_leaves = 2**8-1,metric='None',bagging_freq=1,n_jobs=8,
                         first_metric_only = True,objective=custom_obj,min_data_in_leaf =  2**8-1)

# %%
lgb_re2.fit(X_train,y_train,eval_set = [(X_valid,y_valid)],verbose=10,
           eval_metric =lambda y_true, y_pred: [evaluator_super.feval(y_true, y_pred), rmse(y_true, y_pred)],
           early_stopping_rounds=50)#,categorical_feature=cat_col)
# Out:
# Training until validation scores don't improve for 50 rounds
# [10]	valid_0's WRMSSE: 2.3758	valid_0's RMSE: 2.53618
# [20]	valid_0's WRMSSE: 1.17072	valid_0's RMSE: 2.11921
# [30]	valid_0's WRMSSE: 0.743888	valid_0's RMSE: 2.01121
# [40]	valid_0's WRMSSE: 0.627253	valid_0's RMSE: 1.9842
# [50]	valid_0's WRMSSE: 0.597604	valid_0's RMSE: 1.97505
# [60]	valid_0's WRMSSE: 0.587702	valid_0's RMSE: 1.96969
# [70]	valid_0's WRMSSE: 0.583508	valid_0's RMSE: 1.96679
# [80]	valid_0's WRMSSE: 0.582168	valid_0's RMSE: 1.96523
# [90]	valid_0's WRMSSE: 0.580588	valid_0's RMSE: 1.96348
# [100]	valid_0's WRMSSE: 0.579733	valid_0's RMSE: 1.96201
# [110]	valid_0's WRMSSE: 0.57862	valid_0's RMSE: 1.96078
# [120]	valid_0's WRMSSE: 0.578192	valid_0's RMSE: 1.96006
# [130]	valid_0's WRMSSE: 0.577565	valid_0's RMSE: 1.95906
# [140]	valid_0's WRMSSE: 0.576834	valid_0's RMSE: 1.95826
# [150]	valid_0's WRMSSE: 0.575497	valid_0's RMSE: 1.95746
# [160]	valid_0's WRMSSE: 0.575277	valid_0's RMSE: 1.95724
# [170]	valid_0's WRMSSE: 0.575252	valid_0's RMSE: 1.95669
# [180]	valid_0's WRMSSE: 0.575501	valid_0's RMSE: 1.9561
# [190]	valid_0's WRMSSE: 0.574954	valid_0's RMSE: 1.95592
# [200]	valid_0's WRMSSE: 0.575274	valid_0's RMSE: 1.95581
# [210]	valid_0's WRMSSE: 0.574862	valid_0's RMSE: 1.95556
# [220]	valid_0's WRMSSE: 0.574839	valid_0's RMSE: 1.95511
# Early stopping, best iteration is:
# [176]	valid_0's WRMSSE: 0.574667	valid_0's RMSE: 1.9562
# Evaluated only: WRMSSE
# LGBMRegressor(bagging_freq=1, boosting_type='gbdt', class_weight=None,
#        colsample_bytree=0.8, first_metric_only=True,
#        importance_type='gain', learning_rate=0.05, max_depth=-1,
#        metric='None', min_child_samples=20, min_child_weight=0.001,
#        min_data_in_leaf=255, min_split_gain=0.0, n_estimators=1000,
#        n_jobs=8, num_leaves=255,
#        objective=<function custom_obj at 0x7fc71813d488>, random_state=51,
#        reg_alpha=0.0, reg_lambda=0.0, silent=True, subsample=0.8,
#        subsample_for_bin=200000, subsample_freq=0)

# %%
pd.DataFrame(lgb_re2.feature_importances_,index=X_train.columns).sort_values(0,ascending=False)
# Out:
#                                                   0
# rolling_sale_28_mean                  100242.796524
# rolling_sale_14_mean                   30949.817655
# rolling_sale_7_mean                    19842.335926
# rolling_sale_91_mean                   11656.401668
# rolling_sale_28_quantile75              8235.890716
# last_sale_diff                          5259.848480
# rolling_sale_dayofweek_52_mean          4675.995948
# rolling_sale_28_std                     4091.493200
# rolling_sale_dayofweek_52_quantile75    2959.413061
# dayofweek                               2665.550516
# rolling_sale_364_mean                   2235.643726
# lag_sale_1                              1668.468221
# rolling_sale_364_std                    1556.395732
# rolling_sale_3_mean                     1359.571442
# rolling_sale_dayofweek_24_quantile75    1080.475247
# rolling_sale_14_quantile75               962.826992
# snap                                     696.242049
# rolling_sale_dayofweek_12_mean           647.838744
# rolling_sale_dayofweek_24_mean           644.177815
# rolling_sale_7_quantile75                557.609713
# rolling_sale_dayofweek_52_std            504.301257
# month                                    452.340181
# rolling_sale_7_median                    427.052610
# store_id                                 411.539958
# rolling_sale_7_quantile25                404.679620
# id                                       386.788952
# rolling_sale_dayofweek_8_mean            370.423970
# rolling_sale_dayofweek_8_quantile75      347.819422
# rolling_sale_dayofweek_12_quantile75     340.574035
# item_id                                  340.132141
# ...                                             ...
# rolling_sale_dayofweek_24_std             46.557363
# state_id                                  41.432150
# rolling_sale_182_median                   38.541944
# lag_sale_3                                38.478994
# rolling_sale_dayofweek_24_cv              38.174825
# rolling_sale_dayofweek_8_std              36.459426
# lag_sale_7                                36.316890
# rolling_sale_14_quantile25                35.934655
# rolling_sale_364_median                   34.936202
# rolling_sale_dayofweek_52_median          34.104540
# rolling_sale_dayofweek_4_std              30.899509
# rolling_sale_dayofweek_52_quantile25      28.670847
# rolling_sale_dayofweek_12_cv              28.048549
# rolling_sale_dayofweek_12_std             27.010914
# rolling_sale_dayofweek_8_cv               26.508453
# lag_sale_5                                25.586642
# rolling_sale_dayofweek_12_median          23.800645
# rolling_sale_dayofweek_4_cv               21.575667
# lag_sale_4                                21.507362
# rolling_sale_dayofweek_8_quantile25       20.558733
# rolling_sale_364_quantile25               20.497099
# rolling_sale_182_quantile25               20.232782
# rolling_sale_91_quantile25                20.042032
# rolling_sale_dayofweek_24_median          17.662213
# cat_id                                    17.237767
# rolling_sale_dayofweek_12_quantile25      16.539474
# quarter                                   16.178325
# rolling_sale_dayofweek_24_quantile25      12.953488
# event_name_2                               0.000000
# event_type_2                               0.000000
#
# [91 rows x 1 columns]

# %% [markdown]
# #### fold3

# %%
X_train = train1[(train1.day_num<=1913 - 365)&(train1.day_num>=1913 - 365 - 364)&(train1.date!='2015-12-25')&(train1.date!='2014-12-25')].drop(drop_col,axis=1).copy()
y_train = train1.loc[(train1.day_num<=1913 - 365)&(train1.day_num>=1913 - 365 - 364)&(train1.date!='2015-12-25')&(train1.date!='2014-12-25'),'sale']
X_valid = train1[(train1.day_num<=1969 - 365)&(train1.day_num>=1914 - 365)].drop(drop_col,axis=1).copy()
y_valid = train1.loc[(train1.day_num<=1969 - 365)&(train1.day_num>=1914 - 365),'sale']
y_train[y_train==-999] = 0
y_valid[y_valid==-999] = 0

# %%
lgb_re2 = lgb.LGBMRegressor(n_estimators=1000, random_state=51,subsample=0.8,
                         colsample_bytree=0.8,learning_rate=0.05 ,importance_type = 'gain',
                 max_depth = -1, num_leaves = 2**8-1,metric='None',bagging_freq=1,n_jobs=8,
                         first_metric_only = True,objective=custom_obj,min_data_in_leaf =  2**8-1)

# %%
lgb_re2.fit(X_train,y_train,eval_set = [(X_valid,y_valid)],verbose=10,
           eval_metric =lambda y_true, y_pred: [evaluator_super.feval(y_true, y_pred), rmse(y_true, y_pred)],
           early_stopping_rounds=50)#,categorical_feature=cat_col)
# Out:
# Training until validation scores don't improve for 50 rounds
# [10]	valid_0's WRMSSE: 2.19158	valid_0's RMSE: 2.55154
# [20]	valid_0's WRMSSE: 1.1326	valid_0's RMSE: 2.17613
# [30]	valid_0's WRMSSE: 0.73737	valid_0's RMSE: 2.07297
# [40]	valid_0's WRMSSE: 0.616137	valid_0's RMSE: 2.04348
# [50]	valid_0's WRMSSE: 0.57279	valid_0's RMSE: 2.02903
# [60]	valid_0's WRMSSE: 0.55626	valid_0's RMSE: 2.02182
# [70]	valid_0's WRMSSE: 0.546498	valid_0's RMSE: 2.01763
# [80]	valid_0's WRMSSE: 0.540381	valid_0's RMSE: 2.01438
# [90]	valid_0's WRMSSE: 0.536371	valid_0's RMSE: 2.01182
# [100]	valid_0's WRMSSE: 0.532617	valid_0's RMSE: 2.00982
# [110]	valid_0's WRMSSE: 0.530529	valid_0's RMSE: 2.00813
# [120]	valid_0's WRMSSE: 0.527656	valid_0's RMSE: 2.00722
# [130]	valid_0's WRMSSE: 0.525674	valid_0's RMSE: 2.00607
# [140]	valid_0's WRMSSE: 0.524529	valid_0's RMSE: 2.00482
# [150]	valid_0's WRMSSE: 0.523741	valid_0's RMSE: 2.00385
# [160]	valid_0's WRMSSE: 0.522856	valid_0's RMSE: 2.00309
# [170]	valid_0's WRMSSE: 0.52191	valid_0's RMSE: 2.00192
# [180]	valid_0's WRMSSE: 0.521449	valid_0's RMSE: 2.00117
# [190]	valid_0's WRMSSE: 0.520788	valid_0's RMSE: 2.00035
# [200]	valid_0's WRMSSE: 0.52044	valid_0's RMSE: 1.99974
# [210]	valid_0's WRMSSE: 0.5203	valid_0's RMSE: 1.99937
# [220]	valid_0's WRMSSE: 0.519529	valid_0's RMSE: 1.99898
# [230]	valid_0's WRMSSE: 0.518852	valid_0's RMSE: 1.99885
# [240]	valid_0's WRMSSE: 0.518412	valid_0's RMSE: 1.99848
# [250]	valid_0's WRMSSE: 0.517906	valid_0's RMSE: 1.99811
# [260]	valid_0's WRMSSE: 0.517298	valid_0's RMSE: 1.99785
# [270]	valid_0's WRMSSE: 0.51639	valid_0's RMSE: 1.99761
# [280]	valid_0's WRMSSE: 0.516396	valid_0's RMSE: 1.99747
# [290]	valid_0's WRMSSE: 0.515647	valid_0's RMSE: 1.99698
# [300]	valid_0's WRMSSE: 0.515721	valid_0's RMSE: 1.99675
# [310]	valid_0's WRMSSE: 0.51558	valid_0's RMSE: 1.9966
# [320]	valid_0's WRMSSE: 0.51528	valid_0's RMSE: 1.99628
# [330]	valid_0's WRMSSE: 0.515209	valid_0's RMSE: 1.99605
# [340]	valid_0's WRMSSE: 0.515275	valid_0's RMSE: 1.99585
# [350]	valid_0's WRMSSE: 0.515131	valid_0's RMSE: 1.99569
# [360]	valid_0's WRMSSE: 0.515075	valid_0's RMSE: 1.99552
# [370]	valid_0's WRMSSE: 0.514777	valid_0's RMSE: 1.99549
# [380]	valid_0's WRMSSE: 0.514364	valid_0's RMSE: 1.99529
# [390]	valid_0's WRMSSE: 0.514508	valid_0's RMSE: 1.99513
# [400]	valid_0's WRMSSE: 0.514545	valid_0's RMSE: 1.9949
# [410]	valid_0's WRMSSE: 0.514787	valid_0's RMSE: 1.99471
# [420]	valid_0's WRMSSE: 0.5147	valid_0's RMSE: 1.99476
# [430]	valid_0's WRMSSE: 0.514518	valid_0's RMSE: 1.99476
# Early stopping, best iteration is:
# [380]	valid_0's WRMSSE: 0.514364	valid_0's RMSE: 1.99529
# Evaluated only: WRMSSE
# LGBMRegressor(bagging_freq=1, boosting_type='gbdt', class_weight=None,
#        colsample_bytree=0.8, first_metric_only=True,
#        importance_type='gain', learning_rate=0.05, max_depth=-1,
#        metric='None', min_child_samples=20, min_child_weight=0.001,
#        min_data_in_leaf=255, min_split_gain=0.0, n_estimators=1000,
#        n_jobs=8, num_leaves=255,
#        objective=<function custom_obj at 0x7fc71813d488>, random_state=51,
#        reg_alpha=0.0, reg_lambda=0.0, silent=True, subsample=0.8,
#        subsample_for_bin=200000, subsample_freq=0)

# %%
pd.DataFrame(lgb_re2.feature_importances_,index=X_train.columns).sort_values(0,ascending=False)
# Out:
#                                                   0
# rolling_sale_28_mean                  117267.755975
# rolling_sale_14_mean                   33925.637450
# rolling_sale_7_mean                    19185.872955
# last_sale_diff                          4861.382887
# rolling_sale_dayofweek_52_mean          4312.597926
# dayofweek                               2765.430206
# lag_sale_1                              2324.143749
# rolling_sale_dayofweek_52_quantile75    2289.470479
# rolling_sale_3_mean                     2010.923507
# rolling_sale_364_std                    1861.371809
# rolling_sale_364_mean                   1817.733348
# rolling_sale_7_quantile75               1249.622517
# rolling_sale_91_mean                    1111.266383
# rolling_sale_7_median                    871.813238
# rolling_sale_dayofweek_24_quantile75     792.173923
# rolling_sale_dayofweek_12_mean           763.028770
# snap                                     709.923703
# rolling_sale_dayofweek_8_mean            681.984666
# id                                       557.450188
# rolling_sale_7_quantile25                538.415033
# rolling_sale_dayofweek_52_std            488.514538
# sell_price                               466.667548
# store_id                                 466.636059
# month                                    462.645245
# rolling_sale_dayofweek_8_quantile75      451.710685
# item_id                                  417.206245
# rolling_sale_91_cv                       393.660324
# rolling_sale_7_std                       384.078119
# rolling_sale_28_std                      373.009731
# rolling_sale_dayofweek_24_mean           366.222821
# ...                                             ...
# rolling_sale_364_quantile75               72.269425
# rolling_sale_dayofweek_8_cv               69.884711
# rolling_sale_dayofweek_4_cv               67.731302
# rolling_sale_182_quantile75               67.639557
# rolling_sale_dayofweek_12_std             65.531224
# lag_sale_7                                65.155742
# rolling_sale_dayofweek_12_median          63.465834
# rolling_sale_14_quantile25                60.408998
# lag_sale_4                                60.393915
# rolling_sale_91_median                    57.788316
# rolling_sale_dayofweek_52_median          56.622473
# rolling_sale_dayofweek_2_mean             56.258595
# rolling_sale_dayofweek_8_median           54.602566
# rolling_sale_28_quantile25                52.394259
# rolling_sale_364_median                   51.850915
# lag_sale_5                                50.772100
# rolling_sale_dayofweek_8_quantile25       44.691270
# state_id                                  41.773793
# rolling_sale_dayofweek_52_quantile25      41.500666
# quarter                                   38.853222
# rolling_sale_182_median                   36.734073
# rolling_sale_dayofweek_24_median          31.904717
# rolling_sale_dayofweek_12_quantile25      27.942490
# rolling_sale_364_quantile25               26.872702
# rolling_sale_91_quantile25                26.447804
# rolling_sale_dayofweek_24_quantile25      24.044627
# rolling_sale_182_quantile25               18.242234
# cat_id                                     6.711659
# event_name_2                               6.061514
# event_type_2                               0.099673
#
# [91 rows x 1 columns]
